# %% [markdown]
# # Process bulk counts table
#
# 1. Annotate columns (samples) in a way that time point and replicate are annotated
# 2. Remove rRNA genes
# 3. Perform TPM normalization and alternatively also raw counts

# %%
# Use miniconda environment Jupyter_new for running this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tools import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 Load the dataset and annotation

# %%
bulkPath = '../nf_output/WH8102/countData/countData.tsv'
metaPath = '../SraRunTable_WH8102.csv' # metadata from SRA
gffPath = '../nf_output/WH8102/alignments/dualGenome.gff3' # output from nf pipeline

# %%
# Load and filter data
df_initial = pd.read_csv(bulkPath, sep = '\t', comment='#', index_col=0)
metadata = pd.read_csv(metaPath)

#acc_drop = metadata[metadata["genotype"] == "rpoC G17D"]["Run"].tolist()
#acc_drop = [acc + "_sorted.bam" for acc in acc_drop]
#df_initial.drop(columns=acc_drop, inplace=True)
#metadata = metadata[metadata['genotype'] == 'WT']

# %%
df_initial
# Out:
#                            Chr   Start     End Strand  Length  \
# Geneid
# gene-TX72_RS00005  NC_005070.1     174    1331      +    1158
# gene-TX72_RS00010  NC_005070.1    1333    2058      +     726
# gene-TX72_RS00015  NC_005070.1    2103    4409      +    2307
# gene-TX72_RS00020  NC_005070.1    4468    5898      +    1431
# gene-TX72_RS00025  NC_005070.1    5899    8373      -    2475
# ...                        ...     ...     ...    ...     ...
# gene-BSV9_gp228    NC_008296.2  174751  175461      +     711
# gene-BSV9_gp229    NC_008296.2  175461  175640      +     180
# gene-BSV9_gp230    NC_008296.2  175642  175872      +     231
# gene-BSV9_gp231    NC_008296.2  175876  176640      +     765
# gene-BSV9_gp232    NC_008296.2  176640  177317      +     678
#
#                    SRR2932986_sorted.bam  SRR2932982_sorted.bam  \
# Geneid
# gene-TX72_RS00005                      5                     56
# gene-TX72_RS00010                      2                     14
# gene-TX72_RS00015                     24                    138
# gene-TX72_RS00020                     30                    225
# gene-TX72_RS00025                     50                    239
# ...                                  ...                    ...
# gene-BSV9_gp228                    24954                  17562
# gene-BSV9_gp229                     7607                   5066
# gene-BSV9_gp230                    13304                   6257
# gene-BSV9_gp231                    37779                  18097
# gene-BSV9_gp232                    36530                  17822
#
#                    SRR2932985_sorted.bam  SRR2932987_sorted.bam  \
# Geneid
# gene-TX72_RS00005                     20                     10
# gene-TX72_RS00010                      5                      4
# gene-TX72_RS00015                     49                     29
# gene-TX72_RS00020                     71                     40
# gene-TX72_RS00025                     95                     39
# ...                                  ...                    ...
# gene-BSV9_gp228                    58108                  34623
# gene-BSV9_gp229                    18484                  10374
# gene-BSV9_gp230                    23337                  19502
# gene-BSV9_gp231                    65597                  51439
# gene-BSV9_gp232                    70391                  46963
#
#                    SRR2932981_sorted.bam  SRR2932980_sorted.bam  \
# Geneid
# gene-TX72_RS00005                    465                    457
# gene-TX72_RS00010                     89                     94
# gene-TX72_RS00015                   1197                   1181
# gene-TX72_RS00020                   2018                   2193
# gene-TX72_RS00025                   1699                   1747
# ...                                  ...                    ...
# gene-BSV9_gp228                        1                      0
# gene-BSV9_gp229                        0                      0
# gene-BSV9_gp230                        0                      0
# gene-BSV9_gp231                        0                      0
# gene-BSV9_gp232                        0                      0
#
#                    SRR2932983_sorted.bam  SRR2932984_sorted.bam
# Geneid
# gene-TX72_RS00005                    104                     33
# gene-TX72_RS00010                     19                      6
# gene-TX72_RS00015                    255                    105
# gene-TX72_RS00020                    351                    130
# gene-TX72_RS00025                    431                    165
# ...                                  ...                    ...
# gene-BSV9_gp228                    41236                 116871
# gene-BSV9_gp229                    13173                  37752
# gene-BSV9_gp230                    16773                  53212
# gene-BSV9_gp231                    44287                 132707
# gene-BSV9_gp232                    45457                 125719
#
# [2918 rows x 13 columns]

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 20)
metadata
# Out:
#           Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 0  SRR2932980    RNA-Seq          50  1129754050  PRJNA302091  SAMN04261905
# 1  SRR2932981    RNA-Seq          50  1094868100  PRJNA302091  SAMN04261906
# 2  SRR2932982    RNA-Seq          49   688085244  PRJNA302091  SAMN04261907
# 3  SRR2932983    RNA-Seq         100  2149771000  PRJNA302091  SAMN04261908
# 4  SRR2932984    RNA-Seq         100  2522604100  PRJNA302091  SAMN04261909
# 5  SRR2932985    RNA-Seq          49   718189031  PRJNA302091  SAMN04261910
# 6  SRR2932986    RNA-Seq          49   583276743  PRJNA302091  SAMN04261911
# 7  SRR2932987    RNA-Seq         100  1387329000  PRJNA302091  SAMN04261912
#
#         Bytes Center Name Consent DATASTORE filetype DATASTORE provider  \
# 0   847249097         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 1   819359630         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 2   513724563         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 3  1482033943         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 4  1761715741         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 5   534971255         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 6   435154697         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 7   969777584         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                        DATASTORE region  Experiment GEO_Accession (exp)  \
# 0  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427371          GSM1937594
# 1  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427372          GSM1937595
# 2  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427373          GSM1937596
# 3  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427374          GSM1937597
# 4  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427375          GSM1937598
# 5  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427376          GSM1937599
# 6  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427377          GSM1937600
# 7  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427378          GSM1937601
#
#           infection           Instrument LibraryLayout LibrarySelection  \
# 0  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 1  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 2  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 3  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 4  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 5  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 6  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 7  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
#
#     LibrarySource                              Organism  Platform  \
# 0  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
# 1  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
# 2  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
# 3  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
# 4  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
# 5  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
# 6  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
# 7  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
#
#             ReleaseDate  replicate Sample Name  \
# 0  2015-12-17T00:00:00Z          2  GSM1937594
# 1  2015-12-17T00:00:00Z          3  GSM1937595
# 2  2015-12-17T00:00:00Z          2  GSM1937596
# 3  2015-12-17T00:00:00Z          3  GSM1937597
# 4  2015-12-17T00:00:00Z          3  GSM1937598
# 5  2015-12-17T00:00:00Z          2  GSM1937599
# 6  2015-12-17T00:00:00Z          2  GSM1937600
# 7  2015-12-17T00:00:00Z          3  GSM1937601
#
#                                         source_name  SRA Study  \
# 0  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
# 1  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
# 2  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
# 3  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
# 4  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
# 5  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
# 6  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
# 7  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
#
#       tap_treated    TIME           create_date  version
# 0  Not Applicable    5min  2015-11-19T23:10:00Z        1
# 1  Not Applicable    5min  2015-11-19T23:10:00Z        1
# 2  Not Applicable   30min  2015-11-19T23:08:00Z        1
# 3  Not Applicable   30min  2015-11-19T23:11:00Z        1
# 4  Not Applicable   60min  2015-11-19T23:11:00Z        1
# 5  Not Applicable   60min  2015-11-19T23:08:00Z        1
# 6  Not Applicable  120min  2015-11-19T23:08:00Z        1
# 7  Not Applicable  120min  2015-11-19T23:11:00Z        1

# %% [markdown]
# ## 2 Format the dataset

# %% [markdown]
# ### 2.1 Annotate sample names

# %% [markdown]
# Issue now is that the metadata does not properly annotate sample names. Thus, this will be done manually by adding another sample name column to the metadata.

# %%
# Match GSM IDs and SampleNames inferred from GEO

sampleDict = {'GSM1937594': '5_R1',  'GSM1937595': '5_R2',
              'GSM1937596': '30_R1',  'GSM1937597': '30_R2',
              'GSM1937598': '60_R1',  'GSM1937599': '60_R2',
              'GSM1937600': '120_R1',  'GSM1937601': '120_R2'
}

# %%
metadataFull = annotateData(metadata, sampleDict)

# %%
metadata.head(1)
# Out:
#           Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 0  SRR2932980    RNA-Seq          50  1129754050  PRJNA302091  SAMN04261905
#
#        Bytes Center Name Consent DATASTORE filetype DATASTORE provider  \
# 0  847249097         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                        DATASTORE region  Experiment GEO_Accession (exp)  \
# 0  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427371          GSM1937594
#
#           infection           Instrument LibraryLayout LibrarySelection  \
# 0  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
#
#     LibrarySource                              Organism  Platform  \
# 0  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102  ILLUMINA
#
#             ReleaseDate  replicate Sample Name  \
# 0  2015-12-17T00:00:00Z          2  GSM1937594
#
#                                         source_name  SRA Study  \
# 0  Synechococcus sp. strain WH8102 infected by Syn9  SRP066156
#
#       tap_treated  TIME           create_date  version
# 0  Not Applicable  5min  2015-11-19T23:10:00Z        1

# %%
metadataFull.head()
# Out:
#                               Run Assay Type  AvgSpotLen       Bases  \
# SampleID
# SRR2932980_sorted.bam  SRR2932980    RNA-Seq          50  1129754050
# SRR2932981_sorted.bam  SRR2932981    RNA-Seq          50  1094868100
# SRR2932982_sorted.bam  SRR2932982    RNA-Seq          49   688085244
# SRR2932983_sorted.bam  SRR2932983    RNA-Seq         100  2149771000
# SRR2932984_sorted.bam  SRR2932984    RNA-Seq         100  2522604100
#
#                         BioProject     BioSample       Bytes Center Name  \
# SampleID
# SRR2932980_sorted.bam  PRJNA302091  SAMN04261905   847249097         GEO
# SRR2932981_sorted.bam  PRJNA302091  SAMN04261906   819359630         GEO
# SRR2932982_sorted.bam  PRJNA302091  SAMN04261907   513724563         GEO
# SRR2932983_sorted.bam  PRJNA302091  SAMN04261908  1482033943         GEO
# SRR2932984_sorted.bam  PRJNA302091  SAMN04261909  1761715741         GEO
#
#                       Consent DATASTORE filetype DATASTORE provider  \
# SampleID
# SRR2932980_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
# SRR2932981_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
# SRR2932982_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
# SRR2932983_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
# SRR2932984_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                                            DATASTORE region  Experiment  \
# SampleID
# SRR2932980_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427371
# SRR2932981_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427372
# SRR2932982_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427373
# SRR2932983_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427374
# SRR2932984_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427375
#
#                       GEO_Accession (exp)         infection  \
# SampleID
# SRR2932980_sorted.bam          GSM1937594  Infected by Syn9
# SRR2932981_sorted.bam          GSM1937595  Infected by Syn9
# SRR2932982_sorted.bam          GSM1937596  Infected by Syn9
# SRR2932983_sorted.bam          GSM1937597  Infected by Syn9
# SRR2932984_sorted.bam          GSM1937598  Infected by Syn9
#
#                                 Instrument LibraryLayout LibrarySelection  \
# SampleID
# SRR2932980_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
# SRR2932981_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
# SRR2932982_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
# SRR2932983_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
# SRR2932984_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
#
#                         LibrarySource                              Organism  \
# SampleID
# SRR2932980_sorted.bam  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102
# SRR2932981_sorted.bam  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102
# SRR2932982_sorted.bam  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102
# SRR2932983_sorted.bam  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102
# SRR2932984_sorted.bam  TRANSCRIPTOMIC  Parasynechococcus marenigrum WH 8102
#
#                        Platform           ReleaseDate  replicate Sample Name  \
# SampleID
# SRR2932980_sorted.bam  ILLUMINA  2015-12-17T00:00:00Z          2  GSM1937594
# SRR2932981_sorted.bam  ILLUMINA  2015-12-17T00:00:00Z          3  GSM1937595
# SRR2932982_sorted.bam  ILLUMINA  2015-12-17T00:00:00Z          2  GSM1937596
# SRR2932983_sorted.bam  ILLUMINA  2015-12-17T00:00:00Z          3  GSM1937597
# SRR2932984_sorted.bam  ILLUMINA  2015-12-17T00:00:00Z          3  GSM1937598
#
#                                                             source_name  \
# SampleID
# SRR2932980_sorted.bam  Synechococcus sp. strain WH8102 infected by Syn9
# SRR2932981_sorted.bam  Synechococcus sp. strain WH8102 infected by Syn9
# SRR2932982_sorted.bam  Synechococcus sp. strain WH8102 infected by Syn9
# SRR2932983_sorted.bam  Synechococcus sp. strain WH8102 infected by Syn9
# SRR2932984_sorted.bam  Synechococcus sp. strain WH8102 infected by Syn9
#
#                        SRA Study     tap_treated   TIME           create_date  \
# SampleID
# SRR2932980_sorted.bam  SRP066156  Not Applicable   5min  2015-11-19T23:10:00Z
# SRR2932981_sorted.bam  SRP066156  Not Applicable   5min  2015-11-19T23:10:00Z
# SRR2932982_sorted.bam  SRP066156  Not Applicable  30min  2015-11-19T23:08:00Z
# SRR2932983_sorted.bam  SRP066156  Not Applicable  30min  2015-11-19T23:11:00Z
# SRR2932984_sorted.bam  SRP066156  Not Applicable  60min  2015-11-19T23:11:00Z
#
#                        version               SampleID SampleNames
# SampleID
# SRR2932980_sorted.bam        1  SRR2932980_sorted.bam        5_R1
# SRR2932981_sorted.bam        1  SRR2932981_sorted.bam        5_R2
# SRR2932982_sorted.bam        1  SRR2932982_sorted.bam       30_R1
# SRR2932983_sorted.bam        1  SRR2932983_sorted.bam       30_R2
# SRR2932984_sorted.bam        1  SRR2932984_sorted.bam       60_R1

# %% [markdown]
# Add correct sample names.

# %%
df = changeColnames(df_initial.iloc[:,5:df_initial.shape[1]], metadataFull)
df = df[['5_R1', '5_R2',
         '30_R1', '30_R2',
         '60_R1', '60_R2',
         '120_R1', '120_R2']]
df.head()
# Out:
# SampleNames        5_R1  5_R2  30_R1  30_R2  60_R1  60_R2  120_R1  120_R2
# Geneid
# gene-TX72_RS00005   457   465     56    104     33     20       5      10
# gene-TX72_RS00010    94    89     14     19      6      5       2       4
# gene-TX72_RS00015  1181  1197    138    255    105     49      24      29
# gene-TX72_RS00020  2193  2018    225    351    130     71      30      40
# gene-TX72_RS00025  1747  1699    239    431    165     95      50      39

# %% [markdown]
# ### 2.2 Remove rRNA genes
#
# Consult gff3 file to get rRNA geneids.

# %%
# Load gff3 and split into genes and CDS dfs
gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3.columns=["seq_id", "source", "type", "start", "end", "phase", "strand", "score", "attributes"]
gff3_genes = gff3.loc[gff3["type"] == 'gene']

# Column formating for genes
gff3_genes = gff3_genes.reset_index(drop=True)
dct_genes = gff3_genes["attributes"].str.split(';').apply(lambda items: dict(item.split('=', 1) for item in items if '=' in item))
cols_to_keep = ['ID', 'Name', 'gbkey', 'gene_biotype', 'locus_tag', 'gene']
gff3_genes = pd.concat([gff3_genes, pd.json_normalize(dct_genes)[cols_to_keep]], axis=1)

# Generate locus_tag, product dictonary over all different feature types
attrs = gff3["attributes"].str.split(";", expand=True)
attrs_dicts = attrs.apply(lambda row: {item.split("=")[0]: item.split("=")[1] for item in row if "=" in str(item)}, axis=1)
attrs_df = pd.json_normalize(attrs_dicts)
attrs_df = attrs_df.dropna(subset=["locus_tag", "product"])
locus_product_dict = dict(zip(attrs_df["locus_tag"], attrs_df["product"]))

# Add gene product, if not stated in gff3, fill with gene_biotype
gff3_genes["product"] = gff3_genes["locus_tag"].map(locus_product_dict)
# gff3_genes["product"] = gff3_genes["product"].fillna("other")
gff3_genes["product"] = gff3_genes["product"].fillna(gff3_genes["gene_biotype"])

# If gene = NA, take from ID column
gff3_genes["gene"] = gff3_genes["gene"].fillna(gff3_genes["ID"])

# Drop attributes column
gff3_genes = gff3_genes.drop(["attributes"], axis=1)

# %%
pharokka_path = "../../../2025-12_reannotation_phage_genomes/Pharokka_proteins_phages_out/NC_008296.2_out/pharokka_proteins_full_merged_output.tsv"
gff3_genes = add_pharokka(gff3_genes, pharokka_path)
gff3_genes.loc[gff3_genes['seq_id'] == "NC_008296.2"]
# Out:
#            seq_id  source  type     start       end phase strand score  \
# 2686  NC_008296.2  RefSeq  gene       1.0     249.0     .      +     .
# 2687  NC_008296.2  RefSeq  gene     246.0     845.0     .      +     .
# 2688  NC_008296.2  RefSeq  gene     842.0    1177.0     .      +     .
# 2689  NC_008296.2  RefSeq  gene    1245.0    2192.0     .      +     .
# 2690  NC_008296.2  RefSeq  gene    2189.0    2524.0     .      +     .
# ...           ...     ...   ...       ...       ...   ...    ...   ...
# 2913  NC_008296.2  RefSeq  gene  174751.0  175461.0     .      +     .
# 2914  NC_008296.2  RefSeq  gene  175461.0  175640.0     .      +     .
# 2915  NC_008296.2  RefSeq  gene  175642.0  175872.0     .      +     .
# 2916  NC_008296.2  RefSeq  gene  175876.0  176640.0     .      +     .
# 2917  NC_008296.2  RefSeq  gene  176640.0  177317.0     .      +     .
#
#                    ID        Name gbkey    gene_biotype   locus_tag  \
# 2686    gene-BSV9_gp1    BSV9_gp1  Gene  protein_coding    BSV9_gp1
# 2687    gene-BSV9_gp2          59  Gene  protein_coding    BSV9_gp2
# 2688    gene-BSV9_gp3    BSV9_gp3  Gene  protein_coding    BSV9_gp3
# 2689    gene-BSV9_gp4          32  Gene  protein_coding    BSV9_gp4
# 2690    gene-BSV9_gp5    BSV9_gp5  Gene  protein_coding    BSV9_gp5
# ...               ...         ...   ...             ...         ...
# 2913  gene-BSV9_gp228  BSV9_gp228  Gene  protein_coding  BSV9_gp228
# 2914  gene-BSV9_gp229  BSV9_gp229  Gene  protein_coding  BSV9_gp229
# 2915  gene-BSV9_gp230  BSV9_gp230  Gene  protein_coding  BSV9_gp230
# 2916  gene-BSV9_gp231  BSV9_gp231  Gene  protein_coding  BSV9_gp231
# 2917  gene-BSV9_gp232  BSV9_gp232  Gene  protein_coding  BSV9_gp232
#
#                  gene                                   product  \
# 2686    gene-BSV9_gp1   late promoter transcriptional regulator
# 2687               59                       DNA helicase loader
# 2688    gene-BSV9_gp3                                       gp3
# 2689               32         single strand DNA binding protein
# 2690    gene-BSV9_gp5                                       gp5
# ...               ...                                       ...
# 2913  gene-BSV9_gp228                      thymidylate synthase
# 2914  gene-BSV9_gp229                                     gp229
# 2915  gene-BSV9_gp230                 transcriptional regulator
# 2916  gene-BSV9_gp231  PhoH-like phosphate starvation-inducible
# 2917  gene-BSV9_gp232                               exonuclease
#
#                                          annot  PHROG  \
# 2686   late promoter transcriptional regulator    254
# 2687                       DNA helicase loader    269
# 2688                      hypothetical protein    468
# 2689         single strand DNA binding protein    224
# 2690                      hypothetical protein   3309
# ...                                        ...    ...
# 2913                      thymidylate synthase  10644
# 2914                      hypothetical protein    765
# 2915                 transcriptional regulator    385
# 2916  PhoH-like phosphate starvation-inducible    170
# 2917                               exonuclease    298
#
#                                 category
# 2686            transcription regulation
# 2687  DNA, RNA and nucleotide metabolism
# 2688                    unknown function
# 2689  DNA, RNA and nucleotide metabolism
# 2690                    unknown function
# ...                                  ...
# 2913  DNA, RNA and nucleotide metabolism
# 2914                    unknown function
# 2915            transcription regulation
# 2916                               other
# 2917  DNA, RNA and nucleotide metabolism
#
# [232 rows x 18 columns]

# %%
# Load ggf3 file

gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3 = gff3.loc[gff3.iloc[:,2] == 'gene']

# Format some new columns
gff3['ID'] = pd.DataFrame(gff3.iloc[:,8].str.split('ID=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['GeneType'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene_biotype=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['Symbol'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]

# Add entity host and phage
gff3['Entity'] = np.where(gff3[0] == 'NC_008296.2', 'phage', 'host')
gff3.index = gff3['ID']
rRNAs = gff3.loc[gff3['GeneType'] == 'rRNA', 'ID'].tolist()

# %%
gff3
# Out:
#                              0       1     2         3         4  5  6  7  \
# ID
# gene-TX72_RS00005  NC_005070.1  RefSeq  gene     174.0    1331.0  .  +  .
# gene-TX72_RS00010  NC_005070.1  RefSeq  gene    1333.0    2058.0  .  +  .
# gene-TX72_RS00015  NC_005070.1  RefSeq  gene    2103.0    4409.0  .  +  .
# gene-TX72_RS00020  NC_005070.1  RefSeq  gene    4468.0    5898.0  .  +  .
# gene-TX72_RS00025  NC_005070.1  RefSeq  gene    5899.0    8373.0  .  -  .
# ...                        ...     ...   ...       ...       ... .. .. ..
# gene-BSV9_gp228    NC_008296.2  RefSeq  gene  174751.0  175461.0  .  +  .
# gene-BSV9_gp229    NC_008296.2  RefSeq  gene  175461.0  175640.0  .  +  .
# gene-BSV9_gp230    NC_008296.2  RefSeq  gene  175642.0  175872.0  .  +  .
# gene-BSV9_gp231    NC_008296.2  RefSeq  gene  175876.0  176640.0  .  +  .
# gene-BSV9_gp232    NC_008296.2  RefSeq  gene  176640.0  177317.0  .  +  .
#
#                                                                    8  \
# ID
# gene-TX72_RS00005  ID=gene-TX72_RS00005;Name=dnaN;gbkey=Gene;gene...
# gene-TX72_RS00010  ID=gene-TX72_RS00010;Name=TX72_RS00010;gbkey=G...
# gene-TX72_RS00015  ID=gene-TX72_RS00015;Name=purL;gbkey=Gene;gene...
# gene-TX72_RS00020  ID=gene-TX72_RS00020;Name=purF;gbkey=Gene;gene...
# gene-TX72_RS00025  ID=gene-TX72_RS00025;Name=TX72_RS00025;gbkey=G...
# ...                                                              ...
# gene-BSV9_gp228    ID=gene-BSV9_gp228;Dbxref=GeneID:4238995;Name=...
# gene-BSV9_gp229    ID=gene-BSV9_gp229;Dbxref=GeneID:4238996;Name=...
# gene-BSV9_gp230    ID=gene-BSV9_gp230;Dbxref=GeneID:4238997;Name=...
# gene-BSV9_gp231    ID=gene-BSV9_gp231;Dbxref=GeneID:4238998;Name=...
# gene-BSV9_gp232    ID=gene-BSV9_gp232;Dbxref=GeneID:4238999;Name=...
#
#                                   ID        GeneType Symbol Entity
# ID
# gene-TX72_RS00005  gene-TX72_RS00005  protein_coding   dnaN   host
# gene-TX72_RS00010  gene-TX72_RS00010  protein_coding   None   host
# gene-TX72_RS00015  gene-TX72_RS00015  protein_coding   purL   host
# gene-TX72_RS00020  gene-TX72_RS00020  protein_coding   purF   host
# gene-TX72_RS00025  gene-TX72_RS00025  protein_coding   None   host
# ...                              ...             ...    ...    ...
# gene-BSV9_gp228      gene-BSV9_gp228  protein_coding   None  phage
# gene-BSV9_gp229      gene-BSV9_gp229  protein_coding   None  phage
# gene-BSV9_gp230      gene-BSV9_gp230  protein_coding   None  phage
# gene-BSV9_gp231      gene-BSV9_gp231  protein_coding   None  phage
# gene-BSV9_gp232      gene-BSV9_gp232  protein_coding   None  phage
#
# [2918 rows x 13 columns]

# %% [markdown]
# Perform in silico rRNA depletion.

# %%
df_norRNAs = rRNAdepletion(df,rRNAs)
df_norRNAs.head()
# Out:
# SampleNames        5_R1  5_R2  30_R1  30_R2  60_R1  60_R2  120_R1  120_R2
# Geneid
# gene-TX72_RS06845    67   114    137    478    207     50      41      89
# gene-TX72_RS00470   155   132     17     29     17      5       2       3
# gene-TX72_RS12050    34    14      2     12      4      2       2       1
# gene-BSV9_gp128       0     0     98    253   3890   2014   22539   34506
# gene-TX72_RS06185   153   175     17     32     19      3       4       7

# %% [markdown]
# ### 2.3 Read count normalization

# %% [markdown]
# Important note: gene symbols not available for most genes.

# %%
# Function to fill in missing symbols by geneid.

def fillSymbols(df):
    df_new = df.copy()
    index = df.index.to_list()
    for i in range(0,df.shape[0]):
        if (df.iloc[i,-1:].values == None):
            df_new.iloc[i,-1:] = index[i]
    return df_new

# %% [markdown]
# Convert counts to TPM.

# %%
tpms = TPM(df_norRNAs, df_initial, 0.5)
tpms['Entity'] = gff3.loc[sorted(tpms.index.to_list()), 'Entity']
tpms['Symbol'] = gff3.loc[sorted(tpms.index.to_list()), 'Symbol']

tpms = fillSymbols(tpms)
tpms = make_unique_with_index(tpms)
tpms
# Out:
# SampleNames              5_R1        5_R2      30_R1      30_R2       60_R1  \
# Geneid
# gene-TX72_RS06845   75.662531  126.486614  55.647394  77.405545   22.207195
# gene-TX72_RS00470   49.230916   41.341420   2.000371   1.347853    0.528986
# gene-TX72_RS12050   14.751160    6.109942   0.385933   0.771312    0.183704
# gene-BSV9_gp128      0.204307    0.201347  14.531620  14.948712  151.780755
# gene-TX72_RS06185   52.397542   59.039361   2.156779   1.601028    0.635529
# ...                       ...         ...        ...        ...         ...
# gene-TX72_RS00265   46.602005   50.088498   2.014712   1.066486    0.331186
# gene-TX72_RS00650  303.883848  271.204030  10.830402   7.641714    1.469374
# gene-TX72_RS02965   49.036537   53.216939   2.175740   1.619975    0.575361
# gene-TX72_RS02495   65.297298   52.673166   9.046917   6.145705    3.170227
# gene-TX72_RS14885  105.132468   63.686466   7.312985   1.531144    1.933874
#
# SampleNames             60_R2       120_R1       120_R2 Entity  \
# Geneid
# gene-TX72_RS06845   10.976220    13.424119    20.668697   host
# gene-TX72_RS00470    0.337641     0.228406     0.228291   host
# gene-TX72_RS12050    0.207268     0.308466     0.132133   host
# gene-BSV9_gp128    159.611575  2657.771678  2904.869737  phage
# gene-TX72_RS06185    0.231662     0.443277     0.527445   host
# ...                       ...          ...          ...    ...
# gene-TX72_RS00265    0.380166     0.304653     0.217499   host
# gene-TX72_RS00650    2.377190     2.484027     1.450970   host
# gene-TX72_RS02965    0.297851     0.375081     0.511215   host
# gene-TX72_RS02495    3.135416     1.959128     1.500391   host
# gene-TX72_RS14885    2.805343     1.391685     0.198712   host
#
# SampleNames                   Symbol
# Geneid
# gene-TX72_RS06845  gene-TX72_RS06845
# gene-TX72_RS00470  gene-TX72_RS00470
# gene-TX72_RS12050  gene-TX72_RS12050
# gene-BSV9_gp128                   19
# gene-TX72_RS06185  gene-TX72_RS06185
# ...                              ...
# gene-TX72_RS00265  gene-TX72_RS00265
# gene-TX72_RS00650  gene-TX72_RS00650
# gene-TX72_RS02965  gene-TX72_RS02965
# gene-TX72_RS02495  gene-TX72_RS02495
# gene-TX72_RS14885  gene-TX72_RS14885
#
# [2912 rows x 10 columns]

# %%
# Check gene names unique
len(tpms['Symbol'].unique())
# Out:
# 2912

# %% [markdown]
# Log2+1 normalization raw counts

# %%
logs = logNorm(df_norRNAs)
logs['Entity'] = gff3.loc[sorted(logs.index.to_list()), 'Entity']
logs['Symbol'] = gff3.loc[sorted(logs.index.to_list()), 'Symbol']
logs = fillSymbols(logs)
# Make gene names unique
logs = make_unique_with_index(logs)
logs
# Out:
# SampleNames            5_R1      5_R2     30_R1     30_R2      60_R1  \
# Geneid
# gene-TX72_RS06845  6.087463  6.845490  7.108524  8.903882   7.700440
# gene-TX72_RS00470  7.285402  7.055282  4.169925  4.906891   4.169925
# gene-TX72_RS12050  5.129283  3.906891  1.584963  3.700440   2.321928
# gene-BSV9_gp128    0.000000  0.000000  6.629357  7.988685  11.925925
# gene-TX72_RS06185  7.266787  7.459432  4.169925  5.044394   4.321928
# ...                     ...       ...       ...       ...        ...
# gene-TX72_RS00265  7.276124  7.400879  4.247928  4.643856   3.584963
# gene-TX72_RS00650  9.187352  9.044394  5.857981  6.672425   4.906891
# gene-TX72_RS02965  7.700440  7.839204  4.700440  5.584963   4.700440
# gene-TX72_RS02495  8.049849  7.761551  6.672425  7.434628   7.076816
# gene-TX72_RS14885  5.781360  5.087463  3.459432  2.584963   3.459432
#
# SampleNames            60_R2     120_R1     120_R2 Entity             Symbol
# Geneid
# gene-TX72_RS06845   5.672425   5.392317   6.491853   host  gene-TX72_RS06845
# gene-TX72_RS00470   2.584963   1.584963   2.000000   host  gene-TX72_RS00470
# gene-TX72_RS12050   1.584963   1.584963   1.000000   host  gene-TX72_RS12050
# gene-BSV9_gp128    10.976564  14.460200  15.074601  phage                 19
# gene-TX72_RS06185   2.000000   2.321928   3.000000   host  gene-TX72_RS06185
# ...                      ...        ...        ...    ...                ...
# gene-TX72_RS00265   2.807355   2.000000   2.000000   host  gene-TX72_RS00265
# gene-TX72_RS00650   4.584963   4.087463   3.807355   host  gene-TX72_RS00650
# gene-TX72_RS02965   2.807355   2.584963   3.459432   host  gene-TX72_RS02965
# gene-TX72_RS02495   6.044394   4.807355   4.906891   host  gene-TX72_RS02495
# gene-TX72_RS14885   3.000000   1.584963   0.000000   host  gene-TX72_RS14885
#
# [2912 rows x 10 columns]

# %% [markdown]
# Log2+1 normalization tpms

# %%
logTPMs = logNorm(tpms.iloc[:, :-2])
logTPMs = logTPMs.join(tpms.iloc[:, -2:])
logTPMs = fillSymbols(logTPMs)
# Make gene names unique
logTPMs = make_unique_with_index(logTPMs)
logTPMs
# Out:
# SampleNames            5_R1      5_R2     30_R1     30_R2     60_R1     60_R2  \
# Geneid
# gene-TX72_RS06845  6.260450  6.994202  5.823938  6.292884  4.536500  3.582101
# gene-TX72_RS00470  5.650504  5.403998  1.585141  1.231342  0.612575  0.419690
# gene-TX72_RS12050  3.977386  2.829838  0.470858  0.824818  0.243308  0.271746
# gene-BSV9_gp128    0.268203  0.264653  3.957136  3.995368  7.255319  7.327432
# gene-TX72_RS06185  5.738701  5.907837  1.658453  1.379082  0.709758  0.300606
# ...                     ...       ...       ...       ...       ...       ...
# gene-TX72_RS00265  5.572950  5.674927  1.592020  1.047180  0.412713  0.464842
# gene-TX72_RS00650  8.252116  8.088545  3.564427  3.111317  1.304145  1.755823
# gene-TX72_RS02965  5.644910  5.760672  1.667093  1.389553  0.655682  0.376125
# gene-TX72_RS02495  6.050878  5.746129  3.328681  2.837076  2.060126  2.048032
# gene-TX72_RS14885  6.729722  6.015392  3.055367  1.339790  1.552807  1.928026
#
# SampleNames           120_R1     120_R2 Entity             Symbol
# Geneid
# gene-TX72_RS06845   3.850411   4.437541   host  gene-TX72_RS06845
# gene-TX72_RS00470   0.296788   0.296652   host  gene-TX72_RS00470
# gene-TX72_RS12050   0.387877   0.179043   host  gene-TX72_RS12050
# gene-BSV9_gp128    11.376544  11.504754  phage                 19
# gene-TX72_RS06185   0.529349   0.611120   host  gene-TX72_RS06185
# ...                      ...        ...    ...                ...
# gene-TX72_RS00265   0.383666   0.283921   host  gene-TX72_RS00265
# gene-TX72_RS00650   1.800756   1.293353   host  gene-TX72_RS00650
# gene-TX72_RS02965   0.459517   0.595709   host  gene-TX72_RS02965
# gene-TX72_RS02495   1.565172   1.322154   host  gene-TX72_RS02495
# gene-TX72_RS14885   1.258027   0.261485   host  gene-TX72_RS14885
#
# [2912 rows x 10 columns]

# %% [markdown]
# ## 3 Filter samples, if necessary
#
# Look for outliers visually by PCA.

# %%
columnOrder = ['5_R1', '5_R2',
               '30_R1', '30_R2',
               '60_R1', '60_R2',
               '120_R1', '120_R2']

# %%
txPCA(tpms[columnOrder])

# %%
txPCA(logs[columnOrder])

# %%
txPCA(logTPMs[columnOrder])

# %%
tpmHost = tpms[tpms['Entity'] == 'host']
tpmPhage = tpms[tpms['Entity'] == 'phage']
logTPMsHost = logTPMs[logTPMs['Entity'] == 'host']
logTPMsPhage = logTPMs[logTPMs['Entity'] == 'phage']

# %% [markdown]
# tpmHost

# %%
txPCA(tpmHost[columnOrder])

# %% [markdown]
# tpmPhage

# %%
txPCA(tpmPhage[columnOrder])

# %% [markdown]
# logTPM Host

# %%
txPCA(logTPMsHost[columnOrder])

# %% [markdown]
# logTPM Phage

# %%
txPCA(logTPMsPhage[columnOrder])

# %% [markdown]
# $\rightarrow$ Looks ok.

# %% [markdown]
# ## 4. Final grouping
#
# Summarize time points with mean and standard deviation for TPM-normalized data.

# %%
TPMmeans, TPMsds = getMeanSD(tpms[columnOrder])
TPMmeans = TPMmeans[['5', '30', '60', '120']]
TPMmeans[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMmeans
# Out:
#                             5         30          60          120 Entity  \
# Geneid
# gene-TX72_RS06845  101.074572  66.526470   16.591708    17.046408   host
# gene-TX72_RS00470   45.286168   1.674112    0.433313     0.228349   host
# gene-TX72_RS12050   10.430551   0.578623    0.195486     0.220300   host
# gene-BSV9_gp128      0.202827  14.740166  155.696165  2781.320707  phage
# gene-TX72_RS06185   55.718452   1.878903    0.433596     0.485361   host
# ...                       ...        ...         ...          ...    ...
# gene-TX72_RS00265   48.345252   1.540599    0.355676     0.261076   host
# gene-TX72_RS00650  287.543939   9.236058    1.923282     1.967498   host
# gene-TX72_RS02965   51.126738   1.897857    0.436606     0.443148   host
# gene-TX72_RS02495   58.985232   7.596311    3.152821     1.729760   host
# gene-TX72_RS14885   84.409467   4.422065    2.369608     0.795198   host
#
#                               Symbol
# Geneid
# gene-TX72_RS06845  gene-TX72_RS06845
# gene-TX72_RS00470  gene-TX72_RS00470
# gene-TX72_RS12050  gene-TX72_RS12050
# gene-BSV9_gp128                   19
# gene-TX72_RS06185  gene-TX72_RS06185
# ...                              ...
# gene-TX72_RS00265  gene-TX72_RS00265
# gene-TX72_RS00650  gene-TX72_RS00650
# gene-TX72_RS02965  gene-TX72_RS02965
# gene-TX72_RS02495  gene-TX72_RS02495
# gene-TX72_RS14885  gene-TX72_RS14885
#
# [2912 rows x 6 columns]

# %%
TPMsds = TPMsds[['5', '30', '60', '120']]
TPMsds[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMsds
# Out:
#                            5         30        60         120 Entity  \
# Geneid
# gene-TX72_RS06845  25.412041  10.879076  5.615488    3.622289   host
# gene-TX72_RS00470   3.944748   0.326259  0.095673    0.000058   host
# gene-TX72_RS12050   4.320609   0.192689  0.011782    0.088167   host
# gene-BSV9_gp128     0.001480   0.208546  3.915410  123.549029  phage
# gene-TX72_RS06185   3.320909   0.277875  0.201934    0.042084   host
# ...                      ...        ...       ...         ...    ...
# gene-TX72_RS00265   1.743247   0.474113  0.024490    0.043577   host
# gene-TX72_RS00650  16.339909   1.594344  0.453908    0.516528   host
# gene-TX72_RS02965   2.090201   0.277882  0.138755    0.068067   host
# gene-TX72_RS02495   6.312066   1.450606  0.017405    0.229368   host
# gene-TX72_RS14885  20.723001   2.890921  0.435734    0.596487   host
#
#                               Symbol
# Geneid
# gene-TX72_RS06845  gene-TX72_RS06845
# gene-TX72_RS00470  gene-TX72_RS00470
# gene-TX72_RS12050  gene-TX72_RS12050
# gene-BSV9_gp128                   19
# gene-TX72_RS06185  gene-TX72_RS06185
# ...                              ...
# gene-TX72_RS00265  gene-TX72_RS00265
# gene-TX72_RS00650  gene-TX72_RS00650
# gene-TX72_RS02965  gene-TX72_RS02965
# gene-TX72_RS02495  gene-TX72_RS02495
# gene-TX72_RS14885  gene-TX72_RS14885
#
# [2912 rows x 6 columns]

# %%
propExp = proportionalExp(TPMmeans[['5', '30', '60', '120']])
propExp[['Entity', 'Symbol']] = TPMmeans[['Entity', 'Symbol']]
propExp
# Out:
#                           5        30        60       120 Entity  \
# Geneid
# gene-TX72_RS06845  1.000000  0.658192  0.164153  0.168652   host
# gene-TX72_RS00470  1.000000  0.036967  0.009568  0.005042   host
# gene-TX72_RS12050  1.000000  0.055474  0.018742  0.021121   host
# gene-BSV9_gp128    0.000073  0.005300  0.055979  1.000000  phage
# gene-TX72_RS06185  1.000000  0.033721  0.007782  0.008711   host
# ...                     ...       ...       ...       ...    ...
# gene-TX72_RS00265  1.000000  0.031867  0.007357  0.005400   host
# gene-TX72_RS00650  1.000000  0.032121  0.006689  0.006842   host
# gene-TX72_RS02965  1.000000  0.037121  0.008540  0.008668   host
# gene-TX72_RS02495  1.000000  0.128783  0.053451  0.029325   host
# gene-TX72_RS14885  1.000000  0.052388  0.028073  0.009421   host
#
#                               Symbol
# Geneid
# gene-TX72_RS06845  gene-TX72_RS06845
# gene-TX72_RS00470  gene-TX72_RS00470
# gene-TX72_RS12050  gene-TX72_RS12050
# gene-BSV9_gp128                   19
# gene-TX72_RS06185  gene-TX72_RS06185
# ...                              ...
# gene-TX72_RS00265  gene-TX72_RS00265
# gene-TX72_RS00650  gene-TX72_RS00650
# gene-TX72_RS02965  gene-TX72_RS02965
# gene-TX72_RS02495  gene-TX72_RS02495
# gene-TX72_RS14885  gene-TX72_RS14885
#
# [2912 rows x 6 columns]

# %% [markdown]
# ## 5. Phage gene classification

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelThreshold(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-2)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM*0.2

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x >= thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('middle')
        elif timePoint == 3:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassThreshold'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassThreshold'] = 'None'

    return tpmOut

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelMax(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-3)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x == thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('middle')
        elif timePoint == 3:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassMax'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassMax'] = 'None'

    return tpmOut

# %%
TPMmeans
# Out:
#                             5         30          60          120 Entity  \
# Geneid
# gene-TX72_RS06845  101.074572  66.526470   16.591708    17.046408   host
# gene-TX72_RS00470   45.286168   1.674112    0.433313     0.228349   host
# gene-TX72_RS12050   10.430551   0.578623    0.195486     0.220300   host
# gene-BSV9_gp128      0.202827  14.740166  155.696165  2781.320707  phage
# gene-TX72_RS06185   55.718452   1.878903    0.433596     0.485361   host
# ...                       ...        ...         ...          ...    ...
# gene-TX72_RS00265   48.345252   1.540599    0.355676     0.261076   host
# gene-TX72_RS00650  287.543939   9.236058    1.923282     1.967498   host
# gene-TX72_RS02965   51.126738   1.897857    0.436606     0.443148   host
# gene-TX72_RS02495   58.985232   7.596311    3.152821     1.729760   host
# gene-TX72_RS14885   84.409467   4.422065    2.369608     0.795198   host
#
#                               Symbol
# Geneid
# gene-TX72_RS06845  gene-TX72_RS06845
# gene-TX72_RS00470  gene-TX72_RS00470
# gene-TX72_RS12050  gene-TX72_RS12050
# gene-BSV9_gp128                   19
# gene-TX72_RS06185  gene-TX72_RS06185
# ...                              ...
# gene-TX72_RS00265  gene-TX72_RS00265
# gene-TX72_RS00650  gene-TX72_RS00650
# gene-TX72_RS02965  gene-TX72_RS02965
# gene-TX72_RS02495  gene-TX72_RS02495
# gene-TX72_RS14885  gene-TX72_RS14885
#
# [2912 rows x 6 columns]

# %%
TPMmeans = classLabelThreshold(TPMmeans)
TPMmeans = classLabelMax(TPMmeans)

# %%
TPMmeans[TPMmeans['Entity'] == 'phage']['ClassMax'].value_counts()
# Out:
# ClassMax
# late      106
# middle     65
# early      61
# Name: count, dtype: int64

# %% [markdown]
# Add classes to other dfs.

# %%
gff3_genes["seq_id"].unique()
# Out:
# array(['NC_005070.1', 'NC_008296.2'], dtype=object)

# %%
TPMsds[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
tpms[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
logs[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
propExp[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]

# gff3
gff3_final = gff3_genes.merge(TPMmeans[["ClassThreshold", "ClassMax"]], right_index=True, left_on="ID", how="left")
gff3_host  = gff3_final[gff3_final['seq_id'] == 'NC_005070.1']
gff3_phage = gff3_final[gff3_final['seq_id'] == 'NC_008296.2']

# %% [markdown]
# ## 6. Add variance to all dataframes

# %% [markdown]
# Base variance call on tpms.

# %%
def stabilizedVariance(df):
    labels = list()
    
    i = 0
    while i < df.shape[0]:

        # Get array of expression values at time points
        expressions = list(df.iloc[i,0:(df.shape[1]-4)])

        # Get mean expression for the gene
        exprMean = np.mean(np.array(expressions))

        # Get the variance for the gene
        varGene = np.var(np.array(expressions))

        # Stabilized variance
        stableVarGene = varGene/exprMean

        labels.append(stableVarGene)

        i += 1

    tpmOut = df.copy()
    tpmOut['Variance'] = labels

    return tpmOut

# %%
tpms = stabilizedVariance(tpms)
tpms
# Out:
# SampleNames              5_R1        5_R2      30_R1      30_R2       60_R1  \
# Geneid
# gene-TX72_RS06845   75.662531  126.486614  55.647394  77.405545   22.207195
# gene-TX72_RS00470   49.230916   41.341420   2.000371   1.347853    0.528986
# gene-TX72_RS12050   14.751160    6.109942   0.385933   0.771312    0.183704
# gene-BSV9_gp128      0.204307    0.201347  14.531620  14.948712  151.780755
# gene-TX72_RS06185   52.397542   59.039361   2.156779   1.601028    0.635529
# ...                       ...         ...        ...        ...         ...
# gene-TX72_RS00265   46.602005   50.088498   2.014712   1.066486    0.331186
# gene-TX72_RS00650  303.883848  271.204030  10.830402   7.641714    1.469374
# gene-TX72_RS02965   49.036537   53.216939   2.175740   1.619975    0.575361
# gene-TX72_RS02495   65.297298   52.673166   9.046917   6.145705    3.170227
# gene-TX72_RS14885  105.132468   63.686466   7.312985   1.531144    1.933874
#
# SampleNames             60_R2       120_R1       120_R2 Entity  \
# Geneid
# gene-TX72_RS06845   10.976220    13.424119    20.668697   host
# gene-TX72_RS00470    0.337641     0.228406     0.228291   host
# gene-TX72_RS12050    0.207268     0.308466     0.132133   host
# gene-BSV9_gp128    159.611575  2657.771678  2904.869737  phage
# gene-TX72_RS06185    0.231662     0.443277     0.527445   host
# ...                       ...          ...          ...    ...
# gene-TX72_RS00265    0.380166     0.304653     0.217499   host
# gene-TX72_RS00650    2.377190     2.484027     1.450970   host
# gene-TX72_RS02965    0.297851     0.375081     0.511215   host
# gene-TX72_RS02495    3.135416     1.959128     1.500391   host
# gene-TX72_RS14885    2.805343     1.391685     0.198712   host
#
# SampleNames                   Symbol ClassThreshold ClassMax     Variance
# Geneid
# gene-TX72_RS06845  gene-TX72_RS06845           None     None    29.279522
# gene-TX72_RS00470  gene-TX72_RS00470           None     None    31.552553
# gene-TX72_RS12050  gene-TX72_RS12050           None     None     8.341231
# gene-BSV9_gp128                   19           late     late  1896.017126
# gene-TX72_RS06185  gene-TX72_RS06185           None     None    38.683371
# ...                              ...            ...      ...          ...
# gene-TX72_RS00265  gene-TX72_RS00265           None     None    33.769932
# gene-TX72_RS00650  gene-TX72_RS00650           None     None   201.029414
# gene-TX72_RS02965  gene-TX72_RS02965           None     None    35.173090
# gene-TX72_RS02495  gene-TX72_RS02495           None     None    32.395457
# gene-TX72_RS14885  gene-TX72_RS14885           None     None    59.494481
#
# [2912 rows x 13 columns]

# %%
logs['Variance'] = tpms['Variance']
TPMmeans['Variance'] = tpms['Variance']
TPMsds['Variance'] = tpms['Variance']
propExp['Variance'] = tpms['Variance']

# %% [markdown]
# ## 7. Write data to output

# %%
df_norRNAs[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
df_norRNAs
# Out:
# SampleNames        5_R1  5_R2  30_R1  30_R2  60_R1  60_R2  120_R1  120_R2  \
# Geneid
# gene-TX72_RS06845    67   114    137    478    207     50      41      89
# gene-TX72_RS00470   155   132     17     29     17      5       2       3
# gene-TX72_RS12050    34    14      2     12      4      2       2       1
# gene-BSV9_gp128       0     0     98    253   3890   2014   22539   34506
# gene-TX72_RS06185   153   175     17     32     19      3       4       7
# ...                 ...   ...    ...    ...    ...    ...     ...     ...
# gene-TX72_RS00265   154   168     18     24     11      6       3       3
# gene-TX72_RS00650   582   527     57    101     29     23      16      13
# gene-TX72_RS02965   207   228     25     47     25      6       5      10
# gene-TX72_RS02495   264   216    101    172    134     65      27      29
# gene-TX72_RS14885    54    33     10      5     10      7       2       0
#
# SampleNames       Entity             Symbol
# Geneid
# gene-TX72_RS06845   host  gene-TX72_RS06845
# gene-TX72_RS00470   host  gene-TX72_RS00470
# gene-TX72_RS12050   host  gene-TX72_RS12050
# gene-BSV9_gp128    phage                 19
# gene-TX72_RS06185   host  gene-TX72_RS06185
# ...                  ...                ...
# gene-TX72_RS00265   host  gene-TX72_RS00265
# gene-TX72_RS00650   host  gene-TX72_RS00650
# gene-TX72_RS02965   host  gene-TX72_RS02965
# gene-TX72_RS02495   host  gene-TX72_RS02495
# gene-TX72_RS14885   host  gene-TX72_RS14885
#
# [2912 rows x 10 columns]

# %%
# Full TPM table
tpms.to_csv('Doron_WH8102_full_TPM.tsv', sep = '\t')
# Full raw_counts table
df_norRNAs.to_csv('Doron_WH8102_full_raw_counts.tsv', sep = '\t')
# Summarized (time point means) TPM table
TPMmeans.to_csv('Doron_WH8102_TPM_means.tsv', sep = '\t')
# Summarized (time point) TPM standard deviation
TPMsds.to_csv('Doron_WH8102_TPM_std.tsv', sep = '\t')
# Proportional expression per gene and time point
propExp.to_csv('Doron_WH8102_fractional_expression.tsv', sep = '\t')
# Processed gff3 file
gff3_host.to_csv('Doron_WH8102_host_gff3.tsv', sep='\t')
gff3_phage.to_csv('Doron_WH8102_phage_gff3.tsv', sep='\t')
