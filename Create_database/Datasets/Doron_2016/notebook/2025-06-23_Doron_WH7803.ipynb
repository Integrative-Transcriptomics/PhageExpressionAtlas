# %% [markdown]
# # Process bulk counts table
#
# 1. Annotate columns (samples) in a way that time point and replicate are annotated
# 2. Remove rRNA genes
# 3. Perform TPM normalization and alternatively also raw counts

# %%
# Use miniconda environment Jupyter_new for running this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tools import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 Load the dataset and annotation

# %%
bulkPath = '../nf_output/WH7803/countData/countData.tsv'
metaPath = '../SraRunTable_WH7803.csv' # metadata from SRA
gffPath = '../nf_output/WH7803/alignments/dualGenome.gff3' # output from nf pipeline

# %%
# Load and filter data
df_initial = pd.read_csv(bulkPath, sep = '\t', comment='#', index_col=0)
metadata = pd.read_csv(metaPath)

#acc_drop = metadata[metadata["genotype"] == "rpoC G17D"]["Run"].tolist()
#acc_drop = [acc + "_sorted.bam" for acc in acc_drop]
#df_initial.drop(columns=acc_drop, inplace=True)
#metadata = metadata[metadata['genotype'] == 'WT']

# %%
df_initial
# Out:
#                              Chr   Start     End Strand  Length  \
# Geneid
# gene-SynWH7803_0001   CT971583.1     174    1343      +    1170
# gene-SynWH7803_0002   CT971583.1    1347    2096      +     750
# gene-SynWH7803_0003   CT971583.1    2187    4484      +    2298
# gene-SynWH7803_0004   CT971583.1    4523    5989      +    1467
# gene-SynWH7803_0005   CT971583.1    5992    8457      -    2466
# ...                          ...     ...     ...    ...     ...
# gene-BSV9_gp228      NC_008296.2  174751  175461      +     711
# gene-BSV9_gp229      NC_008296.2  175461  175640      +     180
# gene-BSV9_gp230      NC_008296.2  175642  175872      +     231
# gene-BSV9_gp231      NC_008296.2  175876  176640      +     765
# gene-BSV9_gp232      NC_008296.2  176640  177317      +     678
#
#                      SRR2932976_sorted.bam  SRR2932978_sorted.bam  \
# Geneid
# gene-SynWH7803_0001                     17                     23
# gene-SynWH7803_0002                      8                      4
# gene-SynWH7803_0003                     30                     61
# gene-SynWH7803_0004                     66                    108
# gene-SynWH7803_0005                     19                     32
# ...                                    ...                    ...
# gene-BSV9_gp228                      48034                  17462
# gene-BSV9_gp229                      16375                   4800
# gene-BSV9_gp230                      23594                  11375
# gene-BSV9_gp231                      65111                  29758
# gene-BSV9_gp232                      65215                  24511
#
#                      SRR2932974_sorted.bam  SRR2932979_sorted.bam  \
# Geneid
# gene-SynWH7803_0001                     88                     18
# gene-SynWH7803_0002                     30                      3
# gene-SynWH7803_0003                    165                     34
# gene-SynWH7803_0004                    400                     58
# gene-SynWH7803_0005                    108                     19
# ...                                    ...                    ...
# gene-BSV9_gp228                      16010                  19816
# gene-BSV9_gp229                       4597                   6177
# gene-BSV9_gp230                       5830                  15174
# gene-BSV9_gp231                      18533                  37209
# gene-BSV9_gp232                      22747                  28606
#
#                      SRR2932973_sorted.bam  SRR2932975_sorted.bam  \
# Geneid
# gene-SynWH7803_0001                    345                     67
# gene-SynWH7803_0002                    106                     25
# gene-SynWH7803_0003                    806                    143
# gene-SynWH7803_0004                   1700                    330
# gene-SynWH7803_0005                    459                     84
# ...                                    ...                    ...
# gene-BSV9_gp228                          0                  29166
# gene-BSV9_gp229                          0                   8936
# gene-BSV9_gp230                          0                  12073
# gene-BSV9_gp231                          0                  34945
# gene-BSV9_gp232                          0                  37359
#
#                      SRR2932977_sorted.bam  SRR2932972_sorted.bam
# Geneid
# gene-SynWH7803_0001                     56                    617
# gene-SynWH7803_0002                     14                    203
# gene-SynWH7803_0003                     79                   1309
# gene-SynWH7803_0004                    216                   2764
# gene-SynWH7803_0005                     61                    801
# ...                                    ...                    ...
# gene-BSV9_gp228                      89751                      0
# gene-BSV9_gp229                      27984                      0
# gene-BSV9_gp230                      40254                      0
# gene-BSV9_gp231                     118084                      0
# gene-BSV9_gp232                     130278                      0
#
# [2818 rows x 13 columns]

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 20)
metadata
# Out:
#           Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 0  SRR2932972    RNA-Seq          50  1417026950  PRJNA302091  SAMN04261837
# 1  SRR2932973    RNA-Seq          50   696209050  PRJNA302091  SAMN04261835
# 2  SRR2932974    RNA-Seq          49   714723065  PRJNA302091  SAMN04261836
# 3  SRR2932975    RNA-Seq         100  1580551700  PRJNA302091  SAMN04261838
# 4  SRR2932976    RNA-Seq         100  1087224700  PRJNA302091  SAMN04261839
# 5  SRR2932977    RNA-Seq          49  1320183186  PRJNA302091  SAMN04261840
# 6  SRR2932978    RNA-Seq          49   660191553  PRJNA302091  SAMN04261841
# 7  SRR2932979    RNA-Seq         100  1190992700  PRJNA302091  SAMN04261904
#
#         Bytes Center Name Consent DATASTORE filetype DATASTORE provider  \
# 0  1062813716         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 1   522215045         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 2   532184264         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 3  1095668132         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 4   766546368         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 5   974538124         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 6   492864871         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 7   834774657         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                        DATASTORE region  Experiment GEO_Accession (exp)  \
# 0  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427363          GSM1937586
# 1  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427364          GSM1937587
# 2  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427365          GSM1937588
# 3  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427366          GSM1937589
# 4  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427367          GSM1937590
# 5  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427368          GSM1937591
# 6  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427369          GSM1937592
# 7  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427370          GSM1937593
#
#           infection           Instrument LibraryLayout LibrarySelection  \
# 0  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 1  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 2  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 3  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 4  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 5  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 6  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
# 7  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
#
#     LibrarySource                   Organism  Platform           ReleaseDate  \
# 0  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
# 1  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
# 2  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
# 3  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
# 4  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
# 5  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
# 6  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
# 7  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
#
#    replicate Sample Name                                       source_name  \
# 0          1  GSM1937586  Synechococcus sp. strain WH7803 infected by Syn9
# 1          3  GSM1937587  Synechococcus sp. strain WH7803 infected by Syn9
# 2          1  GSM1937588  Synechococcus sp. strain WH7803 infected by Syn9
# 3          3  GSM1937589  Synechococcus sp. strain WH7803 infected by Syn9
# 4          3  GSM1937590  Synechococcus sp. strain WH7803 infected by Syn9
# 5          1  GSM1937591  Synechococcus sp. strain WH7803 infected by Syn9
# 6          1  GSM1937592  Synechococcus sp. strain WH7803 infected by Syn9
# 7          3  GSM1937593  Synechococcus sp. strain WH7803 infected by Syn9
#
#    SRA Study     tap_treated    TIME           create_date  version
# 0  SRP066156  Not Applicable    5min  2015-11-19T23:11:00Z        1
# 1  SRP066156  Not Applicable    5min  2015-11-19T23:09:00Z        1
# 2  SRP066156  Not Applicable   30min  2015-11-19T23:09:00Z        1
# 3  SRP066156  Not Applicable   30min  2015-11-19T23:10:00Z        1
# 4  SRP066156  Not Applicable   60min  2015-11-19T23:09:00Z        1
# 5  SRP066156  Not Applicable   60min  2015-11-19T23:13:00Z        1
# 6  SRP066156  Not Applicable  120min  2015-11-19T23:08:00Z        1
# 7  SRP066156  Not Applicable  120min  2015-11-19T23:09:00Z        1

# %% [markdown]
# ## 2 Format the dataset

# %% [markdown]
# ### 2.1 Annotate sample names

# %% [markdown]
# Issue now is that the metadata does not properly annotate sample names. Thus, this will be done manually by adding another sample name column to the metadata.

# %%
# Match GSM IDs and SampleNames inferred from GEO

sampleDict = {'GSM1937586': '5_R1',  'GSM1937587': '5_R2',
              'GSM1937588': '30_R1',  'GSM1937589': '30_R2',
              'GSM1937590': '60_R1',  'GSM1937591': '60_R2',
              'GSM1937592': '120_R1',  'GSM1937593': '120_R2'
}

# %%
metadataFull = annotateData(metadata, sampleDict)

# %%
metadata.head(1)
# Out:
#           Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 0  SRR2932972    RNA-Seq          50  1417026950  PRJNA302091  SAMN04261837
#
#         Bytes Center Name Consent DATASTORE filetype DATASTORE provider  \
# 0  1062813716         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                        DATASTORE region  Experiment GEO_Accession (exp)  \
# 0  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427363          GSM1937586
#
#           infection           Instrument LibraryLayout LibrarySelection  \
# 0  Infected by Syn9  Illumina HiSeq 2000        SINGLE             cDNA
#
#     LibrarySource                   Organism  Platform           ReleaseDate  \
# 0  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA  2015-12-17T00:00:00Z
#
#    replicate Sample Name                                       source_name  \
# 0          1  GSM1937586  Synechococcus sp. strain WH7803 infected by Syn9
#
#    SRA Study     tap_treated  TIME           create_date  version
# 0  SRP066156  Not Applicable  5min  2015-11-19T23:11:00Z        1

# %%
metadataFull.head()
# Out:
#                               Run Assay Type  AvgSpotLen       Bases  \
# SampleID
# SRR2932972_sorted.bam  SRR2932972    RNA-Seq          50  1417026950
# SRR2932973_sorted.bam  SRR2932973    RNA-Seq          50   696209050
# SRR2932974_sorted.bam  SRR2932974    RNA-Seq          49   714723065
# SRR2932975_sorted.bam  SRR2932975    RNA-Seq         100  1580551700
# SRR2932976_sorted.bam  SRR2932976    RNA-Seq         100  1087224700
#
#                         BioProject     BioSample       Bytes Center Name  \
# SampleID
# SRR2932972_sorted.bam  PRJNA302091  SAMN04261837  1062813716         GEO
# SRR2932973_sorted.bam  PRJNA302091  SAMN04261835   522215045         GEO
# SRR2932974_sorted.bam  PRJNA302091  SAMN04261836   532184264         GEO
# SRR2932975_sorted.bam  PRJNA302091  SAMN04261838  1095668132         GEO
# SRR2932976_sorted.bam  PRJNA302091  SAMN04261839   766546368         GEO
#
#                       Consent DATASTORE filetype DATASTORE provider  \
# SampleID
# SRR2932972_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
# SRR2932973_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
# SRR2932974_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
# SRR2932975_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
# SRR2932976_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                                            DATASTORE region  Experiment  \
# SampleID
# SRR2932972_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427363
# SRR2932973_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427364
# SRR2932974_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427365
# SRR2932975_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427366
# SRR2932976_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX1427367
#
#                       GEO_Accession (exp)         infection  \
# SampleID
# SRR2932972_sorted.bam          GSM1937586  Infected by Syn9
# SRR2932973_sorted.bam          GSM1937587  Infected by Syn9
# SRR2932974_sorted.bam          GSM1937588  Infected by Syn9
# SRR2932975_sorted.bam          GSM1937589  Infected by Syn9
# SRR2932976_sorted.bam          GSM1937590  Infected by Syn9
#
#                                 Instrument LibraryLayout LibrarySelection  \
# SampleID
# SRR2932972_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
# SRR2932973_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
# SRR2932974_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
# SRR2932975_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
# SRR2932976_sorted.bam  Illumina HiSeq 2000        SINGLE             cDNA
#
#                         LibrarySource                   Organism  Platform  \
# SampleID
# SRR2932972_sorted.bam  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA
# SRR2932973_sorted.bam  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA
# SRR2932974_sorted.bam  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA
# SRR2932975_sorted.bam  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA
# SRR2932976_sorted.bam  TRANSCRIPTOMIC  Synechococcus sp. WH 7803  ILLUMINA
#
#                                 ReleaseDate  replicate Sample Name  \
# SampleID
# SRR2932972_sorted.bam  2015-12-17T00:00:00Z          1  GSM1937586
# SRR2932973_sorted.bam  2015-12-17T00:00:00Z          3  GSM1937587
# SRR2932974_sorted.bam  2015-12-17T00:00:00Z          1  GSM1937588
# SRR2932975_sorted.bam  2015-12-17T00:00:00Z          3  GSM1937589
# SRR2932976_sorted.bam  2015-12-17T00:00:00Z          3  GSM1937590
#
#                                                             source_name  \
# SampleID
# SRR2932972_sorted.bam  Synechococcus sp. strain WH7803 infected by Syn9
# SRR2932973_sorted.bam  Synechococcus sp. strain WH7803 infected by Syn9
# SRR2932974_sorted.bam  Synechococcus sp. strain WH7803 infected by Syn9
# SRR2932975_sorted.bam  Synechococcus sp. strain WH7803 infected by Syn9
# SRR2932976_sorted.bam  Synechococcus sp. strain WH7803 infected by Syn9
#
#                        SRA Study     tap_treated   TIME           create_date  \
# SampleID
# SRR2932972_sorted.bam  SRP066156  Not Applicable   5min  2015-11-19T23:11:00Z
# SRR2932973_sorted.bam  SRP066156  Not Applicable   5min  2015-11-19T23:09:00Z
# SRR2932974_sorted.bam  SRP066156  Not Applicable  30min  2015-11-19T23:09:00Z
# SRR2932975_sorted.bam  SRP066156  Not Applicable  30min  2015-11-19T23:10:00Z
# SRR2932976_sorted.bam  SRP066156  Not Applicable  60min  2015-11-19T23:09:00Z
#
#                        version               SampleID SampleNames
# SampleID
# SRR2932972_sorted.bam        1  SRR2932972_sorted.bam        5_R1
# SRR2932973_sorted.bam        1  SRR2932973_sorted.bam        5_R2
# SRR2932974_sorted.bam        1  SRR2932974_sorted.bam       30_R1
# SRR2932975_sorted.bam        1  SRR2932975_sorted.bam       30_R2
# SRR2932976_sorted.bam        1  SRR2932976_sorted.bam       60_R1

# %% [markdown]
# Add correct sample names.

# %%
df = changeColnames(df_initial.iloc[:,5:df_initial.shape[1]], metadataFull)
df = df[['5_R1', '5_R2',
         '30_R1', '30_R2',
         '60_R1', '60_R2',
         '120_R1', '120_R2']]
df.head()
# Out:
# SampleNames          5_R1  5_R2  30_R1  30_R2  60_R1  60_R2  120_R1  120_R2
# Geneid
# gene-SynWH7803_0001   617   345     88     67     17     56      23      18
# gene-SynWH7803_0002   203   106     30     25      8     14       4       3
# gene-SynWH7803_0003  1309   806    165    143     30     79      61      34
# gene-SynWH7803_0004  2764  1700    400    330     66    216     108      58
# gene-SynWH7803_0005   801   459    108     84     19     61      32      19

# %% [markdown]
# ### 2.2 Remove rRNA genes
#
# Consult gff3 file to get rRNA geneids.

# %%
# Load gff3 and split into genes and CDS dfs
gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3.columns=["seq_id", "source", "type", "start", "end", "phase", "strand", "score", "attributes"]
gff3_genes = gff3.loc[gff3["type"] == 'gene']

# Column formating for genes
gff3_genes = gff3_genes.reset_index(drop=True)
dct_genes = gff3_genes["attributes"].str.split(';').apply(lambda items: dict(item.split('=', 1) for item in items if '=' in item))
cols_to_keep = ['ID', 'Name', 'gbkey', 'gene_biotype', 'locus_tag', 'gene']
gff3_genes = pd.concat([gff3_genes, pd.json_normalize(dct_genes)[cols_to_keep]], axis=1)

# Generate locus_tag, product dictonary over all different feature types
attrs = gff3["attributes"].str.split(";", expand=True)
attrs_dicts = attrs.apply(lambda row: {item.split("=")[0]: item.split("=")[1] for item in row if "=" in str(item)}, axis=1)
attrs_df = pd.json_normalize(attrs_dicts)
attrs_df = attrs_df.dropna(subset=["locus_tag", "product"])
locus_product_dict = dict(zip(attrs_df["locus_tag"], attrs_df["product"]))

# Add gene product, if not stated in gff3, fill with gene_biotype
gff3_genes["product"] = gff3_genes["locus_tag"].map(locus_product_dict)
# gff3_genes["product"] = gff3_genes["product"].fillna("other")
gff3_genes["product"] = gff3_genes["product"].fillna(gff3_genes["gene_biotype"])

# If gene = NA, take from ID column
gff3_genes["gene"] = gff3_genes["gene"].fillna(gff3_genes["ID"])

# Drop attributes column
gff3_genes = gff3_genes.drop(["attributes"], axis=1)

# %%
pharokka_path = "../../../2025-12_reannotation_phage_genomes/Pharokka_proteins_phages_out/NC_008296.2_out/pharokka_proteins_full_merged_output.tsv"
gff3_genes = add_pharokka(gff3_genes, pharokka_path)
gff3_genes.loc[gff3_genes['seq_id'] == "NC_008296.2"]
# Out:
#            seq_id  source  type     start       end phase strand score  \
# 2586  NC_008296.2  RefSeq  gene       1.0     249.0     .      +     .
# 2587  NC_008296.2  RefSeq  gene     246.0     845.0     .      +     .
# 2588  NC_008296.2  RefSeq  gene     842.0    1177.0     .      +     .
# 2589  NC_008296.2  RefSeq  gene    1245.0    2192.0     .      +     .
# 2590  NC_008296.2  RefSeq  gene    2189.0    2524.0     .      +     .
# ...           ...     ...   ...       ...       ...   ...    ...   ...
# 2813  NC_008296.2  RefSeq  gene  174751.0  175461.0     .      +     .
# 2814  NC_008296.2  RefSeq  gene  175461.0  175640.0     .      +     .
# 2815  NC_008296.2  RefSeq  gene  175642.0  175872.0     .      +     .
# 2816  NC_008296.2  RefSeq  gene  175876.0  176640.0     .      +     .
# 2817  NC_008296.2  RefSeq  gene  176640.0  177317.0     .      +     .
#
#                    ID        Name gbkey    gene_biotype   locus_tag  \
# 2586    gene-BSV9_gp1    BSV9_gp1  Gene  protein_coding    BSV9_gp1
# 2587    gene-BSV9_gp2          59  Gene  protein_coding    BSV9_gp2
# 2588    gene-BSV9_gp3    BSV9_gp3  Gene  protein_coding    BSV9_gp3
# 2589    gene-BSV9_gp4          32  Gene  protein_coding    BSV9_gp4
# 2590    gene-BSV9_gp5    BSV9_gp5  Gene  protein_coding    BSV9_gp5
# ...               ...         ...   ...             ...         ...
# 2813  gene-BSV9_gp228  BSV9_gp228  Gene  protein_coding  BSV9_gp228
# 2814  gene-BSV9_gp229  BSV9_gp229  Gene  protein_coding  BSV9_gp229
# 2815  gene-BSV9_gp230  BSV9_gp230  Gene  protein_coding  BSV9_gp230
# 2816  gene-BSV9_gp231  BSV9_gp231  Gene  protein_coding  BSV9_gp231
# 2817  gene-BSV9_gp232  BSV9_gp232  Gene  protein_coding  BSV9_gp232
#
#                  gene                                   product  \
# 2586    gene-BSV9_gp1   late promoter transcriptional regulator
# 2587               59                       DNA helicase loader
# 2588    gene-BSV9_gp3                                       gp3
# 2589               32         single strand DNA binding protein
# 2590    gene-BSV9_gp5                                       gp5
# ...               ...                                       ...
# 2813  gene-BSV9_gp228                      thymidylate synthase
# 2814  gene-BSV9_gp229                                     gp229
# 2815  gene-BSV9_gp230                 transcriptional regulator
# 2816  gene-BSV9_gp231  PhoH-like phosphate starvation-inducible
# 2817  gene-BSV9_gp232                               exonuclease
#
#                                          annot  PHROG  \
# 2586   late promoter transcriptional regulator    254
# 2587                       DNA helicase loader    269
# 2588                      hypothetical protein    468
# 2589         single strand DNA binding protein    224
# 2590                      hypothetical protein   3309
# ...                                        ...    ...
# 2813                      thymidylate synthase  10644
# 2814                      hypothetical protein    765
# 2815                 transcriptional regulator    385
# 2816  PhoH-like phosphate starvation-inducible    170
# 2817                               exonuclease    298
#
#                                 category
# 2586            transcription regulation
# 2587  DNA, RNA and nucleotide metabolism
# 2588                    unknown function
# 2589  DNA, RNA and nucleotide metabolism
# 2590                    unknown function
# ...                                  ...
# 2813  DNA, RNA and nucleotide metabolism
# 2814                    unknown function
# 2815            transcription regulation
# 2816                               other
# 2817  DNA, RNA and nucleotide metabolism
#
# [232 rows x 18 columns]

# %%
# Load ggf3 file

gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3 = gff3.loc[gff3.iloc[:,2] == 'gene']

# Format some new columns
gff3['ID'] = pd.DataFrame(gff3.iloc[:,8].str.split('ID=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['GeneType'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene_biotype=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['Symbol'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]

# Add entity host and phage
gff3['Entity'] = np.where(gff3[0] == 'NC_008296.2', 'phage', 'host')
gff3.index = gff3['ID']
rRNAs = gff3.loc[gff3['GeneType'] == 'rRNA', 'ID'].tolist()

# %%
gff3
# Out:
#                                0       1     2         3         4  5  6  7  \
# ID
# gene-SynWH7803_0001   CT971583.1    EMBL  gene     174.0    1343.0  .  +  .
# gene-SynWH7803_0002   CT971583.1    EMBL  gene    1347.0    2096.0  .  +  .
# gene-SynWH7803_0003   CT971583.1    EMBL  gene    2187.0    4484.0  .  +  .
# gene-SynWH7803_0004   CT971583.1    EMBL  gene    4523.0    5989.0  .  +  .
# gene-SynWH7803_0005   CT971583.1    EMBL  gene    5992.0    8457.0  .  -  .
# ...                          ...     ...   ...       ...       ... .. .. ..
# gene-BSV9_gp228      NC_008296.2  RefSeq  gene  174751.0  175461.0  .  +  .
# gene-BSV9_gp229      NC_008296.2  RefSeq  gene  175461.0  175640.0  .  +  .
# gene-BSV9_gp230      NC_008296.2  RefSeq  gene  175642.0  175872.0  .  +  .
# gene-BSV9_gp231      NC_008296.2  RefSeq  gene  175876.0  176640.0  .  +  .
# gene-BSV9_gp232      NC_008296.2  RefSeq  gene  176640.0  177317.0  .  +  .
#
#                                                                      8  \
# ID
# gene-SynWH7803_0001  ID=gene-SynWH7803_0001;Name=dnaN;gbkey=Gene;ge...
# gene-SynWH7803_0002  ID=gene-SynWH7803_0002;Name=SynWH7803_0002;gbk...
# gene-SynWH7803_0003  ID=gene-SynWH7803_0003;Name=purL;gbkey=Gene;ge...
# gene-SynWH7803_0004  ID=gene-SynWH7803_0004;Name=purF;gbkey=Gene;ge...
# gene-SynWH7803_0005  ID=gene-SynWH7803_0005;Name=gyrA;gbkey=Gene;ge...
# ...                                                                ...
# gene-BSV9_gp228      ID=gene-BSV9_gp228;Dbxref=GeneID:4238995;Name=...
# gene-BSV9_gp229      ID=gene-BSV9_gp229;Dbxref=GeneID:4238996;Name=...
# gene-BSV9_gp230      ID=gene-BSV9_gp230;Dbxref=GeneID:4238997;Name=...
# gene-BSV9_gp231      ID=gene-BSV9_gp231;Dbxref=GeneID:4238998;Name=...
# gene-BSV9_gp232      ID=gene-BSV9_gp232;Dbxref=GeneID:4238999;Name=...
#
#                                       ID        GeneType Symbol Entity
# ID
# gene-SynWH7803_0001  gene-SynWH7803_0001  protein_coding   dnaN   host
# gene-SynWH7803_0002  gene-SynWH7803_0002  protein_coding   None   host
# gene-SynWH7803_0003  gene-SynWH7803_0003  protein_coding   purL   host
# gene-SynWH7803_0004  gene-SynWH7803_0004  protein_coding   purF   host
# gene-SynWH7803_0005  gene-SynWH7803_0005  protein_coding   gyrA   host
# ...                                  ...             ...    ...    ...
# gene-BSV9_gp228          gene-BSV9_gp228  protein_coding   None  phage
# gene-BSV9_gp229          gene-BSV9_gp229  protein_coding   None  phage
# gene-BSV9_gp230          gene-BSV9_gp230  protein_coding   None  phage
# gene-BSV9_gp231          gene-BSV9_gp231  protein_coding   None  phage
# gene-BSV9_gp232          gene-BSV9_gp232  protein_coding   None  phage
#
# [2818 rows x 13 columns]

# %% [markdown]
# Perform in silico rRNA depletion.

# %%
df_norRNAs = rRNAdepletion(df,rRNAs)
df_norRNAs.head()
# Out:
# SampleNames          5_R1  5_R2  30_R1  30_R2  60_R1  60_R2  120_R1  120_R2
# Geneid
# gene-SynWH7803_1494   120    56     14     10      1      9       5       5
# gene-SynWH7803_0867   389   200     30     43      7     20       7       8
# gene-SynWH7803_1979  5594  3457    850    762    129    375     258     132
# gene-SynWH7803_2423    55    28     11      7      3      4       2       1
# gene-SynWH7803_0927   110    57     15     13      1     16       2       3

# %% [markdown]
# ### 2.3 Read count normalization

# %% [markdown]
# Important note: gene symbols not available for most genes.

# %%
# Function to fill in missing symbols by geneid.

def fillSymbols(df):
    df_new = df.copy()
    index = df.index.to_list()
    for i in range(0,df.shape[0]):
        if (df.iloc[i,-1:].values == None):
            df_new.iloc[i,-1:] = index[i]
    return df_new

# %% [markdown]
# Convert counts to TPM.

# %%
tpms = TPM(df_norRNAs, df_initial, 0.5)
tpms['Entity'] = gff3.loc[sorted(tpms.index.to_list()), 'Entity']
tpms['Symbol'] = gff3.loc[sorted(tpms.index.to_list()), 'Symbol']

tpms = fillSymbols(tpms)
tpms = make_unique_with_index(tpms)
tpms
# Out:
# SampleNames                  5_R1         5_R2       30_R1       30_R2  \
# Geneid
# gene-SynWH7803_1494     50.554125    38.969443    1.775897    0.807454
# gene-SynWH7803_0867     71.491609    60.501785    1.634285    1.463509
# gene-SynWH7803_1979   5586.088199  5675.640789  247.914033  139.554882
# gene-SynWH7803_2423     38.752833    32.716101    2.344167    0.959910
# gene-SynWH7803_0927    103.115751    88.213851    4.222549    2.309166
# ...                           ...          ...         ...         ...
# gene-SynWH7803_0751    127.420065   109.027969    4.568160    2.595099
# gene-SynWH7803_1456    114.936813    70.802889    3.603611    2.363206
# gene-SynWH7803_2248    388.370996   401.156606   18.671884   10.474196
# gene-SynWH7803_2444    238.529699   251.596230   11.526322    6.639062
# gene-RNA_4           15720.246614   196.319873   23.043632    7.790835
#
# SampleNames              60_R1      60_R2     120_R1     120_R2 Entity  \
# Geneid
# gene-SynWH7803_1494   0.100418   0.335150   0.574495   0.443004   host
# gene-SynWH7803_0867   0.219664   0.316408   0.342738   0.299531   host
# gene-SynWH7803_1979  20.633182  31.528438  64.263002  25.400233   host
# gene-SynWH7803_2423   0.389968   0.264222   0.434615   0.201084   host
# gene-SynWH7803_0927   0.223359   1.294770   0.580840   0.627056   host
# ...                        ...        ...        ...        ...    ...
# gene-SynWH7803_0751   0.356708   0.689256   0.927611   1.573656   host
# gene-SynWH7803_1456   0.131316   0.853479   0.614669   0.157994   host
# gene-SynWH7803_2248   1.695676   3.759828   4.742362   3.118010   host
# gene-SynWH7803_2444   1.301712   1.618911   2.680976   1.064999   host
# gene-RNA_4            1.614827  10.382021   5.543100   5.051551   host
#
# SampleNames                       Symbol
# Geneid
# gene-SynWH7803_1494  gene-SynWH7803_1494
# gene-SynWH7803_0867  gene-SynWH7803_0867
# gene-SynWH7803_1979                 petF
# gene-SynWH7803_2423  gene-SynWH7803_2423
# gene-SynWH7803_0927  gene-SynWH7803_0927
# ...                                  ...
# gene-SynWH7803_0751  gene-SynWH7803_0751
# gene-SynWH7803_1456  gene-SynWH7803_1456
# gene-SynWH7803_2248  gene-SynWH7803_2248
# gene-SynWH7803_2444  gene-SynWH7803_2444
# gene-RNA_4                    gene-RNA_4
#
# [2812 rows x 10 columns]

# %%
# Check gene names unique
len(tpms['Symbol'].unique())
# Out:
# 2812

# %% [markdown]
# Log2+1 normalization raw counts

# %%
logs = logNorm(df_norRNAs)
logs['Entity'] = gff3.loc[sorted(logs.index.to_list()), 'Entity']
logs['Symbol'] = gff3.loc[sorted(logs.index.to_list()), 'Symbol']
logs = fillSymbols(logs)
# Make gene names unique
logs = make_unique_with_index(logs)
logs
# Out:
# SampleNames               5_R1       5_R2     30_R1     30_R2     60_R1  \
# Geneid
# gene-SynWH7803_1494   6.918863   5.832890  3.906891  3.459432  1.000000
# gene-SynWH7803_0867   8.607330   7.651052  4.954196  5.459432  3.000000
# gene-SynWH7803_1979  12.449922  11.755722  9.733015  9.575539  7.022368
# gene-SynWH7803_2423   5.807355   4.857981  3.584963  3.000000  2.000000
# gene-SynWH7803_0927   6.794416   5.857981  4.000000  3.807355  1.000000
# ...                        ...        ...       ...       ...       ...
# gene-SynWH7803_0751   6.426265   5.491853  3.459432  3.321928  1.000000
# gene-SynWH7803_1456   7.714246   6.303781  4.523562  4.584963  1.000000
# gene-SynWH7803_2248   9.920353   9.250298  7.321928  7.159871  4.754888
# gene-SynWH7803_2444   8.515700   7.876517  5.930737  5.807355  3.700440
# gene-RNA_4           11.923327   4.906891  4.321928  3.459432  1.584963
#
# SampleNames             60_R2    120_R1    120_R2 Entity               Symbol
# Geneid
# gene-SynWH7803_1494  3.321928  2.584963  2.584963   host  gene-SynWH7803_1494
# gene-SynWH7803_0867  4.392317  3.000000  3.169925   host  gene-SynWH7803_0867
# gene-SynWH7803_1979  8.554589  8.016808  7.055282   host                 petF
# gene-SynWH7803_2423  2.321928  1.584963  1.000000   host  gene-SynWH7803_2423
# gene-SynWH7803_0927  4.087463  1.584963  2.000000   host  gene-SynWH7803_0927
# ...                       ...       ...       ...    ...                  ...
# gene-SynWH7803_0751  2.584963  1.584963  2.584963   host  gene-SynWH7803_0751
# gene-SynWH7803_1456  4.247928  2.321928  1.000000   host  gene-SynWH7803_1456
# gene-SynWH7803_2248  6.807355  5.584963  5.357552   host  gene-SynWH7803_2248
# gene-SynWH7803_2444  4.906891  4.087463  3.169925   host  gene-SynWH7803_2444
# gene-RNA_4           4.954196  2.584963  2.807355   host           gene-RNA_4
#
# [2812 rows x 10 columns]

# %% [markdown]
# Log2+1 normalization tpms

# %%
logTPMs = logNorm(tpms.iloc[:, :-2])
logTPMs = logTPMs.join(tpms.iloc[:, -2:])
logTPMs = fillSymbols(logTPMs)
# Make gene names unique
logTPMs = make_unique_with_index(logTPMs)
logTPMs
# Out:
# SampleNames               5_R1       5_R2     30_R1     30_R2     60_R1  \
# Geneid
# gene-SynWH7803_1494   5.688016   5.320826  1.472954  0.853959  0.138051
# gene-SynWH7803_0867   6.179742   5.942556  1.397411  1.300715  0.286484
# gene-SynWH7803_1979  12.447881  12.470822  7.959504  7.134990  4.435174
# gene-SynWH7803_2423   5.312986   5.075366  1.741647  0.970787  0.475051
# gene-SynWH7803_0927   6.702045   6.479196  2.384754  1.726468  0.290848
# ...                        ...        ...       ...       ...       ...
# gene-SynWH7803_0751   7.004727   6.781726  2.477201  1.846032  0.440110
# gene-SynWH7803_1456   6.857195   6.165970  2.202766  1.749837  0.178001
# gene-SynWH7803_2248   8.605002   8.651614  4.298063  3.520321  1.430647
# gene-SynWH7803_2444   7.904061   7.980689  3.646891  2.933396  1.202708
# gene-RNA_4           13.940428   7.624392  4.587583  3.136000  1.386715
#
# SampleNames             60_R2    120_R1    120_R2 Entity               Symbol
# Geneid
# gene-SynWH7803_1494  0.417002  0.654889  0.529075   host  gene-SynWH7803_1494
# gene-SynWH7803_0867  0.396607  0.425178  0.377991   host  gene-SynWH7803_0867
# gene-SynWH7803_1979  5.023630  6.028193  4.722479   host                 petF
# gene-SynWH7803_2423  0.338250  0.520663  0.264337   host  gene-SynWH7803_2423
# gene-SynWH7803_0927  1.198350  0.660692  0.702264   host  gene-SynWH7803_0927
# ...                       ...       ...       ...    ...                  ...
# gene-SynWH7803_0751  0.756388  0.946814  1.363819   host  gene-SynWH7803_0751
# gene-SynWH7803_1456  0.890236  0.691239  0.211628   host  gene-SynWH7803_1456
# gene-SynWH7803_2248  2.250910  2.521644  2.041947   host  gene-SynWH7803_2248
# gene-SynWH7803_2444  1.388967  1.880088  1.046141   host  gene-SynWH7803_2444
# gene-RNA_4           3.508685  2.709974  2.597305   host           gene-RNA_4
#
# [2812 rows x 10 columns]

# %% [markdown]
# ## 3 Filter samples, if necessary
#
# Look for outliers visually by PCA.

# %%
columnOrder = ['5_R1', '5_R2',
               '30_R1', '30_R2',
               '60_R1', '60_R2',
               '120_R1', '120_R2']

# %%
txPCA(tpms[columnOrder])

# %%
txPCA(logs[columnOrder])

# %%
txPCA(logTPMs[columnOrder])

# %%
tpmHost = tpms[tpms['Entity'] == 'host']
tpmPhage = tpms[tpms['Entity'] == 'phage']
logTPMsHost = logTPMs[logTPMs['Entity'] == 'host']
logTPMsPhage = logTPMs[logTPMs['Entity'] == 'phage']

# %% [markdown]
# tpmHost

# %%
txPCA(tpmHost[columnOrder])

# %% [markdown]
# tpmPhage

# %%
txPCA(tpmPhage[columnOrder])

# %% [markdown]
# logTPM Host

# %%
txPCA(logTPMsHost[columnOrder])

# %% [markdown]
# logTPM Phage

# %%
txPCA(logTPMsPhage[columnOrder])

# %% [markdown]
# $\rightarrow$ Looks ok.

# %% [markdown]
# ## 4. Final grouping
#
# Summarize time points with mean and standard deviation for TPM-normalized data.

# %%
TPMmeans, TPMsds = getMeanSD(tpms[columnOrder])
TPMmeans = TPMmeans[['5', '30', '60', '120']]
TPMmeans[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMmeans
# Out:
#                                5          30         60        120 Entity  \
# Geneid
# gene-SynWH7803_1494    44.761784    1.291675   0.217784   0.508749   host
# gene-SynWH7803_0867    65.996697    1.548897   0.268036   0.321135   host
# gene-SynWH7803_1979  5630.864494  193.734458  26.080810  44.831618   host
# gene-SynWH7803_2423    35.734467    1.652039   0.327095   0.317849   host
# gene-SynWH7803_0927    95.664801    3.265858   0.759065   0.603948   host
# ...                          ...         ...        ...        ...    ...
# gene-SynWH7803_0751   118.224017    3.581630   0.522982   1.250633   host
# gene-SynWH7803_1456    92.869851    2.983409   0.492397   0.386332   host
# gene-SynWH7803_2248   394.763801   14.573040   2.727752   3.930186   host
# gene-SynWH7803_2444   245.062965    9.082692   1.460312   1.872988   host
# gene-RNA_4           7958.283243   15.417234   5.998424   5.297325   host
#
#                                   Symbol
# Geneid
# gene-SynWH7803_1494  gene-SynWH7803_1494
# gene-SynWH7803_0867  gene-SynWH7803_0867
# gene-SynWH7803_1979                 petF
# gene-SynWH7803_2423  gene-SynWH7803_2423
# gene-SynWH7803_0927  gene-SynWH7803_0927
# ...                                  ...
# gene-SynWH7803_0751  gene-SynWH7803_0751
# gene-SynWH7803_1456  gene-SynWH7803_1456
# gene-SynWH7803_2248  gene-SynWH7803_2248
# gene-SynWH7803_2444  gene-SynWH7803_2444
# gene-RNA_4                    gene-RNA_4
#
# [2812 rows x 6 columns]

# %%
TPMsds = TPMsds[['5', '30', '60', '120']]
TPMsds[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMsds
# Out:
#                                5         30        60        120 Entity  \
# Geneid
# gene-SynWH7803_1494     5.792341   0.484222  0.117366   0.065746   host
# gene-SynWH7803_0867     5.494912   0.085388  0.048372   0.021604   host
# gene-SynWH7803_1979    44.776295  54.179575  5.447628  19.431385   host
# gene-SynWH7803_2423     3.018366   0.692129  0.062873   0.116765   host
# gene-SynWH7803_0927     7.450950   0.956692  0.535705   0.023108   host
# ...                          ...        ...       ...        ...    ...
# gene-SynWH7803_0751     9.196048   0.986530  0.166274   0.323023   host
# gene-SynWH7803_1456    22.066962   0.620202  0.361082   0.228337   host
# gene-SynWH7803_2248     6.392805   4.098844  1.032076   0.812176   host
# gene-SynWH7803_2444     6.533265   2.443630  0.158600   0.807989   host
# gene-RNA_4           7761.963371   7.626399  4.383597   0.245775   host
#
#                                   Symbol
# Geneid
# gene-SynWH7803_1494  gene-SynWH7803_1494
# gene-SynWH7803_0867  gene-SynWH7803_0867
# gene-SynWH7803_1979                 petF
# gene-SynWH7803_2423  gene-SynWH7803_2423
# gene-SynWH7803_0927  gene-SynWH7803_0927
# ...                                  ...
# gene-SynWH7803_0751  gene-SynWH7803_0751
# gene-SynWH7803_1456  gene-SynWH7803_1456
# gene-SynWH7803_2248  gene-SynWH7803_2248
# gene-SynWH7803_2444  gene-SynWH7803_2444
# gene-RNA_4                    gene-RNA_4
#
# [2812 rows x 6 columns]

# %%
propExp = proportionalExp(TPMmeans[['5', '30', '60', '120']])
propExp[['Entity', 'Symbol']] = TPMmeans[['Entity', 'Symbol']]
propExp
# Out:
#                        5        30        60       120 Entity  \
# Geneid
# gene-SynWH7803_1494  1.0  0.028857  0.004865  0.011366   host
# gene-SynWH7803_0867  1.0  0.023469  0.004061  0.004866   host
# gene-SynWH7803_1979  1.0  0.034406  0.004632  0.007962   host
# gene-SynWH7803_2423  1.0  0.046231  0.009153  0.008895   host
# gene-SynWH7803_0927  1.0  0.034139  0.007935  0.006313   host
# ...                  ...       ...       ...       ...    ...
# gene-SynWH7803_0751  1.0  0.030295  0.004424  0.010579   host
# gene-SynWH7803_1456  1.0  0.032125  0.005302  0.004160   host
# gene-SynWH7803_2248  1.0  0.036916  0.006910  0.009956   host
# gene-SynWH7803_2444  1.0  0.037063  0.005959  0.007643   host
# gene-RNA_4           1.0  0.001937  0.000754  0.000666   host
#
#                                   Symbol
# Geneid
# gene-SynWH7803_1494  gene-SynWH7803_1494
# gene-SynWH7803_0867  gene-SynWH7803_0867
# gene-SynWH7803_1979                 petF
# gene-SynWH7803_2423  gene-SynWH7803_2423
# gene-SynWH7803_0927  gene-SynWH7803_0927
# ...                                  ...
# gene-SynWH7803_0751  gene-SynWH7803_0751
# gene-SynWH7803_1456  gene-SynWH7803_1456
# gene-SynWH7803_2248  gene-SynWH7803_2248
# gene-SynWH7803_2444  gene-SynWH7803_2444
# gene-RNA_4                    gene-RNA_4
#
# [2812 rows x 6 columns]

# %% [markdown]
# ## 5. Phage gene classification

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelThreshold(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-2)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM*0.2

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x >= thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('middle')
        elif timePoint == 3:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassThreshold'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassThreshold'] = 'None'

    return tpmOut

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelMax(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-3)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x == thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('middle')
        elif timePoint == 3:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassMax'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassMax'] = 'None'

    return tpmOut

# %%
TPMmeans
# Out:
#                                5          30         60        120 Entity  \
# Geneid
# gene-SynWH7803_1494    44.761784    1.291675   0.217784   0.508749   host
# gene-SynWH7803_0867    65.996697    1.548897   0.268036   0.321135   host
# gene-SynWH7803_1979  5630.864494  193.734458  26.080810  44.831618   host
# gene-SynWH7803_2423    35.734467    1.652039   0.327095   0.317849   host
# gene-SynWH7803_0927    95.664801    3.265858   0.759065   0.603948   host
# ...                          ...         ...        ...        ...    ...
# gene-SynWH7803_0751   118.224017    3.581630   0.522982   1.250633   host
# gene-SynWH7803_1456    92.869851    2.983409   0.492397   0.386332   host
# gene-SynWH7803_2248   394.763801   14.573040   2.727752   3.930186   host
# gene-SynWH7803_2444   245.062965    9.082692   1.460312   1.872988   host
# gene-RNA_4           7958.283243   15.417234   5.998424   5.297325   host
#
#                                   Symbol
# Geneid
# gene-SynWH7803_1494  gene-SynWH7803_1494
# gene-SynWH7803_0867  gene-SynWH7803_0867
# gene-SynWH7803_1979                 petF
# gene-SynWH7803_2423  gene-SynWH7803_2423
# gene-SynWH7803_0927  gene-SynWH7803_0927
# ...                                  ...
# gene-SynWH7803_0751  gene-SynWH7803_0751
# gene-SynWH7803_1456  gene-SynWH7803_1456
# gene-SynWH7803_2248  gene-SynWH7803_2248
# gene-SynWH7803_2444  gene-SynWH7803_2444
# gene-RNA_4                    gene-RNA_4
#
# [2812 rows x 6 columns]

# %%
TPMmeans = classLabelThreshold(TPMmeans)
TPMmeans = classLabelMax(TPMmeans)

# %%
TPMmeans[TPMmeans['Entity'] == 'phage']['ClassMax'].value_counts()
# Out:
# ClassMax
# late      93
# middle    79
# early     60
# Name: count, dtype: int64

# %% [markdown]
# Add classes to other dfs.

# %%
TPMsds[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
tpms[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
logs[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
propExp[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]

# gff3
gff3_final = gff3_genes.merge(TPMmeans[["ClassThreshold", "ClassMax"]], right_index=True, left_on="ID", how="left")
gff3_host  = gff3_final[gff3_final['seq_id'] == 'CT971583.1']
gff3_phage = gff3_final[gff3_final['seq_id'] == 'NC_008296.2']

# %% [markdown]
# ## 6. Add variance to all dataframes

# %% [markdown]
# Base variance call on tpms.

# %%
def stabilizedVariance(df):
    labels = list()
    
    i = 0
    while i < df.shape[0]:

        # Get array of expression values at time points
        expressions = list(df.iloc[i,0:(df.shape[1]-4)])

        # Get mean expression for the gene
        exprMean = np.mean(np.array(expressions))

        # Get the variance for the gene
        varGene = np.var(np.array(expressions))

        # Stabilized variance
        stableVarGene = varGene/exprMean

        labels.append(stableVarGene)

        i += 1

    tpmOut = df.copy()
    tpmOut['Variance'] = labels

    return tpmOut

# %%
tpms = stabilizedVariance(tpms)
tpms
# Out:
# SampleNames                  5_R1         5_R2       30_R1       30_R2  \
# Geneid
# gene-SynWH7803_1494     50.554125    38.969443    1.775897    0.807454
# gene-SynWH7803_0867     71.491609    60.501785    1.634285    1.463509
# gene-SynWH7803_1979   5586.088199  5675.640789  247.914033  139.554882
# gene-SynWH7803_2423     38.752833    32.716101    2.344167    0.959910
# gene-SynWH7803_0927    103.115751    88.213851    4.222549    2.309166
# ...                           ...          ...         ...         ...
# gene-SynWH7803_0751    127.420065   109.027969    4.568160    2.595099
# gene-SynWH7803_1456    114.936813    70.802889    3.603611    2.363206
# gene-SynWH7803_2248    388.370996   401.156606   18.671884   10.474196
# gene-SynWH7803_2444    238.529699   251.596230   11.526322    6.639062
# gene-RNA_4           15720.246614   196.319873   23.043632    7.790835
#
# SampleNames              60_R1      60_R2     120_R1     120_R2 Entity  \
# Geneid
# gene-SynWH7803_1494   0.100418   0.335150   0.574495   0.443004   host
# gene-SynWH7803_0867   0.219664   0.316408   0.342738   0.299531   host
# gene-SynWH7803_1979  20.633182  31.528438  64.263002  25.400233   host
# gene-SynWH7803_2423   0.389968   0.264222   0.434615   0.201084   host
# gene-SynWH7803_0927   0.223359   1.294770   0.580840   0.627056   host
# ...                        ...        ...        ...        ...    ...
# gene-SynWH7803_0751   0.356708   0.689256   0.927611   1.573656   host
# gene-SynWH7803_1456   0.131316   0.853479   0.614669   0.157994   host
# gene-SynWH7803_2248   1.695676   3.759828   4.742362   3.118010   host
# gene-SynWH7803_2444   1.301712   1.618911   2.680976   1.064999   host
# gene-RNA_4            1.614827  10.382021   5.543100   5.051551   host
#
# SampleNames                       Symbol ClassThreshold ClassMax      Variance
# Geneid
# gene-SynWH7803_1494  gene-SynWH7803_1494           None     None     31.900472
# gene-SynWH7803_0867  gene-SynWH7803_0867           None     None     47.373110
# gene-SynWH7803_1979                 petF           None     None   3911.949377
# gene-SynWH7803_2423  gene-SynWH7803_2423           None     None     24.398196
# gene-SynWH7803_0927  gene-SynWH7803_0927           None     None     66.857411
# ...                                  ...            ...      ...           ...
# gene-SynWH7803_0751  gene-SynWH7803_0751           None     None     83.017958
# gene-SynWH7803_1456  gene-SynWH7803_1456           None     None     70.114864
# gene-SynWH7803_2248  gene-SynWH7803_2248           None     None    271.325997
# gene-SynWH7803_2444  gene-SynWH7803_2444           None     None    169.409853
# gene-RNA_4                    gene-RNA_4           None     None  13480.618211
#
# [2812 rows x 13 columns]

# %%
logs['Variance'] = tpms['Variance']
TPMmeans['Variance'] = tpms['Variance']
TPMsds['Variance'] = tpms['Variance']
propExp['Variance'] = tpms['Variance']

# %% [markdown]
# ## 7. Write data to output

# %%
df_norRNAs[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
df_norRNAs
# Out:
# SampleNames          5_R1  5_R2  30_R1  30_R2  60_R1  60_R2  120_R1  120_R2  \
# Geneid
# gene-SynWH7803_1494   120    56     14     10      1      9       5       5
# gene-SynWH7803_0867   389   200     30     43      7     20       7       8
# gene-SynWH7803_1979  5594  3457    850    762    129    375     258     132
# gene-SynWH7803_2423    55    28     11      7      3      4       2       1
# gene-SynWH7803_0927   110    57     15     13      1     16       2       3
# ...                   ...   ...    ...    ...    ...    ...     ...     ...
# gene-SynWH7803_0751    85    44     10      9      1      5       2       5
# gene-SynWH7803_1456   209    78     22     23      1     18       4       1
# gene-SynWH7803_2248   968   608    159    142     26    111      47      40
# gene-SynWH7803_2444   365   234     60     55     12     29      16       8
# gene-RNA_4           3883    29     19     10      2     30       5       6
#
# SampleNames         Entity               Symbol
# Geneid
# gene-SynWH7803_1494   host  gene-SynWH7803_1494
# gene-SynWH7803_0867   host  gene-SynWH7803_0867
# gene-SynWH7803_1979   host                 petF
# gene-SynWH7803_2423   host  gene-SynWH7803_2423
# gene-SynWH7803_0927   host  gene-SynWH7803_0927
# ...                    ...                  ...
# gene-SynWH7803_0751   host  gene-SynWH7803_0751
# gene-SynWH7803_1456   host  gene-SynWH7803_1456
# gene-SynWH7803_2248   host  gene-SynWH7803_2248
# gene-SynWH7803_2444   host  gene-SynWH7803_2444
# gene-RNA_4            host           gene-RNA_4
#
# [2812 rows x 10 columns]

# %%
# Full TPM table
tpms.to_csv('Doron_WH7803_full_TPM.tsv', sep = '\t')
# Full raw_counts table
df_norRNAs.to_csv('Doron_WH7803_full_raw_counts.tsv', sep = '\t')
# Summarized (time point means) TPM table
TPMmeans.to_csv('Doron_WH7803_TPM_means.tsv', sep = '\t')
# Summarized (time point) TPM standard deviation
TPMsds.to_csv('Doron_WH7803_TPM_std.tsv', sep = '\t')
# Proportional expression per gene and time point
propExp.to_csv('Doron_WH7803_fractional_expression.tsv', sep = '\t')
# Processed gff3 file
gff3_host.to_csv('Doron_WH7803_host_gff3.tsv', sep='\t')
gff3_phage.to_csv('Doron_WH7803_phage_gff3.tsv', sep='\t')
