# %% [markdown]
# # Process bulk counts table
#
# 1. Annotate columns (samples) in a way that time point and replicate are annotated
# 2. Remove rRNA genes
# 3. Perform TPM normalization and alternatively also raw counts

# %%
# Use miniconda environment Jupyter_new for running this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tools import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 Load the dataset and annotation

# %%
bulkPath = '../nf_output_1/countData/countData.tsv'
metaPath = '../Meaden[1]_SraRunTable.csv' # metadata from SRA
gffPath = '../nf_output_1/alignments/dualGenome.gff3' # output from nf pipeline

# %%
# Load data
df_initial = pd.read_csv(bulkPath, sep = '\t', comment='#', index_col=0)
metadata = pd.read_csv(metaPath)

# %%
df_initial.head()
# Out:
#                               Chr  Start   End Strand  Length  \
# Geneid
# gene-R0792_RS00010  NZ_CP136842.1    199   372      -     174
# gene-R0792_RS00015  NZ_CP136842.1    456  1244      -     789
# gene-R0792_RS00020  NZ_CP136842.1   1566  2639      +    1074
# gene-R0792_RS00025  NZ_CP136842.1   2937  4355      +    1419
# gene-R0792_RS00030  NZ_CP136842.1   4508  4891      +     384
#
#                     ERR3662886_sorted.bam  ERR3662906_sorted.bam  \
# Geneid
# gene-R0792_RS00010                      5                      6
# gene-R0792_RS00015                      9                      9
# gene-R0792_RS00020                    682                   1413
# gene-R0792_RS00025                     30                     91
# gene-R0792_RS00030                    357                    524
#
#                     ERR3662884_sorted.bam  ERR3662917_sorted.bam  \
# Geneid
# gene-R0792_RS00010                     12                     11
# gene-R0792_RS00015                     18                     20
# gene-R0792_RS00020                   1480                   1906
# gene-R0792_RS00025                     75                    128
# gene-R0792_RS00030                    763                    734
#
#                     ERR3662899_sorted.bam  ...  ERR3662921_sorted.bam  \
# Geneid                                     ...
# gene-R0792_RS00010                     11  ...                      5
# gene-R0792_RS00015                     21  ...                     14
# gene-R0792_RS00020                   1110  ...                   1285
# gene-R0792_RS00025                    143  ...                     42
# gene-R0792_RS00030                    831  ...                    396
#
#                     ERR3662909_sorted.bam  ERR3662915_sorted.bam  \
# Geneid
# gene-R0792_RS00010                      6                      8
# gene-R0792_RS00015                      9                     13
# gene-R0792_RS00020                    867                   1513
# gene-R0792_RS00025                     62                     94
# gene-R0792_RS00030                    678                    650
#
#                     ERR3662882_sorted.bam  ERR3662894_sorted.bam  \
# Geneid
# gene-R0792_RS00010                     17                      8
# gene-R0792_RS00015                     23                     13
# gene-R0792_RS00020                   1645                    912
# gene-R0792_RS00025                     81                     42
# gene-R0792_RS00030                    862                    730
#
#                     ERR3662881_sorted.bam  ERR3662919_sorted.bam  \
# Geneid
# gene-R0792_RS00010                      7                      2
# gene-R0792_RS00015                      9                      6
# gene-R0792_RS00020                   1015                    804
# gene-R0792_RS00025                     44                     37
# gene-R0792_RS00030                   1086                    733
#
#                     ERR3662903_sorted.bam  ERR3662889_sorted.bam  \
# Geneid
# gene-R0792_RS00010                      5                      4
# gene-R0792_RS00015                     17                     13
# gene-R0792_RS00020                   1654                   1631
# gene-R0792_RS00025                     67                     62
# gene-R0792_RS00030                    699                    510
#
#                     ERR3662902_sorted.bam
# Geneid
# gene-R0792_RS00010                     17
# gene-R0792_RS00015                     26
# gene-R0792_RS00020                   2576
# gene-R0792_RS00025                    105
# gene-R0792_RS00030                   1433
#
# [5 rows x 50 columns]

# %%
pd.set_option('display.max_columns', None)  # Show all columns
metadata
# Out:
#            Run Assay Type  AvgSpotLen       Bases  BioProject     BioSample  \
# 0   ERR3662878    RNA-Seq         271  1238110357  PRJEB31514  SAMEA6168783
# 1   ERR3662879    RNA-Seq         269  1659636862  PRJEB31514  SAMEA6168784
# 2   ERR3662880    RNA-Seq         271  1404460424  PRJEB31514  SAMEA6168785
# 3   ERR3662881    RNA-Seq         272  1251664016  PRJEB31514  SAMEA6168786
# 4   ERR3662882    RNA-Seq         273  1442850885  PRJEB31514  SAMEA6168787
# 5   ERR3662883    RNA-Seq         274  1389826662  PRJEB31514  SAMEA6168788
# 6   ERR3662884    RNA-Seq         274  1489030189  PRJEB31514  SAMEA6168789
# 7   ERR3662885    RNA-Seq         271  2221240172  PRJEB31514  SAMEA6168790
# 8   ERR3662886    RNA-Seq         273  1113741473  PRJEB31514  SAMEA6168791
# 9   ERR3662887    RNA-Seq         274  1559538851  PRJEB31514  SAMEA6168792
# 10  ERR3662888    RNA-Seq         273  1387292208  PRJEB31514  SAMEA6168793
# 11  ERR3662889    RNA-Seq         270  1682219847  PRJEB31514  SAMEA6168794
# 12  ERR3662890    RNA-Seq         281  1226581032  PRJEB31514  SAMEA6168795
# 13  ERR3662891    RNA-Seq         274  1394498267  PRJEB31514  SAMEA6168796
# 14  ERR3662892    RNA-Seq         274  1222009671  PRJEB31514  SAMEA6168797
# 15  ERR3662893    RNA-Seq         275  1257467641  PRJEB31514  SAMEA6168798
# 16  ERR3662894    RNA-Seq         276  1231547383  PRJEB31514  SAMEA6168799
# 17  ERR3662895    RNA-Seq         269  1539485523  PRJEB31514  SAMEA6168800
# 18  ERR3662896    RNA-Seq         270  2217185186  PRJEB31514  SAMEA6168801
# 19  ERR3662897    RNA-Seq         277  1259473443  PRJEB31514  SAMEA6168802
# 20  ERR3662898    RNA-Seq         277  1090908014  PRJEB31514  SAMEA6168803
# 21  ERR3662899    RNA-Seq         275  1221049675  PRJEB31514  SAMEA6168804
# 22  ERR3662900    RNA-Seq         272  1330878311  PRJEB31514  SAMEA6168805
# 23  ERR3662901    RNA-Seq         283   965366575  PRJEB31514  SAMEA6168806
# 24  ERR3662902    RNA-Seq         277  1731273815  PRJEB31514  SAMEA6168807
# 25  ERR3662903    RNA-Seq         274  1302760836  PRJEB31514  SAMEA6168808
# 26  ERR3662904    RNA-Seq         270  1162751334  PRJEB31514  SAMEA6168809
# 27  ERR3662905    RNA-Seq         272  1339447060  PRJEB31514  SAMEA6168810
# 28  ERR3662906    RNA-Seq         272  1242679919  PRJEB31514  SAMEA6168811
# 29  ERR3662907    RNA-Seq         273  1040935624  PRJEB31514  SAMEA6168812
# 30  ERR3662908    RNA-Seq         279  1105571830  PRJEB31514  SAMEA6168813
# 31  ERR3662909    RNA-Seq         274  1155886117  PRJEB31514  SAMEA6168814
# 12        SM20  ERP114085         SM20  Pseudomonas aeruginosa
# 13        SM21  ERP114085         SM21  Pseudomonas aeruginosa
# 14        SM22  ERP114085         SM22  Pseudomonas aeruginosa
# 15        SM23  ERP114085         SM23  Pseudomonas aeruginosa
# 16        SM24  ERP114085         SM24  Pseudomonas aeruginosa
# 17        SM25  ERP114085         SM25  Pseudomonas aeruginosa
# 18        SM26  ERP114085         SM26  Pseudomonas aeruginosa
# 19        SM27  ERP114085         SM27  Pseudomonas aeruginosa
# 20        SM28  ERP114085         SM28  Pseudomonas aeruginosa
# 21        SM29  ERP114085         SM29  Pseudomonas aeruginosa
# 22         SM3  ERP114085          SM3  Pseudomonas aeruginosa
# 23        SM30  ERP114085         SM30  Pseudomonas aeruginosa
# 24        SM31  ERP114085         SM31  Pseudomonas aeruginosa
# 25        SM32  ERP114085         SM32  Pseudomonas aeruginosa
# 26        SM33  ERP114085         SM33  Pseudomonas aeruginosa
# 27        SM34  ERP114085         SM34  Pseudomonas aeruginosa
# 28        SM35  ERP114085         SM35  Pseudomonas aeruginosa
# 29        SM36  ERP114085         SM36  Pseudomonas aeruginosa
# 30        SM37  ERP114085         SM37  Pseudomonas aeruginosa
# 31        SM38  ERP114085         SM38  Pseudomonas aeruginosa
# 32        SM39  ERP114085         SM39  Pseudomonas aeruginosa
# 33         SM4  ERP114085          SM4  Pseudomonas aeruginosa
# 34        SM40  ERP114085         SM40  Pseudomonas aeruginosa
# 35        SM41  ERP114085         SM41  Pseudomonas aeruginosa
# 36        SM42  ERP114085         SM42  Pseudomonas aeruginosa
# 37        SM43  ERP114085         SM43  Pseudomonas aeruginosa
# 38        SM44  ERP114085         SM44  Pseudomonas aeruginosa
# 39        SM45  ERP114085         SM45  Pseudomonas aeruginosa
# 40         SM5  ERP114085          SM5  Pseudomonas aeruginosa
# 41         SM6  ERP114085          SM6  Pseudomonas aeruginosa
# 42         SM7  ERP114085          SM7  Pseudomonas aeruginosa
# 43         SM8  ERP114085          SM8  Pseudomonas aeruginosa
# 44         SM9  ERP114085          SM9  Pseudomonas aeruginosa

# %% [markdown]
# ## 2 Format the dataset

# %% [markdown]
# ### 2.1 Annotate sample names

# %% [markdown]
# Issue now is that the metadata does not properly annotate sample names. Thus, this will be done manually by adding another sample name column to the metadata.

# %%
# Match GSM IDs and SampleNames inferred from GEO

sampleDict = {
    'SAMEA6168783': 'bim-phage-35_R1',
    'SAMEA6168784': 'bim-con-35_R4',
    'SAMEA6168785': 'wt-phage-35_R3',
    'SAMEA6168786': 'wt-phage-35_R4',
    'SAMEA6168787': 'bim-phage-60_R1',
    'SAMEA6168788': 'bim-phage-60_R2',
    'SAMEA6168789': 'bim-con-60_R1',
    'SAMEA6168790': 'bim-con-60_R2',
    'SAMEA6168791': 'wt-phage-60_R1',
    'SAMEA6168792': 'wt-phage-60_R2',
    'SAMEA6168793': 'bim-phage-60_R3',
    'SAMEA6168794': 'bim-con-35_R1',
    'SAMEA6168795': 'bim-phage-60_R4',
    'SAMEA6168796': 'bim-con-60_R3',
    'SAMEA6168797': 'bim-con-60_R4',
    'SAMEA6168798': 'wt-phage-60_R3',
    'SAMEA6168799': 'wt-phage-60_R4',
    'SAMEA6168800': 'bim-phage-120_R1',
    'SAMEA6168801': 'bim-phage-120_R2',
    'SAMEA6168802': 'bim-con-120_R1',
    'SAMEA6168803': 'bim-con-120_R2',
    'SAMEA6168804': 'wt-phage-120_R1',
    'SAMEA6168805': 'wt-phage-35_R1',
    'SAMEA6168806': 'wt-phage-120_R2',
    'SAMEA6168807': 'bim-phage-35_R5',
    'SAMEA6168808': 'bim-con-35_R5',
    'SAMEA6168809': 'bim-con-60_R5',
    'SAMEA6168810': 'bim-con-120_R3',
    'SAMEA6168811': 'bim-con-120_R4',
    'SAMEA6168812': 'bim-con-120_R5',
    'SAMEA6168813': 'wt-phage-35_R5',
    'SAMEA6168814': 'wt-phage-120_R5',
    'SAMEA6168815': 'wt-phage-120_R3',
    'SAMEA6168816': 'bim-phage-35_R2',
    'SAMEA6168817': 'wt-phage-120_R4',
    'SAMEA6168818': 'wt-phage-120_R6',
    'SAMEA6168819': 'bim-phage-60_R5',
    'SAMEA6168820': 'bim-phage-120_R3',
    'SAMEA6168821': 'bim-phage-120_R4',
    'SAMEA6168822': 'bim-phage-120_R5',
    'SAMEA6168823': 'bim-con-35_R2',
    'SAMEA6168824': 'wt-phage-35_R2',
    'SAMEA6168825': 'bim-phage-35_R3',
    'SAMEA6168826': 'bim-phage-35_R4',
    'SAMEA6168827': 'bim-con-35_R3'
}

#

# %%
metadataFull = annotateData(metadata, sampleDict)

# %%
metadata.head(1)
# Out:
#           Run Assay Type  AvgSpotLen       Bases  BioProject     BioSample  \
# 0  ERR3662878    RNA-Seq         271  1238110357  PRJEB31514  SAMEA6168783
#
#        Bytes           Center Name Consent DATASTORE filetype  \
# 0  421926880  UNIVERSITY OF EXETER  public   fastq,run.zq,sra
#
#   DATASTORE provider                      DATASTORE region  \
# 0         gs,ncbi,s3  gs.us-east1,ncbi.public,s3.us-east-1
#
#   ENA-FIRST-PUBLIC (run) ENA_first_public ENA-LAST-UPDATE (run)  \
# 0             2021-06-30       2021-06-30            2021-06-30
#
#   ENA_last_update  Experiment   external_id    INSDC_center_alias  \
# 0      2021-06-30  ERX3654518  SAMEA6168783  UNIVERSITY OF EXETER
#
#       INSDC_center_name    INSDC_first_public     INSDC_last_update  \
# 0  University of Exeter  2021-06-30T00:31:21Z  2021-06-30T00:31:21Z
#
#   INSDC_status             Instrument Library Name LibraryLayout  \
# 0       public  Illumina NovaSeq 6000  unspecified        PAIRED
#
#   LibrarySelection   LibrarySource                Organism  Platform  \
# 0           RT-PCR  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA
#
#             ReleaseDate           create_date  version   Sample Name  \
# 0  2021-06-30T00:00:00Z  2021-07-21T01:39:00Z        1  SAMEA6168783
#
#   Sample_name  SRA Study Submitter_Id             common_name
# 0         SM1  ERP114085          SM1  Pseudomonas aeruginosa

# %%
metadataFull.head()
# Out:
#                               Run Assay Type  AvgSpotLen       Bases  \
# SampleID
# ERR3662878_sorted.bam  ERR3662878    RNA-Seq         271  1238110357
# ERR3662879_sorted.bam  ERR3662879    RNA-Seq         269  1659636862
# ERR3662880_sorted.bam  ERR3662880    RNA-Seq         271  1404460424
# ERR3662881_sorted.bam  ERR3662881    RNA-Seq         272  1251664016
# ERR3662882_sorted.bam  ERR3662882    RNA-Seq         273  1442850885
#
#                        BioProject     BioSample      Bytes  \
# SampleID
# ERR3662878_sorted.bam  PRJEB31514  SAMEA6168783  421926880
# ERR3662879_sorted.bam  PRJEB31514  SAMEA6168784  573146397
# ERR3662880_sorted.bam  PRJEB31514  SAMEA6168785  482335697
# ERR3662881_sorted.bam  PRJEB31514  SAMEA6168786  430081701
# ERR3662882_sorted.bam  PRJEB31514  SAMEA6168787  499252134
#
#                                 Center Name Consent DATASTORE filetype  \
# SampleID
# ERR3662878_sorted.bam  UNIVERSITY OF EXETER  public   fastq,run.zq,sra
# ERR3662879_sorted.bam  UNIVERSITY OF EXETER  public   fastq,run.zq,sra
# ERR3662880_sorted.bam  UNIVERSITY OF EXETER  public   fastq,run.zq,sra
# ERR3662881_sorted.bam  UNIVERSITY OF EXETER  public   fastq,run.zq,sra
# ERR3662882_sorted.bam  UNIVERSITY OF EXETER  public   fastq,run.zq,sra
#
#                       DATASTORE provider  \
# SampleID
# ERR3662878_sorted.bam         gs,ncbi,s3
# ERR3662879_sorted.bam         gs,ncbi,s3
# ERR3662880_sorted.bam         gs,ncbi,s3
# ERR3662881_sorted.bam         gs,ncbi,s3
# ERR3662882_sorted.bam         gs,ncbi,s3
#
#                                            DATASTORE region  \
# SampleID
# ERR3662878_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1
# ERR3662879_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1
# ERR3662880_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1
# ERR3662881_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1
# ERR3662882_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1
#
#                       ENA-FIRST-PUBLIC (run) ENA_first_public  \
# SampleID
# ERR3662878_sorted.bam             2021-06-30       2021-06-30
# ERR3662879_sorted.bam             2021-06-30       2021-06-30
# ERR3662880_sorted.bam             2021-06-30       2021-06-30
# ERR3662881_sorted.bam             2021-06-30       2021-06-30
# ERR3662882_sorted.bam             2021-06-30       2021-06-30
#
#                       ENA-LAST-UPDATE (run) ENA_last_update  Experiment  \
# SampleID
# ERR3662878_sorted.bam            2021-06-30      2021-06-30  ERX3654518
# ERR3662879_sorted.bam            2021-06-30      2021-06-30  ERX3654519
# ERR3662880_sorted.bam            2021-06-30      2021-06-30  ERX3654520
# ERR3662881_sorted.bam            2021-06-30      2021-06-30  ERX3654521
# ERR3662882_sorted.bam            2021-06-30      2021-06-30  ERX3654522
#
#                         external_id    INSDC_center_alias  \
# SampleID
# ERR3662878_sorted.bam  SAMEA6168783  UNIVERSITY OF EXETER
# ERR3662879_sorted.bam  SAMEA6168784  UNIVERSITY OF EXETER
# ERR3662880_sorted.bam  SAMEA6168785  UNIVERSITY OF EXETER
# ERR3662881_sorted.bam  SAMEA6168786  UNIVERSITY OF EXETER
# ERR3662882_sorted.bam  SAMEA6168787  UNIVERSITY OF EXETER
#
#                           INSDC_center_name    INSDC_first_public  \
# SampleID
# ERR3662878_sorted.bam  University of Exeter  2021-06-30T00:31:21Z
# ERR3662879_sorted.bam  University of Exeter  2021-06-30T00:31:21Z
# ERR3662880_sorted.bam  University of Exeter  2021-06-30T00:31:21Z
# ERR3662881_sorted.bam  University of Exeter  2021-06-30T00:31:21Z
# ERR3662882_sorted.bam  University of Exeter  2021-06-30T00:31:21Z
#
#                           INSDC_last_update INSDC_status  \
# SampleID
# ERR3662878_sorted.bam  2021-06-30T00:31:21Z       public
# ERR3662879_sorted.bam  2021-06-30T00:31:21Z       public
# ERR3662880_sorted.bam  2021-06-30T00:31:21Z       public
# ERR3662881_sorted.bam  2021-06-30T00:31:21Z       public
# ERR3662882_sorted.bam  2021-06-30T00:31:21Z       public
#
#                                   Instrument Library Name LibraryLayout  \
# SampleID
# ERR3662878_sorted.bam  Illumina NovaSeq 6000  unspecified        PAIRED
# ERR3662879_sorted.bam  Illumina NovaSeq 6000  unspecified        PAIRED
# ERR3662880_sorted.bam  Illumina NovaSeq 6000  unspecified        PAIRED
# ERR3662881_sorted.bam  Illumina NovaSeq 6000  unspecified        PAIRED
# ERR3662882_sorted.bam  Illumina NovaSeq 6000  unspecified        PAIRED
#
#                       LibrarySelection   LibrarySource  \
# SampleID
# ERR3662878_sorted.bam           RT-PCR  TRANSCRIPTOMIC
# ERR3662879_sorted.bam           RT-PCR  TRANSCRIPTOMIC
# ERR3662880_sorted.bam           RT-PCR  TRANSCRIPTOMIC
# ERR3662881_sorted.bam           RT-PCR  TRANSCRIPTOMIC
# ERR3662882_sorted.bam           RT-PCR  TRANSCRIPTOMIC
#
#                                      Organism  Platform           ReleaseDate  \
# SampleID
# ERR3662878_sorted.bam  Pseudomonas aeruginosa  ILLUMINA  2021-06-30T00:00:00Z
# ERR3662879_sorted.bam  Pseudomonas aeruginosa  ILLUMINA  2021-06-30T00:00:00Z
# ERR3662880_sorted.bam  Pseudomonas aeruginosa  ILLUMINA  2021-06-30T00:00:00Z
# ERR3662881_sorted.bam  Pseudomonas aeruginosa  ILLUMINA  2021-06-30T00:00:00Z
# ERR3662882_sorted.bam  Pseudomonas aeruginosa  ILLUMINA  2021-06-30T00:00:00Z
#
#                                 create_date  version   Sample Name  \
# SampleID
# ERR3662878_sorted.bam  2021-07-21T01:39:00Z        1  SAMEA6168783
# ERR3662879_sorted.bam  2021-07-21T01:39:00Z        1  SAMEA6168784
# ERR3662880_sorted.bam  2021-07-21T01:36:00Z        1  SAMEA6168785
# ERR3662881_sorted.bam  2021-07-21T01:35:00Z        1  SAMEA6168786
# ERR3662882_sorted.bam  2021-07-21T01:39:00Z        1  SAMEA6168787
#
#                       Sample_name  SRA Study Submitter_Id  \
# SampleID
# ERR3662878_sorted.bam         SM1  ERP114085          SM1
# ERR3662879_sorted.bam        SM10  ERP114085         SM10
# ERR3662880_sorted.bam        SM11  ERP114085         SM11
# ERR3662881_sorted.bam        SM12  ERP114085         SM12
# ERR3662882_sorted.bam        SM13  ERP114085         SM13
#
#                                   common_name               SampleID  \
# SampleID
# ERR3662878_sorted.bam  Pseudomonas aeruginosa  ERR3662878_sorted.bam
# ERR3662879_sorted.bam  Pseudomonas aeruginosa  ERR3662879_sorted.bam
# ERR3662880_sorted.bam  Pseudomonas aeruginosa  ERR3662880_sorted.bam
# ERR3662881_sorted.bam  Pseudomonas aeruginosa  ERR3662881_sorted.bam
# ERR3662882_sorted.bam  Pseudomonas aeruginosa  ERR3662882_sorted.bam
#
#                            SampleNames
# SampleID
# ERR3662878_sorted.bam  bim-phage-35_R1
# ERR3662879_sorted.bam    bim-con-35_R4
# ERR3662880_sorted.bam   wt-phage-35_R3
# ERR3662881_sorted.bam   wt-phage-35_R4
# ERR3662882_sorted.bam  bim-phage-60_R1

# %% [markdown]
# Add correct sample names.

# %%
samples = [

    # bim_phage
    'bim-phage-35_R1', 'bim-phage-35_R2', 'bim-phage-35_R3', 'bim-phage-35_R4', 'bim-phage-35_R5',
    'bim-phage-60_R1', 'bim-phage-60_R2', 'bim-phage-60_R3', 'bim-phage-60_R4', 'bim-phage-60_R5',
    'bim-phage-120_R1', 'bim-phage-120_R2', 'bim-phage-120_R3', 'bim-phage-120_R4', 'bim-phage-120_R5',

    # bim_con
    #' bim-con-35_R1', 'bim-con-35_R2', 'bim-con-35_R3', 'bim-con-35_R4', 'bim-con-35_R5',
    # 'bim-con-60_R1', 'bim-con-60_R2', 'bim-con-60_R3', 'bim-con-60_R4', 'bim-con-60_R5',
    # 'bim-con-120_R1', 'bim-con-120_R2', 'bim-con-120_R3', 'bim-con-120_R4', 'bim-con-120_R5',

    # wt_phage
    # 'wt-phage-35_R1', 'wt-phage-35_R3', 'wt-phage-35_R4', 'wt-phage-35_R5',
    # 'wt-phage-60_R1', 'wt-phage-60_R2', 'wt-phage-60_R3', 'wt-phage-60_R4',
    # 'wt-phage-120_R1', 'wt-phage-120_R2', 'wt-phage-120_R3', 'wt-phage-120_R4'
]

df = changeColnames(df_initial.iloc[:,5:df_initial.shape[1]], metadataFull)
df = df[samples]
df
# Out:
# SampleNames         bim-phage-35_R1  bim-phage-35_R2  bim-phage-35_R3  \
# Geneid
# gene-R0792_RS00010                5               11               11
# gene-R0792_RS00015                5               23                9
# gene-R0792_RS00020              869             1472             1996
# gene-R0792_RS00025               37               64               57
# gene-R0792_RS00030              194              718              864
# ...                             ...              ...              ...
# gene-DMS3-48                      2                0                1
# gene-DMS3-49                      1                2                1
# gene-DMS3-50                      0                0                0
# gene-DMS3-51                      0                0                1
# gene-DMS3-52                      2                0                0
#
# SampleNames         bim-phage-35_R4  bim-phage-35_R5  bim-phage-60_R1  \
# Geneid
# gene-R0792_RS00010                5               17               17
# gene-R0792_RS00015               14               26               23
# gene-R0792_RS00020             1285             2576             1645
# gene-R0792_RS00025               42              105               81
# gene-R0792_RS00030              396             1433              862
# ...                             ...              ...              ...
# gene-DMS3-48                      2                4                3
# gene-DMS3-49                      1                2                2
# gene-DMS3-50                      0                1                1
# gene-DMS3-51                      0                1                1
# gene-DMS3-52                      1                0                5
#
# SampleNames         bim-phage-60_R2  bim-phage-60_R3  bim-phage-60_R4  \
# Geneid
# gene-R0792_RS00010                8               12               24
# gene-R0792_RS00015               14               17               33
# gene-R0792_RS00020             1355             1768             1743
# gene-R0792_RS00025               56               83               74
# gene-R0792_RS00030              662              911             1007
# ...                             ...              ...              ...
# gene-DMS3-48                      4                6                5
# gene-DMS3-49                      0                0                1
# gene-DMS3-50                      2                0                0
# gene-DMS3-51                      1                0                1
# gene-DMS3-52                      2                3                3
#
# SampleNames         bim-phage-60_R5  bim-phage-120_R1  bim-phage-120_R2  \
# Geneid
# gene-R0792_RS00010               13                12                29
# gene-R0792_RS00015               18                18                56
# gene-R0792_RS00020             1760              2494              3554
# gene-R0792_RS00025               75               174               242
# gene-R0792_RS00030              568               930              1937
# ...                             ...               ...               ...
# gene-DMS3-48                      4                 3                 3
# gene-DMS3-49                      0                 2                 4
# gene-DMS3-50                      0                 1                 1
# gene-DMS3-51                      0                 0                 1
# gene-DMS3-52                      1                 2                 0
#
# SampleNames         bim-phage-120_R3  bim-phage-120_R4  bim-phage-120_R5
# Geneid
# gene-R0792_RS00010                 8                 9                11
# gene-R0792_RS00015                13                34                20
# gene-R0792_RS00020              1513              2287              1906
# gene-R0792_RS00025                94               152               128
# gene-R0792_RS00030               650               874               734
# ...                              ...               ...               ...
# gene-DMS3-48                       2                 2                 5
# gene-DMS3-49                       2                 0                 0
# gene-DMS3-50                       1                 1                 0
# gene-DMS3-51                       0                 1                 0
# gene-DMS3-52                       1                 4                 1
#
# [6023 rows x 15 columns]

# %% [markdown]
# ### 2.2 Remove rRNA genes
#
# Consult gff3 file to get rRNA geneids.

# %%
# Load gff3 and split into genes and CDS dfs
gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3.columns=["seq_id", "source", "type", "start", "end", "phase", "strand", "score", "attributes"]
gff3_genes = gff3.loc[gff3["type"] == 'gene']

# Column formating for genes
gff3_genes = gff3_genes.reset_index(drop=True)
dct_genes = gff3_genes["attributes"].str.split(';').apply(lambda items: dict(item.split('=', 1) for item in items if '=' in item))
cols_to_keep = ['ID', 'Name', 'gbkey', 'gene_biotype', 'locus_tag', 'gene']
gff3_genes = pd.concat([gff3_genes, pd.json_normalize(dct_genes)[cols_to_keep]], axis=1)

# Generate locus_tag, product dictonary over all different feature types
attrs = gff3["attributes"].str.split(";", expand=True)
attrs_dicts = attrs.apply(lambda row: {item.split("=")[0]: item.split("=")[1] for item in row if "=" in str(item)}, axis=1)
attrs_df = pd.json_normalize(attrs_dicts)
attrs_df = attrs_df.dropna(subset=["locus_tag", "product"])
locus_product_dict = dict(zip(attrs_df["locus_tag"], attrs_df["product"]))

# Add gene product, if not stated in gff3, fill with gene_biotype
gff3_genes["product"] = gff3_genes["locus_tag"].map(locus_product_dict)
# gff3_genes["product"] = gff3_genes["product"].fillna("other")
gff3_genes["product"] = gff3_genes["product"].fillna(gff3_genes["gene_biotype"])

# If gene = NA, take from ID column
gff3_genes["gene"] = gff3_genes["gene"].fillna(gff3_genes["ID"])

# Drop attributes column
gff3_genes = gff3_genes.drop(["attributes"], axis=1)

# %%
pharokka_path = "../../../2025-12_reannotation_phage_genomes/Pharokka_proteins_phages_out/NC_008717.1_out/pharokka_proteins_full_merged_output.tsv"
gff3_genes = add_pharokka(gff3_genes, pharokka_path)
gff3_genes.loc[gff3_genes['seq_id'] == "NC_008717.1"]
# Out:
#            seq_id  source  type    start      end phase strand score  \
# 5971  NC_008717.1  RefSeq  gene    170.0    880.0     .      -     .
# 5972  NC_008717.1  RefSeq  gene   1428.0   1862.0     .      +     .
# 5973  NC_008717.1  RefSeq  gene   1862.0   2071.0     .      +     .
# 5974  NC_008717.1  RefSeq  gene   2175.0   4136.0     .      +     .
# 5975  NC_008717.1  RefSeq  gene   4151.0   4903.0     .      +     .
# 5976  NC_008717.1  RefSeq  gene   4900.0   5565.0     .      +     .
# 5977  NC_008717.1  RefSeq  gene   5637.0   6272.0     .      +     .
# 5978  NC_008717.1  RefSeq  gene   6257.0   6373.0     .      +     .
# 5979  NC_008717.1  RefSeq  gene   6373.0   6786.0     .      +     .
# 5980  NC_008717.1  RefSeq  gene   6788.0   7060.0     .      +     .
# 5981  NC_008717.1  RefSeq  gene   7077.0   7595.0     .      +     .
# 5982  NC_008717.1  RefSeq  gene   7597.0   7878.0     .      +     .
# 5983  NC_008717.1  RefSeq  gene   7906.0   8187.0     .      +     .
# 5984  NC_008717.1  RefSeq  gene   8190.0   8471.0     .      +     .
# 5985  NC_008717.1  RefSeq  gene   8473.0   8679.0     .      +     .
# 5986  NC_008717.1  RefSeq  gene   8682.0   8951.0     .      +     .
# 5987  NC_008717.1  RefSeq  gene   9136.0   9318.0     .      +     .
# 5988  NC_008717.1  RefSeq  gene   9315.0   9722.0     .      +     .
# 5989  NC_008717.1  RefSeq  gene   9709.0  10158.0     .      +     .
# 5990  NC_008717.1  RefSeq  gene  10553.0  11023.0     .      +     .
# 5991  NC_008717.1  RefSeq  gene  11023.0  11439.0     .      +     .
# 5992  NC_008717.1  RefSeq  gene  11555.0  11956.0     .      +     .
# 5993  NC_008717.1  RefSeq  gene  12067.0  12255.0     .      +     .
# 5994  NC_008717.1  RefSeq  gene  12263.0  12763.0     .      +     .
# 5995  NC_008717.1  RefSeq  gene  12769.0  13296.0     .      -     .
# 5996  NC_008717.1  RefSeq  gene  13295.0  14947.0     .      +     .
# 5997  NC_008717.1  RefSeq  gene  14957.0  16537.0     .      +     .
# 5998  NC_008717.1  RefSeq  gene  16537.0  17823.0     .      +     .
# 5999  NC_008717.1  RefSeq  gene  17823.0  18290.0     .      +     .
# 6000  NC_008717.1  RefSeq  gene  18401.0  18607.0     .      +     .
# 6001  NC_008717.1  RefSeq  gene  18597.0  18818.0     .      +     .
# 6002  NC_008717.1  RefSeq  gene  19163.0  20134.0     .      +     .
# 6003  NC_008717.1  RefSeq  gene  20138.0  21052.0     .      +     .
# 6004  NC_008717.1  RefSeq  gene  21119.0  21460.0     .      +     .
# 6005  NC_008717.1  RefSeq  gene  21460.0  21627.0     .      +     .
# 6006  NC_008717.1  RefSeq  gene  21624.0  22040.0     .      +     .
# 6021  gene-DMS3-51  DMS3-51  Gene  protein_coding   DMS3-51  gene-DMS3-51
# 6022  gene-DMS3-52  DMS3-52  Gene  protein_coding   DMS3-52  gene-DMS3-52
#
#                                                 product  \
# 5971                          transcriptional repressor
# 5972                          transcriptional regulator
# 5973                               hypothetical protein
# 5974                                        transposase
# 5975                          DNA transposition protein
# 5976                          transcriptional regulator
# 5977                               hypothetical protein
# 5978                               hypothetical protein
# 5979                               hypothetical protein
# 5980                               hypothetical protein
# 5981                            host nuclease inhibitor
# 5982                            host nuclease inhibitor
# 5983                               hypothetical protein
# 5984                               hypothetical protein
# 5985                               hypothetical protein
# 5986                               hypothetical protein
# 5987                               hypothetical protein
# 5988                            regulatory protein GemA
# 5989                     late transcriptional activator
# 5990                               hypothetical protein
# 5991                                          endolysin
# 5992                                     Rz-like spanin
# 5993                               hypothetical protein
# 5994                                DNA binding protein
# 5995                               hypothetical protein
# 5996                            terminase large subunit
# 5997                                     portal protein
# 5998                   minor head protein and DNA pilot
# 5999                   tail completion or Neck1 protein
# 6000                       type I-E anti-CRISPR protein
# 6001  winged helix-turn-helix domain-containing protein
# 6002                           head maturation protease
# 6003                                 major head protein
# 6004                               hypothetical protein
# 6005                               hypothetical protein
# 6006                                  head-tail adaptor
# 6007                                     portal protein
# 6008                               hypothetical protein
# 6009             major tail protein with Ig-like domain
# 6010                            tail assembly chaperone
# 6011                   tail length tape measure protein
# 6012                               hypothetical protein
# 6013                                 structural protein
# 6014                              tail assembly protein
# 6015                              tail assembly protein
# 6016                            tail assembly chaperone
# 6017                            tail assembly chaperone
# 6018                                       tail protein
# 6019                                 tail fiber protein
# 6020                               hypothetical protein
# 6021                               hypothetical protein
# 6022                               hypothetical protein
#
#                                        annot    PHROG  \
# 5971               transcriptional repressor      4.0
# 5972               transcriptional regulator   2345.0
# 5973                    hypothetical protein   4468.0
# 5974                             transposase    310.0
# 5975               DNA transposition protein    296.0
# 5976               transcriptional regulator   2030.0
# 5977                    hypothetical protein   3190.0
# 5978                    hypothetical protein   3765.0
# 5979                    hypothetical protein   2119.0
# 5980                    hypothetical protein   2043.0
# 5981                 host nuclease inhibitor  18351.0
# 5982                 host nuclease inhibitor   1518.0
# 5983                    hypothetical protein   4367.0
# 5984                    hypothetical protein  12417.0
# 5985                    hypothetical protein  12417.0
# 5986                    hypothetical protein   3652.0
# 5987                    hypothetical protein  14676.0
# 5988                    hypothetical protein    286.0
# 5989          late transcriptional activator    836.0
# 5990                    hypothetical protein   1024.0
# 5991                               endolysin    873.0
# 5992                          Rz-like spanin   2975.0
# 5993                    hypothetical protein   1103.0
# 5994                     DNA binding protein    756.0
# 5995                    hypothetical protein   1244.0
# 5996                 terminase large subunit     38.0
# 5997                          portal protein    113.0
# 5998        minor head protein and DNA pilot    220.0
# 5999        tail completion or Neck1 protein     26.0
# 6000            type I-E anti-CRISPR protein   8786.0
# 6001                    hypothetical protein   3865.0
# 6002                head maturation protease    328.0
# 6003                      major head protein    371.0
# 6004                    hypothetical protein   4833.0
# 6005                    hypothetical protein   3376.0
# 6006                       head-tail adaptor    195.0
# 6007                          portal protein    209.0
# 6008                    hypothetical protein   3129.0
# 6009  major tail protein with Ig-like domain    807.0
# 6010                 tail assembly chaperone   1442.0
# 6011        tail length tape measure protein   2335.0
# 6012                    hypothetical protein  36425.0
# 6013                      structural protein    687.0
# 6014                   tail assembly protein   1082.0
# 6015                   tail assembly protein    778.0
# 6016                 tail assembly chaperone   1180.0
# 6017                 tail assembly chaperone   1196.0
# 6018                            tail protein   1101.0
# 6019                      tail fiber protein  14458.0
# 6020                    hypothetical protein   2398.0
# 6021                    hypothetical protein   2687.0
# 6022                    hypothetical protein   2623.0
#
#                                                category
# 5971                           transcription regulation
# 5972                           transcription regulation
# 5973                                   unknown function
# 5974                           integration and excision
# 5975                           integration and excision
# 5976                           transcription regulation
# 5977                                   unknown function
# 5978                                   unknown function
# 5979                                   unknown function
# 5980                                   unknown function
# 5981  moron, auxiliary metabolic gene and host takeover
# 5982  moron, auxiliary metabolic gene and host takeover
# 5983                                   unknown function
# 5984                                   unknown function
# 5985                                   unknown function
# 5986                                   unknown function
# 5987                                   unknown function
# 5988                                   unknown function
# 5989                           transcription regulation
# 5990                                   unknown function
# 5991                                 head and packaging
# 5992                                              lysis
# 5993                                   unknown function
# 5994                 DNA, RNA and nucleotide metabolism
# 5995                                   unknown function
# 5996                                 head and packaging
# 5997                                 head and packaging
# 5998                                 head and packaging
# 5999                                          connector
# 6000  moron, auxiliary metabolic gene and host takeover
# 6001                                   unknown function
# 6002                                 head and packaging
# 6003                                 head and packaging
# 6004                                   unknown function
# 6005                                   unknown function
# 6006                                          connector
# 6007                                 head and packaging
# 6008                                   unknown function
# 6009                                               tail
# 6010                                               tail
# 6011                                               tail
# 6012                                   unknown function
# 6013                                 head and packaging
# 6014                                               tail
# 6015                                               tail
# 6016                                               tail
# 6017                                               tail
# 6018                                               tail
# 6019                                               tail
# 6020                                   unknown function
# 6021                                   unknown function
# 6022                                   unknown function

# %%
# Load ggf3 file

gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3 = gff3.loc[gff3.iloc[:,2] == 'gene']

# Format some new columns
gff3['ID'] = pd.DataFrame(gff3.iloc[:,8].str.split('ID=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['GeneType'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene_biotype=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['Symbol'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]

# Add entity host and phage
gff3['Entity'] = np.where(gff3[0] == 'NC_008717.1', 'phage', 'host')
gff3.index = gff3['ID']
rRNAs = gff3.loc[gff3['GeneType'] == 'rRNA', 'ID'].tolist()

# %% [markdown]
# Perform in silico rRNA depletion.

# %%
df_norRNAs = rRNAdepletion(df,rRNAs)
df_norRNAs
# Out:
# SampleNames         bim-phage-35_R1  bim-phage-35_R2  bim-phage-35_R3  \
# Geneid
# gene-R0792_RS24585              326              565              782
# gene-R0792_RS14545               12               38               43
# gene-R0792_RS28890               54              193              226
# gene-R0792_RS01605              113              131              207
# gene-R0792_RS21865               70              194              208
# ...                             ...              ...              ...
# gene-R0792_RS22495               24               98              115
# gene-R0792_RS04325              121              147              190
# gene-R0792_RS12130               18               27               30
# gene-R0792_RS16410               10               15               17
# gene-R0792_RS28970              205              290              339
#
# SampleNames         bim-phage-35_R4  bim-phage-35_R5  bim-phage-60_R1  \
# Geneid
# gene-R0792_RS24585              473              956              660
# gene-R0792_RS14545               25              106               86
# gene-R0792_RS28890               95              532              547
# gene-R0792_RS01605              113              198              137
# gene-R0792_RS21865              122              239              149
# ...                             ...              ...              ...
# gene-R0792_RS22495               52              270              169
# gene-R0792_RS04325              167              218              199
# gene-R0792_RS12130               24               58               56
# gene-R0792_RS16410               12               31               27
# gene-R0792_RS28970              260              502              354
#
# SampleNames         bim-phage-60_R2  bim-phage-60_R3  bim-phage-60_R4  \
# Geneid
# gene-R0792_RS24585              571              659              671
# gene-R0792_RS14545               56               88              115
# gene-R0792_RS28890              188              294              313
# gene-R0792_RS01605              198              208              178
# gene-R0792_RS21865              136              185              176
# ...                             ...              ...              ...
# gene-R0792_RS22495              112              173              192
# gene-R0792_RS04325              151              190              181
# gene-R0792_RS12130               31               36               48
# gene-R0792_RS16410               14               30               31
# gene-R0792_RS28970              301              363              397
#
# SampleNames         bim-phage-60_R5  bim-phage-120_R1  bim-phage-120_R2  \
# Geneid
# gene-R0792_RS24585              643               819              1256
# gene-R0792_RS14545               43                81               211
# gene-R0792_RS28890              216               352               753
# gene-R0792_RS01605              164               212               402
# gene-R0792_RS21865              147               218               373
# ...                             ...               ...               ...
# gene-R0792_RS22495              133               144               389
# gene-R0792_RS04325              172               266               353
# gene-R0792_RS12130               28                33                96
# gene-R0792_RS16410               13                40                64
# gene-R0792_RS28970              338               486               832
#
# SampleNames         bim-phage-120_R3  bim-phage-120_R4  bim-phage-120_R5
# Geneid
# gene-R0792_RS24585               611               735               641
# gene-R0792_RS14545                44               113                93
# gene-R0792_RS28890               194               359               306
# gene-R0792_RS01605               169               212               182
# gene-R0792_RS21865               164               199               173
# ...                              ...               ...               ...
# gene-R0792_RS22495               118               185               151
# gene-R0792_RS04325               147               214               191
# gene-R0792_RS12130                21                37                39
# gene-R0792_RS16410                31                37                32
# gene-R0792_RS28970               311               466               372
#
# [6011 rows x 15 columns]

# %% [markdown]
# ### 2.3 Read count normalization

# %% [markdown]
# Important note: gene symbols not available for most genes.

# %%
# Function to fill in missing symbols by geneid.

def fillSymbols(df):
    df_new = df.copy()
    index = df.index.to_list()
    for i in range(0,df.shape[0]):
        if (df.iloc[i,-1:].values == None):
            df_new.iloc[i,-1:] = index[i]
    return df_new

# %% [markdown]
# Convert counts to TPM.

# %%
tpms = TPM(df_norRNAs, df_initial, 0.5)
tpms['Entity'] = gff3.loc[sorted(tpms.index.to_list()), 'Entity']
tpms['Symbol'] = gff3.loc[sorted(tpms.index.to_list()), 'Symbol']

tpms = fillSymbols(tpms)
tpms = make_unique_with_index(tpms)
tpms
# Out:
# SampleNames         bim-phage-35_R1  bim-phage-35_R2  bim-phage-35_R3  \
# Geneid
# gene-R0792_RS24585        24.991917        44.914150        50.181220
# gene-R0792_RS14545         0.898380         2.871079         2.619268
# gene-R0792_RS28890         4.094034        15.082387        14.254881
# gene-R0792_RS01605        29.960899        36.017944        45.889948
# gene-R0792_RS21865         9.261758        26.512952        22.948317
# ...                             ...              ...              ...
# gene-R0792_RS22495         1.415142         5.903429         5.589286
# gene-R0792_RS04325        16.659111        20.984651        21.883209
# gene-R0792_RS12130         2.057220         3.173043         2.841511
# gene-R0792_RS16410         0.985293         1.509184         1.375798
# gene-R0792_RS28970        12.067283        17.700193        16.702364
#
# SampleNames         bim-phage-35_R4  bim-phage-35_R5  bim-phage-60_R1  \
# Geneid
# gene-R0792_RS24585        39.219429        55.475389        45.004651
# gene-R0792_RS14545         1.983149         5.799610         5.533941
# gene-R0792_RS28890         7.762885        30.309133        36.610631
# gene-R0792_RS01605        32.420502        39.702558        32.309472
# gene-R0792_RS21865        17.414270        23.840140        17.482908
# ...                             ...              ...              ...
# gene-R0792_RS22495         3.281392        11.838595         8.715088
# gene-R0792_RS04325        24.851651        22.700006        24.349308
# gene-R0792_RS12130         2.948085         4.929058         5.592753
# gene-R0792_RS16410         1.269262         2.239679         2.297085
# gene-R0792_RS28970        16.552756        22.357989        18.530285
#
# SampleNames         bim-phage-60_R2  bim-phage-60_R3  bim-phage-60_R4  \
# Geneid
# gene-R0792_RS24585        40.174999        49.036100        59.133962
# gene-R0792_RS14545         3.729253         6.178431         9.550075
# gene-R0792_RS28890        13.004376        21.489432        27.093620
# gene-R0792_RS01605        48.121896        53.462563        54.209047
# gene-R0792_RS21865        16.468733        23.671891        26.676176
# ...                             ...              ...              ...
# gene-R0792_RS22495         5.967737         9.734600        12.792022
# gene-R0792_RS04325        19.077059        25.372032        28.630355
# gene-R0792_RS12130         3.216939         3.942636         6.204765
# gene-R0792_RS16410         1.249590         2.780103         3.400646
# gene-R0792_RS28970        16.259539        20.734178        26.854025
#
# SampleNames         bim-phage-60_R5  bim-phage-120_R1  bim-phage-120_R2  \
# Geneid
# gene-R0792_RS24585        44.713471         52.574890         58.685730
# gene-R0792_RS14545         2.838003          4.909314          9.275006
# gene-R0792_RS28890        14.763396         22.193564         34.537571
# gene-R0792_RS01605        39.418340         47.014404         64.830368
# gene-R0792_RS21865        17.590159         24.058512         29.939775
# ...                             ...               ...               ...
# gene-R0792_RS22495         6.999848          6.995436         13.727612
# gene-R0792_RS04325        21.470299         30.625682         29.574580
# gene-R0792_RS12130         2.876917          3.122244          6.547718
# gene-R0792_RS16410         1.149962          3.185256          3.693088
# gene-R0792_RS28970        18.043875         23.943826         29.828784
#
# SampleNames         bim-phage-120_R3  bim-phage-120_R4  bim-phage-120_R5  \
# Geneid
# gene-R0792_RS24585         52.534449         54.624723         49.321908
# gene-R0792_RS14545          3.589563          7.914733          6.749765
# gene-R0792_RS28890         16.398565         26.202576         23.126622
# gene-R0792_RS01605         50.218069         54.426211         48.389225
# gene-R0792_RS21865         24.255014         25.429474         22.894470
# ...                              ...               ...               ...
# gene-R0792_RS22495          7.682164         10.396041          8.789686
# gene-R0792_RS04325         22.698590         28.535995         26.373704
# gene-R0792_RS12130          2.683359          4.046043          4.411974
# gene-R0792_RS16410          3.317555          3.414269          3.063278
# gene-R0792_RS28970         20.529911         26.579054         21.971048
#
# SampleNames        Entity                       Symbol
# Geneid
# gene-R0792_RS24585   host                         aroB
# gene-R0792_RS14545   host           gene-R0792_RS14545
# gene-R0792_RS28890   host           gene-R0792_RS28890
# gene-R0792_RS01605   host           gene-R0792_RS01605
# gene-R0792_RS21865   host                         rsmG
# ...                   ...                          ...
# gene-R0792_RS22495   host  gene-R0792_RS22495_gene_zwf
# gene-R0792_RS04325   host           gene-R0792_RS04325
# gene-R0792_RS12130   host           gene-R0792_RS12130
# gene-R0792_RS16410   host           gene-R0792_RS16410
# gene-R0792_RS28970   host                         sbcB
#
# [6011 rows x 17 columns]

# %%
# Check gene names unique
len(tpms['Symbol'].unique())
# Out:
# 6011

# %% [markdown]
# Log2+1 normalization tpms

# %%
logTPMs = logNorm(tpms.iloc[:, :-2])
logTPMs = logTPMs.join(tpms.iloc[:, -2:])
logTPMs = fillSymbols(logTPMs)
# Make gene names unique
logTPMs = make_unique_with_index(logTPMs)
logTPMs
# Out:
# SampleNames         bim-phage-35_R1  bim-phage-35_R2  bim-phage-35_R3  \
# Geneid
# gene-R0792_RS24585         4.699991         5.520867         5.677543
# gene-R0792_RS14545         0.924769         1.952736         1.855698
# gene-R0792_RS28890         2.348808         4.007410         3.931199
# gene-R0792_RS01605         4.952375         5.210153         5.551207
# gene-R0792_RS21865         3.359206         4.782039         4.581852
# ...                             ...              ...              ...
# gene-R0792_RS22495         1.272108         2.787313         2.720122
# gene-R0792_RS04325         4.142341         4.458425         4.516217
# gene-R0792_RS12130         1.612220         2.061100         1.941674
# gene-R0792_RS16410         0.989352         1.327218         1.248412
# gene-R0792_RS28970         3.707887         4.224981         4.145870
#
# SampleNames         bim-phage-35_R4  bim-phage-35_R5  bim-phage-60_R1  \
# Geneid
# gene-R0792_RS24585         5.329821         5.819550         5.523708
# gene-R0792_RS14545         1.576836         2.765452         2.707953
# gene-R0792_RS28890         3.131406         4.968512         5.233069
# gene-R0792_RS01605         5.062662         5.347048         5.057861
# gene-R0792_RS21865         4.202752         4.634601         4.208120
# ...                             ...              ...              ...
# gene-R0792_RS22495         2.098080         3.682415         3.280227
# gene-R0792_RS04325         4.692185         4.566816         4.663874
# gene-R0792_RS12130         1.981153         2.567803         2.720881
# gene-R0792_RS16410         1.182223         1.695851         1.721191
# gene-R0792_RS28970         4.133626         4.545844         4.287641
#
# SampleNames         bim-phage-60_R2  bim-phage-60_R3  bim-phage-60_R4  \
# Geneid
# gene-R0792_RS24585         5.363697         5.644897         5.910108
# gene-R0792_RS14545         2.241612         2.843669         3.399181
# gene-R0792_RS28890         3.807806         4.491175         4.812171
# gene-R0792_RS01605         5.618294         5.767193         5.786833
# gene-R0792_RS21865         4.126703         4.624796         4.790573
# ...                             ...              ...              ...
# gene-R0792_RS22495         2.800690         3.424197         3.785762
# gene-R0792_RS04325         4.327476         4.720937         4.889004
# gene-R0792_RS12130         2.076196         2.305281         2.848951
# gene-R0792_RS16410         1.169662         1.918425         2.137715
# gene-R0792_RS28970         4.109322         4.441894         4.799814
#
# SampleNames         bim-phage-60_R5  bim-phage-120_R1  bim-phage-120_R2  \
# Geneid
# gene-R0792_RS24585         5.514547          5.743485          5.899314
# gene-R0792_RS14545         1.940356          2.562991          3.361067
# gene-R0792_RS28890         3.978506          4.535653          5.151273
# gene-R0792_RS01605         5.336938          5.585395          6.040681
# gene-R0792_RS21865         4.216467          4.647229          4.951391
# ...                             ...               ...               ...
# gene-R0792_RS22495         2.999973          2.999177          3.880452
# gene-R0792_RS04325         4.489947          4.983025          4.934261
# gene-R0792_RS12130         1.954910          2.043430          2.916041
# gene-R0792_RS16410         1.104311          2.065316          2.230537
# gene-R0792_RS28970         4.251255          4.640611          4.946206
#
# SampleNames         bim-phage-120_R3  bim-phage-120_R4  bim-phage-120_R5  \
# Geneid
# gene-R0792_RS24585          5.742396          5.797654          5.653115
# gene-R0792_RS14545          2.198357          3.156192          2.954153
# gene-R0792_RS28890          4.120896          4.765671          4.592554
# gene-R0792_RS01605          5.678581          5.792496          5.626124
# gene-R0792_RS21865          4.658498          4.724076          4.578605
# ...                              ...               ...               ...
# gene-R0792_RS22495          3.118055          3.510461          3.291263
# gene-R0792_RS04325          4.566729          4.884402          4.774719
# gene-R0792_RS12130          1.881022          2.335152          2.436155
# gene-R0792_RS16410          2.110215          2.142174          2.022644
# gene-R0792_RS28970          4.428270          4.785501          4.521745
#
# SampleNames        Entity                       Symbol
# Geneid
# gene-R0792_RS24585   host                         aroB
# gene-R0792_RS14545   host           gene-R0792_RS14545
# gene-R0792_RS28890   host           gene-R0792_RS28890
# gene-R0792_RS01605   host           gene-R0792_RS01605
# gene-R0792_RS21865   host                         rsmG
# ...                   ...                          ...
# gene-R0792_RS22495   host  gene-R0792_RS22495_gene_zwf
# gene-R0792_RS04325   host           gene-R0792_RS04325
# gene-R0792_RS12130   host           gene-R0792_RS12130
# gene-R0792_RS16410   host           gene-R0792_RS16410
# gene-R0792_RS28970   host                         sbcB
#
# [6011 rows x 17 columns]

# %% [markdown]
# ## 3 Filter samples, if necessary: WT_Phage
#
# Look for outliers visually by PCA.

# %%
columnOrder = ['bim-phage-35_R1', 'bim-phage-35_R2', 'bim-phage-35_R3', 'bim-phage-35_R4', 'bim-phage-35_R5',
               'bim-phage-60_R1', 'bim-phage-60_R2', 'bim-phage-60_R3', 'bim-phage-60_R4', 'bim-phage-60_R5',
               'bim-phage-120_R1', 'bim-phage-120_R2', 'bim-phage-120_R3', 'bim-phage-120_R4', 'bim-phage-120_R5']

# %%
txPCA(tpms[columnOrder])

# %%
txPCA(logTPMs[columnOrder])

# %%
tpmHost = tpms[tpms['Entity'] == 'host']
tpmPhage = tpms[tpms['Entity'] == 'phage']
logTPMsHost = logTPMs[logTPMs['Entity'] == 'host']
logTPMsPhage = logTPMs[logTPMs['Entity'] == 'phage']

# %% [markdown]
# tpmHost

# %%
txPCA(tpmHost[columnOrder])

# %% [markdown]
# tpmPhage

# %%
txPCA(tpmPhage[columnOrder])

# %% [markdown]
# logTPM Host

# %%
txPCA(logTPMsHost[columnOrder])

# %% [markdown]
# logTPM Phage

# %%
txPCA(logTPMsPhage[columnOrder])

# %% [markdown]
# $\rightarrow$ Log normalized values look fine, with exception of phage logTPMs, there actually non normalized values look better. And 35_R1 is debatable, whether it should be removed or not. Decided to keep everything for now.

# %% [markdown]
# ## 4. Final grouping
#
# Summarize time points with mean and standard deviation for TPM-normalized data.

# %%
tpms.columns = tpms.columns.str.replace('bim-phage-', '')

# %%
tpms
# Out:
# SampleNames             35_R1      35_R2      35_R3      35_R4      35_R5  \
# Geneid
# gene-R0792_RS24585  24.991917  44.914150  50.181220  39.219429  55.475389
# gene-R0792_RS14545   0.898380   2.871079   2.619268   1.983149   5.799610
# gene-R0792_RS28890   4.094034  15.082387  14.254881   7.762885  30.309133
# gene-R0792_RS01605  29.960899  36.017944  45.889948  32.420502  39.702558
# gene-R0792_RS21865   9.261758  26.512952  22.948317  17.414270  23.840140
# ...                       ...        ...        ...        ...        ...
# gene-R0792_RS22495   1.415142   5.903429   5.589286   3.281392  11.838595
# gene-R0792_RS04325  16.659111  20.984651  21.883209  24.851651  22.700006
# gene-R0792_RS12130   2.057220   3.173043   2.841511   2.948085   4.929058
# gene-R0792_RS16410   0.985293   1.509184   1.375798   1.269262   2.239679
# gene-R0792_RS28970  12.067283  17.700193  16.702364  16.552756  22.357989
#
# SampleNames             60_R1      60_R2      60_R3      60_R4      60_R5  \
# Geneid
# gene-R0792_RS24585  45.004651  40.174999  49.036100  59.133962  44.713471
# gene-R0792_RS14545   5.533941   3.729253   6.178431   9.550075   2.838003
# gene-R0792_RS28890  36.610631  13.004376  21.489432  27.093620  14.763396
# gene-R0792_RS01605  32.309472  48.121896  53.462563  54.209047  39.418340
# gene-R0792_RS21865  17.482908  16.468733  23.671891  26.676176  17.590159
# ...                       ...        ...        ...        ...        ...
# gene-R0792_RS22495   8.715088   5.967737   9.734600  12.792022   6.999848
# gene-R0792_RS04325  24.349308  19.077059  25.372032  28.630355  21.470299
# gene-R0792_RS12130   5.592753   3.216939   3.942636   6.204765   2.876917
# gene-R0792_RS16410   2.297085   1.249590   2.780103   3.400646   1.149962
# gene-R0792_RS28970  18.530285  16.259539  20.734178  26.854025  18.043875
#
# SampleNames            120_R1     120_R2     120_R3     120_R4     120_R5  \
# Geneid
# gene-R0792_RS24585  52.574890  58.685730  52.534449  54.624723  49.321908
# gene-R0792_RS14545   4.909314   9.275006   3.589563   7.914733   6.749765
# gene-R0792_RS28890  22.193564  34.537571  16.398565  26.202576  23.126622
# gene-R0792_RS01605  47.014404  64.830368  50.218069  54.426211  48.389225
# gene-R0792_RS21865  24.058512  29.939775  24.255014  25.429474  22.894470
# ...                       ...        ...        ...        ...        ...
# gene-R0792_RS22495   6.995436  13.727612   7.682164  10.396041   8.789686
# gene-R0792_RS04325  30.625682  29.574580  22.698590  28.535995  26.373704
# gene-R0792_RS12130   3.122244   6.547718   2.683359   4.046043   4.411974
# gene-R0792_RS16410   3.185256   3.693088   3.317555   3.414269   3.063278
# gene-R0792_RS28970  23.943826  29.828784  20.529911  26.579054  21.971048
#
# SampleNames        Entity                       Symbol
# Geneid
# gene-R0792_RS24585   host                         aroB
# gene-R0792_RS14545   host           gene-R0792_RS14545
# gene-R0792_RS28890   host           gene-R0792_RS28890
# gene-R0792_RS01605   host           gene-R0792_RS01605
# gene-R0792_RS21865   host                         rsmG
# ...                   ...                          ...
# gene-R0792_RS22495   host  gene-R0792_RS22495_gene_zwf
# gene-R0792_RS04325   host           gene-R0792_RS04325
# gene-R0792_RS12130   host           gene-R0792_RS12130
# gene-R0792_RS16410   host           gene-R0792_RS16410
# gene-R0792_RS28970   host                         sbcB
#
# [6011 rows x 17 columns]

# %%
columnOrder = ['35_R1', '35_R2', '35_R3', '35_R4', '35_R5',
               '60_R1', '60_R2', '60_R3', '60_R4', '60_R5',
               '120_R1', '120_R2', '120_R3', '120_R4', '120_R5']

# %%
TPMmeans, TPMsds = getMeanSD(tpms[columnOrder])
TPMmeans = TPMmeans[['35', '60', '120']]
TPMmeans[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMmeans
# Out:
#                            35         60        120 Entity  \
# Geneid
# gene-R0792_RS24585  42.956421  47.612637  53.548340   host
# gene-R0792_RS14545   2.834297   5.565941   6.487676   host
# gene-R0792_RS28890  14.300664  22.592291  24.491780   host
# gene-R0792_RS01605  36.798370  45.504264  52.975655   host
# gene-R0792_RS21865  19.995487  20.377973  25.315449   host
# ...                       ...        ...        ...    ...
# gene-R0792_RS22495   5.605569   8.841859   9.518188   host
# gene-R0792_RS04325  21.415725  23.779810  27.561710   host
# gene-R0792_RS12130   3.189783   4.366802   4.162268   host
# gene-R0792_RS16410   1.475843   2.175477   3.334689   host
# gene-R0792_RS28970  17.076117  20.084380  24.570524   host
#
#                                          Symbol
# Geneid
# gene-R0792_RS24585                         aroB
# gene-R0792_RS14545           gene-R0792_RS14545
# gene-R0792_RS28890           gene-R0792_RS28890
# gene-R0792_RS01605           gene-R0792_RS01605
# gene-R0792_RS21865                         rsmG
# ...                                         ...
# gene-R0792_RS22495  gene-R0792_RS22495_gene_zwf
# gene-R0792_RS04325           gene-R0792_RS04325
# gene-R0792_RS12130           gene-R0792_RS12130
# gene-R0792_RS16410           gene-R0792_RS16410
# gene-R0792_RS28970                         sbcB
#
# [6011 rows x 5 columns]

# %%
TPMsds = TPMsds[['35', '60', '120']]
TPMsds[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMsds
# Out:
#                            35        60       120 Entity  \
# Geneid
# gene-R0792_RS24585  10.482781  6.407689  3.078626   host
# gene-R0792_RS14545   1.631741  2.326566  2.037875   host
# gene-R0792_RS28890   8.986680  8.616401  5.941217   host
# gene-R0792_RS01605   5.614568  8.451045  6.431399   host
# gene-R0792_RS21865   6.129495  4.048524  2.447976   host
# ...                       ...       ...       ...    ...
# gene-R0792_RS22495   3.518553  2.369406  2.398160   host
# gene-R0792_RS04325   2.701285  3.281372  2.808918   host
# gene-R0792_RS12130   0.947393  1.311711  1.344251   host
# gene-R0792_RS16410   0.419018  0.870672  0.214974   host
# gene-R0792_RS28970   3.279929  3.673108  3.321448   host
#
#                                          Symbol
# Geneid
# gene-R0792_RS24585                         aroB
# gene-R0792_RS14545           gene-R0792_RS14545
# gene-R0792_RS28890           gene-R0792_RS28890
# gene-R0792_RS01605           gene-R0792_RS01605
# gene-R0792_RS21865                         rsmG
# ...                                         ...
# gene-R0792_RS22495  gene-R0792_RS22495_gene_zwf
# gene-R0792_RS04325           gene-R0792_RS04325
# gene-R0792_RS12130           gene-R0792_RS12130
# gene-R0792_RS16410           gene-R0792_RS16410
# gene-R0792_RS28970                         sbcB
#
# [6011 rows x 5 columns]

# %%
propExp = proportionalExp(TPMmeans[['35', '60', '120']])
propExp[['Entity', 'Symbol']] = TPMmeans[['Entity', 'Symbol']]
propExp
# Out:
#                           35        60       120 Entity  \
# Geneid
# gene-R0792_RS24585  0.802199  0.889152  1.000000   host
# gene-R0792_RS14545  0.436874  0.857925  1.000000   host
# gene-R0792_RS28890  0.583896  0.922444  1.000000   host
# gene-R0792_RS01605  0.694628  0.858966  1.000000   host
# gene-R0792_RS21865  0.789853  0.804962  1.000000   host
# ...                      ...       ...       ...    ...
# gene-R0792_RS22495  0.588932  0.928944  1.000000   host
# gene-R0792_RS04325  0.777010  0.862784  1.000000   host
# gene-R0792_RS12130  0.730462  1.000000  0.953162   host
# gene-R0792_RS16410  0.442573  0.652378  1.000000   host
# gene-R0792_RS28970  0.694984  0.817418  1.000000   host
#
#                                          Symbol
# Geneid
# gene-R0792_RS24585                         aroB
# gene-R0792_RS14545           gene-R0792_RS14545
# gene-R0792_RS28890           gene-R0792_RS28890
# gene-R0792_RS01605           gene-R0792_RS01605
# gene-R0792_RS21865                         rsmG
# ...                                         ...
# gene-R0792_RS22495  gene-R0792_RS22495_gene_zwf
# gene-R0792_RS04325           gene-R0792_RS04325
# gene-R0792_RS12130           gene-R0792_RS12130
# gene-R0792_RS16410           gene-R0792_RS16410
# gene-R0792_RS28970                         sbcB
#
# [6011 rows x 5 columns]

# %% [markdown]
# ## 5. Phage gene classification

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelThreshold(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-2)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM*0.2

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x >= thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('middle')
        elif timePoint == 2:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassThreshold'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassThreshold'] = 'None'

    return tpmOut

# %%
# # Export fractional expressions with T=0.6 + Host/Phage Annotation for Orthofinder Analysis
# t = classLabelThreshold(propExp)
# t = t[t["Entity"] == "phage"]
# t["Host"] = "Pseudomonas_aeruginosa_PA14"
# t["Phage"] = "Pseudomonas_phage_DMS3"
# t.to_csv("/ceph/ibmi/studenten/waffen/Cross_Analysis/Orthofinder_Clustering/Fractional_Expressions/T060/Meaden_BIM_fractional_expression_T=0.6.tsv", sep="\t")

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelMax(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-3)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x == thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('middle')
        elif timePoint == 2:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassMax'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassMax'] = 'None'

    return tpmOut

# %%
TPMmeans = classLabelThreshold(TPMmeans)
TPMmeans = classLabelMax(TPMmeans)

# %%
TPMmeans
# Out:
#                            35         60        120 Entity  \
# Geneid
# gene-R0792_RS24585  42.956421  47.612637  53.548340   host
# gene-R0792_RS14545   2.834297   5.565941   6.487676   host
# gene-R0792_RS28890  14.300664  22.592291  24.491780   host
# gene-R0792_RS01605  36.798370  45.504264  52.975655   host
# gene-R0792_RS21865  19.995487  20.377973  25.315449   host
# ...                       ...        ...        ...    ...
# gene-R0792_RS22495   5.605569   8.841859   9.518188   host
# gene-R0792_RS04325  21.415725  23.779810  27.561710   host
# gene-R0792_RS12130   3.189783   4.366802   4.162268   host
# gene-R0792_RS16410   1.475843   2.175477   3.334689   host
# gene-R0792_RS28970  17.076117  20.084380  24.570524   host
#
#                                          Symbol ClassThreshold ClassMax
# Geneid
# gene-R0792_RS24585                         aroB           None     None
# gene-R0792_RS14545           gene-R0792_RS14545           None     None
# gene-R0792_RS28890           gene-R0792_RS28890           None     None
# gene-R0792_RS01605           gene-R0792_RS01605           None     None
# gene-R0792_RS21865                         rsmG           None     None
# ...                                         ...            ...      ...
# gene-R0792_RS22495  gene-R0792_RS22495_gene_zwf           None     None
# gene-R0792_RS04325           gene-R0792_RS04325           None     None
# gene-R0792_RS12130           gene-R0792_RS12130           None     None
# gene-R0792_RS16410           gene-R0792_RS16410           None     None
# gene-R0792_RS28970                         sbcB           None     None
#
# [6011 rows x 7 columns]

# %%
TPMmeans[TPMmeans['Entity'] == 'phage']['ClassMax'].value_counts()
# Out:
# ClassMax
# middle    28
# late      16
# early      8
# Name: count, dtype: int64

# %% [markdown]
# Add classes to other dfs.

# %%
TPMsds[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
tpms[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
propExp[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]

# gff3
gff3_final = gff3_genes.merge(TPMmeans[["ClassThreshold", "ClassMax"]], right_index=True, left_on="ID", how="left")
gff3_host  = gff3_final[gff3_final['seq_id'] == 'NZ_CP136842.1']
gff3_phage = gff3_final[gff3_final['seq_id'] == 'NC_008717.1']
gff3_genes["seq_id"].unique()
# Out:
# array(['NZ_CP136842.1', 'NC_008717.1'], dtype=object)

# %% [markdown]
# ## 6. Add variance to all dataframes

# %% [markdown]
# Base variance call on tpms.

# %%
def stabilizedVariance(df):
    labels = list()
    
    i = 0
    while i < df.shape[0]:

        # Get array of expression values at time points
        expressions = list(df.iloc[i,0:(df.shape[1]-4)])

        # Get mean expression for the gene
        exprMean = np.mean(np.array(expressions))

        # Get the variance for the gene
        varGene = np.var(np.array(expressions))

        # Stabilized variance
        stableVarGene = varGene/exprMean

        labels.append(stableVarGene)

        i += 1

    tpmOut = df.copy()
    tpmOut['Variance'] = labels

    return tpmOut

# %%
tpms = stabilizedVariance(tpms)
tpms
# Out:
# SampleNames             35_R1      35_R2      35_R3      35_R4      35_R5  \
# Geneid
# gene-R0792_RS24585  24.991917  44.914150  50.181220  39.219429  55.475389
# gene-R0792_RS14545   0.898380   2.871079   2.619268   1.983149   5.799610
# gene-R0792_RS28890   4.094034  15.082387  14.254881   7.762885  30.309133
# gene-R0792_RS01605  29.960899  36.017944  45.889948  32.420502  39.702558
# gene-R0792_RS21865   9.261758  26.512952  22.948317  17.414270  23.840140
# ...                       ...        ...        ...        ...        ...
# gene-R0792_RS22495   1.415142   5.903429   5.589286   3.281392  11.838595
# gene-R0792_RS04325  16.659111  20.984651  21.883209  24.851651  22.700006
# gene-R0792_RS12130   2.057220   3.173043   2.841511   2.948085   4.929058
# gene-R0792_RS16410   0.985293   1.509184   1.375798   1.269262   2.239679
# gene-R0792_RS28970  12.067283  17.700193  16.702364  16.552756  22.357989
#
# SampleNames             60_R1      60_R2      60_R3      60_R4      60_R5  \
# Geneid
# gene-R0792_RS24585  45.004651  40.174999  49.036100  59.133962  44.713471
# gene-R0792_RS14545   5.533941   3.729253   6.178431   9.550075   2.838003
# gene-R0792_RS28890  36.610631  13.004376  21.489432  27.093620  14.763396
# gene-R0792_RS01605  32.309472  48.121896  53.462563  54.209047  39.418340
# gene-R0792_RS21865  17.482908  16.468733  23.671891  26.676176  17.590159
# ...                       ...        ...        ...        ...        ...
# gene-R0792_RS22495   8.715088   5.967737   9.734600  12.792022   6.999848
# gene-R0792_RS04325  24.349308  19.077059  25.372032  28.630355  21.470299
# gene-R0792_RS12130   5.592753   3.216939   3.942636   6.204765   2.876917
# gene-R0792_RS16410   2.297085   1.249590   2.780103   3.400646   1.149962
# gene-R0792_RS28970  18.530285  16.259539  20.734178  26.854025  18.043875
#
# SampleNames            120_R1     120_R2     120_R3     120_R4     120_R5  \
# Geneid
# gene-R0792_RS24585  52.574890  58.685730  52.534449  54.624723  49.321908
# gene-R0792_RS14545   4.909314   9.275006   3.589563   7.914733   6.749765
# gene-R0792_RS28890  22.193564  34.537571  16.398565  26.202576  23.126622
# gene-R0792_RS01605  47.014404  64.830368  50.218069  54.426211  48.389225
# gene-R0792_RS21865  24.058512  29.939775  24.255014  25.429474  22.894470
# ...                       ...        ...        ...        ...        ...
# gene-R0792_RS22495   6.995436  13.727612   7.682164  10.396041   8.789686
# gene-R0792_RS04325  30.625682  29.574580  22.698590  28.535995  26.373704
# gene-R0792_RS12130   3.122244   6.547718   2.683359   4.046043   4.411974
# gene-R0792_RS16410   3.185256   3.693088   3.317555   3.414269   3.063278
# gene-R0792_RS28970  23.943826  29.828784  20.529911  26.579054  21.971048
#
# SampleNames        Entity                       Symbol ClassThreshold  \
# Geneid
# gene-R0792_RS24585   host                         aroB           None
# gene-R0792_RS14545   host           gene-R0792_RS14545           None
# gene-R0792_RS28890   host           gene-R0792_RS28890           None
# gene-R0792_RS01605   host           gene-R0792_RS01605           None
# gene-R0792_RS21865   host                         rsmG           None
# ...                   ...                          ...            ...
# gene-R0792_RS22495   host  gene-R0792_RS22495_gene_zwf           None
# gene-R0792_RS04325   host           gene-R0792_RS04325           None
# gene-R0792_RS12130   host           gene-R0792_RS12130           None
# gene-R0792_RS16410   host           gene-R0792_RS16410           None
# gene-R0792_RS28970   host                         sbcB           None
#
# SampleNames        ClassMax  Variance
# Geneid
# gene-R0792_RS24585     None  1.504276
# gene-R0792_RS14545     None  1.306293
# gene-R0792_RS28890     None  4.057038
# gene-R0792_RS01605     None  2.035897
# gene-R0792_RS21865     None  1.180760
# ...                     ...       ...
# gene-R0792_RS22495     None  1.355776
# gene-R0792_RS04325     None  0.620914
# gene-R0792_RS12130     None  0.445106
# gene-R0792_RS16410     None  0.392601
# gene-R0792_RS28970     None  1.032362
#
# [6011 rows x 20 columns]

# %%
TPMmeans['Variance'] = tpms['Variance']
TPMsds['Variance'] = tpms['Variance']
propExp['Variance'] = tpms['Variance']

# %% [markdown]
# ## 7. Write data to output

# %%
df_norRNAs[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]

# %%
# Full TPM table
tpms.to_csv('Meaden_BIM_full_TPM.tsv', sep = '\t')
# Full raw_counts table
df_norRNAs.to_csv('Meaden_BIM_full_raw_counts.tsv', sep = '\t')
# Summarized (time point means) TPM table
TPMmeans.to_csv('Meaden_BIM_TPM_means.tsv', sep = '\t')
# Summarized (time point) TPM standard deviation
TPMsds.to_csv('Meaden_BIM_TPM_std.tsv', sep = '\t')
# Proportional expression per gene and time point
propExp.to_csv('Meaden_BIM_fractional_expression.tsv', sep = '\t')
# Processed gff3 file
gff3_host.to_csv('Meaden_BIM_host_gff3.tsv', sep='\t')
gff3_phage.to_csv('Meaden_BIM_phage_gff3.tsv', sep='\t')
