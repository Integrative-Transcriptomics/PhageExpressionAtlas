# %% [markdown]
# # Process bulk counts table
#
# 1. Annotate columns (samples) in a way that time point and replicate are annotated
# 2. Remove rRNA genes
# 3. Perform TPM normalization and alternatively also raw counts

# %%
# Use miniconda environment Jupyter_new for running this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tools import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 Load the dataset and annotation

# %%
bulkPath = '../nf_output/countData/countData.tsv'
metaPath = '../Brandão_SraRunTable.csv' # metadata from SRA
gffPath = '../nf_output/alignments/dualGenome.gff3' # output from nf pipeline

# %%
# Load data
df_initial = pd.read_csv(bulkPath, sep = '\t', comment='#', index_col=0)
df_initial = df_initial.drop(columns=['SRR13160348_sorted.bam', 'SRR13160339_sorted.bam', 'SRR13160350_sorted.bam', 
                                      'SRR13160346_sorted.bam', 'SRR13160344_sorted.bam', 'SRR13160345_sorted.bam', 
                                      'SRR13160341_sorted.bam', 'SRR13160343_sorted.bam', 'SRR13160349_sorted.bam', 
                                      'SRR13160347_sorted.bam', 'SRR13160342_sorted.bam', 'SRR13160340_sorted.bam'])
metadata = pd.read_csv(metaPath)
metadata = metadata[metadata['medium'] == 'LB']

# %%
df_initial.head()
# Out:
#                      Chr  Start   End Strand  Length  SRR13160338_sorted.bam  \
# Geneid
# gene-PA0001  NC_002516.2    483  2027      +    1545                     132
# gene-PA0002  NC_002516.2   2056  3159      +    1104                      62
# gene-PA0003  NC_002516.2   3169  4278      +    1110                     148
# gene-PA0004  NC_002516.2   4275  6695      +    2421                     323
# gene-PA0005  NC_002516.2   7018  7791      -     774                      23
#
#              SRR13160334_sorted.bam  SRR13160330_sorted.bam  \
# Geneid
# gene-PA0001                     132                     758
# gene-PA0002                      94                     410
# gene-PA0003                     196                     905
# gene-PA0004                     339                    2078
# gene-PA0005                      20                     116
#
#              SRR13160332_sorted.bam  SRR13160335_sorted.bam  \
# Geneid
# gene-PA0001                     686                     164
# gene-PA0002                     384                      72
# gene-PA0003                     909                     198
# gene-PA0004                    2345                     405
# gene-PA0005                      89                      26
#
#              SRR13160333_sorted.bam  SRR13160331_sorted.bam  \
# Geneid
# gene-PA0001                     356                     156
# gene-PA0002                     147                      95
# gene-PA0003                     500                     166
# gene-PA0004                     742                     467
# gene-PA0005                      50                      19
#
#              SRR13160336_sorted.bam  SRR13160327_sorted.bam  \
# Geneid
# gene-PA0001                      11                     819
# gene-PA0002                       9                     371
# gene-PA0003                      19                     954
# gene-PA0004                      39                    1488
# gene-PA0005                       4                     108
#
#              SRR13160329_sorted.bam  SRR13160337_sorted.bam  \
# Geneid
# gene-PA0001                     742                     197
# gene-PA0002                     479                     105
# gene-PA0003                     948                     238
# gene-PA0004                    2129                     509
# gene-PA0005                     108                      34
#
#              SRR13160328_sorted.bam
# Geneid
# gene-PA0001                    1042
# gene-PA0002                     593
# gene-PA0003                    1200
# gene-PA0004                    2562
# gene-PA0005                     130

# %%
pd.set_option('display.max_columns', None)  # Show all columns
metadata
# Out:
#             Run Assay Type  AvgSpotLen Bacteria_Strain       Bases  \
# 0   SRR13160327    RNA-Seq         151        DSM22644  1868243892
# 1   SRR13160328    RNA-Seq         150        DSM22644  2189743274
# 2   SRR13160329    RNA-Seq         150        DSM22644  1963423268
# 3   SRR13160330    RNA-Seq         150        DSM22644  1538993587
# 4   SRR13160331    RNA-Seq         150        DSM22644   961305555
# 5   SRR13160332    RNA-Seq         150        DSM22644  1920789462
# 6   SRR13160333    RNA-Seq         151        DSM22644  1860867981
# 7   SRR13160334    RNA-Seq         150        DSM22644  1306828614
# 8   SRR13160335    RNA-Seq         150        DSM22644  1617102027
# 9   SRR13160336    RNA-Seq         150        DSM22644   731096029
# 10  SRR13160337    RNA-Seq         150        DSM22644  1910625803
# 11  SRR13160338    RNA-Seq         151        DSM22644  1493754128
#
#      BioProject     BioSample      Bytes Center Name Consent  \
# 0   PRJNA681237  SAMN16946609  657757396         GEO  public
# 1   PRJNA681237  SAMN16946607  723417172         GEO  public
# 2   PRJNA681237  SAMN16946606  715089768         GEO  public
# 3   PRJNA681237  SAMN16946604  534572046         GEO  public
# 4   PRJNA681237  SAMN16946603  317983625         GEO  public
# 5   PRJNA681237  SAMN16946602  674663360         GEO  public
# 6   PRJNA681237  SAMN16946601  654010627         GEO  public
# 7   PRJNA681237  SAMN16946600  475597024         GEO  public
# 8   PRJNA681237  SAMN16946599  569732201         GEO  public
# 9   PRJNA681237  SAMN16946598  241233973         GEO  public
# 10  PRJNA681237  SAMN16946597  690111473         GEO  public
# 11  PRJNA681237  SAMN16946596  526069628         GEO  public
#
#    DATASTORE filetype DATASTORE provider  \
# 0    fastq,run.zq,sra         gs,ncbi,s3
# 1    fastq,run.zq,sra         gs,ncbi,s3
# 2    fastq,run.zq,sra         gs,ncbi,s3
# 3    fastq,run.zq,sra         gs,ncbi,s3
# 4    fastq,run.zq,sra         gs,ncbi,s3
# 5    fastq,run.zq,sra         gs,ncbi,s3
# 6    fastq,run.zq,sra         gs,ncbi,s3
# 7    fastq,run.zq,sra         gs,ncbi,s3
# 8    fastq,run.zq,sra         gs,ncbi,s3
# 9    fastq,run.zq,sra         gs,ncbi,s3
# 10   fastq,run.zq,sra         gs,ncbi,s3
# 11   fastq,run.zq,sra         gs,ncbi,s3
#
#                         DATASTORE region  Experiment GEO_Accession (exp)  \
# 0   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599337          GSM4948299
# 1   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599338          GSM4948300
# 2   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599339          GSM4948301
# 3   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599340          GSM4948302
# 4   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599341          GSM4948303
# 5   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599342          GSM4948304
# 6   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599343          GSM4948305
# 7   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599344          GSM4948306
# 8   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599322          GSM4948307
# 9   gs.us-east1,ncbi.public,s3.us-east-1  SRX9599323          GSM4948308
# 10  gs.us-east1,ncbi.public,s3.us-east-1  SRX9599324          GSM4948309
# 11  gs.us-east1,ncbi.public,s3.us-east-1  SRX9599325          GSM4948310
#
#           Instrument LibraryLayout LibrarySelection   LibrarySource medium  \
# 0   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 1   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 2   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 3   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 4   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 5   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 6   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 7   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 8   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 9   Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 10  Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
# 11  Illumina MiniSeq        PAIRED             cDNA  TRANSCRIPTOMIC     LB
#
#                        Organism           phage_moi  Platform  \
# 0   Pseudomonas aeruginosa PAO1  phage wasn't added  ILLUMINA
# 1   Pseudomonas aeruginosa PAO1  phage wasn't added  ILLUMINA
# 2   Pseudomonas aeruginosa PAO1  phage wasn't added  ILLUMINA
# 3   Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
# 4   Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
# 5   Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
# 6   Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
# 7   Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
# 8   Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
# 9   Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
# 10  Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
# 11  Pseudomonas aeruginosa PAO1              MOI=75  ILLUMINA
#
#              ReleaseDate           create_date  version Sample Name  \
# 0   2020-11-30T00:00:00Z  2020-11-28T01:17:00Z        1  GSM4948299
# 1   2020-11-30T00:00:00Z  2020-11-28T01:16:00Z        1  GSM4948300
# 2   2020-11-30T00:00:00Z  2020-11-28T01:16:00Z        1  GSM4948301
# 3   2020-11-30T00:00:00Z  2020-11-28T01:15:00Z        1  GSM4948302
# 4   2020-11-30T00:00:00Z  2020-11-28T01:14:00Z        1  GSM4948303
# 5   2020-11-30T00:00:00Z  2020-11-28T01:16:00Z        1  GSM4948304
# 6   2020-11-30T00:00:00Z  2020-11-28T01:15:00Z        1  GSM4948305
# 7   2020-11-30T00:00:00Z  2020-11-28T01:15:00Z        1  GSM4948306
# 8   2020-11-30T00:00:00Z  2020-11-28T01:16:00Z        1  GSM4948307
# 9   2020-11-30T00:00:00Z  2020-11-28T01:13:00Z        1  GSM4948308
# 10  2020-11-30T00:00:00Z  2020-11-28T01:16:00Z        1  GSM4948309
# 11  2020-11-30T00:00:00Z  2020-11-28T01:15:00Z        1  GSM4948310
#
#                                      source_name  SRA Study  \
# 0                     early exponential bacteria  SRP294562
# 1                     early exponential bacteria  SRP294562
# 2                     early exponential bacteria  SRP294562
# 3    early exponential 5 min infected with phage  SRP294562
# 4    early exponential 5 min infected with phage  SRP294562
# 5    early exponential 5 min infected with phage  SRP294562
# 6   early exponential 10 min infected with phage  SRP294562
# 7   early exponential 10 min infected with phage  SRP294562
# 8   early exponential 10 min infected with phage  SRP294562
# 9   early exponential 15 min infected with phage  SRP294562
# 10  early exponential 15 min infected with phage  SRP294562
# 11  early exponential 15 min infected with phage  SRP294562
#
#                 STAGE     treatment_time
# 0   early exponential          untreated
# 1   early exponential          untreated
# 2   early exponential          untreated
# 3   early exponential   5 min with phage
# 4   early exponential   5 min with phage
# 5   early exponential   5 min with phage
# 6   early exponential  10 min with phage
# 7   early exponential  10 min with phage
# 8   early exponential  10 min with phage
# 9   early exponential  15 min with phage
# 10  early exponential  15 min with phage
# 11  early exponential  15 min with phage

# %% [markdown]
# ## 2 Format the dataset

# %% [markdown]
# ### 2.1 Annotate sample names

# %% [markdown]
# Issue now is that the metadata does not properly annotate sample names. Thus, this will be done manually by adding another sample name column to the metadata.

# %%
# Match GSM IDs and SampleNames inferred from GEO

sampleDict = {'GSM4948299': '0_R1', 'GSM4948300': '0_R2', 'GSM4948301': '0_R3',
              'GSM4948302': '5_R1', 'GSM4948303': '5_R2', 'GSM4948304': '5_R3',
              'GSM4948305': '10_R1', 'GSM4948306': '10_R2', 'GSM4948307': '10_R3',
              'GSM4948308': '15_R1', 'GSM4948309': '15_R2', 'GSM4948310': '15_R3',
}

# %%
metadataFull = annotateData(metadata, sampleDict)

# %%
metadata.head(1)
# Out:
#            Run Assay Type  AvgSpotLen Bacteria_Strain       Bases  \
# 0  SRR13160327    RNA-Seq         151        DSM22644  1868243892
#
#     BioProject     BioSample      Bytes Center Name Consent  \
# 0  PRJNA681237  SAMN16946609  657757396         GEO  public
#
#   DATASTORE filetype DATASTORE provider                      DATASTORE region  \
# 0   fastq,run.zq,sra         gs,ncbi,s3  gs.us-east1,ncbi.public,s3.us-east-1
#
#    Experiment GEO_Accession (exp)        Instrument LibraryLayout  \
# 0  SRX9599337          GSM4948299  Illumina MiniSeq        PAIRED
#
#   LibrarySelection   LibrarySource medium                     Organism  \
# 0             cDNA  TRANSCRIPTOMIC     LB  Pseudomonas aeruginosa PAO1
#
#             phage_moi  Platform           ReleaseDate           create_date  \
# 0  phage wasn't added  ILLUMINA  2020-11-30T00:00:00Z  2020-11-28T01:17:00Z
#
#    version Sample Name                 source_name  SRA Study  \
# 0        1  GSM4948299  early exponential bacteria  SRP294562
#
#                STAGE treatment_time
# 0  early exponential      untreated

# %%
metadataFull.head(1)
# Out:
#                                 Run Assay Type  AvgSpotLen Bacteria_Strain  \
# SampleID
# SRR13160327_sorted.bam  SRR13160327    RNA-Seq         151        DSM22644
#
#                              Bases   BioProject     BioSample      Bytes  \
# SampleID
# SRR13160327_sorted.bam  1868243892  PRJNA681237  SAMN16946609  657757396
#
#                        Center Name Consent DATASTORE filetype  \
# SampleID
# SRR13160327_sorted.bam         GEO  public   fastq,run.zq,sra
#
#                        DATASTORE provider  \
# SampleID
# SRR13160327_sorted.bam         gs,ncbi,s3
#
#                                             DATASTORE region  Experiment  \
# SampleID
# SRR13160327_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1  SRX9599337
#
#                        GEO_Accession (exp)        Instrument LibraryLayout  \
# SampleID
# SRR13160327_sorted.bam          GSM4948299  Illumina MiniSeq        PAIRED
#
#                        LibrarySelection   LibrarySource medium  \
# SampleID
# SRR13160327_sorted.bam             cDNA  TRANSCRIPTOMIC     LB
#
#                                            Organism           phage_moi  \
# SampleID
# SRR13160327_sorted.bam  Pseudomonas aeruginosa PAO1  phage wasn't added
#
#                         Platform           ReleaseDate           create_date  \
# SampleID
# SRR13160327_sorted.bam  ILLUMINA  2020-11-30T00:00:00Z  2020-11-28T01:17:00Z
#
#                         version Sample Name                 source_name  \
# SampleID
# SRR13160327_sorted.bam        1  GSM4948299  early exponential bacteria
#
#                         SRA Study              STAGE treatment_time  \
# SampleID
# SRR13160327_sorted.bam  SRP294562  early exponential      untreated
#
#                                       SampleID SampleNames
# SampleID
# SRR13160327_sorted.bam  SRR13160327_sorted.bam        0_R1

# %% [markdown]
# Add correct sample names.

# %%
df = changeColnames(df_initial.iloc[:,5:df_initial.shape[1]], metadataFull)
df = df[['0_R1', '0_R2', '0_R3', '5_R1', '5_R2', '5_R3', '10_R1', '10_R2', '10_R3', '15_R1', '15_R2', '15_R3']]
df
# Out:
# SampleNames          0_R1  0_R2  0_R3  5_R1  5_R2  5_R3  10_R1  10_R2  10_R3  \
# Geneid
# gene-PA0001           819  1042   742   758   156   686    356    132    164
# gene-PA0002           371   593   479   410    95   384    147     94     72
# gene-PA0003           954  1200   948   905   166   909    500    196    198
# gene-PA0004          1488  2562  2129  2078   467  2345    742    339    405
# gene-PA0005           108   130   108   116    19    89     50     20     26
# ...                   ...   ...   ...   ...   ...   ...    ...    ...    ...
# gene-PPLUZ19_gp46       0     0     2  1624  2076  5798   1158   2056   2118
# gene-PPLUZ19_gp46.1     0     0     2   592   983  2278    481    778    918
# gene-PPLUZ19_gp47       0     0     4   991  1094  2656    493    974   1228
# gene-PPLUZ19_gp48       0     0     0   557   868  1953    395    667   1078
# gene-PPLUZ19_gp49       0     0     1   638   746  2023    460    597    770
#
# SampleNames          15_R1  15_R2  15_R3
# Geneid
# gene-PA0001             11    197    132
# gene-PA0002              9    105     62
# gene-PA0003             19    238    148
# gene-PA0004             39    509    323
# gene-PA0005              4     34     23
# ...                    ...    ...    ...
# gene-PPLUZ19_gp46     2879  18351  12797
# gene-PPLUZ19_gp46.1   1811   8272   5999
# gene-PPLUZ19_gp47     2708  10934   8467
# gene-PPLUZ19_gp48     2506   9774   7255
# gene-PPLUZ19_gp49     1875  11134   7617
#
# [5732 rows x 12 columns]

# %% [markdown]
# ### 2.2 Remove rRNA genes
#
# Consult gff3 file to get rRNA geneids.

# %%
# Load gff3 and split into genes and CDS dfs
gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3.columns=["seq_id", "source", "type", "start", "end", "phase", "strand", "score", "attributes"]
gff3_genes = gff3.loc[gff3["type"] == 'gene']

# Column formating for genes
gff3_genes = gff3_genes.reset_index(drop=True)
dct_genes = gff3_genes["attributes"].str.split(';').apply(lambda items: dict(item.split('=', 1) for item in items if '=' in item))
cols_to_keep = ['ID', 'Name', 'gbkey', 'gene_biotype', 'locus_tag', 'gene']
gff3_genes = pd.concat([gff3_genes, pd.json_normalize(dct_genes)[cols_to_keep]], axis=1)

# Generate locus_tag, product dictonary over all different feature types
attrs = gff3["attributes"].str.split(";", expand=True)
attrs_dicts = attrs.apply(lambda row: {item.split("=")[0]: item.split("=")[1] for item in row if "=" in str(item)}, axis=1)
attrs_df = pd.json_normalize(attrs_dicts)
attrs_df = attrs_df.dropna(subset=["locus_tag", "product"])
locus_product_dict = dict(zip(attrs_df["locus_tag"], attrs_df["product"]))

# Add gene product, if not stated in gff3, fill with gene_biotype
gff3_genes["product"] = gff3_genes["locus_tag"].map(locus_product_dict)
gff3_genes["product"] = gff3_genes["product"].fillna(gff3_genes["gene_biotype"])

# If gene = NA, take from ID column
gff3_genes["gene"] = gff3_genes["gene"].fillna(gff3_genes["ID"])

# Drop attributes column
gff3_genes = gff3_genes.drop(["attributes"], axis=1)

# %%
pharokka_path = "../../../2025-12_reannotation_phage_genomes/Pharokka_proteins_phages_out/NC_010326.1_out/pharokka_proteins_full_merged_output.tsv"

gff3_genes = add_pharokka(gff3_genes, pharokka_path)
gff3_genes.loc[gff3_genes['seq_id'] == "NC_010326.1"]
# Out:
#            seq_id  source  type    start      end phase strand score  \
# 5678  NC_010326.1  RefSeq  gene   1616.0   1744.0     .      +     .
# 5679  NC_010326.1  RefSeq  gene   1757.0   2041.0     .      +     .
# 5680  NC_010326.1  RefSeq  gene   2041.0   2268.0     .      +     .
# 5681  NC_010326.1  RefSeq  gene   2279.0   2818.0     .      +     .
# 5682  NC_010326.1  RefSeq  gene   3186.0   3554.0     .      +     .
# 5683  NC_010326.1  RefSeq  gene   3541.0   3765.0     .      +     .
# 5684  NC_010326.1  RefSeq  gene   3944.0   4204.0     .      +     .
# 5685  NC_010326.1  RefSeq  gene   4204.0   4494.0     .      +     .
# 5686  NC_010326.1  RefSeq  gene   4494.0   4724.0     .      +     .
# 5687  NC_010326.1  RefSeq  gene   4729.0   5016.0     .      +     .
# 5688  NC_010326.1  RefSeq  gene   5095.0   5511.0     .      +     .
# 5689  NC_010326.1  RefSeq  gene   5580.0   5939.0     .      +     .
# 5690  NC_010326.1  RefSeq  gene   5942.0   6751.0     .      +     .
# 5691  NC_010326.1  RefSeq  gene   6831.0   7250.0     .      +     .
# 5692  NC_010326.1  RefSeq  gene   7276.0   7563.0     .      +     .
# 5693  NC_010326.1  RefSeq  gene   7553.0   7681.0     .      +     .
# 5694  NC_010326.1  RefSeq  gene   7749.0   8573.0     .      +     .
# 5695  NC_010326.1  RefSeq  gene   8617.0   9810.0     .      +     .
# 5696  NC_010326.1  RefSeq  gene   9800.0  10420.0     .      +     .
# 5697  NC_010326.1  RefSeq  gene  10420.0  11367.0     .      +     .
# 5698  NC_010326.1  RefSeq  gene  11364.0  11684.0     .      +     .
# 5699  NC_010326.1  RefSeq  gene  11681.0  14104.0     .      +     .
# 5700  NC_010326.1  RefSeq  gene  14101.0  14412.0     .      +     .
# 5701  NC_010326.1  RefSeq  gene  14467.0  15516.0     .      +     .
# 5702  NC_010326.1  RefSeq  gene  15516.0  16457.0     .      +     .
# 5703  NC_010326.1  RefSeq  gene  16447.0  16887.0     .      +     .
# 5704  NC_010326.1  RefSeq  gene  16884.0  17930.0     .      +     .
# 5705  NC_010326.1  RefSeq  gene  17940.0  18311.0     .      +     .
# 5706  NC_010326.1  RefSeq  gene  18304.0  18654.0     .      +     .
# 5707  NC_010326.1  RefSeq  gene  18663.0  21110.0     .      +     .
# 5708  NC_010326.1  RefSeq  gene  21283.0  21534.0     .      +     .
# 5709  NC_010326.1  RefSeq  gene  21534.0  22007.0     .      +     .
# 5710  NC_010326.1  RefSeq  gene  21973.0  22248.0     .      +     .
# 5711  NC_010326.1  RefSeq  gene  22260.0  23792.0     .      +     .
# 5712  NC_010326.1  RefSeq  gene  23796.0  24764.0     .      +     .
# 5713  NC_010326.1  RefSeq  gene  24817.0  25824.0     .      +     .
# 5714  NC_010326.1  RefSeq  gene  25921.0  26475.0     .      +     .
# 5715  NC_010326.1  RefSeq  gene  26478.0  28958.0     .      +     .
# 5716  NC_010326.1  RefSeq  gene  28958.0  29503.0     .      +     .
# 5717  NC_010326.1  RefSeq  gene  29503.0  32199.0     .      +     .
# 5718  NC_010326.1  RefSeq  gene  32203.0  36216.0     .      +     .
# 5719  NC_010326.1  RefSeq  gene  36218.0  36973.0     .      +     .
# 5720  NC_010326.1  RefSeq  gene  36973.0  37431.0     .      +     .
# 5721  NC_010326.1  RefSeq  gene  37424.0  38329.0     .      +     .
# 5722  NC_010326.1  RefSeq  gene  38333.0  38938.0     .      +     .
# 5723  NC_010326.1  RefSeq  gene  38938.0  39243.0     .      +     .
# 5724  NC_010326.1  RefSeq  gene  39253.0  41058.0     .      +     .
# 5725  NC_010326.1  RefSeq  gene  41055.0  41255.0     .      +     .
# 5726  NC_010326.1  RefSeq  gene  41252.0  41734.0     .      +     .
# 5727  NC_010326.1  RefSeq  gene  41692.0  42021.0     .      +     .
# 5728  NC_010326.1  RefSeq  gene  41909.0  42109.0     .      +     .
# 5729  NC_010326.1  RefSeq  gene  42111.0  42425.0     .      +     .
# 5730  NC_010326.1  RefSeq  gene  42473.0  42718.0     .      +     .
# 5731  NC_010326.1  RefSeq  gene  42728.0  42943.0     .      +     .
#
#                              ID                  Name gbkey    gene_biotype  \
# 5678         gene-PPLUZ19_gp0.1                 gp0.1  Gene  protein_coding
# 5679           gene-PPLUZ19_gp1                   gp1  Gene  protein_coding
# 5680           gene-PPLUZ19_gp2                   gp2  Gene  protein_coding
# 5681           gene-PPLUZ19_gp3                   gp3  Gene  protein_coding
# 5682           gene-PPLUZ19_gp4                   gp4  Gene  protein_coding
# 5683           gene-PPLUZ19_gp5                   gp5  Gene  protein_coding
# 5684           gene-PPLUZ19_gp6                   gp6  Gene  protein_coding
# 5685           gene-PPLUZ19_gp7                   gp7  Gene  protein_coding
# 5686           gene-PPLUZ19_gp8                   gp8  Gene  protein_coding
# 5687           gene-PPLUZ19_gp9                   gp9  Gene  protein_coding
# 5688          gene-PPLUZ19_gp10                  gp10  Gene  protein_coding
# 5689          gene-PPLUZ19_gp11                  gp11  Gene  protein_coding
# 5690          gene-PPLUZ19_gp12                  gp12  Gene  protein_coding
# 5691        gene-PPLUZ19_gp12.1                gp12.1  Gene  protein_coding
# 5692          gene-PPLUZ19_gp13                  gp13  Gene  protein_coding
# 5693        gene-PPLUZ19_gp13.1                gp13.1  Gene  protein_coding
# 5694          gene-PPLUZ19_gp14                  gp14  Gene  protein_coding
# 5695          gene-PPLUZ19_gp15                  gp15  Gene  protein_coding
# 5696          gene-PPLUZ19_gp16                  gp16  Gene  protein_coding
# 5697  gene-PPLUZ19_PPLUZ19_gp20  PPLUZ19_PPLUZ19_gp20  Gene  protein_coding
# 5698          gene-PPLUZ19_gp18                  gp18  Gene  protein_coding
# 5699          gene-PPLUZ19_gp19                  gp19  Gene  protein_coding
# 5700          gene-PPLUZ19_gp20                  gp20  Gene  protein_coding
# 5701          gene-PPLUZ19_gp21                  gp21  Gene  protein_coding
# 5702          gene-PPLUZ19_gp22                  gp22  Gene  protein_coding
# 5703          gene-PPLUZ19_gp23                  gp23  Gene  protein_coding
# 5704          gene-PPLUZ19_gp24                  gp24  Gene  protein_coding
# 5705          gene-PPLUZ19_gp25                  gp25  Gene  protein_coding
# 5706        gene-PPLUZ19_gp25.1                gp25.1  Gene  protein_coding
# 5707          gene-PPLUZ19_gp26                  gp26  Gene  protein_coding
# 5708          gene-PPLUZ19_gp27                  gp27  Gene  protein_coding
# 5709          gene-PPLUZ19_gp28                  gp28  Gene  protein_coding
# 5710          gene-PPLUZ19_gp29                  gp29  Gene  protein_coding
# 5711          gene-PPLUZ19_gp30                  gp30  Gene  protein_coding
# 5712          gene-PPLUZ19_gp31                  gp31  Gene  protein_coding
# 5713          gene-PPLUZ19_gp32                  gp32  Gene  protein_coding
# 5714          gene-PPLUZ19_gp33                  gp33  Gene  protein_coding
# 5715          gene-PPLUZ19_gp34                  gp34  Gene  protein_coding
# 5716          gene-PPLUZ19_gp35                  gp35  Gene  protein_coding
# 5717          gene-PPLUZ19_gp36                  gp36  Gene  protein_coding
# 5718          gene-PPLUZ19_gp37                  gp37  Gene  protein_coding
# 5719          gene-PPLUZ19_gp38                  gp38  Gene  protein_coding
# 5720          gene-PPLUZ19_gp39                  gp39  Gene  protein_coding
# 5721          gene-PPLUZ19_gp40                  gp40  Gene  protein_coding
# 5722          gene-PPLUZ19_gp41                  gp41  Gene  protein_coding
# 5723          gene-PPLUZ19_gp42                  gp42  Gene  protein_coding
# 5724          gene-PPLUZ19_gp43                  gp43  Gene  protein_coding
# 5725          gene-PPLUZ19_gp44                  gp44  Gene  protein_coding
# 5726          gene-PPLUZ19_gp45                  gp45  Gene  protein_coding
# 5727          gene-PPLUZ19_gp46                  gp46  Gene  protein_coding
# 5728        gene-PPLUZ19_gp46.1                gp46.1  Gene  protein_coding
# 5729          gene-PPLUZ19_gp47                  gp47  Gene  protein_coding
# 5730          gene-PPLUZ19_gp48                  gp48  Gene  protein_coding
# 5731          gene-PPLUZ19_gp49                  gp49  Gene  protein_coding
#
#                  locus_tag                       gene  \
# 5678         PPLUZ19_gp0.1                      gp0.1
# 5679           PPLUZ19_gp1                        gp1
# 5680           PPLUZ19_gp2                        gp2
# 5681           PPLUZ19_gp3                        gp3
# 5682           PPLUZ19_gp4                        gp4
# 5683           PPLUZ19_gp5                        gp5
# 5684           PPLUZ19_gp6                        gp6
# 5685           PPLUZ19_gp7                        gp7
# 5686           PPLUZ19_gp8                        gp8
# 5687           PPLUZ19_gp9                        gp9
# 5688          PPLUZ19_gp10                       gp10
# 5689          PPLUZ19_gp11                       gp11
# 5690          PPLUZ19_gp12                       gp12
# 5691        PPLUZ19_gp12.1                     gp12.1
# 5692          PPLUZ19_gp13                       gp13
# 5693        PPLUZ19_gp13.1                     gp13.1
# 5694          PPLUZ19_gp14                       gp14
# 5695          PPLUZ19_gp15                       gp15
# 5696          PPLUZ19_gp16                       gp16
# 5697  PPLUZ19_PPLUZ19_gp20  gene-PPLUZ19_PPLUZ19_gp20
# 5698          PPLUZ19_gp18                       gp18
# 5699          PPLUZ19_gp19                       gp19
# 5700          PPLUZ19_gp20                       gp20
# 5701          PPLUZ19_gp21                       gp21
# 5702          PPLUZ19_gp22                       gp22
# 5703          PPLUZ19_gp23                       gp23
# 5704          PPLUZ19_gp24                       gp24
# 5705          PPLUZ19_gp25                       gp25
# 5706        PPLUZ19_gp25.1                     gp25.1
# 5707          PPLUZ19_gp26                       gp26
# 5708          PPLUZ19_gp27                       gp27
# 5709          PPLUZ19_gp28                       gp28
# 5710          PPLUZ19_gp29                       gp29
# 5711          PPLUZ19_gp30                       gp30
# 5712          PPLUZ19_gp31                       gp31
# 5713          PPLUZ19_gp32                       gp32
# 5714          PPLUZ19_gp33                       gp33
# 5715          PPLUZ19_gp34                       gp34
# 5716          PPLUZ19_gp35                       gp35
# 5717          PPLUZ19_gp36                       gp36
# 5718          PPLUZ19_gp37                       gp37
# 5719          PPLUZ19_gp38                       gp38
# 5720          PPLUZ19_gp39                       gp39
# 5721          PPLUZ19_gp40                       gp40
# 5722          PPLUZ19_gp41                       gp41
# 5723          PPLUZ19_gp42                       gp42
# 5724          PPLUZ19_gp43                       gp43
# 5725          PPLUZ19_gp44                       gp44
# 5726          PPLUZ19_gp45                       gp45
# 5727          PPLUZ19_gp46                       gp46
# 5728        PPLUZ19_gp46.1                     gp46.1
# 5729          PPLUZ19_gp47                       gp47
# 5730          PPLUZ19_gp48                       gp48
# 5731          PPLUZ19_gp49                       gp49
#
#                                             product  \
# 5678                           hypothetical protein
# 5679                           hypothetical protein
# 5680                           hypothetical protein
# 5681                           hypothetical protein
# 5682                           hypothetical protein
# 5683                           hypothetical protein
# 5684                           hypothetical protein
# 5685                           hypothetical protein
# 5686                           hypothetical protein
# 5687                           hypothetical protein
# 5688                           hypothetical protein
# 5689                           hypothetical protein
# 5690                                 DNA polymerase
# 5691                           hypothetical protein
# 5692                           hypothetical protein
# 5693                           hypothetical protein
# 5694                                    DNA primase
# 5695                              AAA family ATPase
# 5696                         nucleotidyltransferase
# 5697                                     DNA ligase
# 5698                           hypothetical protein
# 5699                                 DNA polymerase
# 5700                           hypothetical protein
# 5701                           hypothetical protein
# 5702                                    exonuclease
# 5703                               endonuclease VII
# 5704             DNA polymerase exonuclease subunit
# 5705                           hypothetical protein
# 5706                           hypothetical protein
# 5707                                 RNA polymerase
# 5708                           hypothetical protein
# 5709                GNAT family N-acetyltransferase
# 5710                      virion structural protein
# 5711                              head-tail adaptor
# 5712                       head scaffolding protein
# 5713                             major head protein
# 5714                         tail tubular protein A
# 5715                                   tail protein
# 5716                        internal virion protein
# 5717                 internal virion lysozyme motif
# 5718  internal virion protein with endolysin domain
# 5719                             tail fiber protein
# 5720                             tail fiber protein
# 5721                             tail fiber protein
# 5722                             tail fiber protein
# 5723                        terminase small subunit
# 5724                        terminase large subunit
# 5725                                          holin
# 5726                                       lysozyme
# 5727                                     Rz protein
# 5728                                 Rz-like spanin
# 5729                             minor head protein
# 5730                             minor head protein
# 5731                           hypothetical protein
#
#                                               annot     PHROG  \
# 5678                           hypothetical protein     20091
# 5679                           hypothetical protein      5722
# 5680                           hypothetical protein      7124
# 5681                           hypothetical protein      1448
# 5682                           hypothetical protein      6951
# 5683                           hypothetical protein      7027
# 5684                           hypothetical protein     36558
# 5685                           hypothetical protein      4342
# 5686                           hypothetical protein     24541
# 5687                           hypothetical protein      4342
# 5688                           hypothetical protein      5433
# 5689                           hypothetical protein      6915
# 5690                                 DNA polymerase      6982
# 5691                           hypothetical protein      9409
# 5692                           hypothetical protein      2563
# 5693                           hypothetical protein      9768
# 5694                                    DNA primase        47
# 5695                 DnaB-like replicative helicase        19
# 5696                         nucleotidyltransferase      1614
# 5697                                     DNA ligase     30362
# 5698                           hypothetical protein      7292
# 5699                                 DNA polymerase      9556
# 5700                           hypothetical protein      5437
# 5701                           hypothetical protein       862
# 5702                                    exonuclease       107
# 5703                               endonuclease VII       423
# 5704             DNA polymerase exonuclease subunit       403
# 5705                           hypothetical protein     19117
# 5706                           hypothetical protein     18213
# 5707                                 RNA polymerase       414
# 5708                           hypothetical protein      6575
# 5709                           hypothetical protein      3986
# 5710                      virion structural protein      3112
# 5711                              head-tail adaptor       449
# 5712                       head scaffolding protein      1018
# 5713                             major head protein       267
# 5714                                   tail protein       446
# 5715                                   tail protein       457
# 5716                        internal virion protein       805
# 5717                 internal virion lysozyme motif      2083
# 5718  internal virion protein with endolysin domain       342
# 5719                             tail fiber protein      6953
# 5720                             tail fiber protein      8874
# 5721                             tail fiber protein      4176
# 5722                             tail fiber protein      4950
# 5723                        terminase small subunit       891
# 5724                        terminase large subunit     17672
# 5725                                          holin      6597
# 5726                                      endolysin         7
# 5727                                 Rz-like spanin      5151
# 5728                                 Rz-like spanin     21506
# 5729                             minor head protein      6908
# 5730                             minor head protein      7171
# 5731                           hypothetical protein  No_PHROG
#
#                                 category
# 5678                    unknown function
# 5679                    unknown function
# 5680                    unknown function
# 5681                    unknown function
# 5682                    unknown function
# 5683                    unknown function
# 5684                    unknown function
# 5685                    unknown function
# 5686                    unknown function
# 5687                    unknown function
# 5688                    unknown function
# 5689                    unknown function
# 5690  DNA, RNA and nucleotide metabolism
# 5691                    unknown function
# 5692                    unknown function
# 5693                    unknown function
# 5694  DNA, RNA and nucleotide metabolism
# 5695  DNA, RNA and nucleotide metabolism
# 5696  DNA, RNA and nucleotide metabolism
# 5697  DNA, RNA and nucleotide metabolism
# 5698                    unknown function
# 5699  DNA, RNA and nucleotide metabolism
# 5700                    unknown function
# 5701                    unknown function
# 5702  DNA, RNA and nucleotide metabolism
# 5703  DNA, RNA and nucleotide metabolism
# 5704  DNA, RNA and nucleotide metabolism
# 5705                    unknown function
# 5706                    unknown function
# 5707  DNA, RNA and nucleotide metabolism
# 5708                    unknown function
# 5709                    unknown function
# 5710                  head and packaging
# 5711                           connector
# 5712                  head and packaging
# 5713                  head and packaging
# 5714                                tail
# 5715                                tail
# 5716                  head and packaging
# 5717                  head and packaging
# 5718                  head and packaging
# 5719                                tail
# 5720                                tail
# 5721                                tail
# 5722                                tail
# 5723                  head and packaging
# 5724                  head and packaging
# 5725                               lysis
# 5726                               lysis
# 5727                               lysis
# 5728                               lysis
# 5729                  head and packaging
# 5730                  head and packaging
# 5731                    unknown function

# %%
# Load ggf3 file

gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3 = gff3.loc[gff3.iloc[:,2] == 'gene']

# Format some new columns
gff3['ID'] = pd.DataFrame(gff3.iloc[:,8].str.split('ID=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['GeneType'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene_biotype=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['Symbol'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]

# Add entity host and phage
gff3['Entity'] = np.where(gff3[0] == 'NC_010326.1', 'phage', 'host')
gff3.index = gff3['ID']
rRNAs = gff3.loc[gff3['GeneType'] == 'rRNA', 'ID'].tolist()

# %% [markdown]
# Perform in silico rRNA depletion.

# %%
df_norRNAs = rRNAdepletion(df,rRNAs)
df_norRNAs
# Out:
# SampleNames  0_R1  0_R2  0_R3  5_R1  5_R2  5_R3  10_R1  10_R2  10_R3  15_R1  \
# Geneid
# gene-PA4673   303   581   519   464    89   380    108     47     60     10
# gene-PA0041   767  1005   832   835   184   790    220    189    101     12
# gene-PA4390   175   339   215   274    47   320     94     44     69      3
# gene-PA5076   240   414   283   321    85   482    178     66     80      5
# gene-PA4316   120   181   119   114    30   119     58     28     25      1
# ...           ...   ...   ...   ...   ...   ...    ...    ...    ...    ...
# gene-PA2930    22    43    30    18    12    21      3      9      4      1
# gene-PA1153     8    37    29    58     4    36     12      8      7      0
# gene-PA1315    31    56    46    42    16    45     16      6      4      0
# gene-PA3384     6    10     6     4     2     8      2      4      0      0
# gene-PA1017    35    44    31    26     4    34      9     14      6      0
#
# SampleNames  15_R2  15_R3
# Geneid
# gene-PA4673     64     48
# gene-PA0041    174    111
# gene-PA4390     72     50
# gene-PA5076    109     65
# gene-PA4316     32     15
# ...            ...    ...
# gene-PA2930     22      5
# gene-PA1153     10      5
# gene-PA1315      7      2
# gene-PA3384      1      1
# gene-PA1017     12      5
#
# [5719 rows x 12 columns]

# %% [markdown]
# ### 2.3 Read count normalization

# %% [markdown]
# Important note: gene symbols not available for most genes.

# %%
# Function to fill in missing symbols by geneid.

def fillSymbols(df):
    df_new = df.copy()
    index = df.index.to_list()
    for i in range(0,df.shape[0]):
        if (df.iloc[i,-1:].values == None):
            df_new.iloc[i,-1:] = index[i]
    return df_new

# %% [markdown]
# Convert counts to TPM.

# %%
tpms = TPM(df_norRNAs, df_initial, 0.5)
tpms['Entity'] = gff3.loc[sorted(tpms.index.to_list()), 'Entity']
tpms['Symbol'] = gff3.loc[sorted(tpms.index.to_list()), 'Symbol']

tpms = fillSymbols(tpms)
tpms = make_unique_with_index(tpms)
tpms
# Out:
# SampleNames       0_R1       0_R2        0_R3       5_R1       5_R2  \
# Geneid
# gene-PA4673  43.756828  89.212493  106.297698  77.462003  45.499440
# gene-PA0041  11.484691  16.010756   17.679760  14.461164   9.734938
# gene-PA4390  27.637009  56.890863   48.162871  50.000246  26.375665
# gene-PA5076  47.660327  87.408828   79.734482  73.695129  59.745326
# gene-PA4316  13.255471  21.245824   18.656372  14.568991  11.830520
# ...                ...        ...         ...        ...        ...
# gene-PA2930   3.852807   7.926342    7.412176   3.664227   7.547456
# gene-PA1153   2.431086  11.413046   11.974425  19.353219   4.538265
# gene-PA1315   8.130362  15.518031   17.033483  12.688320  15.016861
# gene-PA3384   1.232714   2.118981    1.749498   0.987137   1.671802
# gene-PA1017   2.623424   3.499363    3.303710   2.265176   1.172596
#
# SampleNames       5_R3      10_R1      10_R2      10_R3      15_R1      15_R2  \
# Geneid
# gene-PA4673  52.612028  13.646682  11.066942  15.143144  15.286686   9.325232
# gene-PA0041  11.344518   2.878457   4.582443   2.636820   1.888808   2.618479
# gene-PA4390  48.404440  12.982428  11.324546  19.000817   5.565688  11.448925
# gene-PA5076  91.702779  30.859605  21.296609  27.695638  11.006305  21.760499
# gene-PA4316  12.607218   5.614023   5.066404   4.869920   1.666235   3.585125
# ...                ...        ...        ...        ...        ...        ...
# gene-PA2930   3.530827   0.522845   2.628846   1.337768   2.593719   3.863581
# gene-PA1153  10.011925   3.118902   3.928686   3.724057   1.444071   3.011505
# gene-PA1315  11.262997   3.715297   2.711188   2.016440   1.303186   1.941214
# gene-PA3384   1.546006   0.413618   1.379140   0.164624   0.957538   0.285268
# gene-PA1017   2.445133   0.612455   1.731630   0.833925   0.373119   0.926324
#
# SampleNames      15_R3 Entity       Symbol
# Geneid
# gene-PA4673   9.833026   host  gene-PA4673
# gene-PA0041   2.346249   host  gene-PA0041
# gene-PA4390  11.183136   host  gene-PA4390
# gene-PA5076  18.253307   host  gene-PA5076
# gene-PA4316   2.397718   host         sbcB
# ...                ...    ...          ...
# gene-PA2930   1.324389   host  gene-PA2930
# gene-PA1153   2.212088   host  gene-PA1153
# gene-PA1315   0.907398   host  gene-PA1315
# gene-PA3384   0.400036   host         phnC
# gene-PA1017   0.571559   host         pauA
#
# [5719 rows x 14 columns]

# %%
# Check gene names unique
len(tpms['Symbol'].unique())
# Out:
# 5719

# %% [markdown]
# Log2+1 normalization raw counts

# %%
logs = logNorm(df_norRNAs)
logs['Entity'] = gff3.loc[sorted(logs.index.to_list()), 'Entity']
logs['Symbol'] = gff3.loc[sorted(logs.index.to_list()), 'Symbol']
logs = fillSymbols(logs)
# Make gene names unique
logs = make_unique_with_index(logs)
logs
# Out:
# SampleNames      0_R1      0_R2      0_R3      5_R1      5_R2      5_R3  \
# Geneid
# gene-PA4673  8.247928  9.184875  9.022368  8.861087  6.491853  8.573647
# gene-PA0041  9.584963  9.974415  9.702173  9.707359  7.531381  9.627534
# gene-PA4390  7.459432  8.409391  7.754888  8.103288  5.584963  8.326429
# gene-PA5076  7.912889  8.696968  8.149747  8.330917  6.426265  8.915879
# gene-PA4316  6.918863  7.507795  6.906891  6.845490  4.954196  6.906891
# ...               ...       ...       ...       ...       ...       ...
# gene-PA2930  4.523562  5.459432  4.954196  4.247928  3.700440  4.459432
# gene-PA1153  3.169925  5.247928  4.906891  5.882643  2.321928  5.209453
# gene-PA1315  5.000000  5.832890  5.554589  5.426265  4.087463  5.523562
# gene-PA3384  2.807355  3.459432  2.807355  2.321928  1.584963  3.169925
# gene-PA1017  5.169925  5.491853  5.000000  4.754888  2.321928  5.129283
#
# SampleNames     10_R1     10_R2     10_R3     15_R1     15_R2     15_R3  \
# Geneid
# gene-PA4673  6.768184  5.584963  5.930737  3.459432  6.022368  5.614710
# gene-PA0041  7.787903  7.569856  6.672425  3.700440  7.451211  6.807355
# gene-PA4390  6.569856  5.491853  6.129283  2.000000  6.189825  5.672425
# gene-PA5076  7.483816  6.066089  6.339850  2.584963  6.781360  6.044394
# gene-PA4316  5.882643  4.857981  4.700440  1.000000  5.044394  4.000000
# ...               ...       ...       ...       ...       ...       ...
# gene-PA2930  2.000000  3.321928  2.321928  1.000000  4.523562  2.584963
# gene-PA1153  3.700440  3.169925  3.000000  0.000000  3.459432  2.584963
# gene-PA1315  4.087463  2.807355  2.321928  0.000000  3.000000  1.584963
# gene-PA3384  1.584963  2.321928  0.000000  0.000000  1.000000  1.000000
# gene-PA1017  3.321928  3.906891  2.807355  0.000000  3.700440  2.584963
#
# SampleNames Entity       Symbol
# Geneid
# gene-PA4673   host  gene-PA4673
# gene-PA0041   host  gene-PA0041
# gene-PA4390   host  gene-PA4390
# gene-PA5076   host  gene-PA5076
# gene-PA4316   host         sbcB
# ...            ...          ...
# gene-PA2930   host  gene-PA2930
# gene-PA1153   host  gene-PA1153
# gene-PA1315   host  gene-PA1315
# gene-PA3384   host         phnC
# gene-PA1017   host         pauA
#
# [5719 rows x 14 columns]

# %% [markdown]
# Log2+1 normalization tpms

# %%
logTPMs = logNorm(tpms.iloc[:, :-2])
logTPMs = logTPMs.join(tpms.iloc[:, -2:])
logTPMs = fillSymbols(logTPMs)
# Make gene names unique
logTPMs = make_unique_with_index(logTPMs)
logTPMs
# Out:
# SampleNames      0_R1      0_R2      0_R3      5_R1      5_R2      5_R3  \
# Geneid
# gene-PA4673  5.484036  6.495255  6.745475  6.293922  5.539141  5.744485
# gene-PA0041  3.642088  4.088375  4.223404  3.950577  3.424242  3.625799
# gene-PA4390  4.839809  5.855264  5.619497  5.672432  4.774822  5.626569
# gene-PA5076  5.604674  6.466119  6.335113  6.222942  5.924701  6.534541
# gene-PA4316  3.833444  4.475463  4.296925  3.960604  3.681508  3.766300
# ...               ...       ...       ...       ...       ...       ...
# gene-PA2930  2.278819  3.158069  3.072479  2.221638  3.095495  2.179774
# gene-PA1153  1.778665  3.633785  3.697599  4.347185  2.469434  3.460995
# gene-PA1315  3.190672  4.045970  4.172606  3.774874  4.001520  3.616240
# gene-PA3384  1.158799  1.641075  1.459168  0.990691  1.417813  1.348236
# gene-PA1017  1.857354  2.169721  2.105581  1.707161  1.119420  1.784560
#
# SampleNames     10_R1     10_R2     10_R3     15_R1     15_R2     15_R3  \
# Geneid
# gene-PA4673  3.872502  3.592988  4.012850  4.025621  3.368102  3.437364
# gene-PA0041  1.955483  2.480897  1.862678  1.530474  1.855384  1.742545
# gene-PA4390  3.805543  3.623463  4.321987  2.714946  3.637949  3.606814
# gene-PA5076  4.993656  4.478752  4.842760  3.585720  4.508460  4.267034
# gene-PA4316  2.725528  2.600842  2.553341  1.414804  2.196961  1.764566
# ...               ...       ...       ...       ...       ...       ...
# gene-PA2930  0.606769  1.859511  1.225132  1.845478  2.282019  1.216852
# gene-PA1153  2.042260  2.301203  2.240026  1.289286  2.004144  1.683512
# gene-PA1315  2.237349  1.891881  1.592847  1.203631  1.556412  0.931606
# gene-PA3384  0.499392  1.250440  0.219864  0.969040  0.362069  0.485463
# gene-PA1017  0.689259  1.449762  0.874935  0.457456  0.945850  0.652197
#
# SampleNames Entity       Symbol
# Geneid
# gene-PA4673   host  gene-PA4673
# gene-PA0041   host  gene-PA0041
# gene-PA4390   host  gene-PA4390
# gene-PA5076   host  gene-PA5076
# gene-PA4316   host         sbcB
# ...            ...          ...
# gene-PA2930   host  gene-PA2930
# gene-PA1153   host  gene-PA1153
# gene-PA1315   host  gene-PA1315
# gene-PA3384   host         phnC
# gene-PA1017   host         pauA
#
# [5719 rows x 14 columns]

# %% [markdown]
# ## 3 Filter samples, if necessary
#
# Look for outliers visually by PCA.

# %%
columnOrder = ['0_R1', '0_R2', '0_R3', '5_R1', '5_R2', '5_R3', '10_R1', '10_R2', '10_R3', '15_R1', '15_R2', '15_R3']

# %%
txPCA(tpms[columnOrder])

# %%
txPCA(logs[columnOrder])

# %%
txPCA(logTPMs[columnOrder])

# %%
tpmHost = tpms[tpms['Entity'] == 'host']
tpmPhage = tpms[tpms['Entity'] == 'phage']
logTPMsHost = logTPMs[logTPMs['Entity'] == 'host']
logTPMsPhage = logTPMs[logTPMs['Entity'] == 'phage']

# %%
logTPMs
# Out:
# SampleNames      0_R1      0_R2      0_R3      5_R1      5_R2      5_R3  \
# Geneid
# gene-PA4673  5.484036  6.495255  6.745475  6.293922  5.539141  5.744485
# gene-PA0041  3.642088  4.088375  4.223404  3.950577  3.424242  3.625799
# gene-PA4390  4.839809  5.855264  5.619497  5.672432  4.774822  5.626569
# gene-PA5076  5.604674  6.466119  6.335113  6.222942  5.924701  6.534541
# gene-PA4316  3.833444  4.475463  4.296925  3.960604  3.681508  3.766300
# ...               ...       ...       ...       ...       ...       ...
# gene-PA2930  2.278819  3.158069  3.072479  2.221638  3.095495  2.179774
# gene-PA1153  1.778665  3.633785  3.697599  4.347185  2.469434  3.460995
# gene-PA1315  3.190672  4.045970  4.172606  3.774874  4.001520  3.616240
# gene-PA3384  1.158799  1.641075  1.459168  0.990691  1.417813  1.348236
# gene-PA1017  1.857354  2.169721  2.105581  1.707161  1.119420  1.784560
#
# SampleNames     10_R1     10_R2     10_R3     15_R1     15_R2     15_R3  \
# Geneid
# gene-PA4673  3.872502  3.592988  4.012850  4.025621  3.368102  3.437364
# gene-PA0041  1.955483  2.480897  1.862678  1.530474  1.855384  1.742545
# gene-PA4390  3.805543  3.623463  4.321987  2.714946  3.637949  3.606814
# gene-PA5076  4.993656  4.478752  4.842760  3.585720  4.508460  4.267034
# gene-PA4316  2.725528  2.600842  2.553341  1.414804  2.196961  1.764566
# ...               ...       ...       ...       ...       ...       ...
# gene-PA2930  0.606769  1.859511  1.225132  1.845478  2.282019  1.216852
# gene-PA1153  2.042260  2.301203  2.240026  1.289286  2.004144  1.683512
# gene-PA1315  2.237349  1.891881  1.592847  1.203631  1.556412  0.931606
# gene-PA3384  0.499392  1.250440  0.219864  0.969040  0.362069  0.485463
# gene-PA1017  0.689259  1.449762  0.874935  0.457456  0.945850  0.652197
#
# SampleNames Entity       Symbol
# Geneid
# gene-PA4673   host  gene-PA4673
# gene-PA0041   host  gene-PA0041
# gene-PA4390   host  gene-PA4390
# gene-PA5076   host  gene-PA5076
# gene-PA4316   host         sbcB
# ...            ...          ...
# gene-PA2930   host  gene-PA2930
# gene-PA1153   host  gene-PA1153
# gene-PA1315   host  gene-PA1315
# gene-PA3384   host         phnC
# gene-PA1017   host         pauA
#
# [5719 rows x 14 columns]

# %% [markdown]
# tpmHost

# %%
txPCA(tpmHost[columnOrder])

# %% [markdown]
# tpmPhage

# %%
txPCA(tpmPhage[columnOrder])

# %% [markdown]
# logTPM Host

# %%
txPCA(logTPMsHost[columnOrder])

# %% [markdown]
# logTPM Phage

# %%
txPCA(logTPMsPhage[columnOrder])

# %% [markdown]
# $\rightarrow$ Replicates seem to be fine (not perfect, but no clear outliers detectable)

# %% [markdown]
# ## 4. Final grouping
#
# Summarize time points with mean and standard deviation for TPM-normalized data.

# %%
TPMmeans, TPMsds = getMeanSD(tpms[columnOrder])
TPMmeans = TPMmeans[['0', '5', '10', '15']]
TPMmeans[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMmeans
# Out:
#                      0          5         10         15 Entity       Symbol
# Geneid
# gene-PA4673  79.755673  58.524490  13.285589  11.481648   host  gene-PA4673
# gene-PA0041  15.058402  11.846874   3.365907   2.284512   host  gene-PA0041
# gene-PA4390  44.230248  41.593450  14.435931   9.399250   host  gene-PA4390
# gene-PA5076  71.601212  75.047745  26.617284  17.006703   host  gene-PA5076
# gene-PA4316  17.719222  13.002243   5.183449   2.549693   host         sbcB
# ...                ...        ...        ...        ...    ...          ...
# gene-PA2930   6.397108   4.914170   1.496486   2.593896   host  gene-PA2930
# gene-PA1153   8.606186  11.301136   3.590548   2.222555   host  gene-PA1153
# gene-PA1315  13.560625  12.989393   2.814308   1.383932   host  gene-PA1315
# gene-PA3384   1.700398   1.401648   0.652461   0.547614   host         phnC
# gene-PA1017   3.142166   1.960968   1.059337   0.623667   host         pauA
#
# [5719 rows x 6 columns]

# %%
TPMsds = TPMsds[['0', '5', '10', '15']]
TPMsds[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMsds
# Out:
#                      0          5        10        15 Entity       Symbol
# Geneid
# gene-PA4673  26.393354  13.702050  1.683577  2.698543   host  gene-PA4673
# gene-PA0041   2.617244   1.961900  0.865859  0.301069   host  gene-PA0041
# gene-PA4390  12.262304  10.780303  3.298058  2.712908   host  gene-PA4390
# gene-PA5076  17.216240  13.081587  3.977843  4.477997   host  gene-PA5076
# gene-PA4316   3.328676   1.152342  0.314851  0.790720   host         sbcB
# ...                ...        ...       ...       ...    ...          ...
# gene-PA2930   1.811297   1.862811  0.867066  1.036621   host  gene-PA2930
# gene-PA1153   4.372465   6.116495  0.343808  0.639945   host  gene-PA1153
# gene-PA1315   3.889299   1.547225  0.697378  0.425898   host  gene-PA1315
# gene-PA3384   0.363479   0.297569  0.523798  0.293622   host         phnC
# gene-PA1017   0.375402   0.562283  0.483905  0.228831   host         pauA
#
# [5719 rows x 6 columns]

# %%
propExp = proportionalExp(TPMmeans[['0', '5', '10', '15']])
propExp[['Entity', 'Symbol']] = TPMmeans[['Entity', 'Symbol']]
propExp
# Out:
#                     0         5        10        15 Entity       Symbol
# Geneid
# gene-PA4673  1.000000  0.733797  0.166579  0.143960   host  gene-PA4673
# gene-PA0041  1.000000  0.786728  0.223523  0.151710   host  gene-PA0041
# gene-PA4390  1.000000  0.940385  0.326381  0.212507   host  gene-PA4390
# gene-PA5076  0.954075  1.000000  0.354671  0.226612   host  gene-PA5076
# gene-PA4316  1.000000  0.733793  0.292533  0.143894   host         sbcB
# ...               ...       ...       ...       ...    ...          ...
# gene-PA2930  1.000000  0.768186  0.233932  0.405480   host  gene-PA2930
# gene-PA1153  0.761533  1.000000  0.317716  0.196666   host  gene-PA1153
# gene-PA1315  1.000000  0.957876  0.207535  0.102055   host  gene-PA1315
# gene-PA3384  1.000000  0.824306  0.383711  0.322050   host         phnC
# gene-PA1017  1.000000  0.624082  0.337136  0.198483   host         pauA
#
# [5719 rows x 6 columns]

# %% [markdown]
# ## 5. Phage gene classification

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelThreshold(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-2)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM*0.6

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x >= thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('middle')
        elif timePoint == 3:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassThreshold'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassThreshold'] = 'None'

    return tpmOut

# %%
# Export fractional expressions with T=0.6 + Host/Phage Annotation for Orthofinder Analysis
# t = classLabelThreshold(propExp)
# t = t[t["Entity"] == "phage"]
# t["Host"] = "Pseudomonas_aeruginosa_PAO1"
# t["Phage"] = "Pseudomonas_phage_LUZ19"
# t.to_csv("/ceph/ibmi/studenten/waffen/Cross_Analysis/Orthofinder_Clustering/Fractional_Expressions/T060/Brandao_LB_fractional_expression_T=0.6.tsv", sep="\t")

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelMax(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-3)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x == thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('middle')
        elif timePoint == 3:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassMax'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassMax'] = 'None'

    return tpmOut

# %%
TPMmeans = classLabelThreshold(TPMmeans)
TPMmeans = classLabelMax(TPMmeans)

# %%
TPMmeans
# Out:
#                      0          5         10         15 Entity       Symbol  \
# Geneid
# gene-PA4673  79.755673  58.524490  13.285589  11.481648   host  gene-PA4673
# gene-PA0041  15.058402  11.846874   3.365907   2.284512   host  gene-PA0041
# gene-PA4390  44.230248  41.593450  14.435931   9.399250   host  gene-PA4390
# gene-PA5076  71.601212  75.047745  26.617284  17.006703   host  gene-PA5076
# gene-PA4316  17.719222  13.002243   5.183449   2.549693   host         sbcB
# ...                ...        ...        ...        ...    ...          ...
# gene-PA2930   6.397108   4.914170   1.496486   2.593896   host  gene-PA2930
# gene-PA1153   8.606186  11.301136   3.590548   2.222555   host  gene-PA1153
# gene-PA1315  13.560625  12.989393   2.814308   1.383932   host  gene-PA1315
# gene-PA3384   1.700398   1.401648   0.652461   0.547614   host         phnC
# gene-PA1017   3.142166   1.960968   1.059337   0.623667   host         pauA
#
#             ClassThreshold ClassMax
# Geneid
# gene-PA4673           None     None
# gene-PA0041           None     None
# gene-PA4390           None     None
# gene-PA5076           None     None
# gene-PA4316           None     None
# ...                    ...      ...
# gene-PA2930           None     None
# gene-PA1153           None     None
# gene-PA1315           None     None
# gene-PA3384           None     None
# gene-PA1017           None     None
#
# [5719 rows x 8 columns]

# %%
TPMmeans[TPMmeans['Entity'] == 'phage']['ClassMax'].value_counts()
# Out:
# ClassMax
# middle    25
# late      25
# early      4
# Name: count, dtype: int64

# %% [markdown]
# Add classes to other dfs.

# %%
TPMsds[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
tpms[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
logs[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
propExp[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]

# gff3
gff3_final = gff3_genes.merge(TPMmeans[["ClassThreshold", "ClassMax"]], right_index=True, left_on="ID", how="left")
gff3_host  = gff3_final[gff3_final['seq_id'] == 'NC_002516.2']
gff3_phage = gff3_final[gff3_final['seq_id'] == 'NC_010326.1']
gff3_genes["seq_id"].unique()
# Out:
# array(['NC_002516.2', 'NC_010326.1'], dtype=object)

# %% [markdown]
# ## 6. Add variance to all dataframes

# %% [markdown]
# Base variance call on tpms.

# %%
def stabilizedVariance(df):
    labels = list()
    
    i = 0
    while i < df.shape[0]:

        # Get array of expression values at time points
        expressions = list(df.iloc[i,0:(df.shape[1]-4)])

        # Get mean expression for the gene
        exprMean = np.mean(np.array(expressions))

        # Get the variance for the gene
        varGene = np.var(np.array(expressions))

        # Stabilized variance
        stableVarGene = varGene/exprMean

        labels.append(stableVarGene)

        i += 1

    tpmOut = df.copy()
    tpmOut['Variance'] = labels

    return tpmOut

# %%
tpms = stabilizedVariance(tpms)
tpms
# Out:
# SampleNames       0_R1       0_R2        0_R3       5_R1       5_R2  \
# Geneid
# gene-PA4673  43.756828  89.212493  106.297698  77.462003  45.499440
# gene-PA0041  11.484691  16.010756   17.679760  14.461164   9.734938
# gene-PA4390  27.637009  56.890863   48.162871  50.000246  26.375665
# gene-PA5076  47.660327  87.408828   79.734482  73.695129  59.745326
# gene-PA4316  13.255471  21.245824   18.656372  14.568991  11.830520
# ...                ...        ...         ...        ...        ...
# gene-PA2930   3.852807   7.926342    7.412176   3.664227   7.547456
# gene-PA1153   2.431086  11.413046   11.974425  19.353219   4.538265
# gene-PA1315   8.130362  15.518031   17.033483  12.688320  15.016861
# gene-PA3384   1.232714   2.118981    1.749498   0.987137   1.671802
# gene-PA1017   2.623424   3.499363    3.303710   2.265176   1.172596
#
# SampleNames       5_R3      10_R1      10_R2      10_R3      15_R1      15_R2  \
# Geneid
# gene-PA4673  52.612028  13.646682  11.066942  15.143144  15.286686   9.325232
# gene-PA0041  11.344518   2.878457   4.582443   2.636820   1.888808   2.618479
# gene-PA4390  48.404440  12.982428  11.324546  19.000817   5.565688  11.448925
# gene-PA5076  91.702779  30.859605  21.296609  27.695638  11.006305  21.760499
# gene-PA4316  12.607218   5.614023   5.066404   4.869920   1.666235   3.585125
# ...                ...        ...        ...        ...        ...        ...
# gene-PA2930   3.530827   0.522845   2.628846   1.337768   2.593719   3.863581
# gene-PA1153  10.011925   3.118902   3.928686   3.724057   1.444071   3.011505
# gene-PA1315  11.262997   3.715297   2.711188   2.016440   1.303186   1.941214
# gene-PA3384   1.546006   0.413618   1.379140   0.164624   0.957538   0.285268
# gene-PA1017   2.445133   0.612455   1.731630   0.833925   0.373119   0.926324
#
# SampleNames      15_R3 Entity       Symbol ClassThreshold ClassMax   Variance
# Geneid
# gene-PA4673   9.833026   host  gene-PA4673           None     None  26.635056
# gene-PA0041   2.346249   host  gene-PA0041           None     None   4.000015
# gene-PA4390  11.183136   host  gene-PA4390           None     None  11.504956
# gene-PA5076  18.253307   host  gene-PA5076           None     None  16.865559
# gene-PA4316   2.397718   host         sbcB           None     None   4.156625
# ...                ...    ...          ...            ...      ...        ...
# gene-PA2930   1.324389   host  gene-PA2930           None     None   1.513751
# gene-PA1153   2.212088   host  gene-PA1153           None     None   4.326777
# gene-PA1315   0.907398   host  gene-PA1315           None     None   4.692133
# gene-PA3384   0.400036   host         phnC           None     None   0.356973
# gene-PA1017   0.571559   host         pauA           None     None   0.657289
#
# [5719 rows x 17 columns]

# %%
logs['Variance'] = tpms['Variance']
TPMmeans['Variance'] = tpms['Variance']
TPMsds['Variance'] = tpms['Variance']
propExp['Variance'] = tpms['Variance']

# %% [markdown]
# ## 7. Write data to output

# %%
df_norRNAs[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]

# %%
# Full TPM table
tpms.to_csv('Brandao_LB_full_TPM.tsv', sep = '\t')
# Full raw_counts table
df_norRNAs.to_csv('Brandao_LB_full_raw_counts.tsv', sep = '\t')
# Summarized (time point means) TPM table
TPMmeans.to_csv('Brandao_LB_TPM_means.tsv', sep = '\t')
# Summarized (time point) TPM standard deviation
TPMsds.to_csv('Brandao_LB_TPM_std.tsv', sep = '\t')
# Proportional expression per gene and time point
propExp.to_csv('Brandao_LB_fractional_expression.tsv', sep = '\t')
# Processed gff3 file
gff3_host.to_csv('Brandao_LB_host_gff3.tsv', sep='\t')
gff3_phage.to_csv('Brandao_LB_phage_gff3.tsv', sep='\t')
