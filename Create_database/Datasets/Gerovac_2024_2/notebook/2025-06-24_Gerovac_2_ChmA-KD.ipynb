# %% [markdown]
# # Process bulk counts table
#
# 1. Annotate columns (samples) in a way that time point and replicate are annotated
# 2. Remove rRNA genes
# 3. Perform TPM normalization and alternatively also raw counts

# %%
# Use miniconda environment Jupyter_new for running this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tools import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 Load the dataset and annotation

# %%
bulkPath = '../nf_output/countData/countData.tsv'
metaPath = '../SraRunTable.csv' # metadata from SRA
gffPath = '../nf_output/alignments/dualGenome.gff3' # output from nf pipeline

# %%
# Load and filter data
df_initial = pd.read_csv(bulkPath, sep = '\t', comment='#', index_col=0)
metadata = pd.read_csv(metaPath)

acc_drop = metadata[metadata['treatment'] == 'control anti-sense molucule']["Run"].tolist()
acc_drop = [acc + "_sorted.bam" for acc in acc_drop]
df_initial.drop(columns=acc_drop, inplace=True)
metadata = metadata[metadata['treatment'] == 'chmA-KD anti-sense molucule']

# %%
df_initial
# Out:
#                         Chr   Start     End Strand  Length  \
# Geneid
# gene-PA0001     NC_002516.2     483    2027      +    1545
# gene-PA0002     NC_002516.2    2056    3159      +    1104
# gene-PA0003     NC_002516.2    3169    4278      +    1110
# gene-PA0004     NC_002516.2    4275    6695      +    2421
# gene-PA0005     NC_002516.2    7018    7791      -     774
# ...                     ...     ...     ...    ...     ...
# gene-PHIKZ302   NC_004629.1  273499  273951      -     453
# gene-PHIKZ303   NC_004629.1  274165  276105      -    1941
# gene-PHIKZ304   NC_004629.1  276191  276604      -     414
# gene-PHIKZ305   NC_004629.1  276601  277764      -    1164
# gene-PHIKZ_p85  NC_004629.1  277865  280153      -    2289
#
#                 SRR29325147_sorted.bam  SRR29325140_sorted.bam  \
# Geneid
# gene-PA0001                       1244                    1494
# gene-PA0002                        543                     612
# gene-PA0003                       1021                    1394
# gene-PA0004                       1090                    1364
# gene-PA0005                        220                     249
# ...                                ...                     ...
# gene-PHIKZ302                       86                      88
# gene-PHIKZ303                     1743                    1444
# gene-PHIKZ304                      143                     305
# gene-PHIKZ305                      135                     225
# gene-PHIKZ_p85                     573                     875
#
#                 SRR29325146_sorted.bam  SRR29325143_sorted.bam  \
# Geneid
# gene-PA0001                       1093                    1853
# gene-PA0002                        511                     799
# gene-PA0003                       1187                    1176
# gene-PA0004                       1112                    1533
# gene-PA0005                        212                     383
# ...                                ...                     ...
# gene-PHIKZ302                       68                      76
# gene-PHIKZ303                     1442                    2172
# gene-PHIKZ304                      120                     124
# gene-PHIKZ305                      122                     177
# gene-PHIKZ_p85                     500                     616
#
#                 SRR29325145_sorted.bam  SRR29325149_sorted.bam  \
# Geneid
# gene-PA0001                       1797                    2634
# gene-PA0002                        692                    1054
# gene-PA0003                       1624                    1344
# gene-PA0004                       1622                    1772
# gene-PA0005                        337                     335
# ...                                ...                     ...
# gene-PHIKZ302                      121                      75
# gene-PHIKZ303                     1544                    2050
# gene-PHIKZ304                      516                     126
# gene-PHIKZ305                      364                     161
# gene-PHIKZ_p85                    1546                     602
#
#                 SRR29325141_sorted.bam  SRR29325144_sorted.bam  \
# Geneid
# gene-PA0001                       1520                    2572
# gene-PA0002                        730                    1143
# gene-PA0003                       1721                    1432
# gene-PA0004                       1853                    1762
# gene-PA0005                        396                     390
# ...                                ...                     ...
# gene-PHIKZ302                       83                      94
# gene-PHIKZ303                     2050                    1951
# gene-PHIKZ304                      156                     126
# gene-PHIKZ305                      181                     126
# gene-PHIKZ_p85                     660                     580
#
#                 SRR29325142_sorted.bam  SRR29325148_sorted.bam
# Geneid
# gene-PA0001                       1529                    2400
# gene-PA0002                        587                     847
# gene-PA0003                       1187                    1526
# gene-PA0004                       1221                    1975
# gene-PA0005                        232                     493
# ...                                ...                     ...
# gene-PHIKZ302                       99                     123
# gene-PHIKZ303                     2129                    2443
# gene-PHIKZ304                      149                     149
# gene-PHIKZ305                      151                     185
# gene-PHIKZ_p85                     585                     740
#
# [6054 rows x 15 columns]

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 20)
metadata
# Out:
#            Run Assay Type  AvgSpotLen      Bases    BioProject     BioSample  \
# 0  SRR29325140    RNA-Seq         101  533722178  PRJNA1121384  SAMN41750019
# 1  SRR29325141    RNA-Seq         101  753461919  PRJNA1121384  SAMN41750020
# 2  SRR29325142    RNA-Seq         101  603451366  PRJNA1121384  SAMN41750021
# 3  SRR29325143    RNA-Seq         101  623633691  PRJNA1121384  SAMN41750022
# 4  SRR29325144    RNA-Seq         101  677858773  PRJNA1121384  SAMN41750023
# 5  SRR29325145    RNA-Seq         101  659661603  PRJNA1121384  SAMN41750024
# 6  SRR29325146    RNA-Seq         101  578852311  PRJNA1121384  SAMN41750025
# 7  SRR29325147    RNA-Seq         101  595715170  PRJNA1121384  SAMN41750026
# 8  SRR29325148    RNA-Seq         101  865640700  PRJNA1121384  SAMN41750027
# 9  SRR29325149    RNA-Seq         101  649634121  PRJNA1121384  SAMN41750028
#
#        Bytes cell_line cell_type  \
# 0  170894307      PAO1  bacteria
# 1  243926897      PAO1  bacteria
# 2  191925363      PAO1  bacteria
# 3  201764245      PAO1  bacteria
# 4  216049270      PAO1  bacteria
# 5  211706251      PAO1  bacteria
# 6  182613726      PAO1  bacteria
# 7  187957528      PAO1  bacteria
# 8  273511302      PAO1  bacteria
# 9  207539737      PAO1  bacteria
#
#                                          Center Name Collection_Date Consent  \
# 0  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 1  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 2  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 3  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 4  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 5  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 6  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 7  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 8  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
# 9  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
#
#   DATASTORE filetype DATASTORE provider                      DATASTORE region  \
# 0   fastq,sra,run.zq         gs,ncbi,s3  s3.us-east-1,ncbi.public,gs.us-east1
# 1   fastq,sra,run.zq         s3,gs,ncbi  ncbi.public,s3.us-east-1,gs.us-east1
# 2   sra,fastq,run.zq         gs,s3,ncbi  ncbi.public,gs.us-east1,s3.us-east-1
# 3   run.zq,fastq,sra         ncbi,gs,s3  s3.us-east-1,ncbi.public,gs.us-east1
# 4   run.zq,sra,fastq         s3,ncbi,gs  ncbi.public,gs.us-east1,s3.us-east-1
# 5   run.zq,sra,fastq         gs,ncbi,s3  s3.us-east-1,ncbi.public,gs.us-east1
# 6   sra,run.zq,fastq         ncbi,s3,gs  gs.us-east1,s3.us-east-1,ncbi.public
# 7   sra,run.zq,fastq         s3,gs,ncbi  gs.us-east1,ncbi.public,s3.us-east-1
# 8   sra,fastq,run.zq         gs,s3,ncbi  gs.us-east1,ncbi.public,s3.us-east-1
# 9   sra,run.zq,fastq         ncbi,gs,s3  s3.us-east-1,gs.us-east1,ncbi.public
#
#     Experiment genotype geo_loc_name_country geo_loc_name_country_continent  \
# 0  SRX24841598       wt         uncalculated                   uncalculated
# 1  SRX24841597       wt         uncalculated                   uncalculated
# 2  SRX24841596       wt         uncalculated                   uncalculated
# 3  SRX24841595       wt         uncalculated                   uncalculated
# 4  SRX24841594       wt         uncalculated                   uncalculated
# 5  SRX24841593       wt         uncalculated                   uncalculated
# 6  SRX24841592       wt         uncalculated                   uncalculated
# 7  SRX24841591       wt         uncalculated                   uncalculated
# 8  SRX24841590       wt         uncalculated                   uncalculated
# 9  SRX24841589       wt         uncalculated                   uncalculated
#
#   geo_loc_name    Instrument Library Name LibraryLayout LibrarySelection  \
# 0      missing  NextSeq 2000   GSM8314441        SINGLE             cDNA
# 1      missing  NextSeq 2000   GSM8314440        SINGLE             cDNA
# 2      missing  NextSeq 2000   GSM8314439        SINGLE             cDNA
# 3      missing  NextSeq 2000   GSM8314438        SINGLE             cDNA
# 4      missing  NextSeq 2000   GSM8314437        SINGLE             cDNA
# 5      missing  NextSeq 2000   GSM8314436        SINGLE             cDNA
# 6      missing  NextSeq 2000   GSM8314435        SINGLE             cDNA
# 7      missing  NextSeq 2000   GSM8314434        SINGLE             cDNA
# 8      missing  NextSeq 2000   GSM8314433        SINGLE             cDNA
# 9      missing  NextSeq 2000   GSM8314432        SINGLE             cDNA
#
#     LibrarySource                Organism  Platform           ReleaseDate  \
# 0  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 1  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 2  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 3  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 4  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 5  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 6  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 7  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 8  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
# 9  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
#
#             create_date  version Sample Name        source_name  SRA Study  \
# 0  2024-06-07T18:44:00Z        1  GSM8314441  bacterial culture  SRP512495
# 1  2024-06-07T18:44:00Z        1  GSM8314440  bacterial culture  SRP512495
# 2  2024-06-07T18:44:00Z        1  GSM8314439  bacterial culture  SRP512495
# 3  2024-06-07T18:44:00Z        1  GSM8314438  bacterial culture  SRP512495
# 4  2024-06-07T18:43:00Z        1  GSM8314437  bacterial culture  SRP512495
# 5  2024-06-07T18:44:00Z        1  GSM8314436  bacterial culture  SRP512495
# 6  2024-06-07T18:45:00Z        1  GSM8314435  bacterial culture  SRP512495
# 7  2024-06-07T18:44:00Z        1  GSM8314434  bacterial culture  SRP512495
# 8  2024-06-07T18:44:00Z        1  GSM8314433  bacterial culture  SRP512495
# 9  2024-06-07T18:44:00Z        1  GSM8314432  bacterial culture  SRP512495
#
#               tissue                    treatment
# 0  bacterial culture  chmA-KD anti-sense molucule
# 1  bacterial culture  chmA-KD anti-sense molucule
# 2  bacterial culture  chmA-KD anti-sense molucule
# 3  bacterial culture  chmA-KD anti-sense molucule
# 4  bacterial culture  chmA-KD anti-sense molucule
# 5  bacterial culture  chmA-KD anti-sense molucule
# 6  bacterial culture  chmA-KD anti-sense molucule
# 7  bacterial culture  chmA-KD anti-sense molucule
# 8  bacterial culture  chmA-KD anti-sense molucule
# 9  bacterial culture  chmA-KD anti-sense molucule

# %% [markdown]
# ## 2 Format the dataset

# %% [markdown]
# ### 2.1 Annotate sample names

# %% [markdown]
# Issue now is that the metadata does not properly annotate sample names. Thus, this will be done manually by adding another sample name column to the metadata.

# %%
# Match GSM IDs and SampleNames inferred from GEO

sampleDict = {'GSM8314432': '10_R1',  'GSM8314433': '15_R1',
              'GSM8314434': '20_R1',  'GSM8314435': '25_R1',
              'GSM8314436': '35_R1',  'GSM8314437': '10_R2',
              'GSM8314438': '15_R2',  'GSM8314439': '20_R2',
              'GSM8314440': '25_R2',  'GSM8314441': '35_R2'
}

# %%
metadataFull = annotateData(metadata, sampleDict)

# %%
metadata.head(1)
# Out:
#            Run Assay Type  AvgSpotLen      Bases    BioProject     BioSample  \
# 0  SRR29325140    RNA-Seq         101  533722178  PRJNA1121384  SAMN41750019
#
#        Bytes cell_line cell_type  \
# 0  170894307      PAO1  bacteria
#
#                                          Center Name Collection_Date Consent  \
# 0  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...         missing  public
#
#   DATASTORE filetype DATASTORE provider                      DATASTORE region  \
# 0   fastq,sra,run.zq         gs,ncbi,s3  s3.us-east-1,ncbi.public,gs.us-east1
#
#     Experiment genotype geo_loc_name_country geo_loc_name_country_continent  \
# 0  SRX24841598       wt         uncalculated                   uncalculated
#
#   geo_loc_name    Instrument Library Name LibraryLayout LibrarySelection  \
# 0      missing  NextSeq 2000   GSM8314441        SINGLE             cDNA
#
#     LibrarySource                Organism  Platform           ReleaseDate  \
# 0  TRANSCRIPTOMIC  Pseudomonas aeruginosa  ILLUMINA  2024-07-31T00:00:00Z
#
#             create_date  version Sample Name        source_name  SRA Study  \
# 0  2024-06-07T18:44:00Z        1  GSM8314441  bacterial culture  SRP512495
#
#               tissue                    treatment
# 0  bacterial culture  chmA-KD anti-sense molucule

# %%
metadataFull.head()
# Out:
#                                 Run Assay Type  AvgSpotLen      Bases  \
# SampleID
# SRR29325140_sorted.bam  SRR29325140    RNA-Seq         101  533722178
# SRR29325141_sorted.bam  SRR29325141    RNA-Seq         101  753461919
# SRR29325142_sorted.bam  SRR29325142    RNA-Seq         101  603451366
# SRR29325143_sorted.bam  SRR29325143    RNA-Seq         101  623633691
# SRR29325144_sorted.bam  SRR29325144    RNA-Seq         101  677858773
#
#                           BioProject     BioSample      Bytes cell_line  \
# SampleID
# SRR29325140_sorted.bam  PRJNA1121384  SAMN41750019  170894307      PAO1
# SRR29325141_sorted.bam  PRJNA1121384  SAMN41750020  243926897      PAO1
# SRR29325142_sorted.bam  PRJNA1121384  SAMN41750021  191925363      PAO1
# SRR29325143_sorted.bam  PRJNA1121384  SAMN41750022  201764245      PAO1
# SRR29325144_sorted.bam  PRJNA1121384  SAMN41750023  216049270      PAO1
#
#                        cell_type  \
# SampleID
# SRR29325140_sorted.bam  bacteria
# SRR29325141_sorted.bam  bacteria
# SRR29325142_sorted.bam  bacteria
# SRR29325143_sorted.bam  bacteria
# SRR29325144_sorted.bam  bacteria
#
#                                                               Center Name  \
# SampleID
# SRR29325140_sorted.bam  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...
# SRR29325141_sorted.bam  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...
# SRR29325142_sorted.bam  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...
# SRR29325143_sorted.bam  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...
# SRR29325144_sorted.bam  JÖRG VOGEL LAB, INSTITUTE FOR MOLECULAR INFECT...
#
#                        Collection_Date Consent DATASTORE filetype  \
# SampleID
# SRR29325140_sorted.bam         missing  public   fastq,sra,run.zq
# SRR29325141_sorted.bam         missing  public   fastq,sra,run.zq
# SRR29325142_sorted.bam         missing  public   sra,fastq,run.zq
# SRR29325143_sorted.bam         missing  public   run.zq,fastq,sra
# SRR29325144_sorted.bam         missing  public   run.zq,sra,fastq
#
#                        DATASTORE provider  \
# SampleID
# SRR29325140_sorted.bam         gs,ncbi,s3
# SRR29325141_sorted.bam         s3,gs,ncbi
# SRR29325142_sorted.bam         gs,s3,ncbi
# SRR29325143_sorted.bam         ncbi,gs,s3
# SRR29325144_sorted.bam         s3,ncbi,gs
#
#                                             DATASTORE region   Experiment  \
# SampleID
# SRR29325140_sorted.bam  s3.us-east-1,ncbi.public,gs.us-east1  SRX24841598
# SRR29325141_sorted.bam  ncbi.public,s3.us-east-1,gs.us-east1  SRX24841597
# SRR29325142_sorted.bam  ncbi.public,gs.us-east1,s3.us-east-1  SRX24841596
# SRR29325143_sorted.bam  s3.us-east-1,ncbi.public,gs.us-east1  SRX24841595
# SRR29325144_sorted.bam  ncbi.public,gs.us-east1,s3.us-east-1  SRX24841594
#
#                        genotype geo_loc_name_country  \
# SampleID
# SRR29325140_sorted.bam       wt         uncalculated
# SRR29325141_sorted.bam       wt         uncalculated
# SRR29325142_sorted.bam       wt         uncalculated
# SRR29325143_sorted.bam       wt         uncalculated
# SRR29325144_sorted.bam       wt         uncalculated
#
#                        geo_loc_name_country_continent geo_loc_name  \
# SampleID
# SRR29325140_sorted.bam                   uncalculated      missing
# SRR29325141_sorted.bam                   uncalculated      missing
# SRR29325142_sorted.bam                   uncalculated      missing
# SRR29325143_sorted.bam                   uncalculated      missing
# SRR29325144_sorted.bam                   uncalculated      missing
#
#                           Instrument Library Name LibraryLayout  \
# SampleID
# SRR29325140_sorted.bam  NextSeq 2000   GSM8314441        SINGLE
# SRR29325141_sorted.bam  NextSeq 2000   GSM8314440        SINGLE
# SRR29325142_sorted.bam  NextSeq 2000   GSM8314439        SINGLE
# SRR29325143_sorted.bam  NextSeq 2000   GSM8314438        SINGLE
# SRR29325144_sorted.bam  NextSeq 2000   GSM8314437        SINGLE
#
#                        LibrarySelection   LibrarySource  \
# SampleID
# SRR29325140_sorted.bam             cDNA  TRANSCRIPTOMIC
# SRR29325141_sorted.bam             cDNA  TRANSCRIPTOMIC
# SRR29325142_sorted.bam             cDNA  TRANSCRIPTOMIC
# SRR29325143_sorted.bam             cDNA  TRANSCRIPTOMIC
# SRR29325144_sorted.bam             cDNA  TRANSCRIPTOMIC
#
#                                       Organism  Platform  \
# SampleID
# SRR29325140_sorted.bam  Pseudomonas aeruginosa  ILLUMINA
# SRR29325141_sorted.bam  Pseudomonas aeruginosa  ILLUMINA
# SRR29325142_sorted.bam  Pseudomonas aeruginosa  ILLUMINA
# SRR29325143_sorted.bam  Pseudomonas aeruginosa  ILLUMINA
# SRR29325144_sorted.bam  Pseudomonas aeruginosa  ILLUMINA
#
#                                  ReleaseDate           create_date  version  \
# SampleID
# SRR29325140_sorted.bam  2024-07-31T00:00:00Z  2024-06-07T18:44:00Z        1
# SRR29325141_sorted.bam  2024-07-31T00:00:00Z  2024-06-07T18:44:00Z        1
# SRR29325142_sorted.bam  2024-07-31T00:00:00Z  2024-06-07T18:44:00Z        1
# SRR29325143_sorted.bam  2024-07-31T00:00:00Z  2024-06-07T18:44:00Z        1
# SRR29325144_sorted.bam  2024-07-31T00:00:00Z  2024-06-07T18:43:00Z        1
#
#                        Sample Name        source_name  SRA Study  \
# SampleID
# SRR29325140_sorted.bam  GSM8314441  bacterial culture  SRP512495
# SRR29325141_sorted.bam  GSM8314440  bacterial culture  SRP512495
# SRR29325142_sorted.bam  GSM8314439  bacterial culture  SRP512495
# SRR29325143_sorted.bam  GSM8314438  bacterial culture  SRP512495
# SRR29325144_sorted.bam  GSM8314437  bacterial culture  SRP512495
#
#                                    tissue                    treatment  \
# SampleID
# SRR29325140_sorted.bam  bacterial culture  chmA-KD anti-sense molucule
# SRR29325141_sorted.bam  bacterial culture  chmA-KD anti-sense molucule
# SRR29325142_sorted.bam  bacterial culture  chmA-KD anti-sense molucule
# SRR29325143_sorted.bam  bacterial culture  chmA-KD anti-sense molucule
# SRR29325144_sorted.bam  bacterial culture  chmA-KD anti-sense molucule
#
#                                       SampleID SampleNames
# SampleID
# SRR29325140_sorted.bam  SRR29325140_sorted.bam       35_R2
# SRR29325141_sorted.bam  SRR29325141_sorted.bam       25_R2
# SRR29325142_sorted.bam  SRR29325142_sorted.bam       20_R2
# SRR29325143_sorted.bam  SRR29325143_sorted.bam       15_R2
# SRR29325144_sorted.bam  SRR29325144_sorted.bam       10_R2

# %% [markdown]
# Add correct sample names.

# %%
df = changeColnames(df_initial.iloc[:,5:df_initial.shape[1]], metadataFull)
df = df[['10_R1', '10_R2',
         '15_R1', '15_R2',
         '20_R1', '20_R2',
         '25_R1', '25_R2',
         '35_R1', '35_R2']]
df.head()
# Out:
# SampleNames  10_R1  10_R2  15_R1  15_R2  20_R1  20_R2  25_R1  25_R2  35_R1  \
# Geneid
# gene-PA0001   2634   2572   2400   1853   1244   1529   1093   1520   1797
# gene-PA0002   1054   1143    847    799    543    587    511    730    692
# gene-PA0003   1344   1432   1526   1176   1021   1187   1187   1721   1624
# gene-PA0004   1772   1762   1975   1533   1090   1221   1112   1853   1622
# gene-PA0005    335    390    493    383    220    232    212    396    337
#
# SampleNames  35_R2
# Geneid
# gene-PA0001   1494
# gene-PA0002    612
# gene-PA0003   1394
# gene-PA0004   1364
# gene-PA0005    249

# %% [markdown]
# ### 2.2 Remove rRNA genes
#
# Consult gff3 file to get rRNA geneids.

# %%
# Load gff3 and split into genes and CDS dfs
gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3.columns=["seq_id", "source", "type", "start", "end", "phase", "strand", "score", "attributes"]
gff3_genes = gff3.loc[gff3["type"] == 'gene']

# Column formating for genes
gff3_genes = gff3_genes.reset_index(drop=True)
dct_genes = gff3_genes["attributes"].str.split(';').apply(lambda items: dict(item.split('=', 1) for item in items if '=' in item))
cols_to_keep = ['ID', 'Name', 'gbkey', 'gene_biotype', 'locus_tag', 'gene']
gff3_genes = pd.concat([gff3_genes, pd.json_normalize(dct_genes)[cols_to_keep]], axis=1)

# Generate locus_tag, product dictonary over all different feature types
attrs = gff3["attributes"].str.split(";", expand=True)
attrs_dicts = attrs.apply(lambda row: {item.split("=")[0]: item.split("=")[1] for item in row if "=" in str(item)}, axis=1)
attrs_df = pd.json_normalize(attrs_dicts)
attrs_df = attrs_df.dropna(subset=["locus_tag", "product"])
locus_product_dict = dict(zip(attrs_df["locus_tag"], attrs_df["product"]))

# Add gene product, if not stated in gff3, fill with gene_biotype
gff3_genes["product"] = gff3_genes["locus_tag"].map(locus_product_dict)
# gff3_genes["product"] = gff3_genes["product"].fillna("other")
gff3_genes["product"] = gff3_genes["product"].fillna(gff3_genes["gene_biotype"])

# If gene = NA, take from ID column
gff3_genes["gene"] = gff3_genes["gene"].fillna(gff3_genes["ID"])

# Drop attributes column
gff3_genes = gff3_genes.drop(["attributes"], axis=1)

# %%
pharokka_path = "../../../2025-12_reannotation_phage_genomes/Pharokka_proteins_phages_out/NC_004629.1_out/pharokka_proteins_full_merged_output.tsv"
gff3_genes = add_pharokka(gff3_genes, pharokka_path)
gff3_genes.loc[gff3_genes['seq_id'] == "NC_004629.1"]
# Out:
#            seq_id  source  type     start       end phase strand score  \
# 5678  NC_004629.1  RefSeq  gene     164.0     553.0     .      +     .
# 5679  NC_004629.1  RefSeq  gene     517.0    1101.0     .      +     .
# 5680  NC_004629.1  RefSeq  gene    1076.0    1582.0     .      +     .
# 5681  NC_004629.1  RefSeq  gene    1582.0    2103.0     .      +     .
# 5682  NC_004629.1  RefSeq  gene    2220.0    2624.0     .      +     .
# ...           ...     ...   ...       ...       ...   ...    ...   ...
# 6049  NC_004629.1  RefSeq  gene  273499.0  273951.0     .      -     .
# 6050  NC_004629.1  RefSeq  gene  274165.0  276105.0     .      -     .
# 6051  NC_004629.1  RefSeq  gene  276191.0  276604.0     .      -     .
# 6052  NC_004629.1  RefSeq  gene  276601.0  277764.0     .      -     .
# 6053  NC_004629.1  RefSeq  gene  277865.0  280153.0     .      -     .
#
#                   ID       Name gbkey    gene_biotype  locus_tag  \
# 5678   gene-PHIKZ001   PHIKZ001  Gene  protein_coding   PHIKZ001
# 5679   gene-PHIKZ002   PHIKZ002  Gene  protein_coding   PHIKZ002
# 5680   gene-PHIKZ003   PHIKZ003  Gene  protein_coding   PHIKZ003
# 5681   gene-PHIKZ004   PHIKZ004  Gene  protein_coding   PHIKZ004
# 5682   gene-PHIKZ005   PHIKZ005  Gene  protein_coding   PHIKZ005
# ...              ...        ...   ...             ...        ...
# 6049   gene-PHIKZ302   PHIKZ302  Gene  protein_coding   PHIKZ302
# 6050   gene-PHIKZ303   PHIKZ303  Gene  protein_coding   PHIKZ303
# 6051   gene-PHIKZ304   PHIKZ304  Gene  protein_coding   PHIKZ304
# 6052   gene-PHIKZ305   PHIKZ305  Gene  protein_coding   PHIKZ305
# 6053  gene-PHIKZ_p85  PHIKZ_p85  Gene  protein_coding  PHIKZ_p85
#
#                 gene                                            product  \
# 5678   gene-PHIKZ001                                           PHIKZ001
# 5679   gene-PHIKZ002                                           PHIKZ002
# 5680   gene-PHIKZ003                                           PHIKZ003
# 5681   gene-PHIKZ004                            dihydrofolate reductase
# 5682   gene-PHIKZ005                                           PHIKZ005
# ...              ...                                                ...
# 6049   gene-PHIKZ302                                           PHIKZ302
# 6050   gene-PHIKZ303                          virion structural protein
# 6051   gene-PHIKZ304       glycine zipper 2TM domain-containing protein
# 6052   gene-PHIKZ305  ribonucleotide-diphosphate reductase subunit beta
# 6053  gene-PHIKZ_p85                           ribonucleotide reductase
#
#                                                   annot     PHROG  \
# 5678                               hypothetical protein  No_PHROG
# 5679                               hypothetical protein     16439
# 5680                               hypothetical protein     27208
# 5681                            dihydrofolate reductase       316
# 5682                               hypothetical protein      7672
# ...                                                 ...       ...
# 6049                               hypothetical protein     22034
# 6050                          virion structural protein     24656
# 6051                               hypothetical protein     15869
# 6052  ribonucleoside diphosphate reductase small sub...        86
# 6053             ribonucleotide reductase large subunit      3987
#
#                                 category
# 5678                    unknown function
# 5679                    unknown function
# 5680                    unknown function
# 5681  DNA, RNA and nucleotide metabolism
# 5682                    unknown function
# ...                                  ...
# 6049                    unknown function
# 6050                  head and packaging
# 6051                    unknown function
# 6052  DNA, RNA and nucleotide metabolism
# 6053  DNA, RNA and nucleotide metabolism
#
# [376 rows x 18 columns]

# %%
# Load ggf3 file

gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3 = gff3.loc[gff3.iloc[:,2] == 'gene']

# Format some new columns
gff3['ID'] = pd.DataFrame(gff3.iloc[:,8].str.split('ID=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['GeneType'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene_biotype=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['Symbol'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]

# Add entity host and phage
gff3['Entity'] = np.where(gff3[0] == 'NC_002516.2', 'host', 'phage')
gff3.index = gff3['ID']
rRNAs = gff3.loc[gff3['GeneType'] == 'rRNA', 'ID'].tolist()

# %%
gff3
# Out:
#                           0       1     2         3         4  5  6  7  \
# ID
# gene-PA0001     NC_002516.2  RefSeq  gene     483.0    2027.0  .  +  .
# gene-PA0002     NC_002516.2  RefSeq  gene    2056.0    3159.0  .  +  .
# gene-PA0003     NC_002516.2  RefSeq  gene    3169.0    4278.0  .  +  .
# gene-PA0004     NC_002516.2  RefSeq  gene    4275.0    6695.0  .  +  .
# gene-PA0005     NC_002516.2  RefSeq  gene    7018.0    7791.0  .  -  .
# ...                     ...     ...   ...       ...       ... .. .. ..
# gene-PHIKZ302   NC_004629.1  RefSeq  gene  273499.0  273951.0  .  -  .
# gene-PHIKZ303   NC_004629.1  RefSeq  gene  274165.0  276105.0  .  -  .
# gene-PHIKZ304   NC_004629.1  RefSeq  gene  276191.0  276604.0  .  -  .
# gene-PHIKZ305   NC_004629.1  RefSeq  gene  276601.0  277764.0  .  -  .
# gene-PHIKZ_p85  NC_004629.1  RefSeq  gene  277865.0  280153.0  .  -  .
#
#                                                                 8  \
# ID
# gene-PA0001     ID=gene-PA0001;Dbxref=GeneID:878417;Name=dnaA;...
# gene-PA0002     ID=gene-PA0002;Dbxref=GeneID:879244;Name=dnaN;...
# gene-PA0003     ID=gene-PA0003;Dbxref=GeneID:879229;Name=recF;...
# gene-PA0004     ID=gene-PA0004;Dbxref=GeneID:879230;Name=gyrB;...
# gene-PA0005     ID=gene-PA0005;Dbxref=GeneID:877576;Name=lptA;...
# ...                                                           ...
# gene-PHIKZ302   ID=gene-PHIKZ302;Dbxref=GeneID:1258400;Name=PH...
# gene-PHIKZ303   ID=gene-PHIKZ303;Dbxref=GeneID:1258398;Name=PH...
# gene-PHIKZ304   ID=gene-PHIKZ304;Dbxref=GeneID:1258396;Name=PH...
# gene-PHIKZ305   ID=gene-PHIKZ305;Dbxref=GeneID:1258402;Name=PH...
# gene-PHIKZ_p85  ID=gene-PHIKZ_p85;Dbxref=GeneID:1258206;Name=P...
#
#                             ID        GeneType Symbol Entity
# ID
# gene-PA0001        gene-PA0001  protein_coding   dnaA   host
# gene-PA0002        gene-PA0002  protein_coding   dnaN   host
# gene-PA0003        gene-PA0003  protein_coding   recF   host
# gene-PA0004        gene-PA0004  protein_coding   gyrB   host
# gene-PA0005        gene-PA0005  protein_coding   lptA   host
# ...                        ...             ...    ...    ...
# gene-PHIKZ302    gene-PHIKZ302  protein_coding   None  phage
# gene-PHIKZ303    gene-PHIKZ303  protein_coding   None  phage
# gene-PHIKZ304    gene-PHIKZ304  protein_coding   None  phage
# gene-PHIKZ305    gene-PHIKZ305  protein_coding   None  phage
# gene-PHIKZ_p85  gene-PHIKZ_p85  protein_coding   None  phage
#
# [6054 rows x 13 columns]

# %% [markdown]
# Perform in silico rRNA depletion.

# %%
df_norRNAs = rRNAdepletion(df,rRNAs)
df_norRNAs.head()
# Out:
# SampleNames  10_R1  10_R2  15_R1  15_R2  20_R1  20_R2  25_R1  25_R2  35_R1  \
# Geneid
# gene-PA1729    122    184    164    137     87    132    108    171    172
# gene-PA3070    143    207    222    141    102    120    116    222    185
# gene-PA2558    215    214    282    220    195    272    242    399    473
# gene-PA4980     27     33     23     18     10     13     11     15      9
# gene-PA4627    178    142    140    117    114    118     99    169    180
#
# SampleNames  35_R2
# Geneid
# gene-PA1729    133
# gene-PA3070    134
# gene-PA2558    411
# gene-PA4980      7
# gene-PA4627    113

# %% [markdown]
# ### 2.3 Read count normalization

# %% [markdown]
# Important note: gene symbols not available for most genes.

# %%
# Function to fill in missing symbols by geneid.

def fillSymbols(df):
    df_new = df.copy()
    index = df.index.to_list()
    for i in range(0,df.shape[0]):
        if (df.iloc[i,-1:].values == None):
            df_new.iloc[i,-1:] = index[i]
    return df_new

# %% [markdown]
# Convert counts to TPM.

# %%
tpms = TPM(df_norRNAs, df_initial, 0.5)
tpms['Entity'] = gff3.loc[sorted(tpms.index.to_list()), 'Entity']
tpms['Symbol'] = gff3.loc[sorted(tpms.index.to_list()), 'Symbol']

tpms = fillSymbols(tpms)
tpms = make_unique_with_index(tpms)
tpms
# Out:
# SampleNames      10_R1      10_R2      15_R1      15_R2      20_R1      20_R2  \
# Geneid
# gene-PA1729  15.054930  24.587603  15.610411  18.420465   9.941488  17.392502
# gene-PA3070  11.649319  18.266020  13.947117  12.521614   7.692601  10.448146
# gene-PA2558  24.764622  26.729380  25.067364  27.621563  20.769778  33.446791
# gene-PA4980   2.765191   3.652704   1.824594   2.027773   0.976073   1.449872
# gene-PA4627  14.229525  12.318114   8.648371  10.210459   8.438365  10.089602
# ...                ...        ...        ...        ...        ...        ...
# gene-PA4538  16.043183  19.707495  11.964746  13.904302   6.670048  10.957547
# gene-PA1765   3.653404   5.197380   3.286856   5.078568   2.571876   3.400935
# gene-PA4516  10.003486  12.752394   7.724265   7.500183   8.887189  10.788756
# gene-PA3086  14.567837  18.304360  13.319844  11.242027   7.995153   8.446643
# gene-PA4320  31.333205  43.700104  25.485041  29.461495  13.839591  21.345958
#
# SampleNames      25_R1      25_R2      35_R1      35_R2 Entity       Symbol
# Geneid
# gene-PA1729  15.356303  18.076901  21.999693  17.339013   host  gene-PA1729
# gene-PA3070  10.891529  15.491585  15.627066  11.539085   host  gene-PA3070
# gene-PA2558  32.093009  39.374804  56.466293  49.975220   host  gene-PA2558
# gene-PA4980   1.331694   1.336723   0.991291   0.796992   host  gene-PA4980
# gene-PA4627   9.134600  11.588816  14.931872   9.561994   host  gene-PA4627
# ...                ...        ...        ...        ...    ...          ...
# gene-PA4538  11.183684  10.626531  14.563498   9.812512   host          ndh
# gene-PA1765   3.744184   3.133393   5.252101   4.215204   host  gene-PA1765
# gene-PA4516  11.407955  12.597408  15.343520  11.293852   host  gene-PA4516
# gene-PA3086   8.468294   9.003836   8.014674   5.913850   host  gene-PA3086
# gene-PA4320  16.889934  25.613335  21.265153  15.981219   host  gene-PA4320
#
# [6041 rows x 12 columns]

# %%
# Check gene names unique
len(tpms['Symbol'].unique())
# Out:
# 6041

# %% [markdown]
# Log2+1 normalization raw counts

# %%
logs = logNorm(df_norRNAs)
logs['Entity'] = gff3.loc[sorted(logs.index.to_list()), 'Entity']
logs['Symbol'] = gff3.loc[sorted(logs.index.to_list()), 'Symbol']
logs = fillSymbols(logs)
# Make gene names unique
logs = make_unique_with_index(logs)
logs
# Out:
# SampleNames     10_R1     10_R2     15_R1     15_R2     20_R1     20_R2  \
# Geneid
# gene-PA1729  6.942515  7.531381  7.366322  7.108524  6.459432  7.055282
# gene-PA3070  7.169925  7.700440  7.800900  7.149747  6.686501  6.918863
# gene-PA2558  7.754888  7.748193  8.144658  7.787903  7.614710  8.092757
# gene-PA4980  4.807355  5.087463  4.584963  4.247928  3.459432  3.807355
# gene-PA4627  7.483816  7.159871  7.139551  6.882643  6.845490  6.894818
# ...               ...       ...       ...       ...       ...       ...
# gene-PA4538  8.044394  8.224002  7.994353  7.714246  6.894818  7.400879
# gene-PA1765  5.781360  6.169925  6.000000  6.129283  5.392317  5.584963
# gene-PA4516  6.686501  6.918863  6.686501  6.149747  6.629357  6.700440
# gene-PA3086  7.303781  7.515700  7.546894  6.807355  6.554589  6.426265
# gene-PA4320  9.273796  9.636625  9.348728  9.060696  8.209453  8.625709
#
# SampleNames     25_R1     25_R2     35_R1     35_R2 Entity       Symbol
# Geneid
# gene-PA1729  6.768184  7.426265  7.434628  7.066089   host  gene-PA1729
# gene-PA3070  6.870365  7.800900  7.539159  7.076816   host  gene-PA3070
# gene-PA2558  7.924813  8.643856  8.888743  8.686501   host  gene-PA2558
# gene-PA4980  3.584963  4.000000  3.321928  3.000000   host  gene-PA4980
# gene-PA4627  6.643856  7.409391  7.499846  6.832890   host  gene-PA4627
# ...               ...       ...       ...       ...    ...          ...
# gene-PA4538  7.321928  7.672425  7.851749  7.257388   host          ndh
# gene-PA1765  5.614710  5.781360  6.247928  5.906891   host  gene-PA1765
# gene-PA4516  6.672425  7.238405  7.247928  6.781360   host  gene-PA4516
# gene-PA3086  6.321928  6.832890  6.392317  5.930737   host  gene-PA3086
# gene-PA4320  8.179909  9.204571  8.661778  8.224002   host  gene-PA4320
#
# [6041 rows x 12 columns]

# %% [markdown]
# Log2+1 normalization tpms

# %%
logTPMs = logNorm(tpms.iloc[:, :-2])
logTPMs = logTPMs.join(tpms.iloc[:, -2:])
logTPMs = fillSymbols(logTPMs)
# Make gene names unique
logTPMs = make_unique_with_index(logTPMs)
logTPMs
# Out:
# SampleNames     10_R1     10_R2     15_R1     15_R2     20_R1     20_R2  \
# Geneid
# gene-PA1729  4.004944  4.677373  4.054016  4.279506  3.451737  4.201046
# gene-PA3070  3.660988  4.267987  3.901795  3.757196  3.119788  3.517042
# gene-PA2558  4.687320  4.793343  4.704173  4.839031  4.444255  5.106298
# gene-PA4980  1.912723  2.218069  1.498043  1.598257  0.982636  1.292707
# gene-PA4627  3.928799  3.735318  3.270285  3.486773  3.238537  3.471136
# ...               ...       ...       ...       ...       ...       ...
# gene-PA4538  4.091123  4.372081  3.696522  3.897657  2.939236  3.579850
# gene-PA1765  2.218286  2.631658  2.099920  2.603731  1.836682  2.137810
# gene-PA4516  3.459889  3.781611  3.125034  3.087494  3.305560  3.559340
# gene-PA3086  3.960497  4.270855  3.839944  3.613771  3.169148  3.239802
# gene-PA4320  5.014945  5.482206  4.727106  4.928915  3.891379  4.481942
#
# SampleNames     25_R1     25_R2     35_R1     35_R2 Entity       Symbol
# Geneid
# gene-PA1729  4.031775  4.253755  4.523543  4.196844   host  gene-PA1729
# gene-PA3070  3.571862  4.043658  4.055462  3.648360   host  gene-PA3070
# gene-PA2558  5.048455  5.335383  5.844644  5.671724   host  gene-PA2558
# gene-PA4980  1.221379  1.224487  0.993704  0.845584   host  gene-PA4980
# gene-PA4627  3.341217  3.654071  3.993844  3.400810   host  gene-PA4627
# ...               ...       ...       ...       ...    ...          ...
# gene-PA4538  3.606878  3.539349  3.960094  3.434630   host          ndh
# gene-PA1765  2.246160  2.047327  2.644341  2.382724   host  gene-PA1765
# gene-PA4516  3.633193  3.765260  4.030647  3.619865   host  gene-PA4516
# gene-PA3086  3.243104  3.322481  3.172275  2.789489   host  gene-PA3086
# gene-PA4320  4.161076  4.734077  4.476716  4.085868   host  gene-PA4320
#
# [6041 rows x 12 columns]

# %% [markdown]
# ## 3 Filter samples, if necessary
#
# Look for outliers visually by PCA.

# %%
columnOrder = ['10_R1', '10_R2',
               '15_R1', '15_R2',
               '20_R1', '20_R2',
               '25_R1', '25_R2',
               '35_R1', '35_R2']

# %%
txPCA(tpms[columnOrder])

# %%
txPCA(logs[columnOrder])

# %%
txPCA(logTPMs[columnOrder])

# %%
tpmHost = tpms[tpms['Entity'] == 'host']
tpmPhage = tpms[tpms['Entity'] == 'phage']
logTPMsHost = logTPMs[logTPMs['Entity'] == 'host']
logTPMsPhage = logTPMs[logTPMs['Entity'] == 'phage']

# %% [markdown]
# tpmHost

# %%
txPCA(tpmHost[columnOrder])

# %% [markdown]
# tpmPhage

# %%
txPCA(tpmPhage[columnOrder])

# %% [markdown]
# logTPM Host

# %%
txPCA(logTPMsHost[columnOrder])

# %% [markdown]
# logTPM Phage

# %%
txPCA(logTPMsPhage[columnOrder])

# %% [markdown]
# $\rightarrow$ Looks okay.

# %% [markdown]
# ## 4. Final grouping
#
# Summarize time points with mean and standard deviation for TPM-normalized data.

# %%
TPMmeans, TPMsds = getMeanSD(tpms[columnOrder])
TPMmeans = TPMmeans[['10', '15', '20', '25', '35']]
TPMmeans[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMmeans
# Out:
#                     10         15         20         25         35 Entity  \
# Geneid
# gene-PA1729  19.821267  17.015438  13.666995  16.716602  19.669353   host
# gene-PA3070  14.957670  13.234366   9.070373  13.191557  13.583076   host
# gene-PA2558  25.747001  26.344464  27.108284  35.733906  53.220757   host
# gene-PA4980   3.208947   1.926184   1.212973   1.334209   0.894141   host
# gene-PA4627  13.273819   9.429415   9.263984  10.361708  12.246933   host
# ...                ...        ...        ...        ...        ...    ...
# gene-PA4538  17.875339  12.934524   8.813797  10.905107  12.188005   host
# gene-PA1765   4.425392   4.182712   2.986405   3.438789   4.733653   host
# gene-PA4516  11.377940   7.612224   9.837972  12.002682  13.318686   host
# gene-PA3086  16.436098  12.280935   8.220898   8.736065   6.964262   host
# gene-PA4320  37.516654  27.473268  17.592775  21.251634  18.623186   host
#
#                   Symbol
# Geneid
# gene-PA1729  gene-PA1729
# gene-PA3070  gene-PA3070
# gene-PA2558  gene-PA2558
# gene-PA4980  gene-PA4980
# gene-PA4627  gene-PA4627
# ...                  ...
# gene-PA4538          ndh
# gene-PA1765  gene-PA1765
# gene-PA4516  gene-PA4516
# gene-PA3086  gene-PA3086
# gene-PA4320  gene-PA4320
#
# [6041 rows x 7 columns]

# %%
TPMsds = TPMsds[['10', '15', '20', '25', '35']]
TPMsds[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMsds
# Out:
#                    10        15        20        25        35 Entity  \
# Geneid
# gene-PA1729  4.766337  1.405027  3.725507  1.360299  2.330340   host
# gene-PA3070  3.308350  0.712752  1.377773  2.300028  2.043990   host
# gene-PA2558  0.982379  1.277100  6.338506  3.640898  3.245536   host
# gene-PA4980  0.443756  0.101590  0.236900  0.002514  0.097149   host
# gene-PA4627  0.955705  0.781044  0.825618  1.227108  2.684939   host
# ...               ...       ...       ...       ...       ...    ...
# gene-PA4538  1.832156  0.969778  2.143750  0.278576  2.375493   host
# gene-PA1765  0.771988  0.895856  0.414530  0.305396  0.518448   host
# gene-PA4516  1.374454  0.112041  0.950784  0.594726  2.024834   host
# gene-PA3086  1.868262  1.038909  0.225745  0.267771  1.050412   host
# gene-PA4320  6.183450  1.988227  3.753183  4.361700  2.641967   host
#
#                   Symbol
# Geneid
# gene-PA1729  gene-PA1729
# gene-PA3070  gene-PA3070
# gene-PA2558  gene-PA2558
# gene-PA4980  gene-PA4980
# gene-PA4627  gene-PA4627
# ...                  ...
# gene-PA4538          ndh
# gene-PA1765  gene-PA1765
# gene-PA4516  gene-PA4516
# gene-PA3086  gene-PA3086
# gene-PA4320  gene-PA4320
#
# [6041 rows x 7 columns]

# %%
propExp = proportionalExp(TPMmeans[['10', '15', '20', '25', '35']])
propExp[['Entity', 'Symbol']] = TPMmeans[['Entity', 'Symbol']]
propExp
# Out:
#                    10        15        20        25        35 Entity  \
# Geneid
# gene-PA1729  1.000000  0.858444  0.689512  0.843367  0.992336   host
# gene-PA3070  1.000000  0.884788  0.606403  0.881926  0.908101   host
# gene-PA2558  0.483777  0.495004  0.509355  0.671428  1.000000   host
# gene-PA4980  1.000000  0.600254  0.377997  0.415778  0.278640   host
# gene-PA4627  1.000000  0.710377  0.697914  0.780612  0.922638   host
# ...               ...       ...       ...       ...       ...    ...
# gene-PA4538  1.000000  0.723596  0.493070  0.610064  0.681834   host
# gene-PA1765  0.934879  0.883612  0.630888  0.726456  1.000000   host
# gene-PA4516  0.854284  0.571545  0.738659  0.901191  1.000000   host
# gene-PA3086  1.000000  0.747193  0.500173  0.531517  0.423717   host
# gene-PA4320  1.000000  0.732295  0.468932  0.566459  0.496398   host
#
#                   Symbol
# Geneid
# gene-PA1729  gene-PA1729
# gene-PA3070  gene-PA3070
# gene-PA2558  gene-PA2558
# gene-PA4980  gene-PA4980
# gene-PA4627  gene-PA4627
# ...                  ...
# gene-PA4538          ndh
# gene-PA1765  gene-PA1765
# gene-PA4516  gene-PA4516
# gene-PA3086  gene-PA3086
# gene-PA4320  gene-PA4320
#
# [6041 rows x 7 columns]

# %% [markdown]
# ## 5. Phage gene classification

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelThreshold(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-2)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM*0.2

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x >= thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('middle')
        elif timePoint == 3:
            labels.append('middle')
        elif timePoint == 4:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassThreshold'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassThreshold'] = 'None'

    return tpmOut

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelMax(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-3)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x == thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('middle')
        elif timePoint == 3:
            labels.append('middle')
        elif timePoint == 4:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassMax'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassMax'] = 'None'

    return tpmOut

# %%
TPMmeans = classLabelThreshold(TPMmeans)
TPMmeans = classLabelMax(TPMmeans)

# %%
TPMmeans[TPMmeans['Entity'] == 'phage']['ClassMax'].value_counts()
# Out:
# ClassMax
# early     168
# middle    145
# late       63
# Name: count, dtype: int64

# %% [markdown]
# Add classes to other dfs.

# %%
gff3_genes["seq_id"].unique()
# Out:
# array(['NC_002516.2', 'NC_004629.1'], dtype=object)

# %%
TPMsds[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
tpms[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
logs[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
propExp[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]

# gff3
gff3_final = gff3_genes.merge(TPMmeans[["ClassThreshold", "ClassMax"]], right_index=True, left_on="ID", how="left")
gff3_host  = gff3_final[gff3_final['seq_id'] == 'NC_002516.2']
gff3_phage = gff3_final[gff3_final['seq_id'] == 'NC_004629.1']

# %% [markdown]
# ## 6. Add variance to all dataframes

# %% [markdown]
# Base variance call on tpms.

# %%
def stabilizedVariance(df):
    labels = list()
    
    i = 0
    while i < df.shape[0]:

        # Get array of expression values at time points
        expressions = list(df.iloc[i,0:(df.shape[1]-4)])

        # Get mean expression for the gene
        exprMean = np.mean(np.array(expressions))

        # Get the variance for the gene
        varGene = np.var(np.array(expressions))

        # Stabilized variance
        stableVarGene = varGene/exprMean

        labels.append(stableVarGene)

        i += 1

    tpmOut = df.copy()
    tpmOut['Variance'] = labels

    return tpmOut

# %%
tpms
# Out:
# SampleNames      10_R1      10_R2      15_R1      15_R2      20_R1      20_R2  \
# Geneid
# gene-PA1729  15.054930  24.587603  15.610411  18.420465   9.941488  17.392502
# gene-PA3070  11.649319  18.266020  13.947117  12.521614   7.692601  10.448146
# gene-PA2558  24.764622  26.729380  25.067364  27.621563  20.769778  33.446791
# gene-PA4980   2.765191   3.652704   1.824594   2.027773   0.976073   1.449872
# gene-PA4627  14.229525  12.318114   8.648371  10.210459   8.438365  10.089602
# ...                ...        ...        ...        ...        ...        ...
# gene-PA4538  16.043183  19.707495  11.964746  13.904302   6.670048  10.957547
# gene-PA1765   3.653404   5.197380   3.286856   5.078568   2.571876   3.400935
# gene-PA4516  10.003486  12.752394   7.724265   7.500183   8.887189  10.788756
# gene-PA3086  14.567837  18.304360  13.319844  11.242027   7.995153   8.446643
# gene-PA4320  31.333205  43.700104  25.485041  29.461495  13.839591  21.345958
#
# SampleNames      25_R1      25_R2      35_R1      35_R2 Entity       Symbol  \
# Geneid
# gene-PA1729  15.356303  18.076901  21.999693  17.339013   host  gene-PA1729
# gene-PA3070  10.891529  15.491585  15.627066  11.539085   host  gene-PA3070
# gene-PA2558  32.093009  39.374804  56.466293  49.975220   host  gene-PA2558
# gene-PA4980   1.331694   1.336723   0.991291   0.796992   host  gene-PA4980
# gene-PA4627   9.134600  11.588816  14.931872   9.561994   host  gene-PA4627
# ...                ...        ...        ...        ...    ...          ...
# gene-PA4538  11.183684  10.626531  14.563498   9.812512   host          ndh
# gene-PA1765   3.744184   3.133393   5.252101   4.215204   host  gene-PA1765
# gene-PA4516  11.407955  12.597408  15.343520  11.293852   host  gene-PA4516
# gene-PA3086   8.468294   9.003836   8.014674   5.913850   host  gene-PA3086
# gene-PA4320  16.889934  25.613335  21.265153  15.981219   host  gene-PA4320
#
# SampleNames ClassThreshold ClassMax
# Geneid
# gene-PA1729           None     None
# gene-PA3070           None     None
# gene-PA2558           None     None
# gene-PA4980           None     None
# gene-PA4627           None     None
# ...                    ...      ...
# gene-PA4538           None     None
# gene-PA1765           None     None
# gene-PA4516           None     None
# gene-PA3086           None     None
# gene-PA4320           None     None
#
# [6041 rows x 14 columns]

# %%
tpms = stabilizedVariance(tpms)
tpms
# Out:
# SampleNames      10_R1      10_R2      15_R1      15_R2      20_R1      20_R2  \
# Geneid
# gene-PA1729  15.054930  24.587603  15.610411  18.420465   9.941488  17.392502
# gene-PA3070  11.649319  18.266020  13.947117  12.521614   7.692601  10.448146
# gene-PA2558  24.764622  26.729380  25.067364  27.621563  20.769778  33.446791
# gene-PA4980   2.765191   3.652704   1.824594   2.027773   0.976073   1.449872
# gene-PA4627  14.229525  12.318114   8.648371  10.210459   8.438365  10.089602
# ...                ...        ...        ...        ...        ...        ...
# gene-PA4538  16.043183  19.707495  11.964746  13.904302   6.670048  10.957547
# gene-PA1765   3.653404   5.197380   3.286856   5.078568   2.571876   3.400935
# gene-PA4516  10.003486  12.752394   7.724265   7.500183   8.887189  10.788756
# gene-PA3086  14.567837  18.304360  13.319844  11.242027   7.995153   8.446643
# gene-PA4320  31.333205  43.700104  25.485041  29.461495  13.839591  21.345958
#
# SampleNames      25_R1      25_R2      35_R1      35_R2 Entity       Symbol  \
# Geneid
# gene-PA1729  15.356303  18.076901  21.999693  17.339013   host  gene-PA1729
# gene-PA3070  10.891529  15.491585  15.627066  11.539085   host  gene-PA3070
# gene-PA2558  32.093009  39.374804  56.466293  49.975220   host  gene-PA2558
# gene-PA4980   1.331694   1.336723   0.991291   0.796992   host  gene-PA4980
# gene-PA4627   9.134600  11.588816  14.931872   9.561994   host  gene-PA4627
# ...                ...        ...        ...        ...    ...          ...
# gene-PA4538  11.183684  10.626531  14.563498   9.812512   host          ndh
# gene-PA1765   3.744184   3.133393   5.252101   4.215204   host  gene-PA1765
# gene-PA4516  11.407955  12.597408  15.343520  11.293852   host  gene-PA4516
# gene-PA3086   8.468294   9.003836   8.014674   5.913850   host  gene-PA3086
# gene-PA4320  16.889934  25.613335  21.265153  15.981219   host  gene-PA4320
#
# SampleNames ClassThreshold ClassMax  Variance
# Geneid
# gene-PA1729           None     None  0.821878
# gene-PA3070           None     None  0.661181
# gene-PA2558           None     None  3.642723
# gene-PA4980           None     None  0.422100
# gene-PA4627           None     None  0.430534
# ...                    ...      ...       ...
# gene-PA4538           None     None  0.955347
# gene-PA1765           None     None  0.203191
# gene-PA4516           None     None  0.488767
# gene-PA3086           None     None  1.234998
# gene-PA4320           None     None  2.885496
#
# [6041 rows x 15 columns]

# %%
logs['Variance'] = tpms['Variance']
TPMmeans['Variance'] = tpms['Variance']
TPMsds['Variance'] = tpms['Variance']
propExp['Variance'] = tpms['Variance']

# %% [markdown]
# ## 7. Write data to output

# %%
df_norRNAs[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
df_norRNAs
# Out:
# SampleNames  10_R1  10_R2  15_R1  15_R2  20_R1  20_R2  25_R1  25_R2  35_R1  \
# Geneid
# gene-PA1729    122    184    164    137     87    132    108    171    172
# gene-PA3070    143    207    222    141    102    120    116    222    185
# gene-PA2558    215    214    282    220    195    272    242    399    473
# gene-PA4980     27     33     23     18     10     13     11     15      9
# gene-PA4627    178    142    140    117    114    118     99    169    180
# ...            ...    ...    ...    ...    ...    ...    ...    ...    ...
# gene-PA4538    263    298    254    209    118    168    159    203    230
# gene-PA1765     54     71     63     69     41     47     48     54     75
# gene-PA4516    102    120    102     70     98    103    101    150    151
# gene-PA3086    157    182    186    111     93     85     79    113     83
# gene-PA4320    618    795    651    533    295    394    289    589    404
#
# SampleNames  35_R2 Entity       Symbol
# Geneid
# gene-PA1729    133   host  gene-PA1729
# gene-PA3070    134   host  gene-PA3070
# gene-PA2558    411   host  gene-PA2558
# gene-PA4980      7   host  gene-PA4980
# gene-PA4627    113   host  gene-PA4627
# ...            ...    ...          ...
# gene-PA4538    152   host          ndh
# gene-PA1765     59   host  gene-PA1765
# gene-PA4516    109   host  gene-PA4516
# gene-PA3086     60   host  gene-PA3086
# gene-PA4320    298   host  gene-PA4320
#
# [6041 rows x 12 columns]

# %%
# Full TPM table
tpms.to_csv('Gerovac_ChmA-KD_full_TPM.tsv', sep = '\t')
# Full raw_counts table
df_norRNAs.to_csv('Gerovac_ChmA-KD_full_raw_counts.tsv', sep = '\t')
# Summarized (time point means) TPM table
TPMmeans.to_csv('Gerovac_ChmA-KD_TPM_means.tsv', sep = '\t')
# Summarized (time point) TPM standard deviation
TPMsds.to_csv('Gerovac_ChmA-KD_TPM_std.tsv', sep = '\t')
# Proportional expression per gene and time point
propExp.to_csv('Gerovac_ChmA-KD_fractional_expression.tsv', sep = '\t')
# Processed gff3 file
gff3_host.to_csv('Gerovac_ChmA-KD_host_gff3.tsv', sep='\t')
gff3_phage.to_csv('Gerovac_ChmA-KD_phage_gff3.tsv', sep='\t')
