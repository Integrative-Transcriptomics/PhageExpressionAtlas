# %% [markdown]
# # Process bulk counts table
#
# 1. Annotate columns (samples) in a way that time point and replicate are annotated
# 2. Remove rRNA genes
# 3. Perform TPM normalization and alternatively also raw counts

# %%
# Use miniconda environment Jupyter_new for running this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tools import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 Load the dataset and annotation

# %%
bulkPath = '../nf_output_T4/countData/countData.tsv'
metaPath = '../Guegler_T4_SraRunTable.csv' # metadata from SRA
gffPath = '../nf_output_T4/alignments/dualGenome.gff3' # output from nf pipeline

# %%
# Load data
df_initial = pd.read_csv(bulkPath, sep = '\t', comment='#', index_col=0)
df_initial = df_initial.drop(columns=['SRR13084800_sorted.bam', 'SRR13084802_sorted.bam', 'SRR13084812_sorted.bam', 
                                      'SRR13084801_sorted.bam', 'SRR13084804_sorted.bam', 'SRR13084805_sorted.bam', 
                                      'SRR13084813_sorted.bam', 'SRR13084814_sorted.bam', 'SRR13084815_sorted.bam', 
                                      'SRR13084793_sorted.bam', 'SRR13084803_sorted.bam', 'SRR13084816_sorted.bam'])
metadata = pd.read_csv(metaPath)
metadata = metadata[metadata['plasmid'] == 'pBR322-toxIN']

# %%
df_initial.head()
# Out:
#                  Chr  Start   End Strand  Length  SRR13084797_sorted.bam  \
# Geneid
# gene-b0001  U00096.3    190   255      +      66                     503
# gene-b0002  U00096.3    337  2799      +    2463                     427
# gene-b0003  U00096.3   2801  3733      +     933                     271
# gene-b0004  U00096.3   3734  5020      +    1287                     332
# gene-b0005  U00096.3   5234  5530      +     297                      82
#
#             SRR13084807_sorted.bam  SRR13084811_sorted.bam  \
# Geneid
# gene-b0001                     394                      41
# gene-b0002                    5660                     307
# gene-b0003                    2452                     140
# gene-b0004                    3208                     171
# gene-b0005                     136                       5
#
#             SRR13084799_sorted.bam  SRR13084810_sorted.bam  \
# Geneid
# gene-b0001                     210                      20
# gene-b0002                     600                     269
# gene-b0003                     240                     141
# gene-b0004                     277                     167
# gene-b0005                      69                       5
#
#             SRR13084796_sorted.bam  SRR13084795_sorted.bam  \
# Geneid
# gene-b0001                     935                    1927
# gene-b0002                    1129                    5542
# gene-b0003                     916                    2629
# gene-b0004                    1195                    3543
# gene-b0005                     152                     233
#
#             SRR13084798_sorted.bam  SRR13084809_sorted.bam  \
# Geneid
# gene-b0001                     164                      54
# gene-b0002                     477                     504
# gene-b0003                     305                     265
# gene-b0004                     315                     380
# gene-b0005                      50                      21
#
#             SRR13084794_sorted.bam  SRR13084808_sorted.bam  \
# Geneid
# gene-b0001                   19385                     147
# gene-b0002                    3871                    2668
# gene-b0003                    1543                    1586
# gene-b0004                    1636                    2273
# gene-b0005                     228                      76
#
#             SRR13084806_sorted.bam
# Geneid
# gene-b0001                    1056
# gene-b0002                    4723
# gene-b0003                    1827
# gene-b0004                    2467
# gene-b0005                      71

# %%
pd.set_option('display.max_columns', None)  # Show all columns
metadata
# Out:
#             Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 1   SRR13084794    RNA-Seq          69  1686453978  PRJNA679481  SAMN16834535
# 2   SRR13084795    RNA-Seq          69  1335595671  PRJNA679481  SAMN16834534
# 3   SRR13084796    RNA-Seq          69  1996716825  PRJNA679481  SAMN16834533
# 4   SRR13084797    RNA-Seq          69  1812788079  PRJNA679481  SAMN16834532
# 5   SRR13084798    RNA-Seq          69  2446249893  PRJNA679481  SAMN16834531
# 6   SRR13084799    RNA-Seq          69  1982599701  PRJNA679481  SAMN16834530
# 13  SRR13084806    RNA-Seq          69  2113418388  PRJNA679481  SAMN16834520
# 14  SRR13084807    RNA-Seq          69  2282539872  PRJNA679481  SAMN16834519
# 15  SRR13084808    RNA-Seq          69  2238654147  PRJNA679481  SAMN16834518
# 16  SRR13084809    RNA-Seq          69  2340114507  PRJNA679481  SAMN16834517
# 17  SRR13084810    RNA-Seq          69  2384499861  PRJNA679481  SAMN16834516
# 18  SRR13084811    RNA-Seq          69  2408462664  PRJNA679481  SAMN16834515
#
#         Bytes Center Name Consent DATASTORE filetype DATASTORE provider  \
# 1   655654707         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 2   517075015         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 3   756938636         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 4   689470270         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 5   926640339         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 6   751744534         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 13  828984417         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 14  897364940         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 15  874909502         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 16  916071358         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 17  930160602         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 18  940416985         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                         DATASTORE region        ercc_standard  Experiment  \
# 1   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531475
# 2   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531476
# 3   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531477
# 4   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531478
# 5   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531479
# 6   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531480
# 13  gs.us-east1,ncbi.public,s3.us-east-1                   No  SRX9531487
# 14  gs.us-east1,ncbi.public,s3.us-east-1                   No  SRX9531488
# 15  gs.us-east1,ncbi.public,s3.us-east-1                   No  SRX9531465
# 16  gs.us-east1,ncbi.public,s3.us-east-1                   No  SRX9531466
# 17  gs.us-east1,ncbi.public,s3.us-east-1                   No  SRX9531467
# 18  gs.us-east1,ncbi.public,s3.us-east-1                   No  SRX9531468
#
#    GEO_Accession (exp)   Instrument LibraryLayout LibrarySelection  \
# 1           GSM4914561  NextSeq 500        PAIRED             cDNA
# 2           GSM4914562  NextSeq 500        PAIRED             cDNA
# 3           GSM4914563  NextSeq 500        PAIRED             cDNA
# 4           GSM4914564  NextSeq 500        PAIRED             cDNA
# 5           GSM4914565  NextSeq 500        PAIRED             cDNA
# 6           GSM4914566  NextSeq 500        PAIRED             cDNA
# 13          GSM4914549  NextSeq 500        PAIRED             cDNA
# 14          GSM4914550  NextSeq 500        PAIRED             cDNA
# 15          GSM4914551  NextSeq 500        PAIRED             cDNA
# 16          GSM4914552  NextSeq 500        PAIRED             cDNA
# 17          GSM4914553  NextSeq 500        PAIRED             cDNA
# 18          GSM4914554  NextSeq 500        PAIRED             cDNA
#
#      LibrarySource                                   Organism phage  \
# 1   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 2   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 3   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 4   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 5   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 6   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 13  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 14  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 15  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 16  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 17  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
# 18  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
#
#          plasmid  Platform           ReleaseDate           create_date  \
# 1   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:25:00Z
# 2   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:25:00Z
# 3   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:26:00Z
# 4   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:26:00Z
# 5   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:28:00Z
# 6   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:27:00Z
# 13  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:27:00Z
# 14  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:28:00Z
# 15  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:28:00Z
# 16  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
# 17  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
# 18  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
#
#     version Sample Name               source_name  SRA Study strain substrain  \
# 1         1  GSM4914561  Bacterial liquid culture  SRP293242   K-12    MG1655
# 2         1  GSM4914562  Bacterial liquid culture  SRP293242   K-12    MG1655
# 3         1  GSM4914563  Bacterial liquid culture  SRP293242   K-12    MG1655
# 4         1  GSM4914564  Bacterial liquid culture  SRP293242   K-12    MG1655
# 5         1  GSM4914565  Bacterial liquid culture  SRP293242   K-12    MG1655
# 6         1  GSM4914566  Bacterial liquid culture  SRP293242   K-12    MG1655
# 13        1  GSM4914549  Bacterial liquid culture  SRP293242   K-12    MG1655
# 14        1  GSM4914550  Bacterial liquid culture  SRP293242   K-12    MG1655
# 15        1  GSM4914551  Bacterial liquid culture  SRP293242   K-12    MG1655
# 16        1  GSM4914552  Bacterial liquid culture  SRP293242   K-12    MG1655
# 17        1  GSM4914553  Bacterial liquid culture  SRP293242   K-12    MG1655
# 18        1  GSM4914554  Bacterial liquid culture  SRP293242   K-12    MG1655
#
#     time_post-infection
# 1                   0.0
# 2                   2.5
# 3                   5.0
# 4                  10.0
# 5                  20.0
# 6                  30.0
# 13                  0.0
# 14                  2.5
# 15                  5.0
# 16                 10.0
# 17                 20.0
# 18                 30.0

# %% [markdown]
# ## 2 Format the dataset

# %% [markdown]
# ### 2.1 Annotate sample names

# %% [markdown]
# Issue now is that the metadata does not properly annotate sample names. Thus, this will be done manually by adding another sample name column to the metadata.

# %%
# Match GSM IDs and SampleNames inferred from GEO

sampleDict = {'GSM4914561': '0_R1', 'GSM4914562': '2.5_R1', 'GSM4914563': '5_R1',
              'GSM4914564': '10_R1', 'GSM4914565': '20_R1', 'GSM4914566': '30_R1',
              'GSM4914549': '0_R2', 'GSM4914550': '2.5_R2', 'GSM4914551': '5_R2',
              'GSM4914552': '10_R2', 'GSM4914553': '20_R2', 'GSM4914554': '30_R2',
}

# %%
metadataFull = annotateData(metadata, sampleDict)

# %%
metadata.head(1)
# Out:
#            Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 1  SRR13084794    RNA-Seq          69  1686453978  PRJNA679481  SAMN16834535
#
#        Bytes Center Name Consent DATASTORE filetype DATASTORE provider  \
# 1  655654707         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                        DATASTORE region        ercc_standard  Experiment  \
# 1  gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531475
#
#   GEO_Accession (exp)   Instrument LibraryLayout LibrarySelection  \
# 1          GSM4914561  NextSeq 500        PAIRED             cDNA
#
#     LibrarySource                                   Organism phage  \
# 1  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T4
#
#         plasmid  Platform           ReleaseDate           create_date  \
# 1  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:25:00Z
#
#    version Sample Name               source_name  SRA Study strain substrain  \
# 1        1  GSM4914561  Bacterial liquid culture  SRP293242   K-12    MG1655
#
#    time_post-infection
# 1                  0.0

# %%
metadataFull.head(1)
# Out:
#                                 Run Assay Type  AvgSpotLen       Bases  \
# SampleID
# SRR13084794_sorted.bam  SRR13084794    RNA-Seq          69  1686453978
#
#                          BioProject     BioSample      Bytes Center Name  \
# SampleID
# SRR13084794_sorted.bam  PRJNA679481  SAMN16834535  655654707         GEO
#
#                        Consent DATASTORE filetype DATASTORE provider  \
# SampleID
# SRR13084794_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                                             DATASTORE region  \
# SampleID
# SRR13084794_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1
#
#                               ercc_standard  Experiment GEO_Accession (exp)  \
# SampleID
# SRR13084794_sorted.bam  Prior to extraction  SRX9531475          GSM4914561
#
#                          Instrument LibraryLayout LibrarySelection  \
# SampleID
# SRR13084794_sorted.bam  NextSeq 500        PAIRED             cDNA
#
#                          LibrarySource  \
# SampleID
# SRR13084794_sorted.bam  TRANSCRIPTOMIC
#
#                                                          Organism phage  \
# SampleID
# SRR13084794_sorted.bam  Escherichia coli str. K-12 substr. MG1655    T4
#
#                              plasmid  Platform           ReleaseDate  \
# SampleID
# SRR13084794_sorted.bam  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z
#
#                                  create_date  version Sample Name  \
# SampleID
# SRR13084794_sorted.bam  2020-11-19T10:25:00Z        1  GSM4914561
#
#                                      source_name  SRA Study strain substrain  \
# SampleID
# SRR13084794_sorted.bam  Bacterial liquid culture  SRP293242   K-12    MG1655
#
#                         time_post-infection                SampleID  \
# SampleID
# SRR13084794_sorted.bam                  0.0  SRR13084794_sorted.bam
#
#                        SampleNames
# SampleID
# SRR13084794_sorted.bam        0_R1

# %% [markdown]
# Add correct sample names.

# %%
df = changeColnames(df_initial.iloc[:,5:df_initial.shape[1]], metadataFull)
df = df[['0_R1', '0_R2', '2.5_R1', '2.5_R2', '5_R1', '5_R2', '10_R1', '10_R2', '20_R1', '20_R2', '30_R1', '30_R2']]
df
# Out:
# SampleNames   0_R1  0_R2  2.5_R1  2.5_R2    5_R1  5_R2   10_R1  10_R2   20_R1  \
# Geneid
# gene-b0001   19385  1056    1927     394     935   147     503     54     164
# gene-b0002    3871  4723    5542    5660    1129  2668     427    504     477
# gene-b0003    1543  1827    2629    2452     916  1586     271    265     305
# gene-b0004    1636  2467    3543    3208    1195  2273     332    380     315
# gene-b0005     228    71     233     136     152    76      82     21      50
# ...            ...   ...     ...     ...     ...   ...     ...    ...     ...
# gene-T4p274     21     0   30501    1486   56548  2593   43522   1667   21894
# gene-T4p275     10     1   22210    1678   41786  2824   33609   1649   15662
# gene-T4p276     24     0     416       4   46225   771  158794  11655   64288
# gene-T4p277      9     1     238       2   43666   729   82279   7756   34053
# gene-T4p278     82     1    6767     116  265684  7012  369604  44180  223534
#
# SampleNames  20_R2  30_R1  30_R2
# Geneid
# gene-b0001      20    210     41
# gene-b0002     269    600    307
# gene-b0003     141    240    140
# gene-b0004     167    277    171
# gene-b0005       5     69      5
# ...            ...    ...    ...
# gene-T4p274    829  27070    938
# gene-T4p275    864  18909    871
# gene-T4p276   7636  59062   7497
# gene-T4p277   5269  21326   2758
# gene-T4p278  37265  93203  14495
#
# [4794 rows x 12 columns]

# %% [markdown]
# ### 2.2 Remove rRNA genes

# %% [markdown]
# 2.1 Process gff3 files for front end processing

# %%
# Load gff3 and split into genes and CDS dfs
gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3.columns=["seq_id", "source", "type", "start", "end", "phase", "strand", "score", "attributes"]
gff3_genes = gff3.loc[gff3["type"] == 'gene']

# Column formating for genes
gff3_genes = gff3_genes.reset_index(drop=True)
dct_genes = gff3_genes["attributes"].str.split(';').apply(lambda items: dict(item.split('=', 1) for item in items if '=' in item))
cols_to_keep = ['ID', 'Name', 'gbkey', 'gene_biotype', 'locus_tag', 'gene']
gff3_genes = pd.concat([gff3_genes, pd.json_normalize(dct_genes)[cols_to_keep]], axis=1)

# Generate locus_tag, product dictonary over all different feature types
attrs = gff3["attributes"].str.split(";", expand=True)
attrs_dicts = attrs.apply(lambda row: {item.split("=")[0]: item.split("=")[1] for item in row if "=" in str(item)}, axis=1)
attrs_df = pd.json_normalize(attrs_dicts)
attrs_df = attrs_df.dropna(subset=["locus_tag", "product"])
locus_product_dict = dict(zip(attrs_df["locus_tag"], attrs_df["product"]))

# Add gene product, if not stated in gff3, fill with gene_biotype
gff3_genes["product"] = gff3_genes["locus_tag"].map(locus_product_dict)
# gff3_genes["product"] = gff3_genes["product"].fillna("other")
gff3_genes["product"] = gff3_genes["product"].fillna(gff3_genes["gene_biotype"])

# If gene = NA, take from ID column
gff3_genes["gene"] = gff3_genes["gene"].fillna(gff3_genes["ID"])

# Drop attributes column
gff3_genes = gff3_genes.drop(["attributes"], axis=1)

# %%
pharokka_path = "../../../2025-12_reannotation_phage_genomes/Pharokka_proteins_phages_out/NC_000866.4_out/pharokka_proteins_full_merged_output.tsv"
gff3_genes = add_pharokka(gff3_genes, pharokka_path)
gff3_genes.loc[gff3_genes['seq_id'] == "NC_000866.4"]
# Out:
#            seq_id  source  type     start       end phase strand score  \
# 4506  NC_000866.4  RefSeq  gene      12.0    2189.0     .      -     .
# 4507  NC_000866.4  RefSeq  gene    2200.0    2403.0     .      -     .
# 4508  NC_000866.4  RefSeq  gene    2458.0    2990.0     .      -     .
# 4509  NC_000866.4  RefSeq  gene    2971.0    3351.0     .      -     .
# 4510  NC_000866.4  RefSeq  gene    3654.0    3767.0     .      -     .
# ...           ...     ...   ...       ...       ...   ...    ...   ...
# 4789  NC_000866.4  RefSeq  gene  166815.0  166913.0     .      -     .
# 4790  NC_000866.4  RefSeq  gene  166910.0  166996.0     .      -     .
# 4791  NC_000866.4  RefSeq  gene  167103.0  167660.0     .      -     .
# 4792  NC_000866.4  RefSeq  gene  167743.0  167937.0     .      -     .
# 4793  NC_000866.4  RefSeq  gene  167965.0  168903.0     .      -     .
#
#                ID    Name gbkey    gene_biotype locus_tag    gene  \
# 4506  gene-T4p001    rIIA  Gene  protein_coding    T4p001    rIIA
# 4507  gene-T4p002  rIIA.1  Gene  protein_coding    T4p002  rIIA.1
# 4508  gene-T4p003      60  Gene  protein_coding    T4p003      60
# 4509  gene-T4p004    60.1  Gene  protein_coding    T4p004    60.1
# 4510  gene-T4p005    mobA  Gene  protein_coding    T4p005    mobA
# ...           ...     ...   ...             ...       ...     ...
# 4789  gene-T4p274   ndd.5  Gene  protein_coding    T4p274   ndd.5
# 4790  gene-T4p275   ndd.6  Gene  protein_coding    T4p275   ndd.6
# 4791  gene-T4p276    denB  Gene  protein_coding    T4p276    denB
# 4792  gene-T4p277  denB.1  Gene  protein_coding    T4p277  denB.1
# 4793  gene-T4p278    rIIB  Gene  protein_coding    T4p278    rIIB
#
#                             product                          annot     PHROG  \
# 4506           RIIA lysis inhibitor           RIIA lysis inhibitor       612
# 4507    rIIA.1 hypothetical protein           hypothetical protein      1683
# 4508           DNA topoisomerase II           DNA topoisomerase II      7229
# 4509    gp60.1 hypothetical protein           hypothetical protein  No_PHROG
# 4510            homing endonuclease            homing endonuclease       655
# ...                             ...                            ...       ...
# 4789         outer membrane protein         outer membrane protein      5011
# 4790         outer membrane protein         outer membrane protein      8851
# 4791  DenB-like DNA endonuclease IV  DenB-like DNA endonuclease IV      1360
# 4792    DenB.1 hypothetical protein           hypothetical protein       774
# 4793           RIIB lysis inhibitor           RIIB lysis inhibitor       609
#
#                                 category
# 4506                               lysis
# 4507                    unknown function
# 4508  DNA, RNA and nucleotide metabolism
# 4509                    unknown function
# 4510  DNA, RNA and nucleotide metabolism
# ...                                  ...
# 4789                               other
# 4790                               other
# 4791  DNA, RNA and nucleotide metabolism
# 4792                    unknown function
# 4793                               lysis
#
# [288 rows x 18 columns]

# %% [markdown]
# 2.2 Consult gff3 file to get rRNA geneids.

# %%
# Load ggf3 file
gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3 = gff3.loc[gff3.iloc[:,2] == 'gene']

# Format some new columns
gff3['ID'] = pd.DataFrame(gff3.iloc[:,8].str.split('ID=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['GeneType'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene_biotype=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['Symbol'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]

# Add entity host and phage
gff3['Entity'] = np.where(gff3[0] == 'NC_000866.4', 'phage', 'host')
gff3.index = gff3['ID']
rRNAs = gff3.loc[gff3['GeneType'] == 'rRNA', 'ID'].tolist()

# %% [markdown]
# Perform in silico rRNA depletion.

# %%
df_norRNAs = rRNAdepletion(df,rRNAs)
df_norRNAs
# Out:
# SampleNames   0_R1  0_R2  2.5_R1  2.5_R2  5_R1  5_R2  10_R1  10_R2  20_R1  \
# Geneid
# gene-b4740     218    34     167      60    32    13     22      3     29
# gene-T4p194      3     0    2963       1  5769    25   7946     61  49079
# gene-b3425    1122   311     444     157   106    53     59     16     54
# gene-b1465      48    10      45       7    36     1     23      0     30
# gene-b1757     187    22     149      36    71    10     59      5     58
# ...            ...   ...     ...     ...   ...   ...    ...    ...    ...
# gene-b1142     480     9     128      16   249    19    397     21    249
# gene-b2044      97    15     107      26    58    14     34      6     52
# gene-b4414   26912  4424   15176    5041  7634  3855   1987    973   1704
# gene-b0471    4705   942    4030    1549   812   799    219    207    235
# gene-b4296     325    29     233      44   135    18     94     15    116
#
# SampleNames  20_R2  30_R1  30_R2
# Geneid
# gene-b4740       0     67      2
# gene-T4p194   4771  34707   5524
# gene-b3425       2    101      9
# gene-b1465       1    102      3
# gene-b1757       3    150      8
# ...            ...    ...    ...
# gene-b1142      12    290     10
# gene-b2044       0    138      3
# gene-b4414     527    911    565
# gene-b0471      77    153    124
# gene-b4296      10    329      5
#
# [4772 rows x 12 columns]

# %% [markdown]
# ### 2.3 Read count normalization

# %% [markdown]
# Important note: gene symbols not available for most genes.

# %%
# Function to fill in missing symbols by geneid.

def fillSymbols(df):
    df_new = df.copy()
    index = df.index.to_list()
    for i in range(0,df.shape[0]):
        if (df.iloc[i,-1:].values == None):
            df_new.iloc[i,-1:] = index[i]
    return df_new

# %% [markdown]
# Convert counts to TPM.

# %%
tpms = TPM(df_norRNAs, df_initial, 0.5)
tpms['Entity'] = gff3.loc[sorted(tpms.index.to_list()), 'Entity']
tpms['Symbol'] = gff3.loc[sorted(tpms.index.to_list()), 'Symbol']

tpms = fillSymbols(tpms)
tpms = make_unique_with_index(tpms)
tpms
# Out:
# SampleNames         0_R1         0_R2       2.5_R1       2.5_R2        5_R1  \
# Geneid
# gene-b4740     21.136456    21.039141    15.483124    23.953333    2.032102
# gene-T4p194     0.038956     0.035083    31.518835     0.068332   41.507041
# gene-b3425     67.740672   118.508463    25.632913    38.902145    4.154265
# gene-b1465      1.405418     1.918144     1.259906     0.889518    0.683657
# gene-b1757      2.828814     2.140000     2.155298     2.253854    0.697253
# ...                  ...          ...          ...          ...         ...
# gene-b1142     30.391330     3.787984     7.766449     4.271399   10.200191
# gene-b2044      1.575796     1.579265     1.660224     1.752956    0.611128
# gene-b4414   3905.044971  4047.290323  2104.295241  2994.067653  716.034629
# gene-b0471    281.386167   355.309228   230.313259   379.243710   31.405215
# gene-b4296      4.758040     2.718487     3.261573     2.662361    1.280259
#
# SampleNames         5_R2       10_R1       10_R2       20_R1       20_R2  \
# Geneid
# gene-b4740      5.665708    1.614916    1.798679    1.117043    0.242198
# gene-T4p194     1.231351   65.624299    3.636488  213.830372  265.935914
# gene-b3425     14.007371    2.664199    5.289955    1.287439    0.755480
# gene-b1465      0.188580    0.505264    0.076973    0.345964    0.217658
# gene-b1757      0.687278    0.666050    0.440830    0.345483    0.264418
# ...                  ...         ...         ...         ...         ...
# gene-b1142      5.350947   18.654348    7.224365    6.177233    3.959007
# gene-b2044      1.016724    0.413715    0.558102    0.332140    0.040466
# gene-b4414   2427.126402  213.976340  750.434628   96.813539  383.278409
# gene-b0471    207.422146    9.739084   65.920422    5.512581   23.206976
# gene-b4296      1.173245    1.024933    1.203687    0.666607    0.768575
#
# SampleNames       30_R1       30_R2 Entity Symbol
# Geneid
# gene-b4740     2.853694    1.099832   host   ymgM
# gene-T4p194  168.829528  279.640861  phage     29
# gene-b3425     2.677023    2.607307   host   glpE
# gene-b1465     1.298107    0.461251   host   narV
# gene-b1757     0.992345    0.583214   host   ynjE
# ...                 ...         ...    ...    ...
# gene-b1142     8.030181    3.020307   host   ymfH
# gene-b2044     0.978291    0.257258   host   wcaL
# gene-b4414    57.803159  373.172893   host    tff
# gene-b0471     4.011698   33.858819   host   ybaB
# gene-b4296     2.105016    0.365633   host   yjhF
#
# [4772 rows x 14 columns]

# %%
# Check gene names unique
len(tpms['Symbol'].unique())
# Out:
# 4772

# %% [markdown]
# Log2+1 normalization raw counts

# %%
logs = logNorm(df_norRNAs)
logs['Entity'] = gff3.loc[sorted(logs.index.to_list()), 'Entity']
logs['Symbol'] = gff3.loc[sorted(logs.index.to_list()), 'Symbol']
logs = fillSymbols(logs)
# Make gene names unique
logs = make_unique_with_index(logs)
logs
# Out:
# SampleNames       0_R1       0_R2     2.5_R1     2.5_R2       5_R1       5_R2  \
# Geneid
# gene-b4740    7.774787   5.129283   7.392317   5.930737   5.044394   3.807355
# gene-T4p194   2.000000   0.000000  11.533330   1.000000  12.494356   4.700440
# gene-b3425   10.133142   8.285402   8.797662   7.303781   6.741467   5.754888
# gene-b1465    5.614710   3.459432   5.523562   3.000000   5.209453   1.000000
# gene-b1757    7.554589   4.523562   7.228819   5.209453   6.169925   3.459432
# ...                ...        ...        ...        ...        ...        ...
# gene-b1142    8.909893   3.321928   7.011227   4.087463   7.965784   4.321928
# gene-b2044    6.614710   4.000000   6.754888   4.754888   5.882643   3.906891
# gene-b4414   14.716016  12.111462  13.889599  12.299780  12.898412  11.912889
# gene-b0471   12.200286   9.881114  11.976922  10.598053   9.667112   9.643856
# gene-b4296    8.348728   4.906891   7.870365   5.491853   7.087463   4.247928
#
# SampleNames      10_R1     10_R2      20_R1      20_R2      30_R1      30_R2  \
# Geneid
# gene-b4740    4.523562  2.000000   4.906891   0.000000   6.087463   1.584963
# gene-T4p194  12.956195  5.954196  15.582848  12.220378  15.082981  12.431759
# gene-b3425    5.906891  4.087463   5.781360   1.584963   6.672425   3.321928
# gene-b1465    4.584963  0.000000   4.954196   1.000000   6.686501   2.000000
# gene-b1757    5.906891  2.584963   5.882643   2.000000   7.238405   3.169925
# ...                ...       ...        ...        ...        ...        ...
# gene-b1142    8.636625  4.459432   7.965784   3.700440   8.184875   3.459432
# gene-b2044    5.129283  2.807355   5.727920   0.000000   7.118941   2.000000
# gene-b4414   10.957102  9.927778  10.735556   9.044394   9.832890   9.144658
# gene-b0471    7.781360  7.700440   7.882643   6.285402   7.266787   6.965784
# gene-b4296    6.569856  4.000000   6.870365   3.459432   8.366322   2.584963
#
# SampleNames Entity Symbol
# Geneid
# gene-b4740    host   ymgM
# gene-T4p194  phage     29
# gene-b3425    host   glpE
# gene-b1465    host   narV
# gene-b1757    host   ynjE
# ...            ...    ...
# gene-b1142    host   ymfH
# gene-b2044    host   wcaL
# gene-b4414    host    tff
# gene-b0471    host   ybaB
# gene-b4296    host   yjhF
#
# [4772 rows x 14 columns]

# %% [markdown]
# Log2+1 normalization tpms

# %%
logTPMs = logNorm(tpms.iloc[:, :-2])
logTPMs = logTPMs.join(tpms.iloc[:, -2:])
logTPMs = fillSymbols(logTPMs)
# Make gene names unique
logTPMs = make_unique_with_index(logTPMs)
logTPMs
# Out:
# SampleNames       0_R1       0_R2     2.5_R1     2.5_R2      5_R1       5_R2  \
# Geneid
# gene-b4740    4.468352   4.461996   4.042918   4.641161  1.600318   2.736758
# gene-T4p194   0.055134   0.049747   5.023204   0.095360  5.409630   1.157918
# gene-b3425    6.103092   6.900969   4.735138   5.318394  2.365767   3.907599
# gene-b1465    1.266288   1.545051   1.176263   0.918019  0.751598   0.249239
# gene-b1757    1.936898   1.650765   1.657776   1.702150  0.763202   0.754697
# ...                ...        ...        ...        ...       ...        ...
# gene-b1142    4.972294   2.259418   3.131993   2.398186  3.485451   2.666972
# gene-b2044    1.365018   1.366960   1.411548   1.460981  0.688072   1.012013
# gene-b4414   11.931493  11.983097  11.039807  11.548373  9.485899  11.245628
# gene-b0471    8.141526   8.476986   7.853704   8.570781  5.018154   7.703365
# gene-b4296    2.525578   1.894716   2.091386   1.872774  1.189198   1.119851
#
# SampleNames     10_R1     10_R2     20_R1     20_R2     30_R1     30_R2  \
# Geneid
# gene-b4740   1.386764  1.484746  1.082050  0.312895  1.946242  1.070274
# gene-T4p194  6.057977  2.213033  7.747054  8.060350  7.407944  8.132581
# gene-b3425   1.873498  2.653050  1.193733  0.811866  1.878538  1.850922
# gene-b1465   0.590016  0.106982  0.428640  0.284109  1.200446  0.547204
# gene-b1757   0.736432  0.526900  0.428124  0.338474  0.994467  0.662856
# ...               ...       ...       ...       ...       ...       ...
# gene-b1142   4.296777  3.039904  2.843428  2.310051  3.174755  2.007306
# gene-b2044   0.499491  0.639790  0.413746  0.057229  0.984254  0.330281
# gene-b4414   7.748034  9.553504  6.611962  8.586008  5.877822  8.547561
# gene-b0471   3.424799  6.064375  2.703229  4.597351  2.325300  5.123452
# gene-b4296   1.017874  1.139920  0.736914  0.822588  1.634601  0.449570
#
# SampleNames Entity Symbol
# Geneid
# gene-b4740    host   ymgM
# gene-T4p194  phage     29
# gene-b3425    host   glpE
# gene-b1465    host   narV
# gene-b1757    host   ynjE
# ...            ...    ...
# gene-b1142    host   ymfH
# gene-b2044    host   wcaL
# gene-b4414    host    tff
# gene-b0471    host   ybaB
# gene-b4296    host   yjhF
#
# [4772 rows x 14 columns]

# %% [markdown]
# ## 3 Filter samples, if necessary
#
# Look for outliers visually by PCA.

# %%
columnOrder = ['0_R1', '0_R2', '2.5_R1', '2.5_R2', '5_R1', '5_R2', '10_R1', '10_R2', '20_R1', '20_R2', '30_R1', '30_R2']

# %%
txPCA(tpms[columnOrder])

# %%
txPCA(logs[columnOrder])

# %%
txPCA(logTPMs[columnOrder])

# %%
tpmHost = tpms[tpms['Entity'] == 'host']
tpmPhage = tpms[tpms['Entity'] == 'phage']
logTPMsHost = logTPMs[logTPMs['Entity'] == 'host']
logTPMsPhage = logTPMs[logTPMs['Entity'] == 'phage']

# %%
logTPMs
# Out:
# SampleNames       0_R1       0_R2     2.5_R1     2.5_R2      5_R1       5_R2  \
# Geneid
# gene-b4740    4.468352   4.461996   4.042918   4.641161  1.600318   2.736758
# gene-T4p194   0.055134   0.049747   5.023204   0.095360  5.409630   1.157918
# gene-b3425    6.103092   6.900969   4.735138   5.318394  2.365767   3.907599
# gene-b1465    1.266288   1.545051   1.176263   0.918019  0.751598   0.249239
# gene-b1757    1.936898   1.650765   1.657776   1.702150  0.763202   0.754697
# ...                ...        ...        ...        ...       ...        ...
# gene-b1142    4.972294   2.259418   3.131993   2.398186  3.485451   2.666972
# gene-b2044    1.365018   1.366960   1.411548   1.460981  0.688072   1.012013
# gene-b4414   11.931493  11.983097  11.039807  11.548373  9.485899  11.245628
# gene-b0471    8.141526   8.476986   7.853704   8.570781  5.018154   7.703365
# gene-b4296    2.525578   1.894716   2.091386   1.872774  1.189198   1.119851
#
# SampleNames     10_R1     10_R2     20_R1     20_R2     30_R1     30_R2  \
# Geneid
# gene-b4740   1.386764  1.484746  1.082050  0.312895  1.946242  1.070274
# gene-T4p194  6.057977  2.213033  7.747054  8.060350  7.407944  8.132581
# gene-b3425   1.873498  2.653050  1.193733  0.811866  1.878538  1.850922
# gene-b1465   0.590016  0.106982  0.428640  0.284109  1.200446  0.547204
# gene-b1757   0.736432  0.526900  0.428124  0.338474  0.994467  0.662856
# ...               ...       ...       ...       ...       ...       ...
# gene-b1142   4.296777  3.039904  2.843428  2.310051  3.174755  2.007306
# gene-b2044   0.499491  0.639790  0.413746  0.057229  0.984254  0.330281
# gene-b4414   7.748034  9.553504  6.611962  8.586008  5.877822  8.547561
# gene-b0471   3.424799  6.064375  2.703229  4.597351  2.325300  5.123452
# gene-b4296   1.017874  1.139920  0.736914  0.822588  1.634601  0.449570
#
# SampleNames Entity Symbol
# Geneid
# gene-b4740    host   ymgM
# gene-T4p194  phage     29
# gene-b3425    host   glpE
# gene-b1465    host   narV
# gene-b1757    host   ynjE
# ...            ...    ...
# gene-b1142    host   ymfH
# gene-b2044    host   wcaL
# gene-b4414    host    tff
# gene-b0471    host   ybaB
# gene-b4296    host   yjhF
#
# [4772 rows x 14 columns]

# %% [markdown]
# tpmHost

# %%
txPCA(tpmHost[columnOrder])

# %% [markdown]
# tpmPhage

# %%
txPCA(tpmPhage[columnOrder])

# %% [markdown]
# logTPM Host

# %%
txPCA(logTPMsHost[columnOrder])

# %% [markdown]
# logTPM Phage

# %%
txPCA(logTPMsPhage[columnOrder])

# %% [markdown]
# $\rightarrow$ Replicates seem to be fine (not perfect, but no clear outliers detectable)

# %% [markdown]
# ## 4. Final grouping
#
# Summarize time points with mean and standard deviation for TPM-normalized data.

# %%
TPMmeans, TPMsds = getMeanSD(tpms[columnOrder])
TPMmeans = TPMmeans[['0', '2.5', '5', '10', '20', '30']]
TPMmeans[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMmeans
# Out:
#                        0          2.5            5          10          20  \
# Geneid
# gene-b4740     21.087799    19.718229     3.848905    1.706797    0.679620
# gene-T4p194     0.037019    15.793583    21.369196   34.630394  239.883143
# gene-b3425     93.124568    32.267529     9.080818    3.977077    1.021460
# gene-b1465      1.661781     1.074712     0.436118    0.291118    0.281811
# gene-b1757      2.484407     2.204576     0.692265    0.553440    0.304950
# ...                  ...          ...          ...         ...         ...
# gene-b1142     17.089657     6.018924     7.775569   12.939356    5.068120
# gene-b2044      1.577530     1.706590     0.813926    0.485908    0.186303
# gene-b4414   3976.167647  2549.181447  1571.580516  482.205484  240.045974
# gene-b0471    318.347697   304.778485   119.413680   37.829753   14.359779
# gene-b4296      3.738264     2.961967     1.226752    1.114310    0.717591
#
#                      30 Entity Symbol
# Geneid
# gene-b4740     1.976763   host   ymgM
# gene-T4p194  224.235194  phage     29
# gene-b3425     2.642165   host   glpE
# gene-b1465     0.879679   host   narV
# gene-b1757     0.787779   host   ynjE
# ...                 ...    ...    ...
# gene-b1142     5.525244   host   ymfH
# gene-b2044     0.617774   host   wcaL
# gene-b4414   215.488026   host    tff
# gene-b0471    18.935258   host   ybaB
# gene-b4296     1.235325   host   yjhF
#
# [4772 rows x 8 columns]

# %%
TPMsds = TPMsds[['0', '2.5', '5', '10', '20', '30']]
TPMsds[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMsds
# Out:
#                      0         2.5           5          10          20  \
# Geneid
# gene-b4740    0.048658    4.235104    1.816803    0.091882    0.437422
# gene-T4p194   0.001936   15.725251   20.137845   30.993905   26.052771
# gene-b3425   25.383895    6.634616    4.926553    1.312878    0.265980
# gene-b1465    0.256363    0.185194    0.247539    0.214145    0.064153
# gene-b1757    0.344407    0.049278    0.004988    0.112610    0.040532
# ...                ...         ...         ...         ...         ...
# gene-b1142   13.301673    1.747525    2.424622    5.714991    1.109113
# gene-b2044    0.001735    0.046366    0.202798    0.072194    0.145837
# gene-b4414   71.122676  444.886206  855.545887  268.229144  143.232435
# gene-b0471   36.961530   74.465226   88.008466   28.090669    8.847198
# gene-b4296    1.019777    0.299606    0.053507    0.089377    0.050984
#
#                      30 Entity Symbol
# Geneid
# gene-b4740     0.876931   host   ymgM
# gene-T4p194   55.405667  phage     29
# gene-b3425     0.034858   host   glpE
# gene-b1465     0.418428   host   narV
# gene-b1757     0.204566   host   ynjE
# ...                 ...    ...    ...
# gene-b1142     2.504937   host   ymfH
# gene-b2044     0.360516   host   wcaL
# gene-b4414   157.684867   host    tff
# gene-b0471    14.923560   host   ybaB
# gene-b4296     0.869692   host   yjhF
#
# [4772 rows x 8 columns]

# %%
propExp = proportionalExp(TPMmeans[['0', '2.5', '5', '10', '20', '30']])
propExp[['Entity', 'Symbol']] = TPMmeans[['Entity', 'Symbol']]
propExp
# Out:
#                     0       2.5         5        10        20        30  \
# Geneid
# gene-b4740   1.000000  0.935054  0.182518  0.080938  0.032228  0.093740
# gene-T4p194  0.000154  0.065839  0.089082  0.144364  1.000000  0.934768
# gene-b3425   1.000000  0.346499  0.097513  0.042707  0.010969  0.028372
# gene-b1465   1.000000  0.646723  0.262440  0.175185  0.169584  0.529359
# gene-b1757   1.000000  0.887365  0.278644  0.222765  0.122746  0.317089
# ...               ...       ...       ...       ...       ...       ...
# gene-b1142   1.000000  0.352197  0.454987  0.757145  0.296561  0.323309
# gene-b2044   0.924376  1.000000  0.476931  0.284725  0.109167  0.361993
# gene-b4414   1.000000  0.641115  0.395250  0.121274  0.060371  0.054195
# gene-b0471   1.000000  0.957376  0.375105  0.118832  0.045107  0.059480
# gene-b4296   1.000000  0.792338  0.328161  0.298082  0.191958  0.330454
#
#             Entity Symbol
# Geneid
# gene-b4740    host   ymgM
# gene-T4p194  phage     29
# gene-b3425    host   glpE
# gene-b1465    host   narV
# gene-b1757    host   ynjE
# ...            ...    ...
# gene-b1142    host   ymfH
# gene-b2044    host   wcaL
# gene-b4414    host    tff
# gene-b0471    host   ybaB
# gene-b4296    host   yjhF
#
# [4772 rows x 8 columns]

# %% [markdown]
# ## 5. Phage gene classification

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelThreshold(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-2)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM*0.2

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x >= thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('early')
        elif timePoint == 3:
            labels.append('middle')
        elif timePoint == 4:
            labels.append('late')
        elif timePoint == 5:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassThreshold'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassThreshold'] = 'None'

    return tpmOut

# %%
# Export fractional expressions with T=0.6 + Host/Phage Annotation for Orthofinder Analysis
# t = classLabelThreshold(propExp)
# t = t[t["Entity"] == "phage"]
# t["Host"] = "Escherichia_Coli_plusToxIN"
# t["Phage"] = "Enterobacteria_phage_T4"
# t.to_csv("/ceph/ibmi/studenten/waffen/Cross_Analysis/Orthofinder_Clustering/Fractional_Expressions/T060/Guegler_T4_plusToxIN_fractional_expression_T=0.6.tsv", sep="\t")

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelMax(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-3)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x == thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('early')
        elif timePoint == 3:
            labels.append('middle')
        elif timePoint == 4:
            labels.append('late')
        elif timePoint == 5:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassMax'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassMax'] = 'None'

    return tpmOut

# %%
TPMmeans = classLabelThreshold(TPMmeans)
TPMmeans = classLabelMax(TPMmeans)

# %%
TPMmeans[TPMmeans['Entity'] == 'phage']['ClassThreshold'].value_counts()
# Out:
# ClassThreshold
# early     212
# late       45
# middle     31
# Name: count, dtype: int64

# %% [markdown]
# Add classes to other dfs.

# %%
# Not gff3
TPMsds[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
tpms[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
logs[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
propExp[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]

# gff3
gff3_final = gff3_genes.merge(TPMmeans[["ClassThreshold", "ClassMax"]], right_index=True, left_on="ID", how="left")
gff3_host  = gff3_final[gff3_final['seq_id'] == 'U00096.3']
gff3_phage = gff3_final[gff3_final['seq_id'] == 'NC_000866.4']

# %% [markdown]
# ## 6. Add variance to all dataframes

# %% [markdown]
# Base variance call on tpms.

# %%
def stabilizedVariance(df):
    labels = list()
    
    i = 0
    while i < df.shape[0]:

        # Get array of expression values at time points
        expressions = list(df.iloc[i,0:(df.shape[1]-4)])

        # Get mean expression for the gene
        exprMean = np.mean(np.array(expressions))

        # Get the variance for the gene
        varGene = np.var(np.array(expressions))

        # Stabilized variance
        stableVarGene = varGene/exprMean

        labels.append(stableVarGene)

        i += 1

    tpmOut = df.copy()
    tpmOut['Variance'] = labels

    return tpmOut

# %%
tpms = stabilizedVariance(tpms)
tpms
# Out:
# SampleNames         0_R1         0_R2       2.5_R1       2.5_R2        5_R1  \
# Geneid
# gene-b4740     21.136456    21.039141    15.483124    23.953333    2.032102
# gene-T4p194     0.038956     0.035083    31.518835     0.068332   41.507041
# gene-b3425     67.740672   118.508463    25.632913    38.902145    4.154265
# gene-b1465      1.405418     1.918144     1.259906     0.889518    0.683657
# gene-b1757      2.828814     2.140000     2.155298     2.253854    0.697253
# ...                  ...          ...          ...          ...         ...
# gene-b1142     30.391330     3.787984     7.766449     4.271399   10.200191
# gene-b2044      1.575796     1.579265     1.660224     1.752956    0.611128
# gene-b4414   3905.044971  4047.290323  2104.295241  2994.067653  716.034629
# gene-b0471    281.386167   355.309228   230.313259   379.243710   31.405215
# gene-b4296      4.758040     2.718487     3.261573     2.662361    1.280259
#
# SampleNames         5_R2       10_R1       10_R2       20_R1       20_R2  \
# Geneid
# gene-b4740      5.665708    1.614916    1.798679    1.117043    0.242198
# gene-T4p194     1.231351   65.624299    3.636488  213.830372  265.935914
# gene-b3425     14.007371    2.664199    5.289955    1.287439    0.755480
# gene-b1465      0.188580    0.505264    0.076973    0.345964    0.217658
# gene-b1757      0.687278    0.666050    0.440830    0.345483    0.264418
# ...                  ...         ...         ...         ...         ...
# gene-b1142      5.350947   18.654348    7.224365    6.177233    3.959007
# gene-b2044      1.016724    0.413715    0.558102    0.332140    0.040466
# gene-b4414   2427.126402  213.976340  750.434628   96.813539  383.278409
# gene-b0471    207.422146    9.739084   65.920422    5.512581   23.206976
# gene-b4296      1.173245    1.024933    1.203687    0.666607    0.768575
#
# SampleNames       30_R1       30_R2 Entity Symbol ClassThreshold ClassMax  \
# Geneid
# gene-b4740     2.853694    1.099832   host   ymgM           None     None
# gene-T4p194  168.829528  279.640861  phage     29           late     late
# gene-b3425     2.677023    2.607307   host   glpE           None     None
# gene-b1465     1.298107    0.461251   host   narV           None     None
# gene-b1757     0.992345    0.583214   host   ynjE           None     None
# ...                 ...         ...    ...    ...            ...      ...
# gene-b1142     8.030181    3.020307   host   ymfH           None     None
# gene-b2044     0.978291    0.257258   host   wcaL           None     None
# gene-b4414    57.803159  373.172893   host    tff           None     None
# gene-b0471     4.011698   33.858819   host   ybaB           None     None
# gene-b4296     2.105016    0.365633   host   yjhF           None     None
#
# SampleNames     Variance
# Geneid
# gene-b4740      9.738155
# gene-T4p194   125.420984
# gene-b3425     50.438949
# gene-b1465      0.403361
# gene-b1757      0.637222
# ...                  ...
# gene-b1142      6.337830
# gene-b2044      0.385528
# gene-b4414   1390.503618
# gene-b0471    142.436736
# gene-b4296      0.844947
#
# [4772 rows x 17 columns]

# %%
logs['Variance'] = tpms['Variance']
TPMmeans['Variance'] = tpms['Variance']
TPMsds['Variance'] = tpms['Variance']
propExp['Variance'] = tpms['Variance']

# %% [markdown]
# ## 7. Write data to output

# %%
df_norRNAs[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]

# %%
# Full TPM table
tpms.to_csv('Guegler_T4_plusToxIN_full_TPM.tsv', sep = '\t')
# Full raw_counts table
df_norRNAs.to_csv('Guegler_T4_plusToxIN_full_raw_counts.tsv', sep = '\t')
# Summarized (time point means) TPM table
TPMmeans.to_csv('Guegler_T4_plusToxIN_TPM_means.tsv', sep = '\t')
# Summarized (time point) TPM standard deviation
TPMsds.to_csv('Guegler_T4_plusToxIN_TPM_std.tsv', sep = '\t')
# Proportional expression per gene and time point
propExp.to_csv('Guegler_T4_plusToxIN_fractional_expression.tsv', sep = '\t')
# Processed gff3 file
gff3_host.to_csv('Guegler_T4_plusToxIN_host_gff3.tsv', sep='\t')
gff3_phage.to_csv('Guegler_T4_plusToxIN_phage_gff3.tsv', sep='\t')
