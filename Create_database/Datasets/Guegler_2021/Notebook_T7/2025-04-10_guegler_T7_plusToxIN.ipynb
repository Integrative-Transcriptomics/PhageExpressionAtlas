# %% [markdown]
# # Process bulk counts table
#
# 1. Annotate columns (samples) in a way that time point and replicate are annotated
# 2. Remove rRNA genes
# 3. Perform TPM normalization and alternatively also raw counts

# %%
# Use miniconda environment Jupyter_new for running this notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from tools import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 Load the dataset and annotation

# %%
bulkPath = '../Updated_V2/nf_output/countData/countData.tsv'
metaPath = '../Guegler_T7_SraRunTable.csv' # metadata from SRA
gffPath = '../Updated_V2/nf_output/alignments/dualGenome.gff3' # output from nf pipeline

# %%
# Load data
df_initial = pd.read_csv(bulkPath, sep = '\t', comment='#', index_col=0)
df_initial = df_initial.drop(columns=['SRR13084829_sorted.bam', 'SRR13084830_sorted.bam', 'SRR13084831_sorted.bam', 
                                      'SRR13084832_sorted.bam', 'SRR13084833_sorted.bam', 'SRR13084834_sorted.bam', 
                                      'SRR13084835_sorted.bam', 'SRR13084836_sorted.bam', 'SRR13084837_sorted.bam', 
                                      'SRR13084838_sorted.bam', 'SRR13084839_sorted.bam', 'SRR13084840_sorted.bam'])
metadata = pd.read_csv(metaPath)
metadata = metadata[metadata['plasmid'] == 'pBR322-toxIN']

# %%
df_initial.head()
# Out:
#                  Chr  Start   End Strand  Length  SRR13084823_sorted.bam  \
# Geneid
# gene-b0001  U00096.3    190   255      +      66                    9522
# gene-b0002  U00096.3    337  2799      +    2463                   18008
# gene-b0003  U00096.3   2801  3733      +     933                   10024
# gene-b0004  U00096.3   3734  5020      +    1287                   12019
# gene-b0005  U00096.3   5234  5530      +     297                     364
#
#             SRR13084828_sorted.bam  SRR13084824_sorted.bam  \
# Geneid
# gene-b0001                    2461                    2605
# gene-b0002                    3302                   14282
# gene-b0003                    1767                    8294
# gene-b0004                    2300                   10302
# gene-b0005                      55                     342
#
#             SRR13084817_sorted.bam  SRR13084827_sorted.bam  \
# Geneid
# gene-b0001                    7394                    1359
# gene-b0002                   16256                    3087
# gene-b0003                    9731                    1566
# gene-b0004                   11487                    1766
# gene-b0005                     298                      67
#
#             SRR13084821_sorted.bam  SRR13084822_sorted.bam  \
# Geneid
# gene-b0001                    1598                    2124
# gene-b0002                    4595                    2615
# gene-b0003                    2367                    1616
# gene-b0004                    2696                    1925
# gene-b0005                     113                      65
#
#             SRR13084820_sorted.bam  SRR13084818_sorted.bam  \
# Geneid
# gene-b0001                    1694                    2620
# gene-b0002                    3323                   15776
# gene-b0003                    2002                    9381
# gene-b0004                    2477                   11648
# gene-b0005                     149                     508
#
#             SRR13084825_sorted.bam  SRR13084819_sorted.bam  \
# Geneid
# gene-b0001                    1745                    1368
# gene-b0002                    8589                    4889
# gene-b0003                    5478                    3359
# gene-b0004                    7788                    4481
# gene-b0005                     353                     211
#
#             SRR13084826_sorted.bam
# Geneid
# gene-b0001                    2773
# gene-b0002                    5768
# gene-b0003                    3443
# gene-b0004                    4639
# gene-b0005                     250

# %%
pd.set_option('display.max_columns', None)  # Show all columns
metadata
# Out:
#             Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 0   SRR13084817    RNA-Seq          69  2206520088  PRJNA679480  SAMN16834528
# 1   SRR13084818    RNA-Seq          69  2213756118  PRJNA679480  SAMN16834491
# 2   SRR13084819    RNA-Seq          69  1581480138  PRJNA679480  SAMN16834485
# 3   SRR13084820    RNA-Seq          69  1460984334  PRJNA679480  SAMN16834484
# 4   SRR13084821    RNA-Seq          69  2222009898  PRJNA679480  SAMN16834483
# 5   SRR13084822    RNA-Seq          69  1457150349  PRJNA679480  SAMN16834482
# 6   SRR13084823    RNA-Seq          69  2652171630  PRJNA679480  SAMN16834481
# 7   SRR13084824    RNA-Seq          69  1849919118  PRJNA679480  SAMN16834480
# 8   SRR13084825    RNA-Seq          69  1796950992  PRJNA679480  SAMN16834479
# 9   SRR13084826    RNA-Seq          69  2313809637  PRJNA679480  SAMN16834478
# 10  SRR13084827    RNA-Seq          69  1533143637  PRJNA679480  SAMN16834511
# 11  SRR13084828    RNA-Seq          69  1574337396  PRJNA679480  SAMN16834510
#
#         Bytes Center Name Consent DATASTORE filetype DATASTORE provider  \
# 0   815280924         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 1   818011356         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 2   584321274         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 3   561309085         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 4   812687637         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 5   534875059         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 6   975891801         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 7   685371325         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 8   663468831         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 9   847897895         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 10  562158104         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
# 11  578634537         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                         DATASTORE region        ercc_standard  Experiment  \
# 0   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531489
# 1   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531490
# 2   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531491
# 3   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531492
# 4   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531493
# 5   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531494
# 6   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531495
# 7   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531496
# 8   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531497
# 9   gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531498
# 10  gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531499
# 11  gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531500
#
#    GEO_Accession (exp)   Instrument LibraryLayout LibrarySelection  \
# 0           GSM4914573  NextSeq 500        PAIRED             cDNA
# 1           GSM4914574  NextSeq 500        PAIRED             cDNA
# 2           GSM4914575  NextSeq 500        PAIRED             cDNA
# 3           GSM4914576  NextSeq 500        PAIRED             cDNA
# 4           GSM4914577  NextSeq 500        PAIRED             cDNA
# 5           GSM4914578  NextSeq 500        PAIRED             cDNA
# 6           GSM4914579  NextSeq 500        PAIRED             cDNA
# 7           GSM4914580  NextSeq 500        PAIRED             cDNA
# 8           GSM4914581  NextSeq 500        PAIRED             cDNA
# 9           GSM4914582  NextSeq 500        PAIRED             cDNA
# 10          GSM4914583  NextSeq 500        PAIRED             cDNA
# 11          GSM4914584  NextSeq 500        PAIRED             cDNA
#
#      LibrarySource                                   Organism phage  \
# 0   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 1   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 2   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 3   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 4   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 5   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 6   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 7   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 8   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 9   TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 10  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
# 11  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
#
#          plasmid  Platform           ReleaseDate           create_date  \
# 0   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
# 1   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
# 2   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:27:00Z
# 3   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:27:00Z
# 4   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
# 5   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:27:00Z
# 6   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
# 7   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:28:00Z
# 8   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:28:00Z
# 9   pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
# 10  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:28:00Z
# 11  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:27:00Z
#
#     version Sample Name               source_name  SRA Study strain substrain  \
# 0         1  GSM4914573  Bacterial liquid culture  SRP293243   K-12    MG1655
# 1         1  GSM4914574  Bacterial liquid culture  SRP293243   K-12    MG1655
# 2         1  GSM4914575  Bacterial liquid culture  SRP293243   K-12    MG1655
# 3         1  GSM4914576  Bacterial liquid culture  SRP293243   K-12    MG1655
# 4         1  GSM4914577  Bacterial liquid culture  SRP293243   K-12    MG1655
# 5         1  GSM4914578  Bacterial liquid culture  SRP293243   K-12    MG1655
# 6         1  GSM4914579  Bacterial liquid culture  SRP293243   K-12    MG1655
# 7         1  GSM4914580  Bacterial liquid culture  SRP293243   K-12    MG1655
# 8         1  GSM4914581  Bacterial liquid culture  SRP293243   K-12    MG1655
# 9         1  GSM4914582  Bacterial liquid culture  SRP293243   K-12    MG1655
# 10        1  GSM4914583  Bacterial liquid culture  SRP293243   K-12    MG1655
# 11        1  GSM4914584  Bacterial liquid culture  SRP293243   K-12    MG1655
#
#     time_post-infection
# 0                   0.0
# 1                   2.5
# 2                   5.0
# 3                  10.0
# 4                  20.0
# 5                  30.0
# 6                   0.0
# 7                   2.5
# 8                   5.0
# 9                  10.0
# 10                 20.0
# 11                 30.0

# %% [markdown]
# ## 2 Format the dataset

# %% [markdown]
# ### 2.1 Annotate sample names

# %% [markdown]
# Issue now is that the metadata does not properly annotate sample names. Thus, this will be done manually by adding another sample name column to the metadata.

# %%
# Match GSM IDs and SampleNames inferred from GEO

sampleDict = {'GSM4914573': '0_R1', 'GSM4914574': '2.5_R1', 'GSM4914575': '5_R1',
              'GSM4914576': '10_R1', 'GSM4914577': '20_R1', 'GSM4914578': '30_R1',
              'GSM4914579': '0_R2', 'GSM4914580': '2.5_R2', 'GSM4914581': '5_R2',
              'GSM4914582': '10_R2', 'GSM4914583': '20_R2', 'GSM4914584': '30_R2',
}

# %%
metadataFull = annotateData(metadata, sampleDict)

# %%
metadata.head(1)
# Out:
#            Run Assay Type  AvgSpotLen       Bases   BioProject     BioSample  \
# 0  SRR13084817    RNA-Seq          69  2206520088  PRJNA679480  SAMN16834528
#
#        Bytes Center Name Consent DATASTORE filetype DATASTORE provider  \
# 0  815280924         GEO  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                        DATASTORE region        ercc_standard  Experiment  \
# 0  gs.us-east1,ncbi.public,s3.us-east-1  Prior to extraction  SRX9531489
#
#   GEO_Accession (exp)   Instrument LibraryLayout LibrarySelection  \
# 0          GSM4914573  NextSeq 500        PAIRED             cDNA
#
#     LibrarySource                                   Organism phage  \
# 0  TRANSCRIPTOMIC  Escherichia coli str. K-12 substr. MG1655    T7
#
#         plasmid  Platform           ReleaseDate           create_date  \
# 0  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z  2020-11-19T10:29:00Z
#
#    version Sample Name               source_name  SRA Study strain substrain  \
# 0        1  GSM4914573  Bacterial liquid culture  SRP293243   K-12    MG1655
#
#    time_post-infection
# 0                  0.0

# %%
metadataFull.head(1)
# Out:
#                                 Run Assay Type  AvgSpotLen       Bases  \
# SampleID
# SRR13084817_sorted.bam  SRR13084817    RNA-Seq          69  2206520088
#
#                          BioProject     BioSample      Bytes Center Name  \
# SampleID
# SRR13084817_sorted.bam  PRJNA679480  SAMN16834528  815280924         GEO
#
#                        Consent DATASTORE filetype DATASTORE provider  \
# SampleID
# SRR13084817_sorted.bam  public   fastq,run.zq,sra         gs,ncbi,s3
#
#                                             DATASTORE region  \
# SampleID
# SRR13084817_sorted.bam  gs.us-east1,ncbi.public,s3.us-east-1
#
#                               ercc_standard  Experiment GEO_Accession (exp)  \
# SampleID
# SRR13084817_sorted.bam  Prior to extraction  SRX9531489          GSM4914573
#
#                          Instrument LibraryLayout LibrarySelection  \
# SampleID
# SRR13084817_sorted.bam  NextSeq 500        PAIRED             cDNA
#
#                          LibrarySource  \
# SampleID
# SRR13084817_sorted.bam  TRANSCRIPTOMIC
#
#                                                          Organism phage  \
# SampleID
# SRR13084817_sorted.bam  Escherichia coli str. K-12 substr. MG1655    T7
#
#                              plasmid  Platform           ReleaseDate  \
# SampleID
# SRR13084817_sorted.bam  pBR322-toxIN  ILLUMINA  2021-06-01T00:00:00Z
#
#                                  create_date  version Sample Name  \
# SampleID
# SRR13084817_sorted.bam  2020-11-19T10:29:00Z        1  GSM4914573
#
#                                      source_name  SRA Study strain substrain  \
# SampleID
# SRR13084817_sorted.bam  Bacterial liquid culture  SRP293243   K-12    MG1655
#
#                         time_post-infection                SampleID  \
# SampleID
# SRR13084817_sorted.bam                  0.0  SRR13084817_sorted.bam
#
#                        SampleNames
# SampleID
# SRR13084817_sorted.bam        0_R1

# %% [markdown]
# Add correct sample names.

# %%
df = changeColnames(df_initial.iloc[:,5:df_initial.shape[1]], metadataFull)
df = df[['0_R1', '0_R2', '2.5_R1', '2.5_R2', '5_R1', '5_R2', '10_R1', '10_R2', '20_R1', '20_R2', '30_R1', '30_R2']]
df
# Out:
# SampleNames   0_R1   0_R2  2.5_R1  2.5_R2  5_R1  5_R2  10_R1  10_R2   20_R1  \
# Geneid
# gene-b0001    7394   9522    2620    2605  1368  1745   1694   2773    1598
# gene-b0002   16256  18008   15776   14282  4889  8589   3323   5768    4595
# gene-b0003    9731  10024    9381    8294  3359  5478   2002   3443    2367
# gene-b0004   11487  12019   11648   10302  4481  7788   2477   4639    2696
# gene-b0005     298    364     508     342   211   353    149    250     113
# ...            ...    ...     ...     ...   ...   ...    ...    ...     ...
# gene-T7p56       9      3      34      10     4    40   4071   8751   81531
# gene-T7p57      44     45     295      69    52   439  19885  38288  658200
# gene-T7p58       9     13      58      13     7    79   4075   7497  126265
# gene-T7p59       8      9      52       8    14    86   3015   6216  116990
# gene-T7p60      15     18      71      24    19   154   1696   3365  116326
#
# SampleNames   20_R2   30_R1   30_R2
# Geneid
# gene-b0001     1359    2124    2461
# gene-b0002     3087    2615    3302
# gene-b0003     1566    1616    1767
# gene-b0004     1766    1925    2300
# gene-b0005       67      65      55
# ...             ...     ...     ...
# gene-T7p56    53563   70518   77214
# gene-T7p57   447211  800052  928809
# gene-T7p58    86757  137529  167099
# gene-T7p59    76286  162467  184735
# gene-T7p60    70565  331059  393532
#
# [4566 rows x 12 columns]

# %% [markdown]
# ### 2.2 Remove rRNA genes
#
# Consult gff3 file to get rRNA geneids.

# %%
# Load gff3 and split into genes and CDS dfs
gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3.columns=["seq_id", "source", "type", "start", "end", "phase", "strand", "score", "attributes"]
gff3_genes = gff3.loc[gff3["type"] == 'gene']

# Column formating for genes
gff3_genes = gff3_genes.reset_index(drop=True)
dct_genes = gff3_genes["attributes"].str.split(';').apply(lambda items: dict(item.split('=', 1) for item in items if '=' in item))
cols_to_keep = ['ID', 'Name', 'gbkey', 'gene_biotype', 'locus_tag', 'gene']
gff3_genes = pd.concat([gff3_genes, pd.json_normalize(dct_genes)[cols_to_keep]], axis=1)

# Generate locus_tag, product dictonary over all different feature types
attrs = gff3["attributes"].str.split(";", expand=True)
attrs_dicts = attrs.apply(lambda row: {item.split("=")[0]: item.split("=")[1] for item in row if "=" in str(item)}, axis=1)
attrs_df = pd.json_normalize(attrs_dicts)
attrs_df = attrs_df.dropna(subset=["locus_tag", "product"])
locus_product_dict = dict(zip(attrs_df["locus_tag"], attrs_df["product"]))

# Add gene product, if not stated in gff3, fill with gene_biotype
gff3_genes["product"] = gff3_genes["locus_tag"].map(locus_product_dict)
# gff3_genes["product"] = gff3_genes["product"].fillna("other")
gff3_genes["product"] = gff3_genes["product"].fillna(gff3_genes["gene_biotype"])

# If gene = NA, take from ID column
gff3_genes["gene"] = gff3_genes["gene"].fillna(gff3_genes["ID"])

# Drop attributes column
gff3_genes = gff3_genes.drop(["attributes"], axis=1)

# %%
pharokka_path = "../../../2025-12_reannotation_phage_genomes/Pharokka_proteins_phages_out/NC_001604.1_out/pharokka_proteins_full_merged_output.tsv"
gff3_genes = add_pharokka(gff3_genes, pharokka_path)
gff3_genes.loc[gff3_genes['seq_id'] == "NC_001604.1"]
# Out:
#            seq_id  source  type    start      end phase strand score  \
# 4506  NC_001604.1  RefSeq  gene    891.0   1468.0     .      +     .
# 4507  NC_001604.1  RefSeq  gene   1278.0   1433.0     .      +     .
# 4508  NC_001604.1  RefSeq  gene   1469.0   3138.0     .      +     .
# 4509  NC_001604.1  RefSeq  gene   1496.0   1639.0     .      +     .
# 4510  NC_001604.1  RefSeq  gene   1636.0   1972.0     .      +     .
# 4511  NC_001604.1  RefSeq  gene   1636.0   1797.0     .      +     .
# 4512  NC_001604.1  RefSeq  gene   3139.0   5887.0     .      +     .
# 4513  NC_001604.1  RefSeq  gene   5888.0   6448.0     .      +     .
# 4514  NC_001604.1  RefSeq  gene   6007.0   6135.0     .      +     .
# 4515  NC_001604.1  RefSeq  gene   6449.0   7588.0     .      +     .
# 4516  NC_001604.1  RefSeq  gene   7608.0   7763.0     .      +     .
# 4517  NC_001604.1  RefSeq  gene   7791.0   7880.0     .      +     .
# 4518  NC_001604.1  RefSeq  gene   7906.0   8166.0     .      +     .
# 4519  NC_001604.1  RefSeq  gene   8166.0   8756.0     .      +     .
# 4520  NC_001604.1  RefSeq  gene   8749.0   8895.0     .      +     .
# 4521  NC_001604.1  RefSeq  gene   8898.0   9092.0     .      +     .
# 4522  NC_001604.1  RefSeq  gene   9158.0   9856.0     .      +     .
# 4523  NC_001604.1  RefSeq  gene   9857.0  10276.0     .      +     .
# 4524  NC_001604.1  RefSeq  gene  10257.0  10706.0     .      +     .
# 4525  NC_001604.1  RefSeq  gene  10706.0  11161.0     .      +     .
# 4526  NC_001604.1  RefSeq  gene  11225.0  11590.0     .      +     .
# 4527  NC_001604.1  RefSeq  gene  11565.0  13265.0     .      +     .
# 4528  NC_001604.1  RefSeq  gene  11635.0  11757.0     .      +     .
# 4529  NC_001604.1  RefSeq  gene  11754.0  13265.0     .      +     .
# 4530  NC_001604.1  RefSeq  gene  12988.0  13326.0     .      +     .
# 4531  NC_001604.1  RefSeq  gene  13352.0  13564.0     .      +     .
# 4532  NC_001604.1  RefSeq  gene  13584.0  13853.0     .      +     .
# 4533  NC_001604.1  RefSeq  gene  13927.0  14334.0     .      +     .
# 4534  NC_001604.1  RefSeq  gene  14353.0  16467.0     .      +     .
# 4535  NC_001604.1  RefSeq  gene  16483.0  16839.0     .      +     .
# 4536  NC_001604.1  RefSeq  gene  16851.0  17359.0     .      +     .
# 4537  NC_001604.1  RefSeq  gene  16851.0  17150.0     .      +     .
# 4538  NC_001604.1  RefSeq  gene  17150.0  17359.0     .      +     .
# 4539  NC_001604.1  RefSeq  gene  17359.0  17517.0     .      +     .
# 4540  NC_001604.1  RefSeq  gene  17504.0  18406.0     .      +     .
# 4541  NC_001604.1  RefSeq  gene  18394.0  18507.0     .      +     .
# 4542  NC_001604.1  RefSeq  gene  18605.0  18859.0     .      +     .
# 4543  NC_001604.1  RefSeq  gene  18864.0  19130.0     .      +     .
# 4544  NC_001604.1  RefSeq  gene  19130.0  19531.0     .      +     .
# 4545  NC_001604.1  RefSeq  gene  19535.0  19834.0     .      +     .
# 4546  NC_001604.1  RefSeq  gene  19848.0  20240.0     .      +     .
# 4547  NC_001604.1  RefSeq  gene  20240.0  21850.0     .      +     .
# 4548  NC_001604.1  RefSeq  gene  21950.0  22873.0     .      +     .
# 4549  NC_001604.1  RefSeq  gene  22967.0  24162.0     .      +     .
# 4550  NC_001604.1  RefSeq  gene  22967.0  24004.0     .      +     .
# 4551  NC_001604.1  RefSeq  gene  24228.0  24818.0     .      +     .
# 4552  NC_001604.1  RefSeq  gene  24842.0  27226.0     .      +     .
# 4553  NC_001604.1  RefSeq  gene  27307.0  27723.0     .      +     .
# 4554  NC_001604.1  RefSeq  gene  27728.0  28318.0     .      +     .
# 4555  NC_001604.1  RefSeq  gene  28325.0  30568.0     .      +     .
# 4556  NC_001604.1  RefSeq  gene  30595.0  34551.0     .      +     .
# 4557  NC_001604.1  RefSeq  gene  34624.0  36285.0     .      +     .
# 4558  NC_001604.1  RefSeq  gene  36344.0  36547.0     .      +     .
# 4559  NC_001604.1  RefSeq  gene  36553.0  36822.0     .      +     .
# 4560  NC_001604.1  RefSeq  gene  36917.0  37348.0     .      +     .
# 4561  NC_001604.1  RefSeq  gene  37032.0  37283.0     .      +     .
# 4562  NC_001604.1  RefSeq  gene  37370.0  39130.0     .      +     .
# 4563  NC_001604.1  RefSeq  gene  38016.0  38273.0     .      +     .
# 4564  NC_001604.1  RefSeq  gene  38553.0  38726.0     .      +     .
# 4565  NC_001604.1  RefSeq  gene  39389.0  39538.0     .      +     .
#
#               ID   Name gbkey    gene_biotype locus_tag        gene  \
# 4506  gene-T7p01  T7p01  Gene  protein_coding     T7p01  gene-T7p01
# 4507  gene-T7p02  T7p02  Gene  protein_coding     T7p02  gene-T7p02
# 4508  gene-T7p03  T7p03  Gene  protein_coding     T7p03  gene-T7p03
# 4509  gene-T7p04  T7p04  Gene  protein_coding     T7p04  gene-T7p04
# 4510  gene-T7p05  T7p05  Gene  protein_coding     T7p05  gene-T7p05
# 4511  gene-T7p06  T7p06  Gene  protein_coding     T7p06  gene-T7p06
# 4512  gene-T7p07  T7p07  Gene  protein_coding     T7p07  gene-T7p07
# 4513  gene-T7p08  T7p08  Gene  protein_coding     T7p08  gene-T7p08
# 4514  gene-T7p09  T7p09  Gene  protein_coding     T7p09  gene-T7p09
# 4515  gene-T7p10  T7p10  Gene  protein_coding     T7p10  gene-T7p10
# 4516  gene-T7p11  T7p11  Gene  protein_coding     T7p11  gene-T7p11
# 4517  gene-T7p12  T7p12  Gene  protein_coding     T7p12  gene-T7p12
# 4518  gene-T7p13  T7p13  Gene  protein_coding     T7p13  gene-T7p13
# 4519  gene-T7p14  T7p14  Gene  protein_coding     T7p14  gene-T7p14
# 4520  gene-T7p15  T7p15  Gene  protein_coding     T7p15  gene-T7p15
# 4521  gene-T7p16  T7p16  Gene  protein_coding     T7p16  gene-T7p16
# 4522  gene-T7p17  T7p17  Gene  protein_coding     T7p17  gene-T7p17
# 4523  gene-T7p18  T7p18  Gene  protein_coding     T7p18  gene-T7p18
# 4524  gene-T7p19  T7p19  Gene  protein_coding     T7p19  gene-T7p19
# 4525  gene-T7p20  T7p20  Gene  protein_coding     T7p20  gene-T7p20
# 4526  gene-T7p21  T7p21  Gene  protein_coding     T7p21  gene-T7p21
# 4527  gene-T7p22  T7p22  Gene  protein_coding     T7p22  gene-T7p22
# 4528  gene-T7p23  T7p23  Gene  protein_coding     T7p23  gene-T7p23
# 4529  gene-T7p24  T7p24  Gene  protein_coding     T7p24  gene-T7p24
# 4530  gene-T7p25  T7p25  Gene  protein_coding     T7p25  gene-T7p25
# 4531  gene-T7p26  T7p26  Gene  protein_coding     T7p26  gene-T7p26
# 4532  gene-T7p27  T7p27  Gene  protein_coding     T7p27  gene-T7p27
# 4533  gene-T7p28  T7p28  Gene  protein_coding     T7p28  gene-T7p28
# 4534  gene-T7p29  T7p29  Gene  protein_coding     T7p29  gene-T7p29
# 4535  gene-T7p30  T7p30  Gene  protein_coding     T7p30  gene-T7p30
# 4536  gene-T7p31  T7p31  Gene  protein_coding     T7p31  gene-T7p31
# 4537  gene-T7p32  T7p32  Gene  protein_coding     T7p32  gene-T7p32
# 4538  gene-T7p33  T7p33  Gene  protein_coding     T7p33  gene-T7p33
# 4539  gene-T7p34  T7p34  Gene  protein_coding     T7p34  gene-T7p34
# 4540  gene-T7p35  T7p35  Gene  protein_coding     T7p35  gene-T7p35
# 4541  gene-T7p36  T7p36  Gene  protein_coding     T7p36  gene-T7p36
# 4542  gene-T7p37  T7p37  Gene  protein_coding     T7p37  gene-T7p37
# 4543  gene-T7p38  T7p38  Gene  protein_coding     T7p38  gene-T7p38
# 4544  gene-T7p39  T7p39  Gene  protein_coding     T7p39  gene-T7p39
# 4545  gene-T7p40  T7p40  Gene  protein_coding     T7p40  gene-T7p40
# 4546  gene-T7p41  T7p41  Gene  protein_coding     T7p41  gene-T7p41
# 4547  gene-T7p42  T7p42  Gene  protein_coding     T7p42  gene-T7p42
# 4548  gene-T7p43  T7p43  Gene  protein_coding     T7p43  gene-T7p43
# 4549  gene-T7p44  T7p44  Gene  protein_coding     T7p44  gene-T7p44
# 4550  gene-T7p45  T7p45  Gene  protein_coding     T7p45  gene-T7p45
# 4551  gene-T7p46  T7p46  Gene  protein_coding     T7p46  gene-T7p46
# 4552  gene-T7p47  T7p47  Gene  protein_coding     T7p47  gene-T7p47
# 4553  gene-T7p48  T7p48  Gene  protein_coding     T7p48  gene-T7p48
# 4554  gene-T7p49  T7p49  Gene  protein_coding     T7p49  gene-T7p49
# 4555  gene-T7p50  T7p50  Gene  protein_coding     T7p50  gene-T7p50
# 4556  gene-T7p51  T7p51  Gene  protein_coding     T7p51  gene-T7p51
# 4557  gene-T7p52  T7p52  Gene  protein_coding     T7p52  gene-T7p52
# 4558  gene-T7p53  T7p53  Gene  protein_coding     T7p53  gene-T7p53
# 4559  gene-T7p54  T7p54  Gene  protein_coding     T7p54  gene-T7p54
# 4560  gene-T7p55  T7p55  Gene  protein_coding     T7p55  gene-T7p55
# 4561  gene-T7p56  T7p56  Gene  protein_coding     T7p56  gene-T7p56
# 4562  gene-T7p57  T7p57  Gene  protein_coding     T7p57  gene-T7p57
# 4563  gene-T7p58  T7p58  Gene  protein_coding     T7p58  gene-T7p58
# 4564  gene-T7p59  T7p59  Gene  protein_coding     T7p59  gene-T7p59
# 4565  gene-T7p60  T7p60  Gene  protein_coding     T7p60  gene-T7p60
#
#                                                 product  \
# 4506                          ocr-like anti-restriction
# 4507                               hypothetical protein
# 4508                            serine-threonine kinase
# 4509                               hypothetical protein
# 4510                               hypothetical protein
# 4511                               hypothetical protein
# 4512                                     RNA polymerase
# 4513        dGTPase inhibitor%3B target for F exclusion
# 4514                               hypothetical protein
# 4515                                         DNA ligase
# 4516                               hypothetical protein
# 4517                               hypothetical protein
# 4518                               hypothetical protein
# 4519                                  nucleotide kinase
# 4520                               hypothetical protein
# 4521                           RNA polymerase inhibitor
# 4522  Gp2.5-like ssDNA binding protein and ssDNA ann...
# 4523                                       endonuclease
# 4524                                       endonuclease
# 4525                                            amidase
# 4526                                   HNH endonuclease
# 4527                               DNA primase/helicase
# 4528                               hypothetical protein
# 4529                               DNA primase/helicase
# 4530                               hypothetical protein
# 4531                               hypothetical protein
# 4532                               hypothetical protein
# 4533                               hypothetical protein
# 4534                                   DNA polymerase I
# 4535                               hypothetical protein
# 4536                               hypothetical protein
# 4537                  DUF2675 domain-containing protein
# 4538                               hypothetical protein
# 4539           Gp5.9-like inihibitor of recBCD nuclease
# 4540                                        exonuclease
# 4541                  DUF5516 domain-containing protein
# 4542                  DUF2717 domain-containing protein
# 4543                             DUF5476 family protein
# 4544                  host range and adsorption protein
# 4545                  host range and adsorption protein
# 4546                                   HNH endonuclease
# 4547                                  head-tail adaptor
# 4548                                      head assembly
# 4549                                 major head protein
# 4550                                 major head protein
# 4551                                       tail protein
# 4552                                       tail protein
# 4553                            internal virion protein
# 4554                            internal virion protein
# 4555                            internal virion protein
# 4556      internal virion protein with endolysin domain
# 4557                                 tail fiber protein
# 4558                                              holin
# 4559                            terminase small subunit
# 4560                                     Rz-like spanin
# 4561                                     Rz-like spanin
# 4562                            terminase large subunit
# 4563                               hypothetical protein
# 4564                               hypothetical protein
# 4565                               hypothetical protein
#
#                                                   annot    PHROG  \
# 4506                          ocr-like anti-restriction   2568.0
# 4507                               hypothetical protein   7202.0
# 4508                            serine-threonine kinase   2828.0
# 4509                               hypothetical protein  16572.0
# 4510                               hypothetical protein   8393.0
# 4511                               hypothetical protein   8393.0
# 4512                                     RNA polymerase    414.0
# 4513           dGTPase inhibitor target for F exclusion   2949.0
# 4514                               hypothetical protein   2490.0
# 4515                                         DNA ligase  30362.0
# 4516                               hypothetical protein  17655.0
# 4517                               hypothetical protein  12128.0
# 4518                               hypothetical protein   1777.0
# 4519                                  nucleotide kinase   2585.0
# 4520                               hypothetical protein   1312.0
# 4521                           RNA polymerase inhibitor   1307.0
# 4522  Gp2.5-like ssDNA binding protein and ssDNA ann...    112.0
# 4523                                       endonuclease   1872.0
# 4524                                       endonuclease    945.0
# 4525                                            amidase    822.0
# 4526                                   HNH endonuclease   4578.0
# 4527                               DNA primase/helicase    239.0
# 4528                               hypothetical protein  20075.0
# 4529                               DNA primase/helicase    239.0
# 4530                               hypothetical protein   5140.0
# 4531                               hypothetical protein   1950.0
# 4532                               hypothetical protein   2254.0
# 4533                               hypothetical protein   4023.0
# 4534                                   DNA polymerase I  15971.0
# 4535                               hypothetical protein   5018.0
# 4536                               hypothetical protein  17900.0
# 4537                               hypothetical protein  17900.0
# 4538                               hypothetical protein  17900.0
# 4539           Gp5.9-like inihibitor of recBCD nuclease   9014.0
# 4540                                        exonuclease    107.0
# 4541                               hypothetical protein  11345.0
# 4542                               hypothetical protein   1447.0
# 4543                               hypothetical protein   1391.0
# 4544                  host range and adsorption protein   2746.0
# 4545                  host range and adsorption protein   1320.0
# 4546                                   HNH endonuclease     59.0
# 4547                                  head-tail adaptor    449.0
# 4548                                      head assembly   1052.0
# 4549                                 major head protein    267.0
# 4550                                 major head protein    267.0
# 4551                                       tail protein    446.0
# 4552                                       tail protein    457.0
# 4553                            internal virion protein    308.0
# 4554                            internal virion protein    805.0
# 4555                            internal virion protein   1339.0
# 4556      internal virion protein with endolysin domain    342.0
# 4557                                 tail fiber protein   4242.0
# 4558                                              holin    920.0
# 4559                            terminase small subunit   1351.0
# 4560                                     Rz-like spanin   1327.0
# 4561                                     Rz-like spanin   4306.0
# 4562                            terminase large subunit  15524.0
# 4563                               hypothetical protein   8982.0
# 4564                               hypothetical protein   8173.0
# 4565                               hypothetical protein   2193.0
#
#                                                category
# 4506  moron, auxiliary metabolic gene and host takeover
# 4507                                   unknown function
# 4508                                              other
# 4509                                   unknown function
# 4510                                   unknown function
# 4511                                   unknown function
# 4512                 DNA, RNA and nucleotide metabolism
# 4513                                              other
# 4514                                   unknown function
# 4515                 DNA, RNA and nucleotide metabolism
# 4516                                   unknown function
# 4517                                   unknown function
# 4518                                   unknown function
# 4519                                              other
# 4520                                   unknown function
# 4521                 DNA, RNA and nucleotide metabolism
# 4522                 DNA, RNA and nucleotide metabolism
# 4523                 DNA, RNA and nucleotide metabolism
# 4524                 DNA, RNA and nucleotide metabolism
# 4525                                              lysis
# 4526                 DNA, RNA and nucleotide metabolism
# 4527                 DNA, RNA and nucleotide metabolism
# 4528                                   unknown function
# 4529                 DNA, RNA and nucleotide metabolism
# 4530                                   unknown function
# 4531                                   unknown function
# 4532                                   unknown function
# 4533                                   unknown function
# 4534                 DNA, RNA and nucleotide metabolism
# 4535                                   unknown function
# 4536                                   unknown function
# 4537                                   unknown function
# 4538                                   unknown function
# 4539  moron, auxiliary metabolic gene and host takeover
# 4540                 DNA, RNA and nucleotide metabolism
# 4541                                   unknown function
# 4542                                   unknown function
# 4543                                   unknown function
# 4544  moron, auxiliary metabolic gene and host takeover
# 4545  moron, auxiliary metabolic gene and host takeover
# 4546                 DNA, RNA and nucleotide metabolism
# 4547                                          connector
# 4548                                 head and packaging
# 4549                                 head and packaging
# 4550                                 head and packaging
# 4551                                               tail
# 4552                                               tail
# 4553                                 head and packaging
# 4554                                 head and packaging
# 4555                                 head and packaging
# 4556                                 head and packaging
# 4557                                               tail
# 4558                                              lysis
# 4559                                 head and packaging
# 4560                                              lysis
# 4561                                              lysis
# 4562                                 head and packaging
# 4563                                   unknown function
# 4564                                   unknown function
# 4565                                   unknown function

# %%
# Load ggf3 file

gff3 = pd.read_csv(gffPath, sep='\t', header = None, skiprows = 5)
gff3 = gff3.loc[gff3.iloc[:,2] == 'gene']

# Format some new columns
gff3['ID'] = pd.DataFrame(gff3.iloc[:,8].str.split('ID=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['GeneType'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene_biotype=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]
gff3['Symbol'] = pd.DataFrame(gff3.iloc[:,8].str.split('gene=', expand = True)).iloc[:,1].str.split(';', expand = True).iloc[:,0]

# Add entity host and phage
gff3['Entity'] = np.where(gff3[0] == 'U00096.3', 'host', 'phage')
gff3.index = gff3['ID']
rRNAs = gff3.loc[gff3['GeneType'] == 'rRNA', 'ID'].tolist()

# %% [markdown]
# Perform in silico rRNA depletion.

# %%
df_norRNAs = rRNAdepletion(df,rRNAs)
df_norRNAs
# Out:
# SampleNames   0_R1   0_R2  2.5_R1  2.5_R2   5_R1   5_R2  10_R1  10_R2  20_R1  \
# Geneid
# gene-b0435    6417   7340    3626    3329   1361   1569    918   1488   1277
# gene-b1336      87    139      93      56     40     44     25     60     34
# gene-b1145     772   1168     636     381    368    370    297    523    267
# gene-b3597     201    266     162     142     43     70     51     63     48
# gene-b2545     320    386     339     239    141    209    125    188    129
# ...            ...    ...     ...     ...    ...    ...    ...    ...    ...
# gene-b4663    3581   4673    3812    2886   2584   2667   2370   2782   1407
# gene-b3552    1180   1270    1285    1052    831   1057    818   1341    580
# gene-b3143      40     50      42      20     12     16     14     13     22
# gene-b4226   25255  36175   32220   21904  15871  24052  15350  25700  14074
# gene-b3710     227    272     268     196    125    175     84    128     90
#
# SampleNames  20_R2  30_R1  30_R2
# Geneid
# gene-b0435     806   1689   1904
# gene-b1336      14     21     48
# gene-b1145     201    195    215
# gene-b3597      30     40     93
# gene-b2545      69     74    106
# ...            ...    ...    ...
# gene-b4663    1060    796    965
# gene-b3552     389    208    215
# gene-b3143       6      5     17
# gene-b4226    9227   5594   5664
# gene-b3710      46     47     80
#
# [4544 rows x 12 columns]

# %% [markdown]
# ### 2.3 Read count normalization

# %% [markdown]
# Important note: gene symbols not available for most genes.

# %%
# Function to fill in missing symbols by geneid.

def fillSymbols(df):
    df_new = df.copy()
    index = df.index.to_list()
    for i in range(0,df.shape[0]):
        if (df.iloc[i,-1:].values == None):
            df_new.iloc[i,-1:] = index[i]
    return df_new

# %% [markdown]
# Convert counts to TPM.

# %%
tpms = TPM(df_norRNAs, df_initial, 0.5)
tpms['Entity'] = gff3.loc[sorted(tpms.index.to_list()), 'Entity']
tpms['Symbol'] = gff3.loc[sorted(tpms.index.to_list()), 'Symbol']

tpms = fillSymbols(tpms)
tpms = make_unique_with_index(tpms)
tpms
# Out:
# SampleNames        0_R1        0_R2      2.5_R1      2.5_R2        5_R1  \
# Geneid
# gene-b0435   268.637618  249.378669  125.866214  145.154210   78.663245
# gene-b1336     0.762776    0.986952    0.675805    0.512964    0.487301
# gene-b1145    15.234310   18.701900   10.407424    7.835532   10.030326
# gene-b3597     2.359080    2.532197    1.577399    1.737529    0.702927
# gene-b2545     4.017275    3.931749    3.528287    3.126502    2.448010
# ...                 ...         ...         ...         ...         ...
# gene-b4663   547.991438  580.341696  483.658925  459.970571  545.806393
# gene-b3552    23.809492   20.796561   21.496945   22.108328   23.147263
# gene-b3143     0.774594    0.783868    0.673951    0.408340    0.329976
# gene-b4226   633.125083  736.005063  669.709348  571.895344  549.167448
# gene-b3710     2.575148    2.503341    2.519913    2.316504    1.960730
#
# SampleNames        5_R2       10_R1       10_R2       20_R1       20_R2  \
# Geneid
# gene-b0435    74.300216   45.469267   55.521234   53.307462   49.359334
# gene-b1336     0.438709    0.262886    0.469952    0.299802    0.184808
# gene-b1145     8.263049    6.938237    9.199205    5.258650    5.809829
# gene-b3597     0.933436    0.713038    0.662446    0.566025    0.522073
# gene-b2545     2.969719    1.860309    2.105350    1.618078    1.273657
# ...                 ...         ...         ...         ...         ...
# gene-b4663   461.573694  428.930195  379.361550  214.675939  237.237567
# gene-b3552    24.120834   19.522735   24.109274   11.671119   11.485650
# gene-b3143     0.356887    0.327963    0.230071    0.428971    0.181759
# gene-b4226   681.901390  455.086464  574.095896  351.716445  338.206208
# gene-b3710     2.246600    1.131137    1.296084    1.021164    0.769551
#
# SampleNames       30_R1       30_R2 Entity Symbol
# Geneid
# gene-b0435   124.938060  130.325032   host   bolA
# gene-b1336     0.331103    0.691157   host   abgT
# gene-b1145     6.810934    6.947323   host   ymfK
# gene-b3597     0.837642    1.789473   host   yibH
# gene-b2545     1.649664    2.182223   host   yphC
# ...                 ...         ...    ...    ...
# gene-b4663   215.293149  241.494369   host   azuC
# gene-b3552     7.428922    7.105217   host   yiaD
# gene-b3143     0.185831    0.547145   host   yraI
# gene-b4226   247.759570  232.135223   host    ppa
# gene-b3710     0.949839    1.489576   host   mdtL
#
# [4544 rows x 14 columns]

# %%
# Check gene names unique
len(tpms['Symbol'].unique())
# Out:
# 4544

# %% [markdown]
# Log2+1 normalization tpms

# %%
logTPMs = logNorm(tpms.iloc[:, :-2])
logTPMs = logTPMs.join(tpms.iloc[:, -2:])
logTPMs = fillSymbols(logTPMs)
# Make gene names unique
logTPMs = make_unique_with_index(logTPMs)
logTPMs
# Out:
# SampleNames      0_R1      0_R2    2.5_R1    2.5_R2      5_R1      5_R2  \
# Geneid
# gene-b0435   8.074878  7.967968  6.987164  7.191348  6.315842  6.234582
# gene-b1336   0.817849  0.990557  0.744854  0.597378  0.572697  0.524775
# gene-b1145   4.020974  4.300263  3.511901  3.143317  3.463404  3.211487
# gene-b3597   1.748066  1.820566  1.365916  1.452874  0.768016  0.951167
# gene-b2545   2.326904  2.302099  2.178965  2.044919  1.785764  1.989037
# ...               ...       ...       ...       ...       ...       ...
# gene-b4663   9.100640  9.183243  8.920826  8.848531  9.094886  8.853539
# gene-b3552   4.632820  4.446029  4.491657  4.530341  4.593788  4.650812
# gene-b3143   0.827489  0.835009  0.743257  0.493996  0.411400  0.440300
# gene-b4226   9.308624  9.525531  9.389544  9.162128  9.103727  9.415533
# gene-b3710   1.838003  1.808731  1.815540  1.729663  1.565953  1.698929
#
# SampleNames     10_R1     10_R2     20_R1     20_R2     30_R1     30_R2  \
# Geneid
# gene-b0435   5.538205  5.820721  5.763079  5.654187  6.976571  7.036998
# gene-b1336   0.336724  0.555769  0.378292  0.244653  0.412622  0.758011
# gene-b1145   2.988819  3.350385  2.645851  2.767618  2.965495  2.990469
# gene-b3597   0.776557  0.733308  0.647107  0.606038  0.877855  1.479993
# gene-b2545   1.516171  1.634756  1.388508  1.185014  1.405809  1.670035
# ...               ...       ...       ...       ...       ...       ...
# gene-b4663   8.747959  8.571228  7.752721  7.896257  7.756844  7.921807
# gene-b3552   4.359151  4.650148  3.663472  3.642199  3.075348  3.018851
# gene-b3143   0.409215  0.298742  0.514976  0.240936  0.245898  0.629609
# gene-b4226   8.833164  9.167659  8.462365  8.406019  7.958608  7.865023
# gene-b3710   1.091624  1.199176  1.015186  0.823384  0.963355  1.315900
#
# SampleNames Entity Symbol
# Geneid
# gene-b0435    host   bolA
# gene-b1336    host   abgT
# gene-b1145    host   ymfK
# gene-b3597    host   yibH
# gene-b2545    host   yphC
# ...            ...    ...
# gene-b4663    host   azuC
# gene-b3552    host   yiaD
# gene-b3143    host   yraI
# gene-b4226    host    ppa
# gene-b3710    host   mdtL
#
# [4544 rows x 14 columns]

# %% [markdown]
# ## 3 Filter samples, if necessary
#
# Look for outliers visually by PCA.

# %%
columnOrder = ['0_R1', '0_R2', '2.5_R1', '2.5_R2', '5_R1', '5_R2', '10_R1', '10_R2', '20_R1', '20_R2', '30_R1', '30_R2']

# %%
txPCA(tpms[columnOrder])

# %%
txPCA(logTPMs[columnOrder])

# %%
tpmHost = tpms[tpms['Entity'] == 'host']
tpmPhage = tpms[tpms['Entity'] == 'phage']
logTPMsHost = logTPMs[logTPMs['Entity'] == 'host']
logTPMsPhage = logTPMs[logTPMs['Entity'] == 'phage']

# %%
logTPMs
# Out:
# SampleNames      0_R1      0_R2    2.5_R1    2.5_R2      5_R1      5_R2  \
# Geneid
# gene-b0435   8.074878  7.967968  6.987164  7.191348  6.315842  6.234582
# gene-b1336   0.817849  0.990557  0.744854  0.597378  0.572697  0.524775
# gene-b1145   4.020974  4.300263  3.511901  3.143317  3.463404  3.211487
# gene-b3597   1.748066  1.820566  1.365916  1.452874  0.768016  0.951167
# gene-b2545   2.326904  2.302099  2.178965  2.044919  1.785764  1.989037
# ...               ...       ...       ...       ...       ...       ...
# gene-b4663   9.100640  9.183243  8.920826  8.848531  9.094886  8.853539
# gene-b3552   4.632820  4.446029  4.491657  4.530341  4.593788  4.650812
# gene-b3143   0.827489  0.835009  0.743257  0.493996  0.411400  0.440300
# gene-b4226   9.308624  9.525531  9.389544  9.162128  9.103727  9.415533
# gene-b3710   1.838003  1.808731  1.815540  1.729663  1.565953  1.698929
#
# SampleNames     10_R1     10_R2     20_R1     20_R2     30_R1     30_R2  \
# Geneid
# gene-b0435   5.538205  5.820721  5.763079  5.654187  6.976571  7.036998
# gene-b1336   0.336724  0.555769  0.378292  0.244653  0.412622  0.758011
# gene-b1145   2.988819  3.350385  2.645851  2.767618  2.965495  2.990469
# gene-b3597   0.776557  0.733308  0.647107  0.606038  0.877855  1.479993
# gene-b2545   1.516171  1.634756  1.388508  1.185014  1.405809  1.670035
# ...               ...       ...       ...       ...       ...       ...
# gene-b4663   8.747959  8.571228  7.752721  7.896257  7.756844  7.921807
# gene-b3552   4.359151  4.650148  3.663472  3.642199  3.075348  3.018851
# gene-b3143   0.409215  0.298742  0.514976  0.240936  0.245898  0.629609
# gene-b4226   8.833164  9.167659  8.462365  8.406019  7.958608  7.865023
# gene-b3710   1.091624  1.199176  1.015186  0.823384  0.963355  1.315900
#
# SampleNames Entity Symbol
# Geneid
# gene-b0435    host   bolA
# gene-b1336    host   abgT
# gene-b1145    host   ymfK
# gene-b3597    host   yibH
# gene-b2545    host   yphC
# ...            ...    ...
# gene-b4663    host   azuC
# gene-b3552    host   yiaD
# gene-b3143    host   yraI
# gene-b4226    host    ppa
# gene-b3710    host   mdtL
#
# [4544 rows x 14 columns]

# %% [markdown]
# tpmHost

# %%
txPCA(tpmHost[columnOrder])

# %% [markdown]
# tpmPhage

# %%
txPCA(tpmPhage[columnOrder])

# %% [markdown]
# logTPM Host

# %%
txPCA(logTPMsHost[columnOrder])

# %% [markdown]
# logTPM Phage

# %%
txPCA(logTPMsPhage[columnOrder])

# %% [markdown]
# $\rightarrow$ Replicates seem to be fine, raw tpms T10 far away, but logTPMs look very good. Keep all!

# %% [markdown]
# ## 4. Final grouping
#
# Summarize time points with mean and standard deviation for TPM-normalized data.

# %%
TPMmeans, TPMsds = getMeanSD(tpms[columnOrder])
TPMmeans = TPMmeans[['0', '2.5', '5', '10', '20', '30']]
TPMmeans[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMmeans
# Out:
#                      0         2.5           5          10          20  \
# Geneid
# gene-b0435  259.008144  135.510212   76.481730   50.495250   51.333398
# gene-b1336    0.874864    0.594384    0.463005    0.366419    0.242305
# gene-b1145   16.968105    9.121478    9.146687    8.068721    5.534239
# gene-b3597    2.445639    1.657464    0.818181    0.687742    0.544049
# gene-b2545    3.974512    3.327394    2.708865    1.982829    1.445867
# ...                ...         ...         ...         ...         ...
# gene-b4663  564.166567  471.814748  503.690043  404.145872  225.956753
# gene-b3552   22.303026   21.802637   23.634048   21.816005   11.578385
# gene-b3143    0.779231    0.541146    0.343431    0.279017    0.305365
# gene-b4226  684.565073  620.802346  615.534419  514.591180  344.961327
# gene-b3710    2.539244    2.418208    2.103665    1.213611    0.895358
#
#                     30 Entity Symbol
# Geneid
# gene-b0435  127.631546   host   bolA
# gene-b1336    0.511130   host   abgT
# gene-b1145    6.879128   host   ymfK
# gene-b3597    1.313557   host   yibH
# gene-b2545    1.915943   host   yphC
# ...                ...    ...    ...
# gene-b4663  228.393759   host   azuC
# gene-b3552    7.267069   host   yiaD
# gene-b3143    0.366488   host   yraI
# gene-b4226  239.947397   host    ppa
# gene-b3710    1.219707   host   mdtL
#
# [4544 rows x 8 columns]

# %%
TPMsds = TPMsds[['0', '2.5', '5', '10', '20', '30']]
TPMsds[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]
TPMsds
# Out:
#                     0        2.5          5         10         20         30  \
# Geneid
# gene-b0435   9.629474   9.643998   2.181515   5.025983   1.974064   2.693486
# gene-b1336   0.112088   0.081420   0.024296   0.103533   0.057497   0.180027
# gene-b1145   1.733795   1.285946   0.883639   1.130484   0.275589   0.068194
# gene-b3597   0.086559   0.080065   0.115255   0.025296   0.021976   0.475916
# gene-b2545   0.042763   0.200892   0.260854   0.122520   0.172211   0.266279
# ...               ...        ...        ...        ...        ...        ...
# gene-b4663  16.175129  11.844177  42.116350  24.784323  11.280814  13.100610
# gene-b3552   1.506466   0.305692   0.486785   2.293269   0.092735   0.161853
# gene-b3143   0.004637   0.132805   0.013456   0.048946   0.123606   0.180657
# gene-b4226  51.439990  48.907002  66.366971  59.504716   6.755119   7.812174
# gene-b3710   0.035904   0.101705   0.142935   0.082473   0.125806   0.269868
#
#            Entity Symbol
# Geneid
# gene-b0435   host   bolA
# gene-b1336   host   abgT
# gene-b1145   host   ymfK
# gene-b3597   host   yibH
# gene-b2545   host   yphC
# ...           ...    ...
# gene-b4663   host   azuC
# gene-b3552   host   yiaD
# gene-b3143   host   yraI
# gene-b4226   host    ppa
# gene-b3710   host   mdtL
#
# [4544 rows x 8 columns]

# %%
propExp = proportionalExp(TPMmeans[['0', '2.5', '5', '10', '20', '30']])
propExp[['Entity', 'Symbol']] = TPMmeans[['Entity', 'Symbol']]
propExp
# Out:
#                    0       2.5         5        10        20        30 Entity  \
# Geneid
# gene-b0435  1.000000  0.523189  0.295287  0.194956  0.198192  0.492770   host
# gene-b1336  1.000000  0.679402  0.529231  0.418830  0.276963  0.584239   host
# gene-b1145  1.000000  0.537566  0.539052  0.475523  0.326155  0.405415   host
# gene-b3597  1.000000  0.677722  0.334547  0.281212  0.222457  0.537102   host
# gene-b2545  1.000000  0.837183  0.681559  0.498886  0.363785  0.482057   host
# ...              ...       ...       ...       ...       ...       ...    ...
# gene-b4663  1.000000  0.836304  0.892804  0.716359  0.400514  0.404834   host
# gene-b3552  0.943682  0.922510  1.000000  0.923075  0.489903  0.307483   host
# gene-b3143  1.000000  0.694461  0.440731  0.358067  0.391880  0.470320   host
# gene-b4226  1.000000  0.906857  0.899161  0.751705  0.503913  0.350511   host
# gene-b3710  1.000000  0.952334  0.828461  0.477942  0.352608  0.480343   host
#
#            Symbol
# Geneid
# gene-b0435   bolA
# gene-b1336   abgT
# gene-b1145   ymfK
# gene-b3597   yibH
# gene-b2545   yphC
# ...           ...
# gene-b4663   azuC
# gene-b3552   yiaD
# gene-b3143   yraI
# gene-b4226    ppa
# gene-b3710   mdtL
#
# [4544 rows x 8 columns]

# %% [markdown]
# ## 5. Phage gene classification

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelThreshold(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-2)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM*0.2

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x >= thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('early')
        elif timePoint == 3:
            labels.append('middle')
        elif timePoint == 4:
            labels.append('late')
        elif timePoint == 5:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassThreshold'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassThreshold'] = 'None'

    return tpmOut

# %%
# Export fractional expressions with T=0.6 + Host/Phage Annotation for Orthofinder Analysis
# t = classLabelThreshold(propExp)
# t = t[t["Entity"] == "phage"]
# t["Host"] = "Escherichia_Coli_plusToxIN"
# t["Phage"] = "Enterobacteria_phage_T7"
# t.to_csv("/ceph/ibmi/studenten/waffen/Cross_Analysis/Orthofinder_Clustering/Fractional_Expressions/T060/Guegler_T7_plusToxIN_fractional_expression_T=0.6.tsv", sep="\t")

# %%
# Add a classification label based on exceeding 20 % of maximal expression

def classLabelMax(tpm):
    
    labels = list()
    
    i = 0
    while i < tpm.shape[0]:

        # Get array of expression values at time points
        expressions = list(tpm.iloc[i,0:(tpm.shape[1]-3)])

        # Get maximal value for each gene across time points
        maxTPM = max(expressions)

        # Get the threshold value
        thresHold = maxTPM

        # Subset expressions based on threshold
        filteredExpressions = [x for x in expressions if x == thresHold]

        # Get index of time point
        indices = [expressions.index(x) for x in filteredExpressions]
        timePoint = min(indices)

        if timePoint == 0:
            labels.append('early')
        elif timePoint == 1:
            labels.append('early')
        elif timePoint == 2:
            labels.append('early')
        elif timePoint == 3:
            labels.append('middle')
        elif timePoint == 4:
            labels.append('late')
        elif timePoint == 5:
            labels.append('late')

        i += 1

    tpmOut = tpm.copy()
    tpmOut['ClassMax'] = labels
    tpmOut.loc[tpmOut['Entity'] == 'host', 'ClassMax'] = 'None'

    return tpmOut

# %%
TPMmeans = classLabelThreshold(TPMmeans)
TPMmeans = classLabelMax(TPMmeans)

# %%
TPMmeans
# Out:
#                      0         2.5           5          10          20  \
# Geneid
# gene-b0435  259.008144  135.510212   76.481730   50.495250   51.333398
# gene-b1336    0.874864    0.594384    0.463005    0.366419    0.242305
# gene-b1145   16.968105    9.121478    9.146687    8.068721    5.534239
# gene-b3597    2.445639    1.657464    0.818181    0.687742    0.544049
# gene-b2545    3.974512    3.327394    2.708865    1.982829    1.445867
# ...                ...         ...         ...         ...         ...
# gene-b4663  564.166567  471.814748  503.690043  404.145872  225.956753
# gene-b3552   22.303026   21.802637   23.634048   21.816005   11.578385
# gene-b3143    0.779231    0.541146    0.343431    0.279017    0.305365
# gene-b4226  684.565073  620.802346  615.534419  514.591180  344.961327
# gene-b3710    2.539244    2.418208    2.103665    1.213611    0.895358
#
#                     30 Entity Symbol ClassThreshold ClassMax
# Geneid
# gene-b0435  127.631546   host   bolA           None     None
# gene-b1336    0.511130   host   abgT           None     None
# gene-b1145    6.879128   host   ymfK           None     None
# gene-b3597    1.313557   host   yibH           None     None
# gene-b2545    1.915943   host   yphC           None     None
# ...                ...    ...    ...            ...      ...
# gene-b4663  228.393759   host   azuC           None     None
# gene-b3552    7.267069   host   yiaD           None     None
# gene-b3143    0.366488   host   yraI           None     None
# gene-b4226  239.947397   host    ppa           None     None
# gene-b3710    1.219707   host   mdtL           None     None
#
# [4544 rows x 10 columns]

# %%
TPMmeans[TPMmeans['Entity'] == 'phage']['ClassThreshold'].value_counts()
# Out:
# ClassThreshold
# late      33
# middle    27
# Name: count, dtype: int64

# %% [markdown]
# Add classes to other dfs.

# %%
TPMsds[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
tpms[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]
propExp[['ClassThreshold', 'ClassMax']] = TPMmeans[['ClassThreshold', 'ClassMax']]

# gff3
gff3_final = gff3_genes.merge(TPMmeans[["ClassThreshold", "ClassMax"]], right_index=True, left_on="ID", how="left")
gff3_host  = gff3_final[gff3_final['seq_id'] == 'U00096.3']
gff3_phage = gff3_final[gff3_final['seq_id'] == 'NC_001604.1']

# %% [markdown]
# ## 6. Add variance to all dataframes

# %% [markdown]
# Base variance call on tpms.

# %%
def stabilizedVariance(df):
    labels = list()
    
    i = 0
    while i < df.shape[0]:

        # Get array of expression values at time points
        expressions = list(df.iloc[i,0:(df.shape[1]-4)])

        # Get mean expression for the gene
        exprMean = np.mean(np.array(expressions))

        # Get the variance for the gene
        varGene = np.var(np.array(expressions))

        # Stabilized variance
        stableVarGene = varGene/exprMean

        labels.append(stableVarGene)

        i += 1

    tpmOut = df.copy()
    tpmOut['Variance'] = labels

    return tpmOut

# %%
tpms = stabilizedVariance(tpms)
tpms
# Out:
# SampleNames        0_R1        0_R2      2.5_R1      2.5_R2        5_R1  \
# Geneid
# gene-b0435   268.637618  249.378669  125.866214  145.154210   78.663245
# gene-b1336     0.762776    0.986952    0.675805    0.512964    0.487301
# gene-b1145    15.234310   18.701900   10.407424    7.835532   10.030326
# gene-b3597     2.359080    2.532197    1.577399    1.737529    0.702927
# gene-b2545     4.017275    3.931749    3.528287    3.126502    2.448010
# ...                 ...         ...         ...         ...         ...
# gene-b4663   547.991438  580.341696  483.658925  459.970571  545.806393
# gene-b3552    23.809492   20.796561   21.496945   22.108328   23.147263
# gene-b3143     0.774594    0.783868    0.673951    0.408340    0.329976
# gene-b4226   633.125083  736.005063  669.709348  571.895344  549.167448
# gene-b3710     2.575148    2.503341    2.519913    2.316504    1.960730
#
# SampleNames        5_R2       10_R1       10_R2       20_R1       20_R2  \
# Geneid
# gene-b0435    74.300216   45.469267   55.521234   53.307462   49.359334
# gene-b1336     0.438709    0.262886    0.469952    0.299802    0.184808
# gene-b1145     8.263049    6.938237    9.199205    5.258650    5.809829
# gene-b3597     0.933436    0.713038    0.662446    0.566025    0.522073
# gene-b2545     2.969719    1.860309    2.105350    1.618078    1.273657
# ...                 ...         ...         ...         ...         ...
# gene-b4663   461.573694  428.930195  379.361550  214.675939  237.237567
# gene-b3552    24.120834   19.522735   24.109274   11.671119   11.485650
# gene-b3143     0.356887    0.327963    0.230071    0.428971    0.181759
# gene-b4226   681.901390  455.086464  574.095896  351.716445  338.206208
# gene-b3710     2.246600    1.131137    1.296084    1.021164    0.769551
#
# SampleNames       30_R1       30_R2 Entity Symbol ClassThreshold ClassMax  \
# Geneid
# gene-b0435   124.938060  130.325032   host   bolA           None     None
# gene-b1336     0.331103    0.691157   host   abgT           None     None
# gene-b1145     6.810934    6.947323   host   ymfK           None     None
# gene-b3597     0.837642    1.789473   host   yibH           None     None
# gene-b2545     1.649664    2.182223   host   yphC           None     None
# ...                 ...         ...    ...    ...            ...      ...
# gene-b4663   215.293149  241.494369   host   azuC           None     None
# gene-b3552     7.428922    7.105217   host   yiaD           None     None
# gene-b3143     0.185831    0.547145   host   yraI           None     None
# gene-b4226   247.759570  232.135223   host    ppa           None     None
# gene-b3710     0.949839    1.489576   host   mdtL           None     None
#
# SampleNames   Variance
# Geneid
# gene-b0435   44.578109
# gene-b1336    0.098601
# gene-b1145    1.565208
# gene-b3597    0.382395
# gene-b2545    0.314347
# ...                ...
# gene-b4663   44.077350
# gene-b3552    2.247027
# gene-b3143    0.096426
# gene-b4226   55.258731
# gene-b3710    0.252105
#
# [4544 rows x 17 columns]

# %%
TPMmeans['Variance'] = tpms['Variance']
TPMsds['Variance'] = tpms['Variance']
propExp['Variance'] = tpms['Variance']

# %% [markdown]
# ## 7. Write data to output

# %%
df_norRNAs[['Entity', 'Symbol']] = tpms[['Entity', 'Symbol']]

# %%
# Full TPM table
tpms.to_csv('Guegler_T7_plusToxIN_full_TPM.tsv', sep = '\t')
# Full raw_counts table
df_norRNAs.to_csv('Guegler_T7_plusToxIN_full_raw_counts.tsv', sep = '\t')
# Summarized (time point means) TPM table
TPMmeans.to_csv('Guegler_T7_plusToxIN_TPM_means.tsv', sep = '\t')
# Summarized (time point) TPM standard deviation
TPMsds.to_csv('Guegler_T7_plusToxIN_TPM_std.tsv', sep = '\t')
# Proportional expression per gene and time point
propExp.to_csv('Guegler_T7_plusToxIN_fractional_expression.tsv', sep = '\t')
# Processed gff3 file
gff3_host.to_csv('Guegler_T7_plusToxIN_host_gff3.tsv', sep='\t')
gff3_phage.to_csv('Guegler_T7_plusToxIN_phage_gff3.tsv', sep='\t')
