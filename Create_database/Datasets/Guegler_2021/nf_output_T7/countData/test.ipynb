# %%
import pandas as pd

# %%
df1 = pd.read_csv('/ceph/ibmi/studenten/waffen/Data_NW/Guegler_2021/nf_output_T7/countData/countData.tsv.summary', sep = '\t', comment='#', index_col=0)
df2 = pd.read_csv('/ceph/ibmi/studenten/waffen/Data_NW/Guegler_2021/Updated/nf_output_updated/countData/countData.tsv.summary', sep = '\t', comment='#', index_col=0)
